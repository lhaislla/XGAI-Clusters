# %%
import pandas as pd
import numpy as np

# %%
categorical_columns = ['NU_ANO_CENSO', 'REGIAO', 'IN_CAPITAL', 'IN_ACESSO_PORTAL_CAPES', 'IN_REPOSITORIO_INSTITUCIONAL', 'IN_BUSCA_INTEGRADA', 'IN_SERVICO_INTERNET', 'IN_PARTICIPA_REDE_SOCIAL',
                       'IN_CATALOGO_ONLINE', 'IN_OUTRAS_BASES', 'NOME_CATEGORIA_ADMINISTRATIVA', 'NOME_ORGANIZACAO_ACADEMICA']
numeric_columns = ['QT_TEC_TOTAL', 'QT_PERIODICO_ELETRONICO', 'QT_LIVRO_ELETRONICO', 'QT_ALUNOS', 'QT_DOCENTES', 'QT_CURSO', 'T1_VL_RECEITAS', 'T1_VL_DESPESAS']

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)

# %% [markdown]
# # Analises dos clusters

# %%
def get_total_categorical_values_cluster(df):
    for col in categorical_columns:
        items = df[col].value_counts().items()

        print(f"====== {col} ======")

        for item in items:
            print(f"{item[0]}: {item[1]} ({(item[1] / df.shape[0]): 0.2%})")

        print()

# %% [markdown]
# # Agglomerative

# %% [markdown]
# ### First cluster

# %%
first_cluster_agg = pd.read_csv('./data/Agglomerative/Primeiro agrupamento (Agglomerative).csv', sep=';')

# %%
get_total_categorical_values_cluster(first_cluster_agg)
# Out:
# ====== NU_ANO_CENSO ======
# 2016: 241 ( 25.42%)
# 2017: 239 ( 25.21%)
# 2018: 238 ( 25.11%)
# 2019: 230 ( 24.26%)
#
# ====== REGIAO ======
# Sudeste: 368 ( 38.82%)
# Sul: 213 ( 22.47%)
# Nordeste: 198 ( 20.89%)
# Norte: 95 ( 10.02%)
# Centro-Oeste: 74 ( 7.81%)
#
# ====== IN_CAPITAL ======
# 0: 499 ( 52.64%)
# 1: 449 ( 47.36%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 1: 871 ( 91.88%)
# 0: 77 ( 8.12%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 1: 580 ( 61.18%)
# 0: 368 ( 38.82%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 579 ( 61.08%)
# 0: 369 ( 38.92%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 910 ( 95.99%)
# 0: 38 ( 4.01%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 711 ( 75.00%)
# 0: 237 ( 25.00%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 853 ( 89.98%)
# 0: 95 ( 10.02%)
#
# ====== IN_OUTRAS_BASES ======
# 1.0: 631 ( 66.56%)
# 0.0: 317 ( 33.44%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Pública Federal: 411 ( 43.35%)
# Privada sem fins lucrativos: 298 ( 31.43%)
# Pública Estadual: 152 ( 16.03%)
# Privada com fins lucrativos: 65 ( 6.86%)
# Pública Municipal e Especial: 22 ( 2.32%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Universidade: 714 ( 75.32%)
# Instituto Federal de Educação, Ciência e Tecnologia: 152 ( 16.03%)
# Centro Universitário: 59 ( 6.22%)
# Faculdade: 15 ( 1.58%)
# Centro Federal de Educação Tecnológica: 8 ( 0.84%)

# %%
first_cluster_agg[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count        948.00                   948.00               948.00     948.00
# mean       1,067.03                11,002.45            30,041.69  19,394.41
# std        1,358.21                36,247.98            90,346.03  21,687.59
# min           33.00                     0.00                 0.00   1,005.00
# 25%          398.75                     0.00                 0.00   6,462.75
# 50%          707.00                    31.00             2,655.00  12,731.00
# 75%        1,189.75                 3,525.00            12,671.00  26,057.75
# max       15,562.00               572,574.00         1,000,000.00 245,102.00
#
#        QT_DOCENTES  QT_CURSO   T1_VL_RECEITAS    T1_VL_DESPESAS
# count       948.00    948.00           948.00            948.00
# mean        962.64     67.27   454,150,088.54    479,909,885.36
# std         836.70     48.33   653,881,575.29    852,086,400.18
# min          60.00      8.00       134,763.64     10,769,001.91
# 25%         413.75     34.00   130,128,444.86    147,817,024.68
# 50%         704.00     53.00   276,350,996.41    278,105,501.08
# 75%       1,228.50     92.00   514,270,381.47    499,588,321.00
# max       6,286.00    321.00 7,599,192,871.00 15,890,130,144.40

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Sul e Nordeste  (38.82%, 22.47%, 20.89%)
# - Instituições com acesso ao portal Capes (91.88%)
# - Predominancia de repositorio institucional (61.18%)
# - Predominancia busca integrada (61.08%)
# - Possuem serviço de internet (95.99%)
# - Participam em redes sociais (75.00%)
# - Possuem catalogo online (89.98%)
# - Possuem outras bases (66.56%)
# - IES publica federal, sem fins lucrativos (43.35%, 31.43%)
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (75.32%, 16.03%)
#
# - Quantidade alta de técnicos na média (1,067.03)
# - Quantidade de alunos média de alunos alto (19,394.41)
# - Corpo docente forte na média (962.64	)
# - Quantidade considerável de cursos na média (média de 67.27)
# - Despesas e receitas média alta
# - Alta quantidade de Quantidade de periodicos e livros eletronicos
# - Quantidade de periodicos e livros eletronicos com relevância alto

# %% [markdown]
# ### Second cluster

# %%
second_cluster_agg = pd.read_csv('./data/Agglomerative/Segundo agrupamento (Agglomerative).csv', sep=';')

# %%
get_total_categorical_values_cluster(second_cluster_agg)
# Out:
# ====== NU_ANO_CENSO ======
# 2016: 577 ( 27.03%)
# 2017: 558 ( 26.14%)
# 2019: 524 ( 24.54%)
# 2018: 476 ( 22.30%)
#
# ====== REGIAO ======
# Sudeste: 833 ( 39.02%)
# Nordeste: 551 ( 25.81%)
# Sul: 396 ( 18.55%)
# Centro-Oeste: 218 ( 10.21%)
# Norte: 137 ( 6.42%)
#
# ====== IN_CAPITAL ======
# 0: 1393 ( 65.25%)
# 1: 742 ( 34.75%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 0: 1670 ( 78.22%)
# 1: 465 ( 21.78%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 0: 1442 ( 67.54%)
# 1: 693 ( 32.46%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 1298 ( 60.80%)
# 0: 837 ( 39.20%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 1790 ( 83.84%)
# 0: 345 ( 16.16%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 1402 ( 65.67%)
# 0: 733 ( 34.33%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 1119 ( 52.41%)
# 0: 1016 ( 47.59%)
#
# ====== IN_OUTRAS_BASES ======
# 0.0: 1323 ( 61.97%)
# 1.0: 812 ( 38.03%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada com fins lucrativos: 1285 ( 60.19%)
# Privada sem fins lucrativos: 770 ( 36.07%)
# Pública Municipal e Especial: 64 ( 3.00%)
# Pública Estadual: 14 ( 0.66%)
# Pública Federal: 2 ( 0.09%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Faculdade: 2129 ( 99.72%)
# Centro Universitário: 5 ( 0.23%)
# Universidade: 1 ( 0.05%)

# %%
second_cluster_agg[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count      2,135.00                 2,135.00             2,135.00   2,135.00
# mean          14.10                   398.74             3,867.71     282.62
# std           18.39                 2,774.72           139,084.54     341.36
# min            1.00                     0.00                 0.00       1.00
# 25%            6.00                     0.00                 0.00      68.00
# 50%           10.00                     5.00                 0.00     166.00
# 75%           16.00                    48.00                33.50     372.00
# max          449.00                54,365.00         6,424,945.00   3,633.00
#
#        QT_DOCENTES  QT_CURSO  T1_VL_RECEITAS  T1_VL_DESPESAS
# count     2,135.00  2,135.00        2,135.00        2,135.00
# mean         21.21      2.75    1,982,280.26    2,025,236.50
# std          17.92      2.34    4,747,147.30    6,470,177.04
# min           1.00      1.00            0.01            2.00
# 25%          10.00      1.00      337,634.51      351,376.38
# 50%          16.00      2.00      886,312.00      886,696.00
# 75%          27.00      3.00    1,931,850.57    2,007,175.73
# max         280.00     24.00   95,894,788.00  191,892,519.06

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (39.02%, 25.81% )
# - Uma incidência das IES não estarem numa capital (65.25%)
# - Predominância das Instituições sem acesso ao portal Capes (78.22%)
# - Predominância das Instituições sem repetorio institucional (67.54%)
# - Possuem busca integrada (60.80%)
# - Possuem serviço de internet (83.84%)
# - Participam em redes sociais (65.67%)
# - Possuem predominâncai em ter outras bases (61.97%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (96,26%)
# - Maioria dos anos da IES são Faculdade (99.72%)
#
# - Pouca quantidade de técnicos abaixo da média (14.10)
# - Quantidade de alunos média de alunos abaixo (282.62)
# - Corpo docente muito pouco na média (17.92)
# - Pouca quantidade de cursos (2.34)
# - Despesas e receitas média baixa
# - Quantidade de periodicos e livros eletronicos com relevância baixo

# %% [markdown]
# ### Third cluster

# %%
third_cluster_agg = pd.read_csv('./data/Agglomerative/Terceiro agrupamento (Agglomerative).csv', sep=';')

# %%
get_total_categorical_values_cluster(third_cluster_agg)
# Out:
# ====== NU_ANO_CENSO ======
# 2018: 528 ( 26.87%)
# 2019: 521 ( 26.51%)
# 2017: 464 ( 23.61%)
# 2016: 452 ( 23.00%)
#
# ====== REGIAO ======
# Sudeste: 975 ( 49.62%)
# Nordeste: 437 ( 22.24%)
# Sul: 288 ( 14.66%)
# Norte: 142 ( 7.23%)
# Centro-Oeste: 123 ( 6.26%)
#
# ====== IN_CAPITAL ======
# 0: 1192 ( 60.66%)
# 1: 773 ( 39.34%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 0: 1187 ( 60.41%)
# 1: 778 ( 39.59%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 1: 1093 ( 55.62%)
# 0: 872 ( 44.38%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 1515 ( 77.10%)
# 0: 450 ( 22.90%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 1924 ( 97.91%)
# 0: 41 ( 2.09%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 1232 ( 62.70%)
# 0: 733 ( 37.30%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 1703 ( 86.67%)
# 0: 262 ( 13.33%)
#
# ====== IN_OUTRAS_BASES ======
# 1.0: 1556 ( 79.19%)
# 0.0: 409 ( 20.81%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada sem fins lucrativos: 977 ( 49.72%)
# Privada com fins lucrativos: 923 ( 46.97%)
# Pública Municipal e Especial: 40 ( 2.04%)
# Pública Federal: 15 ( 0.76%)
# Pública Estadual: 10 ( 0.51%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Faculdade: 1321 ( 67.23%)
# Centro Universitário: 601 ( 30.59%)
# Universidade: 43 ( 2.19%)

# %%
third_cluster_agg[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count      1,965.00                 1,965.00             1,965.00   1,965.00
# mean         151.54                22,190.13            16,930.37   5,742.87
# std          204.63               295,367.05           231,402.09  17,710.34
# min            1.00                     0.00                 0.00       2.00
# 25%           51.00                    41.00             1,226.00   1,636.00
# 50%           93.00                   320.00             6,623.00   3,059.00
# 75%          182.00                 4,000.00             9,155.00   5,374.00
# max        3,482.00             6,437,318.00        10,000,000.00 370,652.00
#
#        QT_DOCENTES  QT_CURSO   T1_VL_RECEITAS    T1_VL_DESPESAS
# count     1,965.00  1,965.00         1,965.00          1,965.00
# mean        149.49     18.09    73,871,411.67     79,483,263.76
# std         111.51     16.45   303,142,944.33    676,157,147.30
# min           1.00      1.00        36,843.47      1,130,746.33
# 25%          72.00      9.00    14,606,845.09     12,133,038.72
# 50%         117.00     14.00    28,874,918.03     24,181,059.20
# 75%         191.00     22.00    62,951,334.00     52,121,930.28
# max         807.00    183.00 6,258,050,290.00 22,161,393,800.00

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (49.62% e 22.24%)
# - Predominãncia das IES não estarem numa capital (60.66%)
# - Instituições sem acesso ao portal Capes (60.41%)
# - Possuem predominância em possuir busca integrada (77.10%)
# - Possuem predominância em serviço de internet (97.91%)
# - Predominância em participar em redes sociais (62.70%)
# - Possuem catalogo online (86.67%)
# - Possuem predominância em ter outras bases (79.19%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (96,69%)
# - Maioria dos anos da IES são Faculdade e centro universitario (67.23% e 30.59%)
#
# - Quantidade média de técnicos moderada (151.54)
# - Quantidade de alunos média de alunos normal (5,742.87	)
# - Corpo docente com quantidade média moderada (149.49)
# - Pouca quantidade de cursos (18.09)
# - Despesas e receitas média moderadas para alto
# - Quantidade de periodicos e livros eletronicos com relevância alto

# %% [markdown]
# ### Forth cluster

# %%
forth_cluster_agg = pd.read_csv('./data/Agglomerative/Quarto agrupamento (Agglomerative).csv', sep=';')

# %%
get_total_categorical_values_cluster(forth_cluster_agg)
# Out:
# ====== NU_ANO_CENSO ======
# 2019: 475 ( 32.03%)
# 2018: 417 ( 28.12%)
# 2017: 297 ( 20.03%)
# 2016: 294 ( 19.82%)
#
# ====== REGIAO ======
# Sudeste: 496 ( 33.45%)
# Sul: 357 ( 24.07%)
# Nordeste: 304 ( 20.50%)
# Centro-Oeste: 226 ( 15.24%)
# Norte: 100 ( 6.74%)
#
# ====== IN_CAPITAL ======
# 0: 938 ( 63.25%)
# 1: 545 ( 36.75%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 0: 958 ( 64.60%)
# 1: 525 ( 35.40%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 0: 764 ( 51.52%)
# 1: 719 ( 48.48%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 1083 ( 73.03%)
# 0: 400 ( 26.97%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 1431 ( 96.49%)
# 0: 52 ( 3.51%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 1043 ( 70.33%)
# 0: 440 ( 29.67%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 1124 ( 75.79%)
# 0: 359 ( 24.21%)
#
# ====== IN_OUTRAS_BASES ======
# 1.0: 1024 ( 69.05%)
# 0.0: 459 ( 30.95%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada com fins lucrativos: 867 ( 58.46%)
# Privada sem fins lucrativos: 582 ( 39.24%)
# Pública Municipal e Especial: 31 ( 2.09%)
# Pública Federal: 3 ( 0.20%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Faculdade: 1477 ( 99.60%)
# Centro Universitário: 6 ( 0.40%)

# %%
forth_cluster_agg[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count      1,483.00                 1,483.00             1,483.00   1,483.00
# mean          24.47                17,567.76            12,180.19     629.78
# std           21.10               522,594.48           162,783.38     585.06
# min            1.00                     0.00                 0.00      11.00
# 25%           11.00                    20.00             1,741.00     224.00
# 50%           18.00                   100.00             6,372.00     475.00
# 75%           30.00                   600.00             8,648.50     839.00
# max          311.00            20,083,543.00         6,229,914.00   4,488.00
#
#        QT_DOCENTES  QT_CURSO  T1_VL_RECEITAS  T1_VL_DESPESAS
# count     1,483.00  1,483.00        1,483.00        1,483.00
# mean         32.80      4.70    4,533,739.31    4,080,641.43
# std          20.75      3.47    6,067,438.10    5,209,064.96
# min           3.00      1.00        3,125.00       42,500.00
# 25%          17.00      2.00    1,242,556.92    1,348,383.59
# 50%          28.00      4.00    2,751,112.26    2,675,040.99
# 75%          43.00      6.00    5,580,204.38    5,133,079.24
# max         155.00     29.00   79,434,370.49   79,923,866.93

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,15%)
# - Predominância das regiões Sudeste e Sul (33.45%, 24.07%)
# - Uma incidência das IES não estarem numa capital (63.25%)
# - Predominância das Instituições sem acesso ao portal Capes ( 64.60%)
# - Possuem predominância em busca integrada (73.03%)
# - Possuem serviço de internet (96.49%)
# - Predominância em participar em redes sociais (70.33%)
# - Possuem predominância em ter catalogo online (75.79%)
# - Possuem predominância em ter outras bases (69.05%)
# - Maioria das iinstituições são privada (com e sem fins lucrativos) (97,7%)
# - Maioria dos anos da IES são Faculdade (99.60%)
#
# - Quantidade de técnicos na média baixo (24.47%)
# - Quantidade de alunos média de alunos  moderado (629.78)
# - Corpo docente abaixo da média  (32.80)
# - Pouca quantidade média de cursos (4.70)
# - Despesas e receitas média moderado
# - Quantidade de periodicos e livros eletronicos com relevância alto

# %% [markdown]
# ### Firth cluster

# %%
firth_cluster_agg = pd.read_csv('./data/Agglomerative/Quinto agrupamento (Agglomerative).csv', sep=';')

# %%
get_total_categorical_values_cluster(firth_cluster_agg)
# Out:
# ====== NU_ANO_CENSO ======
# 2016: 321 ( 35.24%)
# 2017: 248 ( 27.22%)
# 2018: 214 ( 23.49%)
# 2019: 128 ( 14.05%)
#
# ====== REGIAO ======
# Sudeste: 445 ( 48.85%)
# Nordeste: 147 ( 16.14%)
# Centro-Oeste: 134 ( 14.71%)
# Sul: 124 ( 13.61%)
# Norte: 61 ( 6.70%)
#
# ====== IN_CAPITAL ======
# 0: 634 ( 69.59%)
# 1: 277 ( 30.41%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 0: 646 ( 70.91%)
# 1: 265 ( 29.09%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 0: 572 ( 62.79%)
# 1: 339 ( 37.21%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 635 ( 69.70%)
# 0: 276 ( 30.30%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 834 ( 91.55%)
# 0: 77 ( 8.45%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 618 ( 67.84%)
# 0: 293 ( 32.16%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 665 ( 73.00%)
# 0: 246 ( 27.00%)
#
# ====== IN_OUTRAS_BASES ======
# 0.0: 556 ( 61.03%)
# 1.0: 355 ( 38.97%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada sem fins lucrativos: 548 ( 60.15%)
# Privada com fins lucrativos: 294 ( 32.27%)
# Pública Municipal e Especial: 48 ( 5.27%)
# Pública Estadual: 16 ( 1.76%)
# Pública Federal: 5 ( 0.55%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Faculdade: 885 ( 97.15%)
# Centro Universitário: 25 ( 2.74%)
# Universidade: 1 ( 0.11%)

# %%
firth_cluster_agg[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count        911.00                   911.00               911.00     911.00
# mean          52.92                   166.28                55.79   1,429.16
# std          110.52                   963.53               433.94   1,203.80
# min            5.00                     0.00                 0.00      89.00
# 25%           24.00                     0.00                 0.00     581.50
# 50%           37.00                    14.00                 0.00   1,043.00
# 75%           57.50                   100.00                 1.00   1,902.00
# max        2,207.00                17,156.00             8,000.00   8,367.00
#
#        QT_DOCENTES  QT_CURSO   T1_VL_RECEITAS  T1_VL_DESPESAS
# count       911.00    911.00           911.00          911.00
# mean         65.70      7.29    18,623,640.27   10,655,911.89
# std          41.84      4.95   136,380,970.82   15,830,657.17
# min           6.00      1.00        89,327.57      306,039.11
# 25%          36.00      4.00     4,129,303.48    4,025,294.12
# 50%          56.00      6.00     8,013,288.00    7,109,575.50
# 75%          84.00     10.00    15,222,986.02   12,697,594.68
# max         300.00     30.00 4,000,452,318.90  294,064,951.75

# %% [markdown]
# Conclusões:
#
# - Predominancia dos anos de 2016 e 2017 (35.24% e 27.22%)
# - Predominância das regiões Sudeste e Nordeste e Centro-Oeste (48.85%, 16.14%, 14.71%)
# - Predominãncia das IES não estarem numa capital (69.59%)
# - Instituições sem acesso ao portal Capes (70.91%)
# - Instituições sem acesso repositorio institucional (62.79%)
# - Possuem predominância em possuir busca integrada (69.70%)
# - Possuem predominância em serviço de internet (91.55%)
# - Predominância em participar em redes sociais (67.84%)
# - Possuem catalogo online (73.00%)
# - Possuem predominância em ter outras bases (61.03%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (92,42%)
# - Maioria dos anos da IES são Faculdade  (97.15%)
#
# - Quantidade média de técnicos abaixo (52.92)
# - Quantidade de alunos média de alunos normal (1,429.16)
# - Corpo docente com quantidade média moderada (65.70)
# - Pouca quantidade de cursos (7.29)
# - Despesas e receitas média moderadas para alto
# - Quantidade de periodicos e livros eletronicos com relevância baixo

# %% [markdown]
# # K-means

# %% [markdown]
# ### First cluster

# %%
first_cluster_kmeans = pd.read_csv('./data/K-means/Primeiro agrupamento (K-means).csv', sep=';')

# %%
get_total_categorical_values_cluster(first_cluster_kmeans)
# Out:
# ====== NU_ANO_CENSO ======
# 2016: 149 ( 27.75%)
# 2017: 137 ( 25.51%)
# 2018: 132 ( 24.58%)
# 2019: 119 ( 22.16%)
#
# ====== REGIAO ======
# Sudeste: 201 ( 37.43%)
# Nordeste: 120 ( 22.35%)
# Sul: 101 ( 18.81%)
# Norte: 71 ( 13.22%)
# Centro-Oeste: 44 ( 8.19%)
#
# ====== IN_CAPITAL ======
# 0: 321 ( 59.78%)
# 1: 216 ( 40.22%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 1: 469 ( 87.34%)
# 0: 68 ( 12.66%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 1: 271 ( 50.47%)
# 0: 266 ( 49.53%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 313 ( 58.29%)
# 0: 224 ( 41.71%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 510 ( 94.97%)
# 0: 27 ( 5.03%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 384 ( 71.51%)
# 0: 153 ( 28.49%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 463 ( 86.22%)
# 0: 74 ( 13.78%)
#
# ====== IN_OUTRAS_BASES ======
# 0.0: 281 ( 52.33%)
# 1.0: 256 ( 47.67%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Pública Federal: 264 ( 49.16%)
# Privada sem fins lucrativos: 123 ( 22.91%)
# Pública Estadual: 113 ( 21.04%)
# Privada com fins lucrativos: 24 ( 4.47%)
# Pública Municipal e Especial: 13 ( 2.42%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Universidade: 322 ( 59.96%)
# Instituto Federal de Educação, Ciência e Tecnologia: 110 ( 20.48%)
# Centro Universitário: 79 ( 14.71%)
# Faculdade: 22 ( 4.10%)
# Centro Federal de Educação Tecnológica: 4 ( 0.74%)

# %%
first_cluster_kmeans[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count        537.00                   537.00               537.00     537.00
# mean         765.03                    88.07             4,257.21  12,553.95
# std          771.47                 1,633.33            18,064.84  11,019.01
# min           20.00                     0.00                 0.00     375.00
# 25%          290.00                     0.00                 0.00   5,038.00
# 50%          557.00                     0.00                 1.00   9,090.00
# 75%          935.00                     3.00             2,127.00  15,797.00
# max        5,670.00                37,835.00           223,350.00  68,600.00
#
#        QT_DOCENTES  QT_CURSO   T1_VL_RECEITAS    T1_VL_DESPESAS
# count       537.00    537.00           537.00            537.00
# mean        761.73     52.45   340,006,634.24    373,171,331.44
# std         657.55     40.42   550,425,214.82    878,480,744.42
# min          51.00      1.00       102,665.47     12,814,291.76
# 25%         301.00     27.00    71,049,153.95     97,099,748.00
# 50%         545.00     42.00   207,574,418.88    220,906,797.80
# 75%         951.00     63.00   366,195,544.48    366,195,544.48
# max       3,701.00    321.00 7,599,192,871.00 15,890,130,144.40

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%)
# - Uma incidência das IES não estarem numa capital (59,78%)
# - Instituições com acesso ao portal Capes (87.34%)
# - Possuem serviço de internet (94.97%)
# - Participam em redes sociais (71.51%)
# - Possuem catalogo online (86.22%)
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%)
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%)
#
# - Quantidade alta de técnicos na média (765.03)
# - Quantidade de alunos média de alunos alto (12,553.95)
# - Corpo docente forte na média (761.73)
# - Quantidade considerável de cursos na média (média de 52.45)
# - Despesas e receitas média moderadas
# - Quantidade de periodicos e livros eletronicos com relevância baixa

# %% [markdown]
# ### Second cluster

# %%
second_cluster_kmeans = pd.read_csv('./data/K-means/Segundo agrupamento (K-means).csv', sep=';')

# %%
get_total_categorical_values_cluster(second_cluster_kmeans)
# Out:
# ====== NU_ANO_CENSO ======
# 2019: 297 ( 32.00%)
# 2018: 261 ( 28.12%)
# 2016: 195 ( 21.01%)
# 2017: 175 ( 18.86%)
#
# ====== REGIAO ======
# Sudeste: 325 ( 35.02%)
# Nordeste: 238 ( 25.65%)
# Sul: 166 ( 17.89%)
# Centro-Oeste: 153 ( 16.49%)
# Norte: 46 ( 4.96%)
#
# ====== IN_CAPITAL ======
# 0: 551 ( 59.38%)
# 1: 377 ( 40.62%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 0: 587 ( 63.25%)
# 1: 341 ( 36.75%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 1: 477 ( 51.40%)
# 0: 451 ( 48.60%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 690 ( 74.35%)
# 0: 238 ( 25.65%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 863 ( 93.00%)
# 0: 65 ( 7.00%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 687 ( 74.03%)
# 0: 241 ( 25.97%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 602 ( 64.87%)
# 0: 326 ( 35.13%)
#
# ====== IN_OUTRAS_BASES ======
# 1.0: 643 ( 69.29%)
# 0.0: 285 ( 30.71%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada com fins lucrativos: 624 ( 67.24%)
# Privada sem fins lucrativos: 291 ( 31.36%)
# Pública Estadual: 5 ( 0.54%)
# Pública Municipal e Especial: 5 ( 0.54%)
# Pública Federal: 3 ( 0.32%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Faculdade: 927 ( 99.89%)
# Universidade: 1 ( 0.11%)

# %%
second_cluster_kmeans[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count        928.00                   928.00               928.00     928.00
# mean          12.87                 1,680.80            11,675.25     153.83
# std           13.90                 8,124.14           210,971.48     154.13
# min            1.00                     0.00                 0.00       1.00
# 25%            6.00                    20.00               200.00      53.75
# 50%            9.00                    70.00             2,100.00     113.00
# 75%           15.00                   400.00             7,726.75     215.50
# max          161.00               179,324.00         6,424,945.00   2,086.00
#
#        QT_DOCENTES  QT_CURSO  T1_VL_RECEITAS  T1_VL_DESPESAS
# count       928.00    928.00          928.00          928.00
# mean         14.20      2.30    1,475,556.24    1,626,618.40
# std          10.38      1.94   15,700,553.63   15,868,979.79
# min           1.00      1.00            0.01            2.00
# 25%           9.00      1.00      211,203.48      262,411.89
# 50%          12.00      2.00      615,428.62      629,806.48
# 75%          18.00      3.00    1,157,021.17    1,238,916.58
# max         154.00     24.00  476,631,170.46  481,208,448.88

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%)
# - Predominância das regiões Sudeste e Nordeste (60,67%)
# - Uma incidência das IES não estarem numa capital (59.38%)
# - Predominância das Instituições sem acesso ao portal Capes (63.25%)
# - Possuem busca integrada (74.35%)
# - Possuem serviço de internet (93.00%)
# - Participam em redes sociais (74.03%)
# - Possuem predominância em catalogo online (64.87%)
# - Possuem predominâncai em ter outras bases (69.29%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (98,6)
# - Maioria dos anos da IES são Faculdade (99.89%)
#
# - Pouca quantidade de técnicos na média (12.87)
# - Quantidade de alunos média de alunos abaixo (153.83)
# - Corpo docente muito pouco na média (14.20)
# - Pouca quantidade de cursos (2.30)
# - Despesas e receitas média moderadas
# - Quantidade de periodicos e livros eletronicos com relevância baixa

# %% [markdown]
# ### Third cluster

# %%
third_cluster_kmeans = pd.read_csv('./data/K-means/Terceiro agrupamento (K-means).csv', sep=';')

# %%
get_total_categorical_values_cluster(third_cluster_kmeans)
# Out:
# ====== NU_ANO_CENSO ======
# 2016: 345 ( 27.91%)
# 2017: 337 ( 27.27%)
# 2018: 286 ( 23.14%)
# 2019: 268 ( 21.68%)
#
# ====== REGIAO ======
# Sudeste: 583 ( 47.17%)
# Nordeste: 237 ( 19.17%)
# Sul: 216 ( 17.48%)
# Centro-Oeste: 112 ( 9.06%)
# Norte: 88 ( 7.12%)
#
# ====== IN_CAPITAL ======
# 0: 775 ( 62.70%)
# 1: 461 ( 37.30%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 0: 1027 ( 83.09%)
# 1: 209 ( 16.91%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 0: 923 ( 74.68%)
# 1: 313 ( 25.32%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 651 ( 52.67%)
# 0: 585 ( 47.33%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 978 ( 79.13%)
# 0: 258 ( 20.87%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 774 ( 62.62%)
# 0: 462 ( 37.38%)
#
# ====== IN_CATALOGO_ONLINE ======
# 0: 668 ( 54.05%)
# 1: 568 ( 45.95%)
#
# ====== IN_OUTRAS_BASES ======
# 0.0: 934 ( 75.57%)
# 1.0: 302 ( 24.43%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada sem fins lucrativos: 643 ( 52.02%)
# Privada com fins lucrativos: 565 ( 45.71%)
# Pública Municipal e Especial: 21 ( 1.70%)
# Pública Estadual: 6 ( 0.49%)
# Pública Federal: 1 ( 0.08%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Faculdade: 1235 ( 99.92%)
# Centro Universitário: 1 ( 0.08%)

# %%
third_cluster_kmeans[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count      1,236.00                 1,236.00             1,236.00   1,236.00
# mean          10.78                    38.75                17.38     185.81
# std           13.17                   390.28               177.16     160.48
# min            1.00                     0.00                 0.00       1.00
# 25%            5.00                     0.00                 0.00      70.00
# 50%            8.00                     0.00                 0.00     143.00
# 75%           13.00                    10.00                 0.00     260.25
# max          277.00                 9,331.00             4,000.00   1,587.00
#
#        QT_DOCENTES  QT_CURSO  T1_VL_RECEITAS  T1_VL_DESPESAS
# count     1,236.00  1,236.00        1,236.00        1,236.00
# mean         16.72      2.03    1,550,846.21    1,585,898.44
# std          10.01      1.39    3,915,629.37    6,214,497.12
# min           1.00      1.00            0.01            2.00
# 25%          10.00      1.00      389,521.86      387,356.53
# 50%          15.00      2.00      855,917.78      855,450.93
# 75%          22.00      3.00    1,559,343.44    1,567,425.95
# max         142.00     20.00   78,935,409.20  191,892,519.06

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%)
# - Predominãncia das IES não estarem numa capital (62.70%)
# - Instituições sem acesso ao portal Capes (83.09%)
# - Possuem predominância em não possuir repositorio institucional (74.68%)
# - Possuem predominância em serviço de internet (79.13%)
# - Predominância em participar em redes sociais (62.62%)
# - Possuem predominância em ter outras bases (75.57%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (97,73)
# - Maioria dos anos da IES são Faculdade (99.92%)
#
# - Quantidade baixa de média de técnicos (10.78)
# - Quantidade de alunos média de alunos baixo (185.81	)
# - Corpo docente muito baixo na média (16.72)
# - Pouca quantidade de cursos (2.03)
# - Despesas e receitas média moderadas
# - Quantidade de periodicos e livros eletronicos com relevância baixa

# %% [markdown]
# ### Forth cluster

# %%
forth_cluster_kmeans = pd.read_csv('./data/K-means/Quarto agrupamento (K-means).csv', sep=';')

# %%
get_total_categorical_values_cluster(forth_cluster_kmeans)
# Out:
# ====== NU_ANO_CENSO ======
# 2019: 468 ( 30.63%)
# 2018: 450 ( 29.45%)
# 2017: 318 ( 20.81%)
# 2016: 292 ( 19.11%)
#
# ====== REGIAO ======
# Sudeste: 596 ( 39.01%)
# Sul: 346 ( 22.64%)
# Nordeste: 325 ( 21.27%)
# Centro-Oeste: 159 ( 10.41%)
# Norte: 102 ( 6.68%)
#
# ====== IN_CAPITAL ======
# 0: 1052 ( 68.85%)
# 1: 476 ( 31.15%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 0: 989 ( 64.73%)
# 1: 539 ( 35.27%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 1: 808 ( 52.88%)
# 0: 720 ( 47.12%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 1181 ( 77.29%)
# 0: 347 ( 22.71%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 1489 ( 97.45%)
# 0: 39 ( 2.55%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 1088 ( 71.20%)
# 0: 440 ( 28.80%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 1214 ( 79.45%)
# 0: 314 ( 20.55%)
#
# ====== IN_OUTRAS_BASES ======
# 1.0: 1122 ( 73.43%)
# 0.0: 406 ( 26.57%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada com fins lucrativos: 866 ( 56.68%)
# Privada sem fins lucrativos: 632 ( 41.36%)
# Pública Municipal e Especial: 28 ( 1.83%)
# Pública Estadual: 2 ( 0.13%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Faculdade: 1515 ( 99.15%)
# Centro Universitário: 12 ( 0.79%)
# Universidade: 1 ( 0.07%)

# %%
forth_cluster_kmeans[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count      1,528.00                 1,528.00             1,528.00   1,528.00
# mean          33.68                17,212.81            19,758.56     932.89
# std           26.16               514,813.19           301,869.62     858.73
# min            2.00                     0.00                 5.00      22.00
# 25%           17.00                    29.00             2,000.00     487.00
# 50%           27.00                   129.00             7,000.00     771.50
# 75%           41.00                   559.25             8,734.00   1,205.25
# max          346.00            20,083,543.00        10,000,000.00  24,310.00
#
#        QT_DOCENTES  QT_CURSO   T1_VL_RECEITAS   T1_VL_DESPESAS
# count     1,528.00  1,528.00         1,528.00         1,528.00
# mean         45.12      6.21    16,180,821.28    11,879,650.46
# std          22.36      4.01   186,450,066.90    87,466,525.39
# min           1.00      1.00         3,125.00       248,908.99
# 25%          29.00      3.00     2,793,845.86     2,633,540.37
# 50%          41.00      5.00     5,174,117.05     4,541,098.14
# 75%          58.00      8.00     9,047,620.84     7,993,876.03
# max         153.00     40.00 5,745,640,000.00 2,918,280,000.00

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%)
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%)
# - Uma incidência das IES não estarem numa capital (68.85%)
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%)
# - Possuem predominância em busca integrada (77.29%)
# - Possuem serviço de internet (97.45%)
# - Predominância em participar em redes sociais (71.20%)
# - Possuem predominância em ter catalogo online (79.45%)
# - Possuem predominância em ter outras bases (73.43%)
# - Maioria das iinstituições são privada (com e sem fins lucrativos) (98,04)
# - Maioria dos anos da IES são Faculdade (99.15%)
#
# - Quantidade de técnicos na média baixo (33.68	)
# - Quantidade de alunos média de alunos  moderado (932.89)
# - Corpo docente muito na média (45.12)
# - Pouca quantidade média de cursos (6.21)
# - Despesas e receitas média acima do moderado
# - Quantidade de periodicos e livros eletronicos com relevância alto

# %% [markdown]
# ### Firth cluster

# %%
firth_cluster_kmeans = pd.read_csv('./data/K-means/Quinto agrupamento (K-means).csv', sep=';')

# %%
get_total_categorical_values_cluster(firth_cluster_kmeans)
# Out:
# ====== NU_ANO_CENSO ======
# 2019: 347 ( 26.63%)
# 2018: 334 ( 25.63%)
# 2017: 322 ( 24.71%)
# 2016: 300 ( 23.02%)
#
# ====== REGIAO ======
# Sudeste: 571 ( 43.82%)
# Nordeste: 334 ( 25.63%)
# Sul: 189 ( 14.50%)
# Norte: 109 ( 8.37%)
# Centro-Oeste: 100 ( 7.67%)
#
# ====== IN_CAPITAL ======
# 0: 771 ( 59.17%)
# 1: 532 ( 40.83%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 0: 828 ( 63.55%)
# 1: 475 ( 36.45%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 1: 718 ( 55.10%)
# 0: 585 ( 44.90%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 1015 ( 77.90%)
# 0: 288 ( 22.10%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 1270 ( 97.47%)
# 0: 33 ( 2.53%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 787 ( 60.40%)
# 0: 516 ( 39.60%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 1115 ( 85.57%)
# 0: 188 ( 14.43%)
#
# ====== IN_OUTRAS_BASES ======
# 1.0: 1020 ( 78.28%)
# 0.0: 283 ( 21.72%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada com fins lucrativos: 715 ( 54.87%)
# Privada sem fins lucrativos: 547 ( 41.98%)
# Pública Municipal e Especial: 27 ( 2.07%)
# Pública Federal: 9 ( 0.69%)
# Pública Estadual: 5 ( 0.38%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Faculdade: 862 ( 66.16%)
# Centro Universitário: 420 ( 32.23%)
# Universidade: 19 ( 1.46%)
# Instituto Federal de Educação, Ciência e Tecnologia: 2 ( 0.15%)

# %%
firth_cluster_kmeans[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count      1,303.00                 1,303.00             1,303.00   1,303.00
# mean         143.65                31,306.84            11,317.78   4,691.86
# std          136.18               362,333.87            55,653.40   4,874.23
# min           12.00                     0.00                 0.00      72.00
# 25%           70.00                   105.00               564.00   2,496.00
# 50%          108.00                   422.00             6,157.00   3,621.00
# 75%          180.50                 5,625.00             8,729.50   5,386.50
# max        2,654.00             6,437,318.00         1,200,000.00  89,706.00
#
#        QT_DOCENTES  QT_CURSO   T1_VL_RECEITAS    T1_VL_DESPESAS
# count     1,303.00  1,303.00         1,303.00          1,303.00
# mean        151.18     18.49    52,263,088.00     61,435,145.70
# std          75.60     13.72   140,361,418.17    529,816,318.16
# min          10.00      1.00       312,066.18      2,600,437.90
# 25%          97.00     11.00    20,850,115.51     16,877,562.19
# 50%         132.00     16.00    32,806,982.59     27,917,450.09
# 75%         189.00     22.00    59,547,232.10     48,137,697.00
# max         550.00    183.00 4,158,885,757.32 17,002,300,000.00

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%)
# - Uma incidência das IES não estarem numa capital (59.17%)
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%)
# - Possuem predominância em busca integrada (77.90%)
# - Possuem serviço de internet (97.47%)
# - Predominância em participar em redes sociais (60.40%)
# - Possuem catalogo online (85.57%)
# - Possuem predominância em ter outras bases (78.28%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (96,85)
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%)
#
# - Quantidade de técnicos médio moderado (143.65)
# - Quantidade de alunos média de alunos acima do moderado (4,691.86)
# - Corpo docente muito acima da  média (151.18)
# - Moderada quantidade média de cursos (18.49)
# - Despesas e receitas média altas
# - Quantidade de periodicos e livros eletronicos com relevância alto

# %% [markdown]
# ### Sixth cluster

# %%
sixth_cluster_kmeans = pd.read_csv('./data/K-means/Sexto agrupamento (K-means).csv', sep=';')

# %%
get_total_categorical_values_cluster(sixth_cluster_kmeans)
# Out:
# ====== NU_ANO_CENSO ======
# 2016: 471 ( 35.63%)
# 2017: 372 ( 28.14%)
# 2018: 261 ( 19.74%)
# 2019: 218 ( 16.49%)
#
# ====== REGIAO ======
# Sudeste: 577 ( 43.65%)
# Nordeste: 275 ( 20.80%)
# Sul: 217 ( 16.41%)
# Centro-Oeste: 159 ( 12.03%)
# Norte: 94 ( 7.11%)
#
# ====== IN_CAPITAL ======
# 0: 915 ( 69.21%)
# 1: 407 ( 30.79%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 0: 967 ( 73.15%)
# 1: 355 ( 26.85%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 0: 899 ( 68.00%)
# 1: 423 ( 32.00%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 865 ( 65.43%)
# 0: 457 ( 34.57%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 1198 ( 90.62%)
# 0: 124 ( 9.38%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 863 ( 65.28%)
# 0: 459 ( 34.72%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 957 ( 72.39%)
# 0: 365 ( 27.61%)
#
# ====== IN_OUTRAS_BASES ======
# 0.0: 823 ( 62.25%)
# 1.0: 499 ( 37.75%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada sem fins lucrativos: 667 ( 50.45%)
# Privada com fins lucrativos: 523 ( 39.56%)
# Pública Municipal e Especial: 100 ( 7.56%)
# Pública Estadual: 24 ( 1.82%)
# Pública Federal: 8 ( 0.61%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Faculdade: 1261 ( 95.39%)
# Centro Universitário: 53 ( 4.01%)
# Universidade: 6 ( 0.45%)
# Instituto Federal de Educação, Ciência e Tecnologia: 2 ( 0.15%)

# %%
sixth_cluster_kmeans[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count      1,322.00                 1,322.00             1,322.00   1,322.00
# mean          46.05                   181.31                20.60   1,202.21
# std           95.21                 1,624.34               157.65   1,028.28
# min            1.00                     0.00                 0.00      62.00
# 25%           19.00                     0.00                 0.00     503.25
# 50%           31.00                     6.00                 0.00     879.00
# 75%           50.00                    63.75                 0.00   1,503.25
# max        2,207.00                38,000.00             3,090.00   8,316.00
#
#        QT_DOCENTES  QT_CURSO   T1_VL_RECEITAS   T1_VL_DESPESAS
# count     1,322.00  1,322.00         1,322.00         1,322.00
# mean         60.92      6.76    20,169,429.75    12,427,568.59
# std          41.19      5.27   174,260,340.20    75,731,466.95
# min           3.00      1.00             1.00        98,800.00
# 25%          34.00      4.00     3,080,043.69     3,007,529.00
# 50%          50.00      6.00     6,047,025.04     5,573,239.50
# 75%          73.00      9.00    12,369,185.83    11,492,529.14
# max         300.00    113.00 4,000,452,318.90 2,255,916,597.00

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%)
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%)
# - Predominância das IES não estarem numa capital (69.21%)
# - Predominância das Instituições sem acesso ao portal Capes (73.15%)
# - Predominância das Instituições sem repositorio institucional (68.00%)
# - Possuem predominância em busca integrada (65.43%)
# - Possuem serviço de internet (90.62%)
# - Predominância em participar em redes sociais (65.28%)
# - Possuem catalogo online (72.39%)
# - Possuem predominância em ter outras bases (62.25%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (90,01%)
# - Maioria dos anos da IES são Faculdade (95.39%)
#
# - Quantidade de técnicos médio baixo (46.05	)
# - Quantidade de alunos média de alunos  moderado (1,202.21)
# - Corpo docente moderado na  média (60.92)
# - Moderada quantidade baixa de cursos (16.76)
# - Despesas e receitas média altas
# - Baixa quantidade de Quantidade de periodicos e livros eletronicos
# - Quantidade de periodicos e livros eletronicos com relevância baixo

# %% [markdown]
# ### Seventh cluster

# %%
seventh_cluster_kmeans = pd.read_csv('./data/K-means/Sétimo agrupamento (K-means).csv', sep=';')

# %%
get_total_categorical_values_cluster(seventh_cluster_kmeans)
# Out:
# ====== NU_ANO_CENSO ======
# 2019: 161 ( 27.38%)
# 2018: 149 ( 25.34%)
# 2017: 145 ( 24.66%)
# 2016: 133 ( 22.62%)
#
# ====== REGIAO ======
# Sudeste: 264 ( 44.90%)
# Sul: 143 ( 24.32%)
# Nordeste: 108 ( 18.37%)
# Centro-Oeste: 48 ( 8.16%)
# Norte: 25 ( 4.25%)
#
# ====== IN_CAPITAL ======
# 1: 317 ( 53.91%)
# 0: 271 ( 46.09%)
#
# ====== IN_ACESSO_PORTAL_CAPES ======
# 1: 516 ( 87.76%)
# 0: 72 ( 12.24%)
#
# ====== IN_REPOSITORIO_INSTITUCIONAL ======
# 1: 414 ( 70.41%)
# 0: 174 ( 29.59%)
#
# ====== IN_BUSCA_INTEGRADA ======
# 1: 395 ( 67.18%)
# 0: 193 ( 32.82%)
#
# ====== IN_SERVICO_INTERNET ======
# 1: 581 ( 98.81%)
# 0: 7 ( 1.19%)
#
# ====== IN_PARTICIPA_REDE_SOCIAL ======
# 1: 423 ( 71.94%)
# 0: 165 ( 28.06%)
#
# ====== IN_CATALOGO_ONLINE ======
# 1: 545 ( 92.69%)
# 0: 43 ( 7.31%)
#
# ====== IN_OUTRAS_BASES ======
# 1.0: 536 ( 91.16%)
# 0.0: 52 ( 8.84%)
#
# ====== NOME_CATEGORIA_ADMINISTRATIVA ======
# Privada sem fins lucrativos: 272 ( 46.26%)
# Pública Federal: 151 ( 25.68%)
# Privada com fins lucrativos: 117 ( 19.90%)
# Pública Estadual: 37 ( 6.29%)
# Pública Municipal e Especial: 11 ( 1.87%)
#
# ====== NOME_ORGANIZACAO_ACADEMICA ======
# Universidade: 410 ( 69.73%)
# Centro Universitário: 131 ( 22.28%)
# Instituto Federal de Educação, Ciência e Tecnologia: 38 ( 6.46%)
# Faculdade: 5 ( 0.85%)
# Centro Federal de Educação Tecnológica: 4 ( 0.68%)

# %%
seventh_cluster_kmeans[numeric_columns].describe()
# Out:
#        QT_TEC_TOTAL  QT_PERIODICO_ELETRONICO  QT_LIVRO_ELETRONICO  QT_ALUNOS  \
# count        588.00                   588.00               588.00     588.00
# mean       1,170.62                20,580.04            51,040.33  27,666.31
# std        1,577.99                45,203.40           117,262.32  37,426.76
# min           42.00                     0.00                 0.00     933.00
# 25%          417.75                   354.50             5,305.00  10,074.00
# 50%          727.50                 5,416.50            10,810.50  18,228.00
# 75%        1,241.50                27,972.00            21,087.00  32,646.50
# max       15,562.00               572,574.00         1,000,000.00 370,652.00
#
#        QT_DOCENTES  QT_CURSO   T1_VL_RECEITAS    T1_VL_DESPESAS
# count       588.00    588.00           588.00            588.00
# mean        970.69     73.91   507,239,181.16    531,850,625.47
# std         897.50     48.37   726,312,568.20  1,146,523,723.87
# min          90.00     10.00       796,666.35     42,123,282.22
# 25%         409.75     40.00   148,696,340.42    142,580,692.62
# 50%         640.50     59.00   283,766,807.44    260,395,339.91
# 75%       1,230.75     99.00   566,429,608.87    506,231,701.56
# max       6,286.00    296.00 6,258,050,290.00 22,161,393,800.00

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%)
# - Predominância das Instituições com acesso ao portal Capes (87.76%)
# - Predominância das Instituições com repositorio institucional (70.41%)
# - Possuem predominância em busca integrada (67.18%)
# - Possuem serviço de internet (98.81%)
# - Predominância em participar em redes sociais (71.94%)
# - Possuem catalogo online (92.69%)
# - Possuem predominância em ter outras bases (91.16%)
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%)
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%)
#
# - Quantidade de técnicos médio alto (1,170.62	)
# - Quantidade de alunos média de alunos alto (27,666.31)
# - Corpo docente alto na  média (970.69)
# - altga quantidade baixa de cursos (73.91)
# - Despesas e receitas média altas
# - Alta quantidade de Quantidade de periodicos e livros eletronicos
# - Quantidade de periodicos e livros eletronicos com relevância alto

# %% [markdown]
# # K-means

# %%
analise_kmeans = pd.DataFrame([], columns=['prompt', 'cluster', 'temperature', 'Total_suposições', 'Mapeadas_pelo_modelo', 'Ignoradas_pelo_modelo', 'alucinação_do_modelo', 'insights'])

# %%
def show_result_kmeans_prompt(df, temperature, cluster):
    return df.loc[(df['temperature'] == temperature) & (df['cluster'] == cluster), ['result']]['result'].tolist()[0]

# %%
kmeans_fase2.loc[(kmeans_fase2['temperature'] == 1) & (kmeans_fase2['cluster'] == 'primeiro'), ['result']]['result'].tolist()[0]
# Out:
# 'Entendi o desafio! Vou te guiar passo a passo para analisar os agrupamentos baseado nos dados fornecidos.\n\n**Passo 1: Preparação dos Dados**\n\nAntes de começar a analisar, é fundamental garantir que os dados estejam em ordem e sem erros. Isso inclui:\n\n* Verificar se há faltas ou valores faltantes em alguma das colunas\n* Convertê-lo para um formato fácil de processamento (por exemplo, números reais)\n* Limpar ou remover linhas com valores inconsistentes\n\n**Passo 2: Análise Exploratória**\n\nÉ fundamental entender a distribuição dos dados e identificar padrões ou tendências. Isso inclui:\n\n* Descrições estatísticas das colunas (meias, medias, desvios padrão)\n* Gráficos de barras, históricos ou box-plots para visualizar a distribuição dos valores\n* Análise de correlação entre as colunas para identificar relações estatísticas\n\n**Passo 3: Identificação de Características Principais**\n\nAgora é hora de identificar as características principais que contribuem para o agrupamento. Isso inclui:\n\n* Analisar a distribuição dos dados e identificar outliers ou valores anormais\n* Verificar se há padrões ou tendências em relação às colunas independentes\n* Identificar colunas que tenham uma grande influência no agrupamento\n\n**Passo 4: Análise de Cluster**\n\nCom as características principais identificadas, é hora de analisar os clusters. Isso inclui:\n\n* Verificar se há agrupamentos claramente definidos ou se há sobreposição entre as cluster\n* Analisar a densidade dos dados dentro e fora dos clusters para entender melhor a estrutura do agrupamento\n* Identificar padrões de distribuição das características dentro e fora dos clusters\n\n**Passo 5: Análise Geral**\n\nFinalmente, é hora de fazer uma análise geral do agrupamento. Isso inclui:\n\n* Resumir as principais conclusões tiradas durante a análise\n* Identificar as características mais importantes para o agrupamento\n* Sugestão de possíveis explicações para o agrupamento\n\nAgora que temos passado, vamos aplicar isso ao seu problema. Por favor forneça os dados csv e eu irei te guiar através da análise dos clusters!'

# %%
analise_kmeans
# Out:
#     prompt   cluster  temperature  Total_suposições  Mapeadas_pelo_modelo  \
# 0   Fase 2  primeiro         0.00                15                     7
# 1   Fase 2  primeiro         0.50                15                     9
# 2   Fase 2  primeiro         1.00                15                     5
# 3   Fase 2   segundo         0.00                17                     2
# 4   Fase 2   segundo         0.50                17                     4
# 5   Fase 2   segundo         1.00                17                     5
# 6   Fase 2  terceiro         0.00                15                     2
# 7   Fase 2  terceiro         0.50                15                     5
# 8   Fase 2  terceiro         1.00                15                     7
# 9   Fase 2    quarto         0.00                17                     3
# 10  Fase 2    quarto         0.50                17                     7
# 11  Fase 2    quarto         1.00                17                     4
# 12  Fase 2    quinto         0.00                16                     4
# 13  Fase 2    quinto         0.50                16                     5
# 14  Fase 2    quinto         1.00                16                     6
# 15  Fase 2     sexto         0.00                18                     9
# 16  Fase 2     sexto         0.50                18                     4
# 17  Fase 2     sexto         1.00                18                     3
# 18  Fase 2    setimo         0.00                16                     7
# 19  Fase 2    setimo         0.50                16                     7
# 20  Fase 2    setimo         1.00                16                     9
#
#     Ignoradas_pelo_modelo  alucinação_do_modelo  insights
# 0                       8                     1         0
# 1                       6                     2         0
# 2                      10                     2         0
# 3                      15                     4         0
# 4                      13                     2         0
# 5                      12                     3         0
# 6                      13                     3         1
# 7                      10                     2         4
# 8                       8                     1         1
# 9                      14                     3         2
# 10                     10                     3         0
# 11                     13                     3         1
# 12                     12                     3         0
# 13                     11                     3         1
# 14                     10                     1         0
# 15                      9                     1         0
# 16                     14                     1         0
# 17                     15                     0         0
# 18                      9                     1         0
# 19                      9                     1         0
# 20                      7                     3         0

# %%
analise_kmeans.to_csv('analise_kmeans.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Fase 2

# %%
kmeans_fase2 = pd.read_csv('Models/webUI/results/K-means_Fase 2_results.csv')

# %% [markdown]
# ### First Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'primeiro'))
# Out:
# Para começar a analisar o arquivo CSV e entender os fatores que levaram à criação do cluster, é necessário seguir um método sistemático que considere tanto as características dos dados quanto os padrões estatísticos observados.
#
# 1. **Preparação dos Dados**: O primeiro passo é garantir que os dados estejam em ordem e pré-processados para análise. Isso pode incluir a limpeza de dados duplicados, ausentes ou anormais, bem como a transformação de variáveis não numéricas em valores numéricos.
#
# 2. **Seleção das Características Relevantes**: Em seguida, identificamos as características que são mais relevantes para entender o agrupamento do cluster. Isso pode envolver a análise de correlação entre as variáveis ou a aplicação de técnicas de seleção de características, como o Randonômico Forestal (RF), Otimização de Máxima Acuracia da Árvore (OAAS) etc.
#
# 3. **Análise Exploratória**: Realizamos uma análise exploratória dos dados para identificar padrões e tendências, seja através de gráficos simples (histogramas, boxplots, scatter plots) ou utilizando técnicas estatísticas como a distribuição das variáveis, mediana, interquartil e percentis.
#
# 4. **Análise Cluster**: Após selecionar as características relevantes e realizar uma análise exploratória dos dados, podemos prosseguir com a análise do cluster. Isso envolve a visualização dos clusters utilizando técnicas de redução dimensional (PCA, t-SNE) para entender melhor a estrutura dos agrupamentos.
#
# 5. **Avaliação das Características**: Avaliamos qual é o papel da cada característica no agrupamento dos dados. Isso pode incluir testar a hipótese de que uma característica é relevante ou não para o cluster, utilizando estatística multivariada (ANOVA, ANOVA, etc).
#
# 6. **Análise Geral**: Finalmente, após identificar as características relevantes e avaliar sua importância para o agrupamento dos dados, realizamos uma análise geral do cluster. Isso pode incluir discutir a estrutura do cluster, as relações entre as características dentro do cluster, se há tendências ou padrões de comportamento específicos.
#
# 7. **Conclusão**: Com base na análise dos dados e suas características, é possível tirar conclusões sobre o que levou à formação do cluster e quais são as implicações práticas para os problemas apresentados pelos dados.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%) (NOT OK)
# - Uma incidência das IES não estarem numa capital (59,78%) (NOT OK)
# - Instituições com acesso ao portal Capes (87.34%) (NOT OK)
# - Possuem serviço de internet (94.97%) (NOT OK)
# - Participam em redes sociais (71.51%) (NOT OK)
# - Possuem catalogo online (86.22%) (NOT OK)
# - Busca integrada (58.29%) (NOT OK)
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%) (NOT OK)
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%) (NOT OK)
#
# - Quantidade alta de técnicos na média (765.03) (NOT OK)
# - Quantidade de alunos média de alunos alto (12,553.95) (NOT OK)
# - Corpo docente forte na média (761.73) (NOT OK)
# - Quantidade considerável de cursos na média (média de 52.45) (NOT OK)
# - Despesas e receitas média moderadas (NOT OK)
# - Quantidade de periodicos e livros eletronicos com relevância baixa (NOT OK)
#
# Insights falsos:
#
# - Análise de gráficos que não são gerados
# - Falta de explicação sobre as variaveis
# - Detalhamento do passo a passo ao invés da análise em si
#
#
# Enfatiza a presença de analises mais detalhadas

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2', 'primeiro', 0, 15, 7, 8, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'primeiro'))
# Out:
# Entendi o problema! Vou realizar uma análise estatística para entender os fatores que levaram à criação de um determinado cluster.
#
# Primeiramente, é importante saber que um cluster é um agrupamento de dados próximos uns aos outros, com base em algum critério de distância ou similaridade. Neste caso, vou focar em encontrar as características estatísticas que definem esse agrupamento.
#
# A primeira coisa que vou fazer é visualizar os dados do CSV. Vou criar uma tabela com as principais características dos dados, como média, moda e desvios padrão, para entender melhor a distribuição dos dados.
#
# A seguir, vou calcular a matriz de similaridade entre as instâncias do cluster. Isso será feito calculando a distância entre cada par de instâncias, utilizando uma medida de distância como o distância euclidiana ou a distância de Manhattan.
#
# Com essa matriz de similaridade, vou identificar os critérios que definem o agrupamento. Vou procurar por características que sejam significativas e que façam sentido no contexto do problema. Isso pode incluir características que são próximas uns às outras no espaço de dados, ou características que estão relacionadas com a mesma variável ou classe.
#
# Para isso, vou usar técnicas de análise estatística, como o teste de independência e o teste t de Student, para determinar se as características que identificamos são significativas.
#
# Agora, vamos considerar um exemplo. Digamos que temos um CSV com as seguintes características:
#
# | Coluna | Valor |
# | --- | --- |
# | A | 10 |
# | B | 20 |
# | C | 30 |
# | D | 40 |
#
# Vou começar visualizando essas características e calculando a matriz de similaridade entre as instâncias. No exemplo, posso ver que as colunas A e B têm valores próximos uns aos outros, enquanto as colunas C e D têm valores mais distantes.
#
# A seguir, vou procurar por características que sejam significativas e que façam sentido no contexto do problema. Vou considerar a hipótese de que a variável A é a característica principal que define o agrupamento.
#
# Vou calcular o teste t de Student para determinar se a variável A é significativa em relação à variável B. Se o p-value for menor que um nível de confiança (por exemplo, 0,05), isso indicaria que a variável A é uma característica importante do agrupamento.
#
# Além disso, vou calcular o teste de independência para determinar se as colunas C e D estão relacionadas com a variável A. Se o p-value for menor que um nível de confiança, isso indicaria que as colunas C e D estão significativamente relacionadas com a variável A.
#
# Em resumo, vou utilizar técnicas de análise estatística para identificar os critérios que definem o agrupamento e entender como as características interagem entre si. Isso permitirá que eu forneça uma explicação mais detalhada sobre como o cluster foi formado.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%) (NOT OK)
# - Uma incidência das IES não estarem numa capital (59,78%) NOT OK
# - Instituições com acesso ao portal Capes (87.34%) NOT OK
# - Possuem serviço de internet (94.97%) NOT OK
# - Participam em redes sociais (71.51%) NOT OK
# - Possuem catalogo online (86.22%) NOT OK
# - Busca integrada (58.29%) NOT OK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%) NOT OK
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%) NOT OK
#
# - Quantidade alta de técnicos na média (765.03) NOTOK
# - Quantidade de alunos média de alunos alto (12,553.95) NOTOK
# - Corpo docente forte na média (761.73) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOT NOTOK
#
# Insights falsos:
#
# - A análise apresentou dados inconsistentes com o foco da analise(alucinou)

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'primeiro', 0.5, 15, 9, 6, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'primeiro'))
# Out:
# Entendi o desafio! Vou te guiar passo a passo para analisar os agrupamentos baseado nos dados fornecidos.
#
# **Passo 1: Preparação dos Dados**
#
# Antes de começar a analisar, é fundamental garantir que os dados estejam em ordem e sem erros. Isso inclui:
#
# * Verificar se há faltas ou valores faltantes em alguma das colunas
# * Convertê-lo para um formato fácil de processamento (por exemplo, números reais)
# * Limpar ou remover linhas com valores inconsistentes
#
# **Passo 2: Análise Exploratória**
#
# É fundamental entender a distribuição dos dados e identificar padrões ou tendências. Isso inclui:
#
# * Descrições estatísticas das colunas (meias, medias, desvios padrão)
# * Gráficos de barras, históricos ou box-plots para visualizar a distribuição dos valores
# * Análise de correlação entre as colunas para identificar relações estatísticas
#
# **Passo 3: Identificação de Características Principais**
#
# Agora é hora de identificar as características principais que contribuem para o agrupamento. Isso inclui:
#
# * Analisar a distribuição dos dados e identificar outliers ou valores anormais
# * Verificar se há padrões ou tendências em relação às colunas independentes
# * Identificar colunas que tenham uma grande influência no agrupamento
#
# **Passo 4: Análise de Cluster**
#
# Com as características principais identificadas, é hora de analisar os clusters. Isso inclui:
#
# * Verificar se há agrupamentos claramente definidos ou se há sobreposição entre as cluster
# * Analisar a densidade dos dados dentro e fora dos clusters para entender melhor a estrutura do agrupamento
# * Identificar padrões de distribuição das características dentro e fora dos clusters
#
# **Passo 5: Análise Geral**
#
# Finalmente, é hora de fazer uma análise geral do agrupamento. Isso inclui:
#
# * Resumir as principais conclusões tiradas durante a análise
# * Identificar as características mais importantes para o agrupamento
# * Sugestão de possíveis explicações para o agrupamento
#
# Agora que temos passado, vamos aplicar isso ao seu problema. Por favor forneça os dados csv e eu irei te guiar através da análise dos clusters!

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%) NOT OK
# - Uma incidência das IES não estarem numa capital (59,78%) NOT OK
# - Instituições com acesso ao portal Capes (87.34%) OK
# - Possuem serviço de internet (94.97%) NOT OK
# - Participam em redes sociais (71.51%) NOT OK
# - Possuem catalogo online (86.22%) NOT OK
# - Busca integrada (58.29%) NOT OK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%) NOT OK
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%) NOT OK
#
# - Quantidade alta de técnicos na média (765.03) NOT OK
# - Quantidade de alunos média de alunos alto (12,553.95) NOT OK
# - Corpo docente forte na média (761.73) NOT OK
# - Despesas e receitas média moderadas NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOT OK
#
# - A análise apresnetada é apenas um detalhamento das etapas que devem ser seguidas para analisar os clusters.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'primeiro', 1, 15, 5, 10, 2, 0]

# %% [markdown]
# ### Second Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'segundo'))
# Out:
# Para realizar essa análise, vamos seguir um passo a passo lógico:
#
# 1. **Preparação dos Dados**: O primeiro passo é preparar os dados para o análise. Isso inclui garantir que os dados estejam em uma tabela e que todos os valores estejam convertidos para o mesmo tipo (por exemplo, numéricos).
#
# 2. **Visualização Inicial**: A visualização inicial é fundamental para entender o agrupamento geral dos dados. Vamos usar um gráfico de barra ou um histograma para ver se há algum padrão ou tendência nos dados.
#
# 3. **Identificação de Características Isoladas**: Em seguida, vamos procurar características isoladas que possam estar relacionadas ao cluster. Isso pode incluir medidas estatísticas como a média, o mínimo e o máximo da característica.
#
# 4. **Análise das Conjugações entre Características**: A seguir, vamos analisar as conjugações entre características. Isso significa comparar o valor de cada caracteistic com os valores dos outros caracteres. Vamos procurar conjunções que possam estar relacionadas ao cluster.
#
# 5. **Análise da Distribuição dos Dados**: Em seguida, vamos analisar a distribuição dos dados para entender melhor como eles estão agrupados. Isso pode incluir medidas estatísticas como a variação padrão (σ) e o coeficiente de variância (CV).
#
# 6. **Identificação do Centro do Cluster**: Após identificar características isoladas e conjugações, vamos procurar o centro do cluster. Isso pode ser feito calculando a média das características ou analisando as conjunções.
#
# 7. **Análise da Simetria do Cluster**: A seguir, vamos analisar a simetria do cluster para entender melhor como os dados estão agrupados em torno do centro.
#
# 8. **Conclusão Geral**: Finalmente, vamos realizar uma análise geral do agrupamento e identificar as principais características que levaram à criação do cluster.
#
# Com essa estrutura de pensamento, podemos começar a analisar os dados fornecidos no csv sem utilizar código.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOTOK
# - Possuem busca integrada (74.35%) OK
# - Possuem serviço de internet (93.00%) NOTOK
# - Participam em redes sociais (74.03%) NOTOK
# - Possuem predominância em catalogo online (64.87%) NOTOK
# - Possuem predominâncai em ter outras bases (69.29%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (98,6) OK
# - Maioria dos anos da IES são Faculdade (99.89%) NOTOK
#
# - Pouca quantidade de técnicos na média (12.87) NOTOK
# - Quantidade de alunos média de alunos abaixo (153.83) NOTOK
# - Corpo docente muito pouco na média (14.20) NOTOK
# - Pouca quantidade de cursos (2.30) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# Insights falsos:
# -  Mudança de contexto da análise, o modelo criou váriaveis que não existiam

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'segundo', 0, 17, 2, 15, 4, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'segundo'))
# Out:
# Entendi! Para realizar essa análise, vamos seguir um processo sistemático para entender melhor os fatores que levaram à criação do cluster.
#
# **Etapa 1: Preparação dos Dados**
#
# Antes de começar a analisar o cluster, é importante garantir que os dados estejam limpos e organizados. Isso inclui verificar se há erros de digitação, valores faltantes e outliers. Além disso, é fundamental entender a estrutura dos dados e identificar quais são as variáveis relevantes para a análise.
#
# **Etapa 2: Visualização dos Dados**
#
# A visualização dos dados é uma etapa crucial para entender melhor o agrupamento do cluster. Nessa etapa, vamos criar gráficos que ajudem a ilustrar as características dos dados e como elas se relacionam entre si.
#
# Por exemplo, podemos criar:
#
# *   Gráfico de barras ou linha para comparar valores da variável dependente.
# *   Gráfico de dispersão (bi-plano) para visualizar a relação entre duas ou mais variáveis.
# *   Distribuição de histograma para entender a forma como uma variável está distribuída.
#
# Esses gráficos ajudam a identificar padrões e tendências nos dados que podem não ser evidentes apenas ao analisar os valores individuais.
#
# **Etapa 3: Análise das Variáveis**
#
# Após visualizar os dados, vamos selecionar as variáveis mais relevantes para o cluster. Isso pode incluir características como:
#
# *   Variações de uma variável dependente.
# *   Correlações entre diferentes variáveis.
# *   Densidade e distribuição de valores.
#
# Essa etapa é fundamental para entender como os dados se relacionam uns com os outros e quais são as principais características que definem o cluster.
#
# **Etapa 4: Análise dos Agrupamentos**
#
# Com base nas análises anteriores, vamos identificar os fatores que levaram à criação do cluster. Isso pode incluir:
#
# *   Características individuais de uma variável.
# *   Conjugações entre diferentes características.
# *   Distribuição e densidade de valores.
#
# Essa etapa é a mais crítica, pois aqui vamos encontrar as razões pelos quais os dados foram agrupados em um mesmo cluster.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOTOK
# - Possuem busca integrada (74.35%) NOTOK
# - Possuem serviço de internet (93.00%) NOTOK
# - Participam em redes sociais (74.03%) NOTOK
# - Possuem predominância em catalogo online (64.87%) NOTOK
# - Possuem predominâncai em ter outras bases (69.29%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (98,6) NOTOK
# - Maioria dos anos da IES são Faculdade (99.89%) NOTOK
#
# - Pouca quantidade de técnicos na média (12.87) NOTOK
# - Quantidade de alunos média de alunos abaixo (153.83) NOTOK
# - Corpo docente muito pouco na média (14.20) NOTOK
# - Pouca quantidade de cursos (2.30) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# Insights:
# - Analise inconsistente

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'segundo', 0.5, 17, 4, 13, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'segundo'))
# Out:
# Entendi! Vou abordar essa análise com base nos dados estatísticos fornecidos. Para começar, gostaria de saber qual é o CSV que foi fornecido como entrada para a análise do cluster. Uma vez que receber esse arquivo, vou prosseguir com as seguintes etapas:
#
# 1.  **Carregar e limpar os dados**: Primeiro, vou carregar os dados do CSV fornecidos e verificar se há alguma linha ou coluna vazia. Em seguida, vou remover qualquer caractere não numérico ou espaço, caso exista.
# 2.  **Definir a métrica de agrupamento**: Vou escolher uma métrica para avaliar a estrutura dos dados e decidir quais características são relevantes para a análise do cluster. No geral, as características que são mais estáveis e possuem maior impacto nos resultados de agrupamento tendem a ser aquelas que são avaliadas como características.
# 3.  **Agrupar os dados**: Com base na métrica de agrupamento escolhida, vou agrupar os dados em cluster com base nas características relevantes. Em geral, é importante garantir que o número total de clusters seja previsível, e que cada cluster contenha pelo menos uma instância.
# 4.  **Analisar a estrutura dos clusters**: Após identificar os grupos, vou analisar a distribuição das características dentro de cada grupo para entender melhor as relações entre eles. Isso pode incluir medias, variâncias, percentiles e outros indicadores que ajudem na compreensão do agrupamento.
#
# Agora, sem informações sobre o CSV fornecido como entrada, é difícil realizar a análise específica.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOTOK
# - Possuem busca integrada (74.35%) OK
# - Possuem serviço de internet (93.00%) OK
# - Participam em redes sociais (74.03%) NOTOK
# - Possuem predominância em catalogo online (64.87%) NOTOK
# - Possuem predominâncai em ter outras bases (69.29%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (98,6) NOTOK
# - Maioria dos anos da IES são Faculdade (99.89%) NOTOK
#
# - Pouca quantidade de técnicos na média (12.87) NOTOK
# - Quantidade de alunos média de alunos abaixo (153.83) NOTOK
# - Corpo docente muito pouco na média (14.20) NOTOK
# - Pouca quantidade de cursos (2.30) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# Insights falsos:
# - A análise não detalha quais as características e nem a relevancia delas
# - é uma análsie superficial, como se houvesse criado um gráfico de dispersão para analisar.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'segundo', 1.0, 17, 5, 12, 3, 0]

# %% [markdown]
# ### Third Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'terceiro'))
# Out:
# Para iniciar a análise do cluster fornecido em formato csv, é necessário seguir um passo a passo lógico e estatístico para entender melhor as características dos agrupamentos identificados.
#
# ### Passo 1: Importância da Entidade Central (Mediana)
#
# Primeiro, vamos verificar a mediana como ponto de partida para avaliar os valores que podem estar relacionados à formação do cluster. A escolha da mediana é uma opção popular para simplificar as análises estatísticas, especialmente em conjuntos de dados com um número não muito grande de observações.
#
# ### Passo 2: Análise das Variáveis
#
# Em seguida, vamos avaliar a influência de cada característica no agrupamento. Isso pode incluir uma análise exploratória para entender se há características que estão relacionadas entre si e também com o cluster em questão.
#
# #### Características Conjugadas
# Uma característica conjugada é uma variável que está relacionada à outra através de uma relação matemática (por exemplo, multiplicativa ou aditiva). A presença de características conjugadas pode indicar uma estrutura subjacente no conjunto de dados que pode ser útil para entender melhor o agrupamento.
#
# #### Características Isoladas
# Uma característica isolada é uma variável única que não tem relação direta com outras variáveis. Em alguns casos, uma característica isolada pode ser um bom indicador de pertencimento a um cluster específico, especialmente se ela for extremamente discreta ou tende a dividir o conjunto de dados em dois agrupamentos distintos.
#
# ### Passo 3: Análise Multivariada
#
# A análise multivariada é uma técnica estatística que avalia múltiplas variáveis simultaneamente para entender como elas se relacionam entre si e com os objetivos ou conceitos de interesse. Neste caso, estamos interessados em entender como as características do cluster estão associadas e quais são as características cruciais que definem o agrupamento.
#
# ### Passo 4: Identificação da Linha do Agrupamento
#
# Uma vez identificadas as características relacionadas ao cluster, podemos pensar na linha de pensamento para a definição da característica central. A escolha pode variar conforme análise das variáveis disponíveis.
#
# ### Passo 5: Avaliação e Generalização
#
# Finalmente, é importante avaliar a precisão do agrupamento proposto e considerar possibilidades alternativas ou melhorias sobre o atual. Isso envolve testes estatísticos para avaliar a robustez do resultado obtido.
#
# ### Observação Final
#
# A abordagem utilizada pode variar conforme as características disponíveis, tamanho das amostras e complexidade dos dados. No entanto, a ideia é sempre buscar uma compreensão clara e abrangente sobre os fatores subjacentes que levaram à formação do cluster identificado.
#
# Vamos proceder com base nesses passos para entender melhor o agrupamento fornecido no formato csv.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOTOK
# - Predominãncia das IES não estarem numa capital (62.70%) NOTOK
# - Instituições sem acesso ao portal Capes (83.09%) NOTOK
# - Possuem predominância em não possuir repositorio institucional (74.68%) NOTOK
# - Possuem predominância em serviço de internet (79.13%) NOTOK
# - Predominância em participar em redes sociais (62.62%) NOTOK
# - Possuem predominância em ter outras bases (75.57%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (97,73)  NOTOK
# - Maioria dos anos da IES são Faculdade (99.92%) NOTOK
#
# - Quantidade baixa de média de técnicos (10.78) NOTOK
# - Quantidade de alunos média de alunos baixo (185.81) NOTOK
# - Corpo docente muito baixo na média (16.72) NOTOK
# - Pouca quantidade de cursos (2.03) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# Insights falsos:
# - A análise descreve etapas para um processo de análise do cluster, mas não análisa o cluster e o contexto da base de dados.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'terceiro', 0, 15, 2, 13, 3, 1]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'terceiro'))
# Out:
# Entendido! Vamos proceder com a análise dos dados.
#
# Primeiramente, é importante lembrar que o cluster é um agrupamento de instâncias que compartilham características semelhantes entre si. A criação de um cluster pode ser influenciada por uma variedade de fatores, incluindo características estatísticas individuais e combinações dessas características.
#
# Para começar a análise, vamos observar as características dos dados fornecidos no CSV. Nós não temos acesso ao arquivo CSV, mas podemos criar um cenário hipotético para a sua análise.
#
# Suponha que o CSV tenha as seguintes colunas: ID, Valor1, Valor2, Valor3 e Valor4. Vamos supor que essas características são estatísticas de desempenho de um produto ou serviço.
#
# **Análise de características individuais**
#
# Aqui estão algumas observações iniciais sobre as características individuais:
#
# *   **Valor1:** Esta característica pode representar o valor unitário do produto ou serviço. Observamos que valores mais altos tendem a estar associados a produtos ou serviços mais caros.
# *   **Valor2:** Essa característica pode representar a frequência de uso do produto ou serviço. Vemos que valores mais altos estão associados a produtos ou serviços mais utilizados.
# *   **Valor3:** Esta característica pode representar a durabilidade do produto ou serviço. Observe-se que valores mais baixos estão associados a produtos ou serviços menos duráveis.
# *   **Valor4:** Essa característica pode representar a satisfação do cliente. Vemos que valores mais altos estão associados a clientes mais satisfeitos.
#
# **Análise de combinações de características**
#
# Agora, vamos analisar as combinações de características para entender melhor como elas contribuem para a criação do cluster:
#
# *   **Valor1 e Valor2:** Vemos que valores mais altos em ambos os aspectos tendem a estar associados a produtos ou serviços mais caros e utilizados. Isso sugere uma relação positiva entre essas características.
# *   **Valor3 e Valor4:** Observe-se que valores mais baixos em um dos aspectos estão associados a produtos ou serviços menos duráveis, enquanto valores mais altos estão associados a clientes mais satisfeitos. Isso sugere uma relação negativa entre essas características.
#
# **Análise geral do agrupamento**
#
# Com base nas observações acima, podemos fazer algumas inferências sobre o cluster:
#
# *   O cluster parece estar focado em produtos ou serviços que são caros e utilizados frequentemente.
# *   Há uma relação positiva entre o valor unitário e a frequência de uso dos produtos ou serviços.
# *   Existem produtos ou serviços mais duráveis, mas com clientes menos satisfeitos.
#
# Em resumo, a análise sugere que o cluster está associado a produtos ou serviços caros e utilizados frequentemente, com uma relação positiva entre valor unitário e frequência de uso. Há também produtos ou serviços mais duráveis, mas com clientes menos satisfeitos.
#
# É importante notar que essa é uma análise hipotética, pois não temos acesso ao CSV real. A análise pode variar dependendo das características individuais e combinações presentes no arquivo CSV.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOTOK
# - Predominãncia das IES não estarem numa capital (62.70%) NOTOK
# - Instituições sem acesso ao portal Capes (83.09%) NOTOK
# - Possuem predominância em não possuir repositorio institucional (74.68%) NOTOK
# - Possuem predominância em serviço de internet (79.13%) NOTOK
# - Predominância em participar em redes sociais (62.62%) NOTOK
# - Possuem predominância em ter outras bases (75.57%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (97,73) OK
# - Maioria dos anos da IES são Faculdade (99.92%) NOTOK
#
# - Quantidade baixa de média de técnicos (10.78) NOTOK
# - Quantidade de alunos média de alunos baixo (185.81	) NOTOK
# - Corpo docente muito baixo na média (16.72) NOTOK
# - Pouca quantidade de cursos (2.03) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# Insights:
# - A análise reconhece que se trata de informações de Nível superior, mas não apresneta detalhes.
# - Também cria variaveisfora de contexto, como idade.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'terceiro', 0.5, 15, 5, 10, 2, 4]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'terceiro'))
# Out:
# **Análise do Cluster**
#
# A primeira coisa que façamos é visualizar as características dos dados para entender melhor o agrupamento. Vamos considerar as seguintes características: idade, salário e nível de educação.
#
# *   **Idade:** A idade parece ser um fator importante no agrupamento. Os indivíduos mais jovens estão concentrados em uma faixa específica da distribuição de idade, enquanto aqueles mais velhos formam outro grupo.
# *   **Salário:** O salário também é um fator importante. Os indivíduos com salários mais altos estão concentrados em outra faixa da distribuição de salário, enquanto aqueles com salários mais baixos estão concentrados em outra.
#
# **Característica Conjunta: Idade x Salário**
#
# Agora vamos analisar a relação entre a idade e o salário. Vamos considerar as seguintes características:
#
# *   **Idade - Salário:** A distribuição de idade x salário mostra que os indivíduos mais jovens tendem a ter salários mais baixos, enquanto aqueles mais velhos têm salários mais altos.
# *   **Idade - Nível de Educação:** A distribuição de idade x nível de educação também mostra que os indivíduos com níveis mais elevados de educação tendem a ter idades mais avançadas.
#
# **Característica Conjunta: Salário x Nível de Educação**
#
# Agora vamos analisar a relação entre o salário e o nível de educação. Vamos considerar as seguintes características:
#
# *   **Salário - Nível de Educação:** A distribuição de salário x nível de educação mostra que os indivíduos com níveis mais elevados de educação tendem a ter salários mais altos.
#
# **Análise Geral do Agrupamento**
#
# A partir das análises feitas acima, podemos concluir que o agrupamento é baseado nas características idade e salário. Os indivíduos mais jovens tendem a ter salários mais baixos, enquanto aqueles mais velhos têm salários mais altos. Além disso, os indivíduos com níveis mais elevados de educação tendem a ter idades mais avançadas e salários mais altos.
#
# Em resumo, o agrupamento é baseado na combinação das características idade, salário e nível de educação. Os indivíduos mais jovens e com níveis mais baixos de educação formam um grupo, enquanto aqueles mais velhos e com níveis mais elevados de educação formam outro.
#
# **O que Foi Analisado?**
#
# *   Características individuais (idade, salário, nível de educação)
# *   Distribuição de características conjuntas (idade - salário, idade - nível de educação, salário - nível de educação)
# *   Relações entre as características (idade e salário, idade e nível de educação, salário e nível de educação)
#
# **Conclusão**
#
# A análise do cluster mostrou que o agrupamento é baseado nas características idade e salário, com uma relação complexa entre a idade e o salário, além da relação entre o salário e o nível de educação. Além disso, os indivíduos mais jovens e com níveis mais baixos de educação formam um grupo, enquanto aqueles mais velhos e com níveis mais elevados de educação formam outro.
#
# **Recomendações**
#
# *   Considerar a criação de uma nova característica que combine as características idade, salário e nível de educação para melhor entender o agrupamento.
# *   Analisar a relação entre a idade e o salário em mais detalhes, considerando também outros fatores como renda familiar ou estilo de vida.
#
# **Considerações Finais**
#
# A análise do cluster mostrou que é importante considerar as características individuais e conjuntas para entender melhor o agrupamento. Além disso, a relação complexa entre as características pode levar a uma compreensão mais profunda do agrupamento.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOTOK
# - Predominãncia das IES não estarem numa capital (62.70%) NOTOK
# - Instituições sem acesso ao portal Capes (83.09%) NOTOK
# - Possuem predominância em não possuir repositorio institucional (74.68%) NOTOK
# - Possuem predominância em serviço de internet (79.13%) NOTOK
# - Predominância em participar em redes sociais (62.62%) NOTOK
# - Possuem predominância em ter outras bases (75.57%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (97,73) NOTOK
# - Maioria dos anos da IES são Faculdade (99.92%) NOTOK
#
# - Quantidade baixa de média de técnicos (10.78) NOTOK
# - Quantidade de alunos média de alunos baixo (185.81) NOTOK
# - Corpo docente muito baixo na média (16.72) NOTOK
# - Pouca quantidade de cursos (2.03) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
#
#
# Insights:
# - A análise foca em detalhar o processo de criação de um cluster.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'terceiro', 1.0, 15, 7, 8, 1, 1]

# %% [markdown]
# ### Forth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'quarto'))
# Out:
# Vamos começar com a análise do dado fornecido!
#
# No início, observei o formato do arquivo csv e notei que as instâncias estão separadas por uma barra (";") como delimitador. Isso é um bom sinal, pois facilita a leitura e manipulação dos dados.
#
# Agora, vamos analisar as características dos agrupamentos:
#
# *   **Variabilidade**: A variabilidade das características é alta em muitas das instâncias do cluster. Isso sugere que essas características são importantes para definir o agrupamento.
# *   **Conexão**: Algumas características estão conjugadas com outras, o que sugere uma conexão lógica entre elas. Por exemplo, uma característica pode estar relacionada a outra característica de forma direta ou indireta.
# *   **Isolamento**: Uma característica está isolada, o que significa que não tem nenhuma relação com as outras características.
#
# É importante notar que esses fatores podem variar dependendo do tipo de dados e da abordagem utilizada para análise.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOTOK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOTOK
# - Uma incidência das IES não estarem numa capital (68.85%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) NOTOK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOTOK
# - Predominância em participar em redes sociais (71.20%) NOTOK
# - Possuem predominância em ter catalogo online (79.45%) NOTOK
# - Possuem predominância em ter outras bases (73.43%) NOTOK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) (98,04) NOTOK
# - Maioria dos anos da IES são Faculdade (99.15%) NOTOK
#
# - Quantidade de técnicos na média baixo (33.68	) NOTOK
# - Quantidade de alunos média de alunos  moderado (932.89) NOTOK
# - Corpo docente muito na média (45.12) NOTOK
# - Pouca quantidade média de cursos (6.21) NOTOK
# - Despesas e receitas média acima do moderado NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - Destaca a necessidade de análises aprofundadas
# - Descreve as etapas, mas não realiza a análise das variaveis.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quarto', 0, 17, 3, 14, 3, 2]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'quarto'))
# Out:
# **Análise do Cluster**
#
#  Ao receber o CSV com as instâncias de um determinado cluster, o objetivo é analisar os fatores que levaram à sua criação. Para isso, vou seguir uma cadeia de pensamento lógica para entender melhor os agrupamentos.
#
# 1. **Características das Instâncias**
#
#  Primeiramente, eu vou analisar as características individuais das instâncias do cluster. Vou verificar se há características que sejam consistentes ou conjugadas entre si. Isso ajudará a identificar padrões ou tendências que possam ter contribuído para a criação do agrupamento.
#
# 2. **Distribuição dos Valores**
#
#  Em seguida, vou verificar a distribuição dos valores das características individuais. Vou analisar se há valores que são frequentemente repetidos ou se há um rango de valores mais amplo do que outro. Isso pode indicar que certas características têm um impacto maior na formação do cluster.
#
# 3. **Correlações entre Características**
#
#  Em seguida, vou verificar as correlações entre as características individuais. Vou analisar se há características que estão relacionadas ou conjugadas com outras características. Isso pode ajudar a entender como os agrupamentos foram formados.
#
# 4. **Análise de Grupos**
#
#  Depois, vou criar grupos das instâncias do cluster com base nas características e valores analisados anteriormente. Vou verificar se há padrões ou tendências dentro de cada grupo. Isso pode ajudar a entender melhor a estrutura dos agrupamentos.
#
# 5. **Análise Geral**
#
#  Finalmente, vou fazer uma análise geral dos agrupamentos. Vou verificar se há características ou valores que estejam associados ao surgimento do cluster. Além disso, vou analisar se há padrões ou tendências mais amplos que possam ser identificados.
#
# **Hipóteses**
#
#  Com base na análise das características individuais, distribuição dos valores e correlações entre as características, posso formular as seguintes hipóteses:
#
# * A característica X tem um impacto maior na formação do cluster.
# * A característica Y está relacionada à característica X e pode estar contribuindo para a criação do agrupamento.
#
# **Conclusão**
#
#  Ao analisar os dados estatísticos, pude identificar alguns padrões e tendências que podem ter contribuído para a criação do cluster. A característica X parece ter um impacto maior na formação do cluster, enquanto a característica Y está relacionada à característica X. Além disso, há uma distribuição dos valores das características individuais que pode indicar que certas características têm um impacto maior na formação do agrupamento.
#
# Em resumo, o cluster foi criado devido a uma combinação de características individuais e valores que sejam consistentes ou conjugadas entre si. A característica X tem um impacto maior na formação do cluster, enquanto a característica Y está relacionada à característica X.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOTOK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOTOK
# - Uma incidência das IES não estarem numa capital (68.85%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) NOTOK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOTOK
# - Predominância em participar em redes sociais (71.20%) NOTOK
# - Possuem predominância em ter catalogo online (79.45%) NOTOK
# - Possuem predominância em ter outras bases (73.43%) NOTOK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) (98,04) NOTOK
# - Maioria dos anos da IES são Faculdade (99.15%) NOTOK
#
# - Quantidade de técnicos na média baixo (33.68	) NOTOK
# - Quantidade de alunos média de alunos  moderado (932.89) NOTOK
# - Corpo docente muito na média (45.12) NOTOK
# - Pouca quantidade média de cursos (6.21) NOTOK
# - Despesas e receitas média acima do moderado NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights:
# - A análise acaba sendo das etapas de análise do cluster,e não das variaveis.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quarto', 0.5, 17, 7, 10, 3, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'quarto'))
# Out:
# Entendi o desafio! Vamos começar a análise do cluster fornecido no CSV.
#
# **Etapa 1: Preparação dos dados**
#
# Antes de começar a analisar os agrupamentos, é importante garantir que os dados estejam em ordem e sem erros. Isso inclui verificar se há valores faltantes ou duplicados, bem como garantir que as colunas estejam em ordem correta.
#
# **Etapa 2: Caracterização dos agrupamentos**
#
# Agora é hora de analisar os agrupamentos individuais. Vou começar com a caracterização da primeira instância do cluster.
#
# * **Características**: A primeira instância tem as seguintes características:
#  + Coluna 1: valor A
#  + Coluna 2: valor B
#  + Coluna 3: valor C
# * **Relacionamento com outras instâncias**: Verificarei se há alguma conexão ou padrão entre essa instância e as demais.
#
# Agora, vou fazer a mesma análise para as outras instâncias do cluster. Em seguida, farei uma análise geral dos agrupamentos como um todo.
#
# **Análise de agrupamento**
#
# Ao analisar as características individuais das instâncias do cluster, noto que:
#
# * A Coluna 1 tem valores A e B, mas não há padrões claros.
# * A Coluna 2 tem valores C e D, com alguns padrões sutis.
# * A Coluna 3 tem valores E e F, com um padrão claro de aumento linear.
#
# Agora, quando analizo as conexões entre as instâncias do cluster, noto que:
#
# * Algumas instâncias têm características semelhantes em diferentes colunas (por exemplo, uma instância tem valor A na Coluna 1 e valor C na Coluna 3).
# * Outras instâncias têm características discordantes entre si (por exemplo, duas instâncias têm valores opostos na Coluna 2).
#
# Com base nesses padrões, posso inferir que o cluster é formado por:
#
# * Instâncias com características semelhantes em diferentes colunas, sugerindo uma relação estrutural entre as características.
# * Instâncias com características discordantes entre si, sugerindo uma diversidade interna dentro do cluster.
#
# **Análise geral**
#
# Em resumo, o cluster parece estar formado por duas subgrupos principais:
#
# 1. **Subgrupo 1**: Instâncias com características semelhantes em diferentes colunas, sugerindo uma relação estrutural entre as características.
# 2. **Subgrupo 2**: Instâncias com características discordantes entre si, sugerindo uma diversidade interna dentro do cluster.
#
# Essa análise sugere que o cluster é formado por duas subgrupos principais, cada um com suas características únicas e padrões de relacionamento entre elas.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOTOK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOTOK
# - Uma incidência das IES não estarem numa capital (68.85%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) NOTOK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOTOK
# - Predominância em participar em redes sociais (71.20%) NOTOK
# - Possuem predominância em ter catalogo online (79.45%) NOTOK
# - Possuem predominância em ter outras bases (73.43%) NOTOK
# - Maioria das iinstituições são privada (com e sem fins lucrativos)  (98,04) OK
# - Maioria dos anos da IES são Faculdade (99.15%) OK
#
# - Quantidade de técnicos na média baixo (33.68	)  NOTOK
# - Quantidade de alunos média de alunos  moderado (932.89) NOTOK
# - Corpo docente muito na média (45.12) NOTOK
# - Pouca quantidade média de cursos (6.21) NOTOK
# - Despesas e receitas média acima do moderado NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - A análise que é fieta acaba sendo da distribuição dos dados e não das caracteristicas das variaveis.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quarto', 1.0, 17, 4, 13, 3, 1]

# %% [markdown]
# ### Firth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'quinto'))
# Out:
# **Análise do Clustering**
#
# A partir dos dados fornecidos, é possível identificar alguns fatores que levaram à criação do cluster. Vamos analisar os agrupamentos e encontrar as características que são isoladas ou conjugadas.
#
# **Características Isoladas**
#
# Uma das primeiras coisas que observamos é a presença de características isoladas, como:
#
# * A característica "Idade" tem um valor médio de 35 anos, o que pode indicar uma faixa etária específica da população.
# * A característica "Gênero" tem uma distribuição desigual, com mais homens do que mulheres.
#
# Essas características isoladas podem ter contribuído para a criação do cluster, pois elas podem ter criado um agrupamento de indivíduos com características semelhantes.
#
# **Características Conjugadas**
#
# Além disso, também observamos algumas características conjugadas, como:
#
# * A característica "Idade" e a característica "Gênero" estão correlacionadas, pois a maioria das pessoas mais velhas é composta por mulheres.
# * A característica "Salário" está relacionada com a característica "Idade", pois as pessoas mais velhas tendem a ter salários mais altos.
#
# Essas características conjugadas podem ter contribuído para a criação do cluster, pois elas podem ter criado um agrupamento de indivíduos com características semelhantes e que estão interligadas entre si.
#
# **Análise Geral do Agrupamento**
#
# Com base nas observações acima, podemos dizer que o cluster está composto por pessoas mais velhas (mais de 40 anos) e mulheres, que tendem a ter salários mais altos. Além disso, a característica "Idade" e a característica "Gênero" estão correlacionadas, o que sugere que essas características podem estar relacionadas entre si.
#
# Em resumo, os fatores que levaram à criação do cluster são:
#
# * Características isoladas como a Idade e a Gênero
# * Características conjugadas como a Idade e a Salário
# * A presença de uma faixa etária específica (mais de 40 anos) e um gênero predominante (mulheres)
#
# Essas características podem ter contribuído para a criação do cluster, criando um agrupamento de indivíduos com características semelhantes.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.17%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) NOTOK
# - Possuem predominância em busca integrada (77.90%) NOTOK
# - Possuem serviço de internet (97.47%) NOTOK
# - Predominância em participar em redes sociais (60.40%) NOTOK
# - Possuem catalogo online (85.57%) NOTOK
# - Possuem predominância em ter outras bases (78.28%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (96,85) OK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) OK
#
# - Quantidade de técnicos médio moderado (143.65) NOTOK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) NOTOK
# - Corpo docente muito acima da  média (151.18) NOTOK
# - Moderada quantidade média de cursos (18.49) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights:
# - Não realiza a análise das variaveis, apenas sugere etapas de analise e o contexto.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quinto', 0, 16, 4, 12, 3, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'quinto'))
# Out:
# Entendo! Vou criar um cenário de análise para entender os fatores que levaram à criação de um determinado cluster.
#
# Suponha que o CSV fornece as seguintes informações sobre 10 instâncias de um cluster:
#
# | Instância | Variável A (A) | Variável B (B) | Variável C (C) |
# | --- | --- | --- | --- |
# | 1   | 0,5       | 8           | 6         |
# | 2   | 0,7       | 9           | 7         |
# | 3   | 0,4       | 7           | 5         |
# | 4   | 0,8       | 10          | 8         |
# | 5   | 0,6       | 8           | 6         |
# | 6   | 0,9       | 11          | 9         |
# | 7   | 0,3       | 5           | 4         |
# | 8   | 0,1       | 4           | 3         |
# | 9   | 0,2       | 6           | 5         |
# | 10  | 0,7       | 9           | 7         |
#
# Para analisar os fatores que levaram à criação desse cluster, vou seguir uma cadeia de pensamento:
#
# **Pergunta inicial**: Quais são as características únicas presentes nas instâncias do cluster?
#
# Ao examinar as instâncias, observo que há uma variedade de valores para cada variável. No entanto, algumas características podem estar relacionadas entre si.
#
# **Hipótese**: Acredito que Variável A (A) e Variável C (C) possam estar relacionadas, pois ambos têm valores menores em comparação com as outras variáveis.
#
# Vou calcular a relação linear entre essas duas variáveis:
#
# * Correlação de Pearson: R(A,C) = 0,85
#
# Isso indica que há uma forte relação positiva entre A e C. Além disso, os valores da Variável B (B) parecem ser relacionados com as valores das outras variáveis.
#
# **Pergunta**: Quais são as características que estão associadas à Variável B (B)?
#
# Ao examinar as instâncias, observo que os valores de B tendem a crescer juntamente com os valores dos outros atributos. Isso sugere que B pode estar relacionado com A e C.
#
# **Análise**: Vou calcular a correlação entre B e cada uma das outras variáveis:
#
# * Correlação de Pearson: R(B,A) = 0,92; R(B,C) = 0,95
#
# Esses resultados confirmam minha hipótese de que B está relacionada com A e C.
#
# **Conclusão**: Baseado nas análises, acredito que o cluster foi criado pela combinação da seguinte relação:
#
# A -> C (com uma forte relação positiva)
#
# B -> A e C (com uma forte relação positiva)
#
# Em resumo, as instâncias do cluster parecem estar relacionadas entre si devido à presença de valores crescentes em B que estão associados a valores crescentes em A e C.
#
# **Análise geral**: Ao analisar as características dos agrupamentos, podemos concluir que:
#
# * Variável A (A) é uma característica importante para definir o cluster.
# * Variável C (C) também é relevante, embora com uma relação positiva mais fraca em comparação com B e A.
# * Variável B (B) tem uma forte relação com as outras variáveis, sugerindo que ela pode ser uma característica dominante para definir o cluster.
#
# Essa análise não é definitiva, mas fornece uma compreensão geral dos fatores que podem estar relacionados à criação do cluster.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.17%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) NOTOK
# - Possuem predominância em busca integrada (77.90%) NOTOK
# - Possuem serviço de internet (97.47%) NOTOK
# - Predominância em participar em redes sociais (60.40%) NOTOK
# - Possuem catalogo online (85.57%) NOTOK
# - Possuem predominância em ter outras bases (78.28%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (96,85) NOTOK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) NOTOK
#
# - Quantidade de técnicos médio moderado (143.65) NOTOK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) NOTOK
# - Corpo docente muito acima da  média (151.18) NOTOK
# - Moderada quantidade média de cursos (18.49) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights :
# - Apenas detalha o processo de criação do cluster, mas não análisa a relevancia das variaveis.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quinto', 0.5, 16, 5, 11, 3, 1]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'quinto'))
# Out:
# Para realizar essa análise, vamos seguir uma cadeia de pensamento lógica para entender os fatores que levaram à criação do cluster.
#
# **Passo 1: Entendendo o Cluster**
#
# Antes de mais nada, é importante entender o que é um cluster e como ele foi criado. Um cluster é um agrupamento de dados que compartilham características semelhantes entre si. Nesse caso, vamos analisar as instâncias do cluster fornecido no csv.
#
# **Passo 2: Analisando as Características**
#
# A próxima etapa é analisar as características presentes no dataset e identificar quaisquer padrões ou tendências significativas. Em seguida, vamos considerar a ocorrência de cada característica isolado e conjugada com outra característica.
#
# **Passo 3: Identificando Características Importantes**
#
# Durante a análise, é provável que algumas características se destacem como mais importantes do que outras. Isso pode ser evidenciado por meio da análise estatística, como a média, mediana e desvios padrão das variáveis.
#
# **Passo 4: Verificando a Cooperação entre Características**
#
# É fundamental verificar como as características se relacionam entre si. Em alguns casos, uma característica pode estar conjugada com outra característica para formar um padrão mais claro.
#
# **Passo 5: Identificando Cluster Centroides**
#
# Após identificar as características importantes e suas relações, é hora de encontrar o centroid do cluster, que é o ponto médio das características dos dados.
#
# **Passo 6: Analisando a Distribuição dos Dados**
#
# Agora, vamos analisar como os dados estão distribuídos ao redor do centroid. Em alguns casos, os dados podem estar distribuídos de forma simétrica, enquanto em outros, pode haver uma distribuição assimétrica.
#
# **Passo 7: Verificando a Coesão dos Dados**
#
# É importante verificar como os dados dentro do cluster estão relacionados entre si. Em alguns casos, os dados podem estar altamente correlacionados, enquanto em outros, pode haver um padrão mais dispersivo.
#
# **Análise Geral do Agrupamento**
#
# A partir das análises anteriores, é possível obter uma visão geral do agrupamento e entender como ele foi criado. Em alguns casos, o cluster pode ter sido criado devido a características que são exclusivas, enquanto em outros, pode ser devido a características que estão associadas.
#
# **Conclusão**
#
# Em resumo, a análise dos dados estatísticos permitirá identificar os fatores importantes que levaram à criação do cluster. Em seguida, é possível entender como as características se relacionam entre si e como os dados dentro do cluster estão distribuídos ao redor do centroid. Isso nos ajudará a compreender o agrupamento de forma mais profunda.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.17%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) NOTOK
# - Possuem predominância em busca integrada (77.90%) NOTOK
# - Possuem serviço de internet (97.47%) NOTOK
# - Predominância em participar em redes sociais (60.40%) NOTOK
# - Possuem catalogo online (85.57%) NOTOK
# - Possuem predominância em ter outras bases (78.28%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (96,85) NOTOK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) NOTOK
#
# - Quantidade de técnicos médio moderado (143.65) NOTOK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) NOTOK
# - Corpo docente muito acima da  média (151.18) NOTOK
# - Moderada quantidade média de cursos (18.49) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - A analise que é feita é sobre a distribuição do cluster.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quinto', 1.0, 16, 6, 10, 1, 0]

# %% [markdown]
# ### Sixth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'sexto'))
# Out:
# Para iniciar essa análise, é importante considerar alguns passos iniciais para entender o problema e definir a linha de pensamento:
#
# 1. **Entendendo o Dado**: O dado fornecido em formato csv contém as instâncias de um determinado cluster. É fundamental entender que o objetivo aqui não é realizar uma análise estatística comum, como a mediação ou variança, mas sim analisar os agrupamentos gerados pelo cluster.
#
# 2. **Definindo o Cluster**: Antes de começar, preciso entender qual é o alvo do clustering e quais características são relevantes para essa análise. Isso é crucial para determinar como abordar as características que podem influenciar a criação do cluster.
#
# 3. **Preparação dos Dados**: A análise será realizada apenas com base nos dados estatísticos, portanto é importante preparar os dados de forma a que seja possível realizar as análises necessárias, como a mediana, percentis, dispersão, etc.
#
# 4. **Análise dos Agrupamentos**: Para entender como o cluster foi criado, preciso analisar os valores isolados ou conjugados que se formaram no grupo. Por exemplo, se um valor está isolado, pode significar que não há nenhuma outra característica que possa ser relacionada com esse ponto.
#
# 5. **Análise de Conexão entre Características**: Para entender como as características se ligam e quais são os fatores de conexão ou divergência entre grupos, é importante analisar a relação entre as diferentes características do dataset. Isso pode ser feito por meio da análise mutual e de dispersões entre as variáveis.
#
# 6. **Análise Geral do Agrupamento**: Após entender os fatores que levaram à criação do cluster e quais são as conexões ou divergências entre características, é hora de realizar uma análise geral do agrupamento para entender como eles se relacionam uns com os outros.
#
# Agora que tenho em mente o contexto e a linha de pensamento, posso iniciar a análise.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%)  NOTOK
# - Predominância das IES não estarem numa capital (69.21%)  NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (73.15%)  NOTOK
# - Predominância das Instituições sem repositorio institucional (68.00%)  NOTOK
# - Possuem predominância em busca integrada (65.43%) NOTOK
# - Possuem serviço de internet (90.62%) NOTOK
# - Predominância em participar em redes sociais (65.28%)  NOTOK
# - Possuem catalogo online (72.39%)  NOTOK
# - Possuem predominância em ter outras bases (62.25%)  NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (90,01%)  NOTOK
# - Maioria dos anos da IES são Faculdade (95.39%)  NOTOK
#
# - Quantidade de técnicos médio baixo (46.05	) NOTOK
# - Quantidade de alunos média de alunos  moderado (1,202.21) NOTOK
# - Corpo docente moderado na  média (60.92) NOTOK
# - Moderada quantidade baixa de cursos (16.76) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixo NOTOK
#
# Insights falsos:
# - Analisa a distibuição do cluster, mas não leva em consideraçãpo o contexto.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'sexto', 0, 18, 9, 9, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'sexto'))
# Out:
# Entendi! Como analista de dados, vou seguir uma abordagem estruturada para entender os fatores que levaram à criação do cluster.
#
# Primeiramente, é importante considerar a qualidade e a quantidade dos dados fornecidos. Vou assumir que o csv fornece as instâncias do cluster em formato de tabulação, com cada linha representando uma instância e cada coluna representando uma característica.
#
# O primeiro passo é identificar os clusters existentes no conjunto de dados. Isso pode ser feito visualizando o gráfico de clusterização, como um gráfico de densidade ou um gráfico de dispersão das características.
#
# Após identificar os clusters, vou analisar as características individuais para entender melhor a estrutura do agrupamento. Isso inclui considerar as seguintes perguntas:
#
# - Qual é a frequência relativa de cada característica dentro e fora dos clusters?
# - Quais são as características mais relevantes para o agrupamento?
#
# Para responder essas perguntas, vou utilizar técnicas estatísticas como análise de frequências, testes de hipótese e modelos de regressão.
#
# Aqui estão algumas possibilidades que podem ser encontradas:
#
# *   Uma característica isolada pode estar presente em um cluster, mas não no outro.
# *   Duas ou mais características podem estar conjugadas para formar um agrupamento.
# *   Algumas características podem ter valores médios ou modais diferentes nos dois clusters.
#
# A partir da análise das características, vou tentar entender a relação entre elas e o agrupamento. Isso pode envolver a identificação de características "dominantes" que desempenham um papel fundamental no agrupamento.
#
# Além disso, vou considerar a estrutura dos clusters em termos da densidade espacial ou da proximidade entre as instâncias. Isso pode ajudar a entender como os clusters se relacionam uns com os outros.
#
# Em seguida, vou considerar as implicações do agrupamento para as partes interessadas. Isso pode incluir a identificação de oportunidades para otimização de processos ou a compreensão de tendências econômicas ou sociais.
#
# Para fins de conclusão, vou apresentar uma análise geral dos agrupamentos, destacando os principais fatores que levaram à sua criação e as implicações mais importantes.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%)  NOTOK
# - Predominância das IES não estarem numa capital (69.21%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (73.15%) NOTOK
# - Predominância das Instituições sem repositorio institucional (68.00%) NOTOK
# - Possuem predominância em busca integrada (65.43%) NOTOK
# - Possuem serviço de internet (90.62%)  NOTOK
# - Predominância em participar em redes sociais (65.28%) NOTOK
# - Possuem catalogo online (72.39%) NOTOK
# - Possuem predominância em ter outras bases (62.25%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (90,01%)  NOTOK
# - Maioria dos anos da IES são Faculdade (95.39%)  NOTOK
#
# - Quantidade de técnicos médio baixo (46.05	) NOTOK
# - Quantidade de alunos média de alunos  moderado (1,202.21) NOTOK
# - Corpo docente moderado na  média (60.92) NOTOK
# - Moderada quantidade baixa de cursos (16.76) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relev ncia baixo NOTOK
#
# Insights falsos:
# - A análise cria variaveis que não estão no contexto do projeto.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'sexto', 0.5, 18, 4, 14, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'sexto'))
# Out:
# Para realizar essa análise, vou seguir um método sistemático para entender os fatores que levaram à criação do cluster.
#
# **Passo 1: Carregar e Preparar os Dados**
#
# Primeiramente, carregarei o arquivo CSV fornecido e prepararei os dados para análise. Isso inclui limpezas de dados, remoção de valores nulos e transformações de escalas.
#
# **Passo 2: Identificar as Características Relevantes**
#
# A próxima etapa é identificar as características relevantes que podem estar relacionadas ao agrupamento do cluster. Isso pode ser feito analisando a distribuição dos dados, o número de valores únicos e a relação entre as variáveis.
#
# **Passo 3: Visualização Exploratória**
#
# Vou criar uma visualização exploratória para entender melhor os padrões nos dados. Isso pode incluir gráficos de barras, histogramas, dispersões e outros tipos de gráficos que ajudem a identificar as relações entre as variáveis.
#
# **Passo 4: Análise Estatística**
#
# Agora, vou realizar análises estatísticas para entender melhor os padrões nos dados. Isso pode incluir testes de significância, análises de correlação e testes de associação.
#
# **Passo 5: Identificar os Fatores que Levaram ao Agrupamento**
#
# Com base nas análises anteriores, vou identificar os fatores que podem ter levado à criação do cluster. Isso pode incluir características isoladas ou conjugadas com outras características.
#
# **Análise Geral do Agrupamento**
#
# Depois de analisar as características e realizar análises estatísticas, vou apresentar uma análise geral do agrupamento. Isso inclui:
#
# *   Descrição dos clusters: Quais são os valores típicos das características nos clusters?
# *   Diferenças entre os clusters: Como as características mudam entre os clusters?
# *   Relação entre as variáveis: Qual é a relação entre as características nos clusters?
#
# **Exemplo de Análise**
#
# Suponha que o arquivo CSV forneça as seguintes informações:
#
# | Variaável A | Variaável B |
# | --- | --- |
# | 10 | 20 |
# | 15 | 30 |
# | 20 | 40 |
# | 25 | 50 |
#
# A característica `Variaável A` parece estar relacionada à `Variaública B`, pois há uma tendência crescente na segunda variável a medida que aumenta a primeira.
#
# Além disso, a análise estatística revelou que a média de `Variaível A` é de 20 e a média de `Variaível B` é de 30. Isso sugere que os valores mais altos da primeira variável estão associados aos valores mais altos da segunda.
#
# A visualização exploratória também revelou uma tendência na dispersão dos dados, indicando que os pontos estão se agrupando em regiões específicas do plano de coordenação.
#
# **Conclusão**
#
# Com base nas análises realizadas, pode-se concluir que a `Variaível A` é uma característica fundamental para o agrupamento do cluster. A relação entre as variáveis e a tendência crescente na segunda variável sugerem que os valores mais altos da primeira variável estão associados aos valores mais altos da segunda.
#
# Em resumo, a análise revelou que a `Variaível A` é um fator chave para o agrupamento do cluster.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%)  NOTOK
# - Predominância das IES não estarem numa capital (69.21%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (73.15%) NOTOK
# - Predominância das Instituições sem repositorio institucional (68.00%) NOTOK
# - Possuem predominância em busca integrada (65.43%) NOTOK
# - Possuem serviço de internet (90.62%) NOTOK
# - Predominância em participar em redes sociais (65.28%) NOTOK
# - Possuem catalogo online (72.39%) NOTOK
# - Possuem predominância em ter outras bases (62.25%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (90,01%)  OK
# - Maioria dos anos da IES são Faculdade (95.39%) OK
#
# - Quantidade de técnicos médio baixo (46.05	) NOTOK
# - Quantidade de alunos média de alunos  moderado (1,202.21) NOTOK
# - Corpo docente moderado na  média (60.92) NOTOK
# - Moderada quantidade baixa de cursos (16.76) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixo NOTOK
#
# Insights falsos:
# - Suposições incondizentes com a realidade;
# - A análsie não é feita para as avariaveis e sim sobre uma suposta distribuição do cluster.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'sexto', 1.0, 18, 3, 15, 0, 0]

# %% [markdown]
# ### Seventh Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'setimo'))
# Out:
# Entendo que você gostaria que eu analise um arquivo CSV fornecido e identifique os fatores que levaram à criação do cluster. Para isso, precisamos seguir uma cadeia de pensamentos para entender o comportamento dos dados.
#
# Primeiramente, é fundamental entender o que é um cluster em análise de clustering. Um cluster é um agrupamento de pontos próximos uns dos outros no espaço de características, onde os pontos não são afins e não têm relações entre si. Os clusters podem ser formados por uma variedade de técnicas, incluindo a aglomeragem, a hierarquia, o k-medoids e a densidade.
#
# Antes de começarmos a analisar o arquivo CSV, é importante saber qual técnica foi utilizada para criar o cluster. Infelizmente não tenho acesso ao código utilizado no procedimento, portanto farei apenas uma análise geral dos agrupamentos que se encontram no arquivo e farei um levantamento de possíveis fatores que podem ter influenciado a formação do cluster.
#
# O primeiro passo é analisar as características do conjunto de dados. Isso inclui verificar a distribuição das características, a simetria da distribuição e a presença de outliers ou pontos anormais. Uma característica importante é a média, que representa o valor central dos dados. Outras características importantes são a variância, a amplitude e a densidade.
#
# Para entender melhor os dados, é preciso analisar as características por si sós e fazer uma análise de variação ou variancia estatística para verificar se há algum padrão ou tendência que possa ajudar na análise do cluster.
#
# Além disso, é preciso observar o conjunto como um todo e observar se há algum padrão ou tendência que possa ser identificada de uma forma geral.
#
# É importante notar que a formação de clusters é influenciada por muitos fatores, incluindo a escolha dos métodos de aglomeragem, os critérios utilizados para avaliar a qualidade do cluster, as características utilizadas como variáveis, etc. Isso significa que o mesmo conjunto de dados pode gerar diferentes clusters com diferentes técnicas e critérios.
#
# Uma vez identificado o conjunto de dados e suas características, é preciso entender o que está acontecendo. Por exemplo, se as características são discretas (ou seja, podem ser classificadas como catóricas) ou contínuas (ou seja, podem ser medidas), isso pode ajudar a entender melhor como o cluster foi formado.
#
# Outro fator importante é entender se há algum padrão ou tendência na distribuição das características. Por exemplo, se as características são simétricas em torno de uma média, isso pode indicar que a formação do cluster não está influenciada por um ponto específico ou anomalia.
#
# Ainda, a presença ou não da variabilidade estatística dos dados também é importante para entender como o cluster foi formado. A variabilidade estatística é medida pelo coefficiente de variação, que representa a razão entre a desvios padrão e a média de cada variável.
#
# Observando as características e sua relação com o conjunto de dados, fica claro que os pontos do cluster foram agrupados de forma que possam se relacionar uns com outros.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%) NOTOK
# - Predominância das Instituições com acesso ao portal Capes (87.76%) NOTOK
# - Predominância das Instituições com repositorio institucional (70.41%)  NOTOK
# - Possuem predominância em busca integrada (67.18%) NOTOK
# - Possuem serviço de internet (98.81%) NOTOK
# - Predominância em participar em redes sociais (71.94%)  NOTOK
# - Possuem catalogo online (92.69%)  NOTOK
# - Possuem predominância em ter outras bases (91.16%)  NOTOK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%)  NOTOK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%)  NOTOK
#
# - Quantidade de técnicos médio alto (1,170.62	) NOTOK
# - Quantidade de alunos média de alunos alto (27,666.31) NOTOK
# - Corpo docente alto na  média (970.69) NOTOK
# - altga quantidade baixa de cursos (73.91) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - Detalha uma etapa de análise dos clusters, mas não analisa o cluster.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'setimo', 0, 16, 7, 9, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'setimo'))
# Out:
# Vou te guiar através do processo de análise de dados para entender o agrupamento em questão.
#
# Primeiramente, é importante lembrar que a análise de cluster é uma técnica estatística usada para identificar padrões ou estruturas não visíveis nos dados. O objetivo é dividir os dados em subconjuntos (clusters) com características semelhantes entre si.
#
# **Passo 1: Preparação dos Dados**
#
# Ao receber o CSV, a primeira coisa que faço é verificar se ele está bem estruturado e se as colunas estão sendo separadas corretamente. Nesse caso, suponho que as instâncias do cluster estarão em uma única linha, com todas as características separadas por vírgulas.
#
# **Passo 2: Exploração dos Dados**
#
# Em seguida, faço uma exploração dos dados para entender a distribuição das características e identificar possíveis tendências ou padrões. Isso inclui:
#
# *   Análise de medidas centrais (média, média deslocada, mediana) e dispersão (desvio padrão, interquartilidade).
# *   Gráficos de distribuição para visualizar a forma como cada característica está se comportando.
# *   Relacionamentos entre as características, buscando identificar conjuntos de características que estão relacionadas.
#
# **Passo 3: Seleção de Características**
#
# Com base na exploração dos dados, escolho as características mais relevantes para analisar em seguida. Isso pode incluir características continuas (como idade ou altura) ou categoricas (como gênero ou idade).
#
# **Passo 4: Algoritmo de Clusterização**
#
# Agora que temos os dados preparados e selecionados, escolho um algoritmo de clusterização para identificar os clusters. Os algoritmos mais comuns incluem:
#
# *   Clustering K-Means
# *   Hierarquia de Cluster
# *   Clustering DBSCAN
#
# **Passo 5: Avaliação dos Resultados**
#
# Após executar o algoritmo de clusterização, avalio os resultados para determinar a qualidade e relevância dos clusters. Isso pode incluir:
#
# *   Coeficiente de Silhouette para avaliar a separação entre os clusters.
# *   Índice de Calinski-Lowellyn para avaliar a qualidade do cluster.
# *   Gráficos de clusterização para visualizar os resultados.
#
# **Análise Geral**
#
# Ao analisar os dados estatísticos, percebo que o cluster em questão está concentrado em características específicas. As instâncias mais próximas estão relacionadas entre si e têm valores semelhantes em várias características. Isso sugere que as características selecionadas são relevantes para definir o agrupamento.
#
# Além disso, noto que há uma característica dominante dentro do cluster, que parece estar relacionada com a idade dos indivíduos. As instâncias mais próximas têm valores altos em relação à idade, enquanto as instâncias menos próximas têm valores mais baixos.
#
# Em resumo, o agrupamento está concentrado em características específicas, como idade, e há uma característica dominante que parece estar relacionada com essa característica.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%) NOTOK
# - Predominância das Instituições com acesso ao portal Capes (87.76%) NOTOK
# - Predominância das Instituições com repositorio institucional (70.41%) NOTOK
# - Possuem predominância em busca integrada (67.18%)  NOTOK
# - Possuem serviço de internet (98.81%)  NOTOK
# - Predominância em participar em redes sociais (71.94%)  NOTOK
# - Possuem catalogo online (92.69%) NOTOK
# - Possuem predominância em ter outras bases (91.16%)
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%)  NOTOK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%)  NOTOK
#
# - Quantidade de técnicos médio alto (1,170.62	) NOTOK
# - Quantidade de alunos média de alunos alto (27,666.31) NOTOK
# - Corpo docente alto na  média (970.69) NOTOK
# - altga quantidade baixa de cursos (73.91) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - A análise feita é da distribuição do cluster, mas não das características do cluster.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'setimo', 0.5, 16, 7, 9, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'setimo'))
# Out:
# Entendo que você deseja que eu analise um conjunto de dados em formato CSV para identificar os fatores que levaram à criação de um determinado cluster. Vou seguir uma cadeia de pensamento lógica para alcançar essa análise.
#
# **Passo 1: Carregar e Preparar os Dados**
#
# O primeiro passo é carregar o conjunto de dados em formato CSV e prepará-lo para a análise. Isso inclui converter as colunas numéricas em tipo "número" e remover quaisquer valores nulos ou duplicados.
#
# **Passo 2: Visualização Inicial**
#
# Agora que os dados estão preparados, é importante visualizá-los inicialmente para entender a distribuição geral das características. Isso pode incluir gráficos de barras, histogramas e scatter plots para cada característica individual. Essa etapa ajuda a identificar quais são as variáveis mais relevantes e se há algum padrão ou tendência aparente.
#
# **Passo 3: Análise de Correlação**
#
# A próxima etapa é analisar a correlação entre as características individuais para entender como elas estão relacionadas. Isso pode ser feito utilizando a matemática estatística, especialmente a análise de variancia e regressão linear simples. Essa análise ajuda a identificar quais características são conjugadas ou independentes entre si.
#
# **Passo 4: Análise de Cluster**
#
# Agora que temos uma boa compreensão das características individuais e sua correlação, podemos começar a analisar o cluster em questão. Isso inclui entender a estrutura do cluster, o número de subclasses (se aplicável), os critérios de separação entre os agrupamentos e quais características são mais relevantes para definir essas subclasses.
#
# **Passo 5: Análise Estatística**
#
# A última etapa é realizar análises estatísticas adicionais para reforçar as conclusões da análise anterior. Isso pode incluir testes de hipótese (por exemplo, ANOVA) e modelos estatísticos (como cluster analysis). Essa análise ajuda a confimar ou refutar os padrões observados nos dados.
#
# **Análise Geral do Agrupamento**
#
# Após realizar todas as etapas acima, podemos fazer uma análise geral do agrupamento. Nesse momento, podemos dizer qual foi o fator que levou à criação do cluster e quais características são mais relevantes para definir essas subclasses.
#
# No final, minha cadeia de pensamento é a seguinte:
#
# - Carregar e preparar os dados.
# - Visualizar inicialmente as características individuais.
# - Analisar a correlação entre as características individuais.
# - Analisar o cluster em questão.
# - Realizar análises estatísticas adicionais.
#
# Essa cadeia de pensamento permite que eu obtenha uma compreensão detalhada dos agrupamentos e identifique os fatores que levaram à criação do cluster.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%) NOTOK
# - Predominância das Instituições com acesso ao portal Capes (87.76%)  NOTOK
# - Predominância das Instituições com repositorio institucional (70.41%)  NOTOK
# - Possuem predominância em busca integrada (67.18%)  NOTOK
# - Possuem serviço de internet (98.81%)  NOTOK
# - Predominância em participar em redes sociais (71.94%)  NOTOK
# - Possuem catalogo online (92.69%)  NOTOK
# - Possuem predominância em ter outras bases (91.16%)  NOTOK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%)  NOTOK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%)  NOTOK
#
# - Quantidade de técnicos médio alto (1,170.62	) NOTOK
# - Quantidade de alunos média de alunos alto (27,666.31) NOTOK
# - Corpo docente alto na  média (970.69) NOTOK
# - altga quantidade baixa de cursos (73.91) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights:
# - A análise cria outras variaveis fora do contexto do cluster.

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'setimo', 1.0, 16, 9, 7, 3, 0]

# %% [markdown]
# # K-means

# %% [markdown]
# ### Fase 4

# %%
analise_kmeans_fase4 = pd.DataFrame([], columns=['prompt', 'cluster', 'temperature', 'Total_suposições', 'Mapeadas_pelo_modelo', 'Ignoradas_pelo_modelo', 'alucinação_do_modelo', 'insights'])

# %%
kmeans_fase4 = pd.read_csv('Models/results/K-means_Fase 4_results.csv')

# %%
kmeans_fase4.loc[(kmeans_fase4['temperature'] == 1) & (kmeans_fase2['cluster'] == 'primeiro'), ['result']]['result'].tolist()[0]
# Out:
# '**QT_ALUNOS**\n\n* Analise estatística: A média da variável QT_ALUNOS é de 500,00 alunos. A mediana é de 450,00 alunos e a moda não é estatisticamente significativa.\n* Relação com outra variável: Existem um padrão de crescimento linear entre a quantidade de alunos e a quantidade de cursos. Isso sugere que as instituições com mais alunos tendem a ter mais cursos.\n\n**QT_DOCENTES**\n\n* Analise estatística: A média da variável QT_DOCENTES é de 200,00 docentes. A mediana é de 180,00 docentes e a moda não é estatisticamente significativa.\n* Relação com outra variável: Existem um padrão de inversão entre a quantidade de docentes e a quantidade de receita da instituição. Isso sugere que as instituições com mais docentes tendem a ter menos receita.\n\n**QT_CURSO**\n\n* Analise estatística: A média da variável QT_CURSO é de 20,00 cursos. A mediana é de 15,00 cursos e a moda não é estatisticamente significativa.\n* Relação com outra variável: Existem um padrão de positividade entre a quantidade de cursos e a quantidade de receita da instituição. Isso sugere que as instituições com mais cursos tendem a ter mais receita.\n\n**QT_TEC_TOTAL**\n\n* Analise estatística: A média da variável QT_TEC_TOTAL é de 30,00 técnicos. A mediana é de 25,00 técnicos e a moda não é estatisticamente significativa.\n* Relação com outra variável: Existem um padrão de inversão entre a quantidade de técnicos e a quantidade de receita da instituição. Isso sugere que as instituições com mais técnicos tendem a ter menos receita.\n\n**QT_PERIODICO_ELETRONICO**\n\n* Analise estatística: A média da variável QT_PERIODICO_ELETRONICO é de 50,00 periodicos eletronicos. A mediana é de 40,00 periodicos eletronicos e a moda não é estatisticamente significativa.\n* Relação com outra variável: Existem um padrão de positividade entre a quantidade de periodicos eletronicos e a quantidade de receita da instituição. Isso sugere que as instituições com mais periodicos eletronicos tendem a ter mais receita.\n\n**QT_LIVRO_ELETRONICO**\n\n* Analise estatística: A média da variável QT_LIVRO_ELETRONICO é de 20,00 livros eletronicos. A mediana é de 15,00 livros eletronicos e a moda não é estatisticamente significativa.\n* Relação com outra variável: Existem um padrão de positividade entre a quantidade de livros eletronicos e a quantidade de receita da instituição. Isso sugere que as instituições com mais livros eletronicos tendem a ter mais receita.\n\n**T1_VL_RECEITAS**\n\n* Analise estatística: A média da variável T1_VL_RECEITAS é de 1000,00 reais. A mediana é de 800,00 reais e a moda não é estatisticamente significativa.\n* Relação com outra variável: Existem um padrão de positividade entre a quantidade de receita da instituição e a quantidade de cursos. Isso sugere que as instituições com mais cursos tendem a ter mais receita.\n\n**T1_VL_DESPESAS**\n\n* Analise estatística: A média da variável T1_VL_DESPESAS é de 500,00 reais. A mediana é de 400,00 reais e a moda não é estatisticamente significativa.\n* Relação com outra variável: Existem um padrão de inversão entre a quantidade de despesa da instituição e a quantidade de receita da instituição. Isso sugere que as instituições com mais despesas tendem a ter menos receita.\n\n**IN_CAPITAL**\n\n* Analise estatística: A frequência de IN_CAPITAL é de 50,00%.\n* Relação com outra variável: Existem um padrão de positividade entre o status de capital e a quantidade de receita da instituição. Isso sugere que as instituições no capital tendem a ter mais receita.\n\n**IN_OUTRAS_BASES**\n\n* Analise estatística: A frequência de IN_OUTRAS_BASES é de 30,00%.\n* Relação com outra variável: Existem um padrão de positividade entre o uso de outras bases e a quantidade de receita da instituição. Isso sugere que as instituições que usam outras bases tendem a ter mais receita.\n\n**IN_REPOSITORIO_INSTITUCIONAL**\n\n* Analise estatística: A frequência de IN_REPOSITORIO_INSTITUCIONAL é de 20,00%.\n* Relação com outra variável: Existem um padrão de po ...

# %%
analise_kmeans_fase4
# Out:
#     prompt   cluster  temperature  Total_suposições  Mapeadas_pelo_modelo  \
# 0   Fase 4  primeiro         0.00                15                     7
# 1   Fase 4  primeiro         0.50                15                     9
# 2   Fase 4  primeiro         1.00                15                     9
# 3   Fase 4   segundo         0.00                17                     2
# 4   Fase 4   segundo         0.50                17                     4
# 5   Fase 4   segundo         1.00                17                     4
# 6   Fase 4  terceiro         0.00                15                     2
# 7   Fase 4  terceiro         0.50                15                     5
# 8   Fase 4  terceiro         1.00                15                     5
# 9   Fase 4    quarto         0.00                17                     3
# 10  Fase 4    quarto         0.50                17                     7
# 11  Fase 4    quarto         1.00                17                     4
# 12  Fase 4    quinto         0.00                16                     4
# 13  Fase 4    quinto         0.50                16                     5
# 14  Fase 4    quinto         1.00                16                     6
# 15  Fase 4     sexto         0.00                18                     9
# 16  Fase 4     sexto         0.50                18                     4
# 17  Fase 4     sexto         1.00                18                     3
# 18  Fase 4    setimo         0.00                16                     7
# 19  Fase 4    setimo         0.50                16                     7
# 20  Fase 4    setimo         1.00                16                     9
#
#     Ignoradas_pelo_modelo  alucinação_do_modelo  insights
# 0                       8                     1         0
# 1                       6                     2         0
# 2                       6                     2         0
# 3                      15                     4         0
# 4                      13                     2         0
# 5                      13                     2         0
# 6                      13                     3         1
# 7                      10                     2         4
# 8                      10                     2         4
# 9                      14                     3         2
# 10                     10                     3         0
# 11                     13                     3         1
# 12                     12                     3         0
# 13                     11                     3         1
# 14                     10                     1         0
# 15                      9                     1         0
# 16                     14                     1         0
# 17                     15                     0         0
# 18                      9                     1         0
# 19                      9                     1         0
# 20                      7                     3         0

# %%
analise_kmeans_fase4.to_csv('analise_kmeans_fase4.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### First Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'primeiro'))
# Out:
# **QT_ALUNOS**:
#  - Analise estatística: média da variável é 200,00 e a mediana é 180,00 com um modo de 100.
#  - Relação com outra variável: Verificar a relação entre o número de alunos e o tamanho do quadro-rio.
#
# **QT_DOCENTES**:
#  - Analise estatística: média da variável é 30,00 e a mediana é 20,00 com um modo de 10.
#  - Relação com outra variável: Verificar a relação entre o número de docentes e a quantidade de cursos oferecidos.
#
# **QT_CURSO**:
#  - Analise estatística: média da variável é 40,00 e a mediana é 30,00 com um modo de 20.
#  - Relação com outra variável: Verificar a relação entre o número de cursos e o tamanho do quadro-rio.
#
# **QT_TEC_TOTAL**:
#  - Analise estatística: média da variável é 60,00 e a mediana é 50,00 com um modo de 30.
#  - Relação com outra variável: Verificar a relação entre o número de técnicos e o tamanho do quadro-rio.
#
# **QT_PERIODICO_ELETRONICO**:
#  - Analise estatística: média da variável é 100,00 e a mediana é 80,00 com um modo de 50.
#  - Relação com outra variável: Verificar a relação entre o número de periodicos eletronicos e o tamanho do quadro-rio.
#
# **QT_LIVRO_ELETRONICO**:
#  - Analise estatística: média da variável é 80,00 e a mediana é 60,00 com um modo de 30.
#  - Relação com outra variável: Verificar a relação entre o número de livros eletronicos e o tamanho do quadro-rio.
#
# **T1_VL_RECEITAS**:
#  - Analise estatística: média da variável é 200.000,00 e a mediana é 150.000,00 com um modo de 50.000,00.
#  - Relação com outra variável: Verificar a relação entre o valor de receita e o tamanho do quadro-rio.
#
# **T1_VL_DESPESAS**:
#  - Analise estatística: média da variável é 100.000,00 e a mediana é 50.000,00 com um modo de 20.000,00.
#  - Relação com outra variável: Verificar a relação entre o valor de despesa e o tamanho do quadro-rio.
#
# **IN_CAPITAL**:
#  - Analise estatística: 70% das instituições têm capital.
#  - Relação com outra variável: Verificar a relação entre o número de instituições com capital e o número de instituições sem capital.
#
# **IN_OUTRAS_BASES**:
#  - Analise estatística: 60% das instituições têm outras bases.
#  - Relação com outra variável: Verificar a relação entre o número de instituições com outras bases e o tamanho do quadro-rio.
#
# **IN_REPOSITORIO_INSTITUCIONAL**:
#  - Analise estatística: 90% das instituições têm repositorio institucional.
#  - Relação com outra variável: Verificar a relação entre o número de instituições com repositorio e o tamanho do quadro-rio.
#
# **IN_BUSCA_INTEGRADA**:
#  - Analise estatística: 80% das instituições têm busca integrada.
#  - Relação com outra variável: Verificar a relação entre o número de instituições com busca integrada e o tamanho do quadro-rio.
#
# **IN_SERVICO_INTERNET**:
#  - Analise estatística: 95% das instituições têm serviço de internet.
#  - Relação com outra variável: Verificar a relação entre o número de instituições com serviço de internet e o tamanho do quadro-rio.
#
# **IN_PARTICIPA_REDE_SOCIAL**:
#  - Analise estatística: 70% das instituições participam das redes sociais.
#  - Relação com outra variável: Verificar a relação entre o número de instituições que participam das redes sociais e o tamanho do quadro-rio.
#
# **IN_CATALOGO_ONLINE**:
#  - Analise estatística: 90% das instituições têm catalogo online.
#  - Relação com outra variável: Verificar a relação entre o número de instituições com catalogo online e o tamanho do quadro-rio.
#
# **IN_ACESSO_PORTAL_CAPES**:
#  - Analise estatística: 95% das instituições têm acesso ao portal CAPES.
#  - Relação com outra variável: Verificar a relação entre o número de instituições que têm acesso ao portal CAPES e o tamanho do quadro-rio.
#
# **NU_ANO_CENSO**:
#  - Analise estatística: A média dos anos de censo é de 2000,00.
#  - Relação com outra variável: Verificar a relação entre o ano de censo e o tamanho do quadro-rio.
#
# **CO_REGIAO**:
#  - Analise estatística: As instituições estão distribuídas em diferentes regiões.
#  - Relação com outra variável: Verificar a relação entre o número de instituições por região e o tamanho do quadro-rio.
#
# **NOME_CATEGORIA_ADMINISTRATIVA**:
#  - Analise estatística: As instituições estão classificadas em diferentes categorias administrativas.
#  - Relação com outra variável: Verificar a relação entre a categoria administrativa das instituições e o tamanho do quadro-rio.
#
# **NOME_ORGANIZACAO_ACADEMICA**:
#  - Analise estatística: As instituições estão associadas a diferentes organizações acadêmicas.
#  - Relação com outra variável: Verificar a relação entre a organização acadêmica das instituições e o tamanho do quadro-rio.
#
# Ao analisar esses dados, é possível identificar tendências e relações entre as variáveis, que podem ser úteis para entender melhor as características das instituições de ensino superior.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%) NOT OK
# - Uma incidência das IES não estarem numa capital (59,78%) NOT OK
# - Instituições com acesso ao portal Capes (87.34%) NOT OK
# - Possuem serviço de internet (94.97%) NOT OK
# - Participam em redes sociais (71.51%) NOT OK
# - Possuem catalogo online (86.22%) NOT OK
# - Busca integrada (58.29%) NOT OK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%) NOT OK
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%) NOT OK
#
# - Quantidade alta de técnicos na média (765.03) NOT OK
# - Quantidade de alunos média de alunos alto (12,553.95) NOT OK
# - Corpo docente forte na média (761.73) NOT OK
# - Quantidade considerável de cursos na média (média de 52.45) NOT OK
# - Despesas e receitas média moderadas NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa OK
#
# InsightS:
# - A análise trouxe  variaveis relevantes condizentes com a base de dados, mas não detalha a importancia no cluster

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4', 'primeiro', 0, 15, 7, 8, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'primeiro'))
# Out:
# **Análise Estatística**
#
# A seguir, apresento as análises estatísticas das variáveis para cada uma das colunas do CSV:
#
# * **QT_ALUNOS**:
#  + Média: 150
#  + Mediana: 120
#  + Moda: 100
#  + Relação com T1_VL_RECEITAS: Positiva, com uma média de 3000
#  + Relação com NOME_CATEGORIA_ADMINISTRATIVA: Positiva, com uma maior frequência em instituições públicas
# * **QT_DOCENTES**:
#  + Média: 80
#  + Mediana: 60
#  + Moda: 50
#  + Relação com T1_VL_RECEITAS: Negativa, com uma média de -1000
#  + Relação com IN_OUTRAS_BASES: Positiva, com uma maior frequência em instituições que têm outras bases
# * **QT_CURSO**:
#  + Média: 30
#  + Mediana: 20
#  + Moda: 10
#  + Relação com NOME_ORGANIZACAO_ACADEMICA: Positiva, com uma maior frequência em universidades públicas
# * **QT_TEC_TOTAL**:
#  + Média: 100
#  + Mediana: 80
#  + Moda: 60
#  + Relação com IN_REPOSITORIO_INSTITUCIONAL: Positiva, com uma maior frequência em instituições que têm repositorio institucional
# * **QT_PERIODICO_ELETRONICO**:
#  + Média: 10
#  + Mediana: 5
#  + Moda: 0
#  + Relação com IN_BUSCA_INTEGRADA: Positiva, com uma maior frequência em instituições que têm busca integrada
# * **QT_LIVRO_ELETRONICO**:
#  + Média: 20
#  + Mediana: 10
#  + Moda: 0
#  + Relação com IN_CATALOGO_ONLINE: Positiva, com uma maior frequência em instituições que têm catalogo online
# * **T1_VL_RECEITAS**:
#  + Média: 10000
#  + Mediana: 8000
#  + Moda: 6000
#  + Relação com QT_ALUNOS e QT_DOCENTES: Positiva, com uma maior frequência em instituições que têm mais alunos e docentes
# * **T1_VL_DESPESAS**:
#  + Média: 5000
#  + Mediana: 3000
#  + Moda: 1000
#  + Relação com QT_ALUNOS e QT_DOCENTES: Negativa, com uma média de -2000
# * **IN_CAPITAL**:
#  + Média: 40%
#  + Mediana: 30%
#  + Moda: 20%
#  + Relação com NOME_CATEGORIA_ADMINISTRATIVA: Positiva, com uma maior frequência em instituições públicas e universidades públicas
# * **IN_OUTRAS_BASES**:
#  + Média: 60%
#  + Mediana: 50%
#  + Moda: 40%
#  + Relação com T1_VL_RECEITAS: Positiva, com uma média de 2000
# * **IN_REPOSITORIO_INSTITUCIONAL**:
#  + Média: 80%
#  + Mediana: 70%
#  + Moda: 60%
#  + Relação com QT_TEC_TOTAL: Positiva, com uma maior frequência em instituições que têm mais técnicos
# * **IN_BUSCA_INTEGRADA**:
#  + Média: 40%
#  + Mediana: 30%
#  + Moda: 20%
#  + Relação com QT_PERIODICO_ELETRONICO: Positiva, com uma maior frequência em instituições que têm mais periodicos eletronicos
# * **IN_SERVICO_INTERNET**:
#  + Média: 90%
#  + Mediana: 80%
#  + Moda: 70%
#  + Relação com IN_CATALOGO_ONLINE: Positiva, com uma maior frequência em instituições que têm catalogo online
# * **IN_PARTICIPA_REDE_SOCIAL**:
#  + Média: 50%
#  + Mediana: 40%
#  + Moda: 30%
#  + Relação com IN_SERVICO_INTERNET: Positiva, com uma maior frequência em instituições que têm serviço de internet
# * **IN_CATALOGO_ONLINE**:
#  + Média: 60%
#  + Mediana: 50%
#  + Moda: 40%
#  + Relação com QT_LIVRO_ELETRONICO: Positiva, com uma maior frequência em instituições que têm mais livros eletronicos
# * **IN_ACESSO_PORTAL_CAPES**:
#  + Média: 80%
#  + Mediana: 70%
#  + Moda: 60%
#  + Relação com NOME_ORGANIZACAO_ACADEMICA: Positiva, com uma maior frequência em universidades públicas
# * **NU_ANO_CENSO**:
#  + Média: 2000
#  + Mediana: 1800
#  + Moda: 1600
#  + Relação com NOME_CATEGORIA_ADMINISTRATIVA: Positiva, com uma maior frequência em instituições públicas e universidades públicas
# * **CO_REGIAO**:
#  + Média: 1
#  + Mediana: 2
#  + Moda: 3
#  + Relação com IN_CAPITAL: Negativa, com uma média de -0,5
#
# **Inferências**
#
# Com base nos resultados das análises estatísticas, podemos concluir que:
#
# * As instituições com mais alunos e docentes tendem a ter receitas mais altas.
# * As instituições públicas têm mais chances de ter mais alunos e docentes do que as privadas.
# * As instituições que têm mais técnicos também têm mais chances de ter um repositorio institucional.
# * As instituições com mais periodicos eletronicos têm mais chances de ter uma busca integrada.
# * As instituições com serviço de internet têm mais chances de ter um catalogo online e mais livros eletronicos.
# * As instituições que têm mais alunos e docentes também tendem a ter receitas mais altas.
#
# **Conclusão**
#
# Com base nos resultados das análises estatísticas, podemos concluir que as instituições com mais alunos e docentes tendem a ter receitas mais altas e ser mais ativas em termos de tecnologia e busca integrada. As instituições públicas também tendem a ter mais chances de ter mais alunos e docentes do que as privadas. No entanto, é importante notar que existem muitas variáveis que podem influenciar as receitas das instituições, como o tamanho da população local, a economia regional e a política educacional.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%)  NOT OK
# - Uma incidência das IES não estarem numa capital (59,78%)  NOT OK
# - Instituições com acesso ao portal Capes (87.34%) NOT OK
# - Possuem serviço de internet (94.97%) OK
# - Participam em redes sociais (71.51%) NOT OK
# - Possuem catalogo online (86.22%) NOT OK
# - Busca integrada (58.29%) NOT OK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%) OK
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%) NOT OK
#
# - Quantidade alta de técnicos na média (765.03) NOT OK
# - Quantidade de alunos média de alunos alto (12,553.95) OK
# - Corpo docente forte na média (761.73) OK
# - Quantidade considerável de cursos na média (média de 52.45)  NOT OK
# - Despesas e receitas média moderadas OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOT OK
#
# Insights:
# - A análise trás uma relaçãoe ntre universidade públicas e o número de docentes onde os alunos tem mais chance de vir a ser docente quando são de uma universidade pública.

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'primeiro', 0.5, 15, 9, 6, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'primeiro'))
# Out:
# **QT_ALUNOS**
#
# * Analise estatística: A média da variável QT_ALUNOS é de 500,00 alunos. A mediana é de 450,00 alunos e a moda não é estatisticamente significativa.
# * Relação com outra variável: Existem um padrão de crescimento linear entre a quantidade de alunos e a quantidade de cursos. Isso sugere que as instituições com mais alunos tendem a ter mais cursos.
#
# **QT_DOCENTES**
#
# * Analise estatística: A média da variável QT_DOCENTES é de 200,00 docentes. A mediana é de 180,00 docentes e a moda não é estatisticamente significativa.
# * Relação com outra variável: Existem um padrão de inversão entre a quantidade de docentes e a quantidade de receita da instituição. Isso sugere que as instituições com mais docentes tendem a ter menos receita.
#
# **QT_CURSO**
#
# * Analise estatística: A média da variável QT_CURSO é de 20,00 cursos. A mediana é de 15,00 cursos e a moda não é estatisticamente significativa.
# * Relação com outra variável: Existem um padrão de positividade entre a quantidade de cursos e a quantidade de receita da instituição. Isso sugere que as instituições com mais cursos tendem a ter mais receita.
#
# **QT_TEC_TOTAL**
#
# * Analise estatística: A média da variável QT_TEC_TOTAL é de 30,00 técnicos. A mediana é de 25,00 técnicos e a moda não é estatisticamente significativa.
# * Relação com outra variável: Existem um padrão de inversão entre a quantidade de técnicos e a quantidade de receita da instituição. Isso sugere que as instituições com mais técnicos tendem a ter menos receita.
#
# **QT_PERIODICO_ELETRONICO**
#
# * Analise estatística: A média da variável QT_PERIODICO_ELETRONICO é de 50,00 periodicos eletronicos. A mediana é de 40,00 periodicos eletronicos e a moda não é estatisticamente significativa.
# * Relação com outra variável: Existem um padrão de positividade entre a quantidade de periodicos eletronicos e a quantidade de receita da instituição. Isso sugere que as instituições com mais periodicos eletronicos tendem a ter mais receita.
#
# **QT_LIVRO_ELETRONICO**
#
# * Analise estatística: A média da variável QT_LIVRO_ELETRONICO é de 20,00 livros eletronicos. A mediana é de 15,00 livros eletronicos e a moda não é estatisticamente significativa.
# * Relação com outra variável: Existem um padrão de positividade entre a quantidade de livros eletronicos e a quantidade de receita da instituição. Isso sugere que as instituições com mais livros eletronicos tendem a ter mais receita.
#
# **T1_VL_RECEITAS**
#
# * Analise estatística: A média da variável T1_VL_RECEITAS é de 1000,00 reais. A mediana é de 800,00 reais e a moda não é estatisticamente significativa.
# * Relação com outra variável: Existem um padrão de positividade entre a quantidade de receita da instituição e a quantidade de cursos. Isso sugere que as instituições com mais cursos tendem a ter mais receita.
#
# **T1_VL_DESPESAS**
#
# * Analise estatística: A média da variável T1_VL_DESPESAS é de 500,00 reais. A mediana é de 400,00 reais e a moda não é estatisticamente significativa.
# * Relação com outra variável: Existem um padrão de inversão entre a quantidade de despesa da instituição e a quantidade de receita da instituição. Isso sugere que as instituições com mais despesas tendem a ter menos receita.
#
# **IN_CAPITAL**
#
# * Analise estatística: A frequência de IN_CAPITAL é de 50,00%.
# * Relação com outra variável: Existem um padrão de positividade entre o status de capital e a quantidade de receita da instituição. Isso sugere que as instituições no capital tendem a ter mais receita.
#
# **IN_OUTRAS_BASES**
#
# * Analise estatística: A frequência de IN_OUTRAS_BASES é de 30,00%.
# * Relação com outra variável: Existem um padrão de positividade entre o uso de outras bases e a quantidade de receita da instituição. Isso sugere que as instituições que usam outras bases tendem a ter mais receita.
#
# **IN_REPOSITORIO_INSTITUCIONAL**
#
# * Analise estatística: A frequência de IN_REPOSITORIO_INSTITUCIONAL é de 20,00%.
# * Relação com outra variável: Existem um padrão de positividade entre o uso do repositorio institucional e a quantidade de receita da instituição. Isso sugere que as instituições que usam o repositorio institucional tendem a ter mais receita.
#
# **IN_BUSCA_INTEGRADA**
#
# * Analise estatística: A frequência de IN_BUSCA_INTEGRADA é de 10,00%.
# * Relação com outra variável: Existem um padrão de positividade entre o uso da busca integrada e a quantidade de receita da instituição. Isso sugere que as instituições que usam a busca integrada tendem a ter mais receita.
#
# **IN_SERVICO_INTERNET**
#
# * Analise estatística: A frequência de IN_SERVICO_INTERNET é de 80,00%.
# * Relação com outra variável: Existem um padrão de positividade entre o uso do serviço internet e a quantidade de receita da instituição. Isso sugere que as instituições que usam o serviço internet tendem a ter mais receita.
#
# **IN_OUTRO**
#
# * Analise estatística: A frequência de IN_OUTRO é de 20,00%.
# * Relação com outra variável: Existem um padrão de positividade entre o uso de outras opções e a quantidade de receita da instituição. Isso sugere que as instituições que usam outras opções tendem a ter mais receita.
#
# **TABELA RESUMIDA**
#
# | Variável | Média | Mediana | Moda |
# | --- | --- | --- | --- |
# | T1_VL_RECEITAS | 1000,00 | 800,00 | - |
# | T1_VL_DESPESAS | 500,00 | 400,00 | - |
# | IN_CAPITAL | 50,00% | - | - |
# | IN_OUTRAS_BASES | 30,00% | - | - |
# | IN_REPOSITORIO_INSTITUCIONAL | 20,00% | - | - |
# | IN_BUSCA_INTEGRADA | 10,00% | - | - |
# | IN_SERVICO_INTERNET | 80,00% | - | - |
#
# Nota: as frequências de IN_CAPITAL, IN_OUTRAS_BASES, IN_REPOSITORIO_INSTITUCIONAL e IN_BUSCA_INTEGRADA são expressas em porcentagem.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%)  NOT OK
# - Uma incidência das IES não estarem numa capital (59,78%) NOT OK
# - Instituições com acesso ao portal Capes (87.34%) NOT OK
# - Possuem serviço de internet (94.97%) NOT OK
# - Participam em redes sociais (71.51%) NOT OK
# - Possuem catalogo online (86.22%) NOT OK
# - Busca integrada (58.29%) NOT OK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%)
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%)
#
# - Quantidade alta de técnicos na média (765.03) OK
# - Quantidade de alunos média de alunos alto (12,553.95)
# - Corpo docente forte na média (761.73) OK
# - Quantidade considerável de cursos na média (média de 52.45) NOT OK
# - Despesas e receitas média moderadas  OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa  NOT OK
#
# Insights :
# - Padrão de positividade entre a quantidade de periodicos eletronicos e a quantidade de receita da instituição (instituições com o maior número de periodicos eletronicos tendem a ter mais receita)

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'primeiro', 1.0, 15, 9, 6, 2, 0]

# %% [markdown]
# ### Second Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'segundo'))
# Out:
# **Coluna**: QT_ALUNOS
# "Analise estatística: média (15.200), mediana (12) e moda (0). Verificar relação com T1_VL_RECEITAS. A média é significativamente maior do que a mediana, indicando uma tendência de concentração de alunos em cursos mais rentáveis."
#
# **Inferências**: Existem instituições que investiram em quantidade de alunos para aumentar as receitas da instituição, mas não necessariamente com um impacto positivo na qualidade do ensino.
#
# **Análise geral do agrupamento**: A variável QT_ALUNOS parece estar relacionada à categoria administrativa da instituição (NOME_CATEGORIA_ADMINISTRATIVA). Instituições de categorias administrativas mais altas tendem a ter mais alunos. No entanto, é importante notar que esta relação pode ser influenciada por outros fatores.
#
# **Coluna**: QT_DOCENTES
# "Analise estatística: média (25), mediana (20) e moda (10). Verificar relação com IN_CAPITAL e NOME_CATEGORIA_ADMINISTRATIVA. A média é significativamente maior do que a mediana, indicando uma tendência de concentração de docentes em instituições de categorias administrativas mais altas."
#
# **Inferências**: Docentes estão mais concentrados em instituições de categorias administrativas mais altas, o que pode ser um fator influenciador na qualidade do ensino.
#
# **Análise geral do agrupamento**: A variável QT_DOCENTES parece estar relacionada à categoria administrativa da instituição. Instituições de categorias administrativas mais altas tendem a ter mais docentes. Além disso, as instituições que participam de outras bases (IN_OUTRAS_BASES) tendem a ter menos docentes.
#
# **Coluna**: QT_CURSO
# "Analise estatística: média (40), mediana (30) e moda (20). Verificar relação com IN_REPOSITORIO_INSTITUCIONAL e IN_BUSCA_INTEGRADA. A média é significativamente maior do que a mediana, indicando uma tendência de concentração de cursos em instituições que têm repositoriios institucionais ou buscas integradas."
#
# **Inferências**: Instituições com repositoriios institucionais ou buscas integradas tendem a ter mais cursos.
#
# **Análise geral do agrupamento**: A variável QT_CURSO parece estar relacionada à presença de repositoriios institucionais e buscas integradas. No entanto, é importante notar que esta relação pode ser influenciada por outros fatores.
#
# **Coluna**: T1_VL_RECEITAS
# "Analise estatística: média (R$ 10.000.000), mediana (R$ 5.000.000) e moda (R$ 0). Verificar relação com QT_ALUNOS e QT_DOCENTES. A média é significativamente maior do que a mediana, indicando uma tendência de concentração de receitas em instituições com mais alunos e docentes."
#
# **Inferências**: Instituições com mais alunos e docentes tendem a ter maiores receitas.
#
# **Análise geral do agrupamento**: A variável T1_VL_RECEITAS parece estar relacionada à quantidade de alunos e docentes. No entanto, é importante notar que esta relação pode ser influenciada por outros fatores.
#
# Essas análises podem ajudar a entender os padrões e tendências dentro do agrupamento de instituições. Além disso, é importante lembrar que as relações entre as variáveis podem ser complexas e multifacetadas, e que outras análises estatísticas ou métodos de análise mais avançados podem ser necessários para obter uma compreensão mais profunda dos padrões e tendências.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOTOK
# - Possuem busca integrada (74.35%) OK
# - Possuem serviço de internet (93.00%) NOTOK
# - Participam em redes sociais (74.03%) NOTOK
# - Possuem predominância em catalogo online (64.87%) NOTOK
# - Possuem predominâncai em ter outras bases (69.29%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (98,6) NOTOK
# - Maioria dos anos da IES são Faculdade (99.89%) NOTOK
#
# - Pouca quantidade de técnicos na média (12.87) NOTOK
# - Quantidade de alunos média de alunos abaixo (153.83) NOTOK
# - Corpo docente muito pouco na média (14.20) NOTOK
# - Pouca quantidade de cursos (2.30) NOTOK
# - Despesas e receitas média moderadas OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa  NOTOK
#
# Insights:
# - Não são apresnetadas Características aprofundadas a respeito das variaveis
# - A análsie destaca a necessidade de analises complementares

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'segundo', 0, 17, 2, 15, 4, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'segundo'))
# Out:
# **Analise Estatística e Inferências**
#
# **QT_ALUNOS**: A média é de 200,00 com uma variação padrão de 50,00. Há uma relação positiva entre a quantidade de alunos e a receita da instituição (R = 0,85), indicando que as instituições com mais alunos tendem a ter mais receita.
#
# **QT_DOCENTES**: A média é de 120,00 com uma variação padrão de 30,00. Há uma relação positiva entre a quantidade de docentes e a receita da instituição (R = 0,80), indicando que as instituições com mais docentes tendem a ter mais receita.
#
# **QT_CURSO**: A média é de 5,00 com uma variação padrão de 2,00. Não há relação significativa entre a quantidade de cursos e a receita da instituição.
#
# **QT_TEC_TOTAL**: A média é de 20,00 com uma variação padrão de 10,00. Há uma relação negativa entre a quantidade de técnicos e a receita da instituição (R = -0,60), indicando que as instituições com mais técnicos tendem a ter menos receita.
#
# **QT_PERIODICO_ELETRONICO**: A média é de 30,00 com uma variação padrão de 15,00. Há uma relação positiva entre a quantidade de periodicos eletronicos e a receita da instituição (R = 0,75), indicando que as instituições com mais periodicos eletronicos tendem a ter mais receita.
#
# **QT_LIVRO_ELETRONICO**: A média é de 10,00 com uma variação padrão de 5,00. Não há relação significativa entre a quantidade de livros eletronicos e a receita da instituição.
#
# **T1_VL_RECEITAS**: A média é de 500.000,00 com uma variação padrão de 150.000,00. Há uma relação positiva entre a receita das instituições e a quantidade de alunos (R = 0,90), indicando que as instituições com mais alunos tendem a ter mais receita.
#
# **T1_VL_DESPESAS**: A média é de 300.000,00 com uma variação padrão de 100.000,00. Há uma relação positiva entre as despesas das instituições e a quantidade de docentes (R = 0,85), indicando que as instituições com mais docentes tendem a ter mais despesas.
#
# **IN_CAPITAL**: A média é de 40% com uma variação padrão de 20%. Há uma relação positiva entre a condição de ser instituição capital e a receita da instituição (R = 0,80), indicando que as instituições capital tendem a ter mais receita.
#
# **IN_OUTRAS_BASES**: A média é de 60% com uma variação padrão de 20%. Há uma relação negativa entre o número de outras bases e a receita da instituição (R = -0,70), indicando que as instituições com mais outras bases tendem a ter menos receita.
#
# **IN_REPOSITORIO_INSTITUCIONAL**: A média é de 80% com uma variação padrão de 20%. Há uma relação positiva entre o número de repositorio institucional e a receita da instituição (R = 0,90), indicando que as instituições com mais repositorio institucional tendem a ter mais receita.
#
# **IN_BUSCA_INTEGRADA**: A média é de 50% com uma variação padrão de 20%. Há uma relação positiva entre o número de busca integrada e a receita da instituição (R = 0,85), indicando que as instituições com mais busca integrada tendem a ter mais receita.
#
# **IN_SERVICO_INTERNET**: A média é de 90% com uma variação padrão de 20%. Há uma relação positiva entre o número de serviço de internet e a receita da instituição (R = 0,95), indicando que as instituições com mais serviço de internet tendem a ter mais receita.
#
# **IN_PARTICIPA_REDE_SOCIAL**: A média é de 70% com uma variação padrão de 20%. Há uma relação positiva entre o número de participação nas redes sociais e a receita da instituição (R = 0,80), indicando que as instituições com mais participação nas redes sociais tendem a ter mais receita.
#
# **IN_CATALOGO_ONLINE**: A média é de 60% com uma variação padrão de 20%. Há uma relação positiva entre o número de catalogo online e a receita da instituição (R = 0,75), indicando que as instituições com mais catalogo online tendem a ter mais receita.
#
# **IN_ACESSO_PORTAL_CAPES**: A média é de 90% com uma variação padrão de 20%. Há uma relação positiva entre o acesso ao portal capes e a receita da instituição (R = 0,95), indicando que as instituições com mais acesso ao portal capes tendem a ter mais receita.
#
# **NU_ANO_CENSO**: A média é de 2015 com uma variação padrão de 10. Há uma relação positiva entre o ano do censo e a receita da instituição (R = 0,80), indicando que as instituições com mais recentes anos do censo tendem a ter mais receita.
#
# **CO_REGIAO**: A média é de Sul com uma variação padrão de N/A. Há uma relação positiva entre o região da instituição e a receita da instituição (R = 0,90), indicando que as instituições na região do sul tendem a ter mais receita.
#
# **NOME_CATEGORIA**: A média é de FSE withholds with 5% of the total revenue (in millions of reais) com uma variação padrão de N/A. Há uma relação positiva entre o nome da categoria e a receita da instituição, indicando que as instituições com nomes mais específicos tendem a ter mais receita.
#
# **INSTITUTIONAL Characteristics**: A média é 60% with 40% of the total revenue (in millions of reais) with uma variação padrão de N/A. Há uma relação positiva entre o institutional characteristics e a receita da instituição, indicating that as institutions with more developed characteristics tend to have more revenue.
#
# **FINANCIAL Characteristics**: A média é 40% with 60% of the total revenue (in millions of reais) com uma variação padrão de N/A. Há uma relação positiva entre o financial characteristics e a receita da instituição, indicating that institutions with more developed financial characteristics tend to have more revenue.
#
# **Institutional Characteristics**: A média é 80% with 20% of the total revenue (in millions of reais) com uma variação padrão de N/A. Há uma relação positiva entre o institutional characteristics e a receita da instituição, indicating that institutions with more developed characteristics tend to have more revenue.
#
# **Financial Characteristics**: A média é 60% with 40% of the total revenue (in millions of reais) com uma variação padrão de N/A. Há uma relação positiva entre o financial characteristics e a receita da instituição, indicating that institutions with more developed financial characteristics tend to have more revenue.
#
# **Institutional Characteristics**: A média é 80% with 20% of the total revenue (in millions of reais) com uma variação padrão de N/A. Há uma relação positiva entre o institutional characteristics e a receita da instituição, indicating that institutions with more developed characteristics tend to have more revenue.
#
# **Financial Characteristics**: A média é 60% with 40% of the total revenue (in millions of reais) com uma variação padrão de N/A. Há uma relação positiva entre o financial characteristics e a receita da instituição, indicating that institutions with more developed financial characteristics tend to have more revenue.
#
# As análises indicam que as instituições mais bem-sucedidas têm características institucionais mais desenvolvidas (como maior exposição ao mercado, maior participação nas redes sociais e maior acesso a serviços) e características financeiras mais desenvolvidas (maior receita de investimentos). Além disso, as instituições com maior quantidade de alunos tendem a ter mais receita.
#
# As análises também indicam que as instituições mais bem-sucedidas são aquelas que têm um bom equilíbrio entre o desenvolvimento das características institucionais e financeiras. As instituições que se destacam em uma ou outra área tendem a ter menos sucesso na outra área.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOT OK
# - Uma incidência das IES não estarem numa capital (59.38%) NOT OK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOT OK
# - Possuem busca integrada (74.35%) NOT OK
# - Possuem serviço de internet (93.00%) NOT OK
# - Participam em redes sociais (74.03%) NOT OK
# - Possuem predominância em catalogo online (64.87%) NOT OK
# - Possuem predominâncai em ter outras bases (69.29%) NOT OK
# - Maioria das instituições são privada (com e sem fins lucrativos) (98,6) NOT OK
# - Maioria dos anos da IES são Faculdade (99.89%) NOT OK
#
# - Pouca quantidade de técnicos na média (12.87) NOT OK
# - Quantidade de alunos média de alunos abaixo (153.83) NOT OK
# - Corpo docente muito pouco na média (14.20) NOT OK
# - Pouca quantidade de cursos (2.30) NOT OK
# - Despesas e receitas média moderadas OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOT OK
#
# Insights :
# - A análise é focada entre a relação das receitas e despesas e as variaveis( instituições com mais técnicos tendem a termais despesas enquanto que com mais docentes tendem a ter mais receita).

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'segundo', 0.5, 17, 4, 13, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'segundo'))
# Out:
# **Coluna**: QT_ALUNOS
#
# *   Analise estatística: A média da variável é de 200, a mediana é de 180 e a moda é de 150.
# *   Relação com outra variável: Não há uma relação estatística clara entre a quantidade de alunos e outras variáveis. No entanto, pode-se observar que instituições com mais alunos tendem a ter mais recursos financeiros (T1_VL_RECEITAS).
#
# **Inferências**: A quantidade de alunos não parece ser um fator determinante na formação do agrupamento. Além disso, é possível que as instituições com mais recursos financeiros possam oferecer cursos e programas mais atraentes para os estudantes.
#
# **Análise geral do agrupamento**: É importante notar que o agrupamento não parece estar diretamente relacionado à quantidade de alunos. Em vez disso, pode-se observar uma tendência de instituições com mais recursos financeiros oferecerem programas e cursos mais atraentes para os estudantes.
#
# **Coluna**: QT_DOCENTES
#
# *   Analise estatística: A média da variável é de 50, a mediana é de 40 e a moda é de 30.
# *   Relação com outra variável: Há uma relação negativa entre a quantidade de docentes e a quantidade de técnicos (QT_TEC_TOTAL). Isso significa que instituições com mais docentes tendem a ter menos técnicos.
#
# **Inferências**: A quantidade de docentes pode ser um fator importante na formação do agrupamento, especialmente se considerarmos a relação com a quantidade de técnicos. É possível que instituições com mais recursos financeiros possam contratar mais docentes e reduzir a necessidade de técnicos.
#
# **Análise geral do agrupamento**: A quantidade de docentes parece ser um fator importante na formação do agrupamento, especialmente quando consideramos a relação com a quantidade de técnicos. É possível que as instituições com mais recursos financeiros possam contratar mais docentes e reduzir a necessidade de técnicos.
#
# **Coluna**: QT_CURSO
#
# *   Analise estatística: A média da variável é de 10, a mediana é de 8 e a moda é de 6.
# *   Relação com outra variável: Não há uma relação estatística clara entre a quantidade de cursos e outras variáveis. No entanto, pode-se observar que instituições com mais recursos financeiros tendem a oferecer mais cursos.
#
# **Inferências**: A quantidade de cursos não parece ser um fator determinante na formação do agrupamento. Além disso, é possível que as instituições com mais recursos financeiros possam oferecer mais cursos e programas para os estudantes.
#
# **Análise geral do agrupamento**: É importante notar que o agrupamento não parece estar diretamente relacionado à quantidade de cursos. Em vez disso, pode-se observar uma tendência de instituições com mais recursos financeiros oferecerem mais cursos e programas para os estudantes.
#
# **Coluna**: QT_TEC_TOTAL
#
# *   Analise estatística: A média da variável é de 20, a mediana é de 15 e a moda é de 10.
# *   Relação com outra variável: Há uma relação negativa entre a quantidade de técnicos e a quantidade de docentes (QT_DOCENTES). Isso significa que instituições com mais técnicos tendem a ter menos docentes.
#
# **Inferências**: A quantidade de técnicos pode ser um fator importante na formação do agrupamento, especialmente se considerarmos a relação com a quantidade de docentes. É possível que as instituições com mais recursos financeiros possam contratar mais técnicos e reduzir a necessidade de docentes.
#
# **Análise geral do agrupamento**: A quantidade de técnicos parece ser um fator importante na formação do agrupamento, especialmente quando consideramos a relação com a quantidade de docentes. É possível que as instituições com mais recursos financeiros possam contratar mais técnicos e reduzir a necessidade de docentes.
#
# **Coluna**: QT_PERIODICO_ELETRONICO
#
# *   Analise estatística: A média da variável é de 5, a mediana é de 3 e a moda é de 2.
# *   Relação com outra variável: Não há uma relação estatística clara entre a quantidade de periodicos eletronicos e outras variáveis.
#
# **Inferências**: A quantidade de periodicos eletronicos não parece ser um fator determinante na formação do agrupamento. É possível que as instituições com mais recursos financeiros possam investir mais em publicações online.
#
# **Análise geral do agrupamento**: Não é possível determinar uma relação entre a quantidade de periodicos eletronicos e o agrupamento. A publicação de documentos online pode ser uma característica de instituições com mais recursos financeiros, mas não é um fator importante na formação do agrupamento.
#
# **Coluna**: QT_LIVRO_ELETRONICO
#
# *   Analise estatística: A média da variável é de 3, a mediana é de 2 e a moda é de 1.
# *   Relação com outra variável: Não há uma relação estatística clara entre a quantidade de livros eletronicos e outras variáveis.
#
# **Inferências**: A quantidade de livros eletronicos não parece ser um fator determinante na formação do agrupamento. É possível que as instituições com mais recursos financeiros possam investir em tecnologia para oferecer mais livros eletronicos.
#
# **Análise geral do agrupamento**: Não é possível determinar uma relação entre a quantidade de livros eletronicos e o agrupamento. A oferta de livros eletronicos pode ser uma característica de instituições com mais recursos financeiros, mas não é um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_TECnicos
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e técnicos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes e reduzir a necessidade de técnicos.
#
# **Inferências**: A relação entre a quantidade de docentes e técnicos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes e reduzir a necessidade de técnicos, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e técnicos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes e reduzir a necessidade de técnicos, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_CURSO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e cursos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais cursos.
#
# **Inferências**: A relação entre a quantidade de docentes e cursos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e cursos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_PERIODICO_ELETRONICO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e periodicos eletronicos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais publicações online.
#
# **Inferências**: A relação entre a quantidade de docentes e periodicos eletronicos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais publicações online, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e periodicos eletronicos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais publicações online, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_LIVRO_ELETRONICO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e livros eletronicos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais tecnologia para os estudantes.
#
# **Inferências**: A relação entre a quantidade de docentes e livros eletronicos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais tecnologia para os estudantes, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e livros eletronicos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais tecnologia para os estudantes, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_CURSO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e cursos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais cursos.
#
# **Inferências**: A relação entre a quantidade de docentes e cursos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e cursos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_PERIODICO_ELETRONICO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e periodicos eletronicos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais publicações online.
#
# **Inferências**: A relação entre a quantidade de docentes e periodicos eletronicos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais publicações online, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e periodicos eletronicos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais publicações online, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_LIVRO_ELETRONICO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e livros eletronicos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais tecnologia para os estudantes.
#
# **Inferências**: A relação entre a quantidade de docentes e livros eletronicos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais tecnologia para os estudantes, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e livros eletronicos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais tecnologia para os estudantes, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_CURSO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e cursos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais cursos.
#
# **Inferências**: A relação entre a quantidade de docentes e cursos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e cursos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_PERIODICO_ELETRONICO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e periodicos eletronicos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais publicações online.
#
# **Inferências**: A relação entre a quantidade de docentes e periodicos eletronicos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais publicações online, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e periodicos eletronicos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais publicações online, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_LIVRO_ELETRONICO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e livros eletronicos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais tecnologia para os estudantes.
#
# **Inferências**: A relação entre a quantidade de docentes e livros eletronicos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais tecnologia para os estudantes, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e livros eletronicos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais tecnologia para os estudantes, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_CURSO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e cursos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais cursos.
#
# **Inferências**: A relação entre a quantidade de docentes e cursos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e cursos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_PERIODICO_ELETRONICO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e periodicos eletronicos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais publicações online.
#
# **Inferências**: A relação entre a quantidade de docentes e periodicos eletronicos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais publicações online, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e periodicos eletronicos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais publicações online, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_LIVRO_ELETRONICO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e livros eletronicos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais tecnologia para os estudantes.
#
# **Inferências**: A relação entre a quantidade de docentes e livros eletronicos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais tecnologia para os estudantes, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e livros eletronicos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais tecnologia para os estudantes, o que pode ser um fator importante na formação do agrupamento.
#
# **Coluna**: QT_DOCENTES x QT_CURSO
#
# *   Analise estatística: Não há uma relação estatística clara entre a quantidade de docentes e cursos.
# *   Relação com outra variável: É possível que as instituições com mais recursos financeiros possam contratar mais docentes, mas não oferecer mais cursos.
#
# **Inferências**: A relação entre a quantidade de docentes e cursos é importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# **Análise geral do agrupamento**: A relação entre a quantidade de docentes e cursos é um fator importante para o agrupamento. As instituições com mais recursos financeiros podem contratar mais docentes, mas não oferecer mais cursos, o que pode ser um fator importante na formação do agrupamento.
#
# Aqui estão os dados:
#
# - 20 alunos - 1 professor
# - 30 alunos - 2 professores
# - 40 alunos - 3 professores
# - 50 alunos - 4 professores
# - 60 alunos - 5 professores
#
# De que tipo de análise estatística se trata a questão?

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOTOK
# - Possuem busca integrada (74.35%) NOTOK
# - Possuem serviço de internet (93.00%) NOTOK
# - Participam em redes sociais (74.03%) NOTOK
# - Possuem predominância em catalogo online (64.87%) NOTOK
# - Possuem predominâncai em ter outras bases (69.29%)NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (98,6) NOTOK
# - Maioria dos anos da IES são Faculdade (99.89%) NOTOK
#
# - Pouca quantidade de técnicos na média (12.87) NOTOK
# - Quantidade de alunos média de alunos abaixo (153.83) NOTOK
# - Corpo docente muito pouco na média (14.20) NOTOK
# - Pouca quantidade de cursos (2.30) NOTOK
# - Despesas e receitas média moderadas OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# Insights:
# - A análsie só foca em 3 variaveis
# - Destaca um relação negativa entre a quantidade de docentes e a quantidade de técnicos

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'segundo', 1.0, 17, 4, 13, 2, 0]

# %% [markdown]
# ### Third Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'terceiro'))
# Out:
# **Análise Estatística e Exploratória dos Agrupamentos**
#
# Considerando as informações fornecidas, podemos começar a analisar os agrupamentos com base nas colunas apresentadas.
#
# **Coluna:** QT_ALUNOS
# "Analise estatística: A média de QT_ALUNOS é de 200, a mediana é de 150 e a moda é de 100. Verificar relação com outra variável: há uma correlação positiva entre QT_ALUNOS e T1_VL_RECEITAS (receita da instituição), sugerindo que as instituições com mais alunos tendem a ter mais receita."
#
# **Inferências:** A relação entre a quantidade de alunos e a receita sugere que as instituições com mais recursos econômicos tendem a ter mais alunos.
#
# **Análise geral do agrupamento:** Os dados indicam que as instituições com mais alunos tendem a ter mais recursos econômicos, o que pode ser um fator importante para a criação de agrupamentos.
#
# **Coluna:** QT_DOCENTES
# "Analise estatística: A média de QT_DOCENTES é de 50, a mediana é de 30 e a moda é de 20. Verificar relação com outra variável: há uma correlação negativa entre QT_DOCENTES e T1_VL_DESPESAS (despesa da instituição), sugerindo que as instituições com mais docentes tendem a ter menos despesas."
#
# **Inferências:** A relação entre a quantidade de docentes e a despesa sugere que as instituições com mais docentes tendem a ter mais recursos disponíveis para investir, o que pode ser um fator importante para a criação de agrupamentos.
#
# **Análise geral do agrupamento:** Os dados indicam que as instituições com mais docentes tendem a ter menos despesas, o que pode ser um fator importante para a criação de agrupamentos.
#
# **Coluna:** IN_CAPITAL
# "Analise estatística: A frequência de IN_CAPITAL é de 30%, com uma média de 2 e uma moda de 1. Verificar relação com outra variável: há uma correlação positiva entre IN_CAPITAL e QT_TEC_TOTAL (quantidade de técnicos), sugerindo que as instituições situadas na capital tendem a ter mais técnicos."
#
# **Inferências:** A relação entre a localização da instituição e a quantidade de técnicos sugere que as instituições situadas na capital tendem a ter mais recursos humanos especializados.
#
# **Análise geral do agrupamento:** Os dados indicam que as instituições situadas na capital tendem a ter mais recursos humanos especializados, o que pode ser um fator importante para a criação de agrupamentos.
#
# **Coluna:** IN_REPOSITORIO_INSTITUCIONAL
# "Analise estatística: A frequência de IN_REPOSITORIO_INSTITUCIONAL é de 20%, com uma média de 1 e uma moda de 0. Verificar relação com outra variável: há uma correlação positiva entre IN_REPOSITORIO_INSTITUCIONAL e NOME_CATEGORIA_ADMINISTRATIVA (categoria administrativa da instituição), sugerindo que as instituições com um repositorio institucional tendem a ter uma categoria administrativa mais avançada."
#
# **Inferências:** A relação entre o repositorio institucional e a categoria administrativa sugere que as instituições com recursos de informação mais avançados tendem a ter uma administração mais eficiente.
#
# **Análise geral do agrupamento:** Os dados indicam que as instituições com recursos de informação mais avançados tendem a ter uma administração mais eficiente, o que pode ser um fator importante para a criação de agrupamentos.
#
# Essas análises estatísticas e exploratórias fornecem informações valiosas sobre os agrupamentos e podem ajudar a entender melhor as relações entre as variáveis.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOT OK
# - Predominãncia das IES não estarem numa capital (62.70%) NOT OK
# - Instituições sem acesso ao portal Capes (83.09%) NOT OK
# - Possuem predominância em não possuir repositorio institucional (74.68%) NOT OK
# - Possuem predominância em serviço de internet (79.13%) NOT OK
# - Predominância em participar em redes sociais (62.62%) NOT OK
# - Possuem predominância em ter outras bases (75.57%) NOT OK
# - Maioria das instituições são privada (com e sem fins lucrativos) (97,73)  NOT OK
# - Maioria dos anos da IES são Faculdade (99.92%) NOT OK
#
# - Quantidade baixa de média de técnicos (10.78) NOT OK
# - Quantidade de alunos média de alunos baixo (185.81) NOT OK
# - Corpo docente muito baixo na média (16.72) NOT OK
# - Pouca quantidade de cursos (2.03) NOT OK
# - Despesas e receitas média moderadas NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância baixaNOT OK
#
# Insights:
# - Análise foca em 3 variaveis `QT_ALUNOS`, `IN_CAPITAL`, `QT_DOCENTES`  e a relação com a receitas e despesas
# - instituições com recursos de informação mais avançados tendem a ter uma administração mais eficiente.

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'terceiro', 0, 15, 2, 13, 3, 1]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'terceiro'))
# Out:
# **Análise dos Agrupamentos**
#
# **Coluna**: QT_ALUNOS
#
# *   Analise estatística: Média = 120, Mediana = 100, Moda = 90
# *   Relação com outra variável: Não há relação significativa com outras variáveis, exceto por uma média ligeiramente maior na região Norte.
# *   Inferências: A instituição tem um número médio de alunos em todo o país, mas uma tendência ligeira para mais alunos no Norte.
#
# **Coluna**: QT_DOCENTES
#
# *   Analise estatística: Média = 50, Mediana = 40, Moda = 30
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos, pois instituições com mais alunos tendem a ter mais docentes.
# *   Inferências: A instituição tem um número médio de docentes em todo o país e está em um relacionamento positivo com a quantidade de alunos.
#
# **Coluna**: QT_CURSO
#
# *   Analise estatística: Média = 20, Mediana = 15, Moda = 10
# *   Relação com outra variável: Não há relação significativa com outras variáveis.
# *   Inferências: A instituição tem um número médio de cursos em todo o país.
#
# **Coluna**: QT_TEC_TOTAL
#
# *   Analise estatística: Média = 80, Mediana = 60, Moda = 40
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de técnicos em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: QT_PERIODICO_ELETRONICO
#
# *   Analise estatística: Média = 5, Mediana = 3, Moda = 2
# *   Relação com outra variável: Não há relação significativa com outras variáveis.
# *   Inferências: A instituição tem um número baixo de publicações eletrônicas em todo o país.
#
# **Coluna**: QT_LIVRO_ELETRONICO
#
# *   Analise estatística: Média = 10, Mediana = 5, Moda = 3
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de livros eletrônicos em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: T1_VL_RECEITAS
#
# *   Analise estatística: Média = 500000, Mediana = 300000, Moda = 200000
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de receita em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: T1_VL_DESPESAS
#
# *   Analise estatística: Média = 200000, Mediana = 100000, Moda = 50000
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de despesas em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_CAPITAL
#
# *   Analise estatística: Média = 0,5, Mediana = 0,25, Moda = 0
# *   Relação com outra variável: Não há relação significativa com outras variáveis.
# *   Inferências: A instituição tem uma probabilidade média de estar na capital em todo o país.
#
# **Coluna**: IN_OUTRAS_BASES
#
# *   Analise estatística: Média = 0,5, Mediana = 0,25, Moda = 0
# *   Relação com outra variável: Não há relação significativa com outras variáveis.
# *   Inferências: A instituição tem uma probabilidade média de ter outras bases em todo o país.
#
# **Coluna**: IN_REPOSITORIO_INSTITUCIONAL
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de repositorio institucional em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_BUSCA_INTEGRADA
#
# *   Analise estatística: Média = 0,9, Mediana = 0,7, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de busca integrada em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_SERVICO_INTERNET
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de serviço de internet em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_PARTICIPA_REDE_SOCIAL
#
# *   Analise estatística: Média = 0,7, Mediana = 0,4, Moda = 0
# *   Relação com outra variável: Não há relação significativa com outras variáveis.
# *   Inferências: A instituição tem uma probabilidade média de participar da rede social em todo o país.
#
# **Coluna**: IN_REPOSITORIO_INSTITUCIONAL
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de busca integrada em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_SERVICO_INTERNET
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de serviço de internet em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_PARTICIPA_REDE_SOCIAL
#
# *   Analise estatística: Média = 0,7, Mediana = 0,4, Moda = 0
# *   Relação com outra variável: Não há relação significativa com outras variáveis.
# *   Inferências: A instituição tem uma probabilidade média de participar da rede social em todo o país.
#
# **Coluna**: IN_REPOSITORIO_INSTITUCIONAL
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de repositorio institucional em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_SERVICO_INTERNET
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de serviço de internet em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_PARTICIPA_REDE_SOCIAL
#
# *   Analise estatística: Média = 0,7, Mediana = 0,4, Moda = 0
# *   Relação com outra variável: Não há relação significativa com outras variáveis.
# *   Inferências: A instituição tem uma probabilidade média de participar da rede social em todo o país.
#
# **Coluna**: IN_REPOSITORIO_INSTITUCIONAL
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de repositorio institucional em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_SERVICO_INTERNET
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de serviço de internet em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_PARTICIPA_REDE_SOCIAL
#
# *   Analise estatística: Média = 0,7, Mediana = 0,4, Moda = 0
# *   Relação com outra variável: Não há relação significativa com outras variáveis.
# *   Inferências: A instituição tem uma probabilidade média de participar da rede social em todo o país.
#
# **Coluna**: IN_REPOSITORIO_INSTITUCIONAL
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de repositorio institucional em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_SERVICO_INTERNET
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de serviço de internet em todo o país e está em um relacionamento positivo com a quantidade de alunos e docentes.
#
# **Coluna**: IN_PARTICIPA_REDE_SOCIAL
#
# *   Analise estatística: Média = 0,7, Mediana = 0,4, Moda = 0
# *   Relação com outra variável: Não há relação significativa com outras variáveis.
# *   Inferências: A instituição tem uma probabilidade média de participar da rede social em todo o país.
#
# **Coluna**: IN_REPOSITORIO_INSTITUCIONAL
#
# *   Analise estatística: Média = 0,8, Mediana = 0,5, Moda = 0
# *   Relação com outra variável: Existe uma relação positiva com a quantidade de alunos e docentes.
# *   Inferências: A instituição tem um número médio de repositorio institucional em todo o país e está em um relacionamento positivo

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOT OK
# - Predominãncia das IES não estarem numa capital (62.70%) NOT OK
# - Instituições sem acesso ao portal Capes (83.09%) NOT OK
# - Possuem predominância em não possuir repositorio institucional (74.68%) NOT OK
# - Possuem predominância em serviço de internet (79.13%) NOT OK
# - Predominância em participar em redes sociais (62.62%) NOT OK
# - Possuem predominância em ter outras bases (75.57%) NOT OK
# - Maioria das instituições são privada (com e sem fins lucrativos) (97,73) NOT OK
# - Maioria dos anos da IES são Faculdade (99.92%) NOT OK
#
# - Quantidade baixa de média de técnicos (10.78) NOT OK
# - Quantidade de alunos média de alunos baixo (185.81) NOT OK
# - Corpo docente muito baixo na média (16.72) NOT OK
# - Pouca quantidade de cursos (2.03) NOT OK
# - Despesas e receitas média moderadas NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOT OK
#
# Insights falsos:
# - A instituição tem maior insidência na região norte
# - Quantidade de Alunos e docentes é positiva
# - A nálise naão destaca todas as variaveis relevantes e apresenta uma descrição superficial das caracteríticas.

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'terceiro', 0.5, 15, 5, 10, 2, 4]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'terceiro'))
# Out:
# **QT_ALUNOS**: "A média da quantidade de alunos é de 200, com uma mediana de 180 e uma moda de 150. Observa-se que a variabilidade é relativamente baixa, indicando um tamanho moderado do agrupamento."
#
# **QT_DOCENTES**: "A média da quantidade de docentes é de 50, com uma mediana de 40 e uma moda de 30. A relação entre o número de alunos e o número de docentes é significativa, pois podemos observar que a quantidade de alunos está inversamente relacionada à quantidade de docentes."
#
# **QT_CURSO**: "A média da quantidade de cursos é de 20, com uma mediana de 15 e uma moda de 10. A relação entre a quantidade de cursos e o número de alunos é positiva, pois as instituições com mais cursos tendem a ter mais alunos."
#
# **QT_TEC_TOTAL**: "A média da quantidade de técnicos é de 5, com uma mediana de 4 e uma moda de 3. A relação entre o número de técnicos e o número de alunos é positiva, pois as instituições com mais técnicos tendem a ter mais alunos."
#
# **QT_PERIODICO_ELETRONICO**: "A média da quantidade de periodicos eletronicos é de 10, com uma mediana de 8 e uma moda de 6. A relação entre o número de periodicos eletronicos e o número de alunos é positiva, pois as instituições com mais periodicos eletronicos tendem a ter mais alunos."
#
# **QT_LIVRO_ELETRONICO**: "A média da quantidade de livros eletronicos é de 5, com uma mediana de 4 e uma moda de 3. A relação entre o número de livros eletronicos e o número de alunos é positiva, pois as instituições com mais livros eletronicos tendem a ter mais alunos."
#
# **T1_VL_RECEITAS**: "A média da receita da instituição é de 100.000,00, com uma mediana de 80.000,00 e uma moda de 60.000,00. A relação entre a receita e o número de alunos é positiva, pois as instituições com mais recursos tendem a ter mais alunos."
#
# **T1_VL_DESPESAS**: "A média das despesas da instituição é de 80.000,00, com uma mediana de 60.000,00 e uma moda de 40.000,00. A relação entre as despesas e o número de alunos é inversa, pois as instituições com mais recursos tendem a ter menos despesas."
#
# **IN_CAPITAL**: "A média da variável IN_CAPITAL é de 0,5, com uma mediana de 0,3 e uma moda de 0. A relação entre o status da instituição e o número de alunos é positiva, pois as instituições em capital tendem a ter mais alunos."
#
# **IN_OUTRAS_BASES**: "A média da variável IN_OUTRAS_BASES é de 1, com uma mediana de 0,5 e uma moda de 0. A relação entre o status da instituição e o número de alunos é positiva, pois as instituições com outras bases tendem a ter mais alunos."
#
# **IN_REPOSITORIO_INSTITUCIONAL**: "A média da variável IN_REPOSITORIO_INSTITUCIONAL é de 0,8, com uma mediana de 0,5 e uma moda de 0. A relação entre o status da instituição e o número de alunos é positiva, pois as instituições com repositorio institucional tendem a ter mais alunos."
#
# **IN_BUSCA_INTEGRADA**: "A média da variável IN_BUSCA_INTEGRADA é de 1, com uma mediana de 0,5 e uma moda de 0. A relação entre o status da instituição e o número de alunos é positiva, pois as instituições com busca integrada tendem a ter mais alunos."
#
# **IN_SERVICO_INTERNET**: "A média da variável IN_SERVICO_INTERNET é de 1, com uma mediana de 0,5 e uma moda de 0. A relação entre o status da instituição e o número de alunos é positiva, pois as instituições com serviço de internet tendem a ter mais alunos."
#
# **IN_PARTICIPA_REDE_SOCIAL**: "A média da variável IN_PARTICIPA_REDE_SOCIAL é de 1,5, com uma mediana de 0,8 e uma moda de 0. A relação entre o status da instituição e o número de alunos é positiva, pois as instituições que participam das redes sociais tendem a ter mais alunos."
#
# **IN_CATALOGO_ONLINE**: "A média da variável IN_CATALOGO_ONLINE é de 1, com uma mediana de 0,5 e uma moda de 0. A relação entre o status da instituição e o número de alunos é positiva, pois as instituições com catalogo online tendem a ter mais alunos."
#
# **IN_ACESSO_PORTAL_CAPES**: "A média da variável IN_ACESSO_PORTAL_CAPES é de 1,5, com uma mediana de 0,8 e uma moda de 0. A relação entre o status da instituição e o número de alunos é positiva, pois as instituições com acesso ao portal CAPES tendem a ter mais alunos."
#
# **NU_ANO_CENSO**: "A média do ano censo é de 2005, com uma mediana de 1990 e uma moda de 1980. A relação entre o ano censo e o número de alunos é positiva, pois as instituições mais antigas tendem a ter mais alunos."
#
# **CO_REGIAO**: "A média da região da instituição é de Sudeste, com uma mediana de Sul e uma moda de Norte. A relação entre a região da instituição e o número de alunos é positiva, pois as instituições localizadas no sul tendem a ter mais alunos."
#
# **TABELA DE CLASSIFICAÇÃO**
#
# As seguintes tabelas podem ser obtidas através do módulo de classificação:
#
# | Classificação | A1 | B2 | C3 |
# | --- | --- | --- | --- |
# | Receita / Despesa | 10/0,5 | 9/0,6 | 8/0,7 |
# | Alunos | 15 | 12 | 10 |
#
# Observações:
#
# * As variáveis IN_CAPITAL e IN_OUTRAS_BASES estão significativamente diferentes da média de 1.
# * As variáveis IN_REPOSITORIO_INSTITUCIONAL, IN_BUSCA_INTEGRADA e IN_SERVICO_INTERNET estão significativamente diferentes da média de 1.
# * As variáveis IN_PARTICIPA_REDE_SOCIAL e IN_CATALOGO_ONLINE estão significativamente diferentes da média de 1.
# * A variável IN_ACESSO_PORTAL_CAPES está significativamente diferente da média de 1,5.
# * A variável NU_ANO_CENSO está significativamente diferente da média de 2005.
# * O grupo CO_REGIAO sul está significativamente diferente do grupo CO_REGIAO norte.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOT OK
# - Predominãncia das IES não estarem numa capital (62.70%) NOT OK
# - Instituições sem acesso ao portal Capes (83.09%) NOT OK
# - Possuem predominância em não possuir repositorio institucional (74.68%) NOT OK
# - Possuem predominância em serviço de internet (79.13%) NOT OK
# - Predominância em participar em redes sociais (62.62%) NOT OK
# - Possuem predominância em ter outras bases (75.57%) NOT OK
# - Maioria das instituições são privada (com e sem fins lucrativos) (97,73)  NOT OK
# - Maioria dos anos da IES são Faculdade (99.92%) NOT OK
#
# - Quantidade baixa de média de técnicos (10.78) NOT OK
# - Quantidade de alunos média de alunos baixo (185.81) NOT OK
# - Corpo docente muito baixo na média (16.72) NOT OK
# - Pouca quantidade de cursos (2.03) NOT OK
# - Despesas e receitas média moderadas NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância baixaNOT OK
#
# Insights falsos:
# - Apesar de trazer as variaveis de influência, detalhou que todas elas eram positivas.

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'terceiro', 1.0, 15, 5, 10, 2, 4]

# %% [markdown]
# ### Forth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'quarto'))
# Out:
# **Análise Estatística das Colunas**
#
# *   **QT_ALUNOS**: A média é de 250 alunos. A mediana é de 200 e a moda não é relevante neste caso. A relação com outra variável pode ser feita com a coluna **T1_VL_RECEITAS**, pois instituições com mais alunos tendem a ter mais receitas.
# *   **QT_DOCENTES**: A média é de 80 docentes. A mediana é de 75 e a moda não é relevante neste caso. A relação com outra variável pode ser feita com a coluna **T1_VL_RECEITAS**, pois instituições com mais docentes tendem a ter mais receitas.
# *   **QT_CURSO**: A média é de 15 cursos. A mediana é de 12 e a moda não é relevante neste caso. A relação com outra variável pode ser feita com a coluna **CO_REGIAO**, pois instituições na mesma região tendem a ter mais cursos.
# *   **QT_TEC_TOTAL**: A média é de 30 técnicos. A mediana é de 25 e a moda não é relevante neste caso. A relação com outra variável pode ser feita com a coluna **IN_CAPITAL**, pois instituições na capital tendem a ter mais técnicos.
# *   **QT_PERIODICO_ELETRONICO**: A média é de 100 periodicos eletrônicos. A mediana é de 80 e a moda não é relevante neste caso. A relação com outra variável pode ser feita com a coluna **T1_VL_RECEITAS**, pois instituições com mais receitas tendem a ter mais periodicos eletrônicos.
# *   **QT_LIVRO_ELETRONICO**: A média é de 50 livros eletrônicos. A mediana é de 40 e a moda não é relevante neste caso. A relação com outra variável pode ser feita com a coluna **T1_VL_RECEITAS**, pois instituições com mais receitas tendem a ter mais livros eletrônicos.
# *   **T1_VL_RECEITAS**: A média é de 1.000.000 de reais. A mediana é de 800.000 e a moda não é relevante neste caso. A relação com outras variáveis pode ser feita com as colunas **QT_ALUNOS** e **QT_DOCENTES**, pois instituições com mais alunos e docentes tendem a ter mais receitas.
# *   **T1_VL_DESPESAS**: A média é de 800.000 reais. A mediana é de 600.000 e a moda não é relevante neste caso. A relação com outras variáveis pode ser feita com as colunas **QT_ALUNOS** e **QT_DOCENTES**, pois instituições com mais alunos e docentes tendem a ter mais despesas.
# *   **IN_CAPITAL**: 40% das instituições estão na capital. Há uma relação positiva entre a variável e a média da coluna **QT_TEC_TOTAL** e da coluna **QT_PERIODICO_ELETRONICO**, pois as instituições na capital tendem a ter mais técnicos e periodicos eletrônicos.
# *   **IN_OUTRAS_BASES**: 60% das instituições têm outras bases. Há uma relação negativa entre a variável e a média da coluna **T1_VL_RECEITAS**, pois as instituições com outras bases tendem a ter menores receitas.
# *   **IN_REPOSITORIO_INSTITUCIONAL**: 30% das instituições têm repositorio institucional. Há uma relação positiva entre a variável e a média da coluna **QT_LIVRO_ELETRONICO**, pois as instituições com repositorio institucional tendem a ter mais livros eletrônicos.
# *   **IN_BUSCA_INTEGRADA**: 50% das instituições têm busca integrada. Há uma relação positiva entre a variável e a média da coluna **QT_CURSO**, pois as instituições com busca integrada tendem a ter mais cursos.
# *   **IN_SERVICO_INTERNET**: 80% das instituições têm serviço de internet. Há uma relação negativa entre a variável e a média da coluna **T1_VL_RECEITAS**, pois as instituições com serviço de internet tendem a ter menores receitas.
# *   **IN_PARTICIPA_REDE_SOCIAL**: 60% das instituições participam nas redes sociais. Há uma relação positiva entre a variável e a média da coluna **T1_VL_RECEITAS**, pois as instituições com participação nas redes sociais tendem a ter mais receitas.
# *   **IN_CATALOGO_ONLINE**: 40% das instituições têm catalogo online. Há uma relação positiva entre a variável e a média da coluna **QT_LIVRO_ELETRONICO**, pois as instituições com catalogo online tendem a ter mais livros eletrônicos.
# *   **IN_ACESSO_PORTAL_CAPES**: 50% das instituições têm acesso portal capes. Há uma relação positiva entre a variável e a média da coluna **T1_VL_RECEITAS**, pois as instituições com acesso ao portal capes tendem a ter mais receitas.
# *   **NU_ANO_CENSO**: A maioria das instituições foi fundada antes de 2010. Há uma relação negativa entre a variável e a média da coluna **T1_VL_RECEITAS**, pois as instituições fundadas após 2010 tendem a ter menores receitas.
# *   **CO_REGIAO**: A maioria das instituições está localizada na região Norte. Há uma relação positiva entre a variável e a média da coluna **QT_CURSO**, pois as instituições localizadas na região Norte tendem a ter mais cursos.
#
# Em resumo, as instituições com mais alunos, docentes, receitas e livros eletrônicos tendem a ter mais técnicos, periodicos eletrônicos, despesas e serviços de internet. As instituições com outras bases tendem a ter menores receitas, enquanto as instituições com repositorio institucional, busca integrada, participação nas redes sociais, catalogo online, acesso ao portal capes e fundadas após 2010 tendem a ter mais livros eletrônicos, cursos, receitas e serviços de internet.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOT OK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOT OK
# - Uma incidência das IES não estarem numa capital (68.85%)NOT OK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) NOT OK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOT OK
# - Predominância em participar em redes sociais (71.20%) NOT OK
# - Possuem predominância em ter catalogo online (79.45%) NOT OK
# - Possuem predominância em ter outras bases (73.43%) NOT OK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) (98,04) NOT OK
# - Maioria dos anos da IES são Faculdade (99.15%) NOT OK
#
# - Quantidade de técnicos na média baixo (33.68	) NOT OK
# - Quantidade de alunos média de alunos  moderado (932.89)NOT OK
# - Corpo docente muito na média (45.12) NOT OK
# - Pouca quantidade média de cursos (6.21) NOT OK
# - Despesas e receitas média acima do moderado NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOT OK
#
# Insights:
# - A maioria das instituiçẽos não esta localizada na rgião norte
# - instituições com mais receitas tendem a ter mais livros eletrônicos.
# - A análise realizada é de correlação

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quarto', 0, 17, 3, 14, 3, 2]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'quarto'))
# Out:
# **Análise do Cluster**
#
# Considerando o CSV fornecido, vamos realizar uma análise estatística e exploratória para entender melhor o cluster.
#
# ** QT_ALUNOS**: "A média de alunos é de 500, com uma mediana de 400 e uma moda de 300. É interessante notar que a distribuição dos alunos parece ser simétrica, sugerindo que pode haver uma relação entre a quantidade de alunos e o tamanho da instituição."
#
# ** QT_DOCENTES**: "A média de docentes é de 20, com uma mediana de 15 e uma moda de 10. É surpreendente notar que a quantidade de docentes parece estar inversamente relacionada à quantidade de alunos, sugerindo que possivelmente as instituições com mais alunos têm menos docentes."
#
# ** QT_CURSO**: "A média de cursos é de 5, com uma mediana de 3 e uma moda de 2. É interessante notar que a quantidade de cursos parece estar relacionada à quantidade de alunos e docentes, sugerindo que as instituições com mais alunos e docentes podem ter mais cursos."
#
# ** QT_TEC_TOTAL**: "A média de técnicos é de 5, com uma mediana de 3 e uma moda de 2. É surpreendente notar que a quantidade de técnicos parece estar inversamente relacionada à quantidade de alunos e docentes, sugerindo que possivelmente as instituições com mais alunos e docentes têm menos técnicos."
#
# ** QT_PERIODICO_ELETRONICO**: "A média de periodicos eletronicos é de 2, com uma mediana de 1 e uma moda de 0. É interessante notar que a quantidade de periodicos eletronicos parece estar relacionada à quantidade de alunos e docentes, sugerindo que as instituições com mais alunos e docentes podem ter mais periodicos eletronicos."
#
# ** QT_LIVRO_ELETRONICO**: "A média de livros eletronicos é de 1, com uma mediana de 0 e uma moda de 0. É surpreendente notar que a quantidade de livros eletronicos parece estar inversamente relacionada à quantidade de alunos e docentes, sugerindo que possivelmente as instituições com mais alunos e docentes têm menos livros eletronicos."
#
# ** T1_VL_RECEITAS**: "A média de receita é de 10.000.000, com uma mediana de 5.000.000 e uma moda de 0. É interessante notar que a quantidade de receita parece estar relacionada à quantidade de alunos e docentes, sugerindo que as instituições com mais alunos e docentes podem ter mais receita."
#
# ** T1_VL_DESPESAS**: "A média de despesas é de 5.000.000, com uma mediana de 2.500.000 e uma moda de 0. É surpreendente notar que a quantidade de despesas parece estar inversamente relacionada à quantidade de alunos e docentes, sugerindo que possivelmente as instituições com mais alunos e docentes têm menos despesas."
#
# ** IN_CAPITAL**: "A média de instituições na capital é de 0,75, com uma mediana de 0 e uma moda de 0. É interessante notar que a quantidade de instituições na capital parece estar relacionada à quantidade de alunos e docentes, sugerindo que as instituições com mais alunos e docentes podem ter mais chances de estar localizadas na capital."
#
# ** IN_OUTRAS_BASES**: "A média de instituições com outras bases é de 0,5, com uma mediana de 0 e uma moda de 0. É surpreendente notar que a quantidade de instituições com outras bases parece estar inversamente relacionada à quantidade de alunos e docentes, sugerindo que possivelmente as instituições com mais alunos e docentes têm menos chances de ter outras bases."
#
# ** IN_REPOSITORIO_INSTITUCIONAL**: "A média de instituições com repositorio institucional é de 0,75, com uma mediana de 0 e uma moda de 0. É interessante notar que a quantidade de instituições com repositorio institucional parece estar relacionada à quantidade de alunos e docentes, sugerindo que as instituições com mais alunos e docentes podem ter mais chances de ter um repositorio institucional."
#
# ** IN_BUSCA_INTEGRADA**: "A média de instituições com busca integrada é de 0,5, com uma mediana de 0 e uma moda de 0. É surpreendente notar que a quantidade de instituições com busca integrada parece estar inversamente relacionada à quantidade de alunos e docentes, sugerindo que possivelmente as instituições com mais alunos e docentes têm menos chances de ter uma busca integrada."
#
# ** IN_SERVICO_INTERNET**: "A média de instituições com serviço de internet é de 0,75, com uma mediana de 0 e uma moda de 0. É interessante notar que a quantidade de instituições com serviço de internet parece estar relacionada à quantidade de alunos e docentes, sugerindo que as instituições com mais alunos e docentes podem ter mais chances de ter um serviço de internet."
#
# ** IN_PARTICIPA_REDE_SOCIAL**: "A média de instituições que participam das redes sociais é de 0,5, com uma mediana de 0 e uma moda de 0. É surpreendente notar que a quantidade de instituições que participam das redes sociais parece estar inversamente relacionada à quantidade de alunos e docentes, sugerindo que possivelmente as instituições com mais alunos e docentes têm menos chances de participar das redes sociais."
#
# ** IN_CATALOGO_ONLINE**: "A média de instituições com catalogo online é de 0,75, com uma mediana de 0 e uma moda de 0. É interessante notar que a quantidade de instituições com catalogo online parece estar relacionada à quantidade de alunos e docentes, sugerindo que as instituições com mais alunos e docentes podem ter mais chances de ter um catalogo online."
#
# ** INstituições na capital com receita maior que 10.000.000: 2**
# **Instituições nas outras bases com receita menor que 5.000.000: 3**
#
# É importante notar que as observações feitas acima são apenas uma análise superficial e podem não refletir a realidade da situação. Além disso, é fundamental considerar outros fatores que podem influenciar a situação das instituições de ensino superior, como a qualidade do ensino, a disponibilidade de recursos e o impacto social das instituições.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOT OK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOT OK
# - Uma incidência das IES não estarem numa capital (68.85%)NOT OK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) NOT OK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOT OK
# - Predominância em participar em redes sociais (71.20%) NOT OK
# - Possuem predominância em ter catalogo online (79.45%) NOT OK
# - Possuem predominância em ter outras bases (73.43%) NOT OK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) (98,04) NOT OK
# - Maioria dos anos da IES são Faculdade (99.15%) NOT OK
#
# - Quantidade de técnicos na média baixo (33.68	) NOT OK
# - Quantidade de alunos média de alunos  moderado (932.89)NOT OK
# - Corpo docente muito na média (45.12) NOT OK
# - Pouca quantidade média de cursos (6.21) NOT OK
# - Despesas e receitas média acima do moderado NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOT OK
#
# Insights:
# - instituições com mais alunos e docentes podem ter mais chances de ter um repositorio institucional

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quarto', 0.5, 17, 7, 10, 3, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'quarto'))
# Out:
# **Análise Estatística**
#
# A seguir, apresentamos as análises estatísticas para cada variável:
#
# * **QT_ALUNOS**: Média = 500, Mediana = 450, Moda = 400 (aparece mais de uma vez). Verificar relação com: QT_DOCENTES.
# * **QT_DOCENTES**: Média = 80, Mediana = 70, Moda = 60 (aparece mais de uma vez). Verificar relação com: QT_ALUNOS.
# * **QT_CURSO**: Média = 10, Mediana = 9, Moda = 8. Não há relação estatística significativa com outras variáveis.
# * **QT_TEC_TOTAL**: Média = 20, Mediana = 18, Moda = 15 (aparece mais de uma vez). Verificar relação com: QT-periodico_eletronico e QT_LIVRO_ELETRONICO.
# * **QT_PERIODICO_ELETRONICO**: Média = 5, Mediana = 4, Moda = 3. Verificar relação com: QT_TEC_TOTAL e QT_LIVRO_ELETRONICO.
# * **QT_LIVRO_ELETRONICO**: Média = 2, Mediana = 1, Moda = 0 (aparece mais de uma vez). Verificar relação com: QT_PERIODICO_ELETRONICO e QT_TEC_TOTAL.
# * **T1_VL_RECEITAS**: Média = 10.000.000, Mediana = 8.500.000, Moda = 7.000.000. Verificar relação com: T1_VL_DESPESAS e IN_CAPITAL.
# * **T1_VL_DESPESAS**: Média = 2.000.000, Mediana = 1.800.000, Moda = 1.500.000. Verificar relação com: T1_VL_RECEITAS e IN_CAPITAL.
# * **IN_CAPITAL**: Sim/Não (aproximadamente 50% sim, 50% não). Não há relação estatística significativa com outras variáveis.
# * **IN_OUTRAS_BASES**: Sim/Não (aproximadamente 30% sim, 70% não). Verificar relação com: IN_REPOSITORIO_INSTITUCIONAL e IN_BUSCA_INTEGRADA.
# * **IN_REPOSITORIO_INSTITUCIONAL**: Sim/Não (aproximadamente 60% sim, 40% não). Verificar relação com: IN_OUTRAS_BASES e IN_BUSCA_INTEGRADA.
# * **IN_BUSCA_INTEGRADA**: Sim/Não (aproximadamente 80% sim, 20% não). Verificar relação com: IN_REPOSITORIO_INSTITUCIONAL e IN_SERVICO_INTERNET.
# * **IN_SERVICO_INTERNET**: Sim/Não (aproximadamente 90% sim, 10% não). Não há relação estatística significativa com outras variáveis.
# * **IN_PARTICIPA_REDE_SOCIAL**: Sim/Não (aproximadamente 40% sim, 60% não). Verificar relação com: IN_CATALOGO_ONLINE e IN_ACESSO_PORTAL_CAPES.
# * **IN_CATALOGO_ONLINE**: Sim/Não (aproximadamente 70% sim, 30% não). Verificar relação com: IN_PARTICIPA_REDE_SOCIAL e IN_ACESSO_PORTAL_CAPES.
# * **IN_ACESSO_PORTAL_CAPES**: Sim/Não (aproximadamente 95% sim, 5% não). Não há relação estatística significativa com outras variáveis.
# * **NU_ANO_CENSO**: Ano (aproximadamente 70 anos, média 2000). Não há relação estatística significativa com outras variáveis.
# * **CO_REGIAO**: Região (aproximadamente 30% Sul, 20% Norte, 50% Central). Não há relação estatística significativa com outras variáveis.
# * **NOME_CATEGORIA_ADMINISTRATIVA**: Categorização administrativa (aproximadamente 40% Administração Pública, 30% Privada, 30% Associativa). Não há relação estatística significativa com outras variáveis.
# * **NOME_ORGANIZACAO_ACADEMICA**: Organização acadêmica (aproximadamente 60% Federação, 20% União, 20% Independente). Não há relação estatística significativa com outras variáveis.
#
# **Inferências**
#
# Com base nos resultados, podemos inferir:
#
# * As instituições com mais alunos tendem a ter mais docentes.
# * As instituições com mais técnicos tendem a ter mais periodicos eletronicos e livros eletronicos.
# * A receita das instituições é maior quando elas estão na capital e têm um custo menor.
# * O serviço de internet é mais comum em instituições que buscam integração e têm uma presença online forte.
#
# **Análise Geral do Agrupamento**
#
# Diante dos resultados, podemos observar que as instituições podem ser agrupadas de acordo com suas características estatísticas. As instituições com mais alunos e docentes tendem a ter mais recursos e uma presença online mais forte. No entanto, é importante notar que há uma grande variedade de características entre as instituições, e não todas elas podem ser explicadas por apenas algumas variáveis.
#
# Além disso, é importante observar que as instituições na capital tendem a ter uma receita maior e um custo menor, o que sugere que elas podem ter mais recursos disponíveis. No entanto, também há instituições que estão fora da capital mas têm uma presença online forte, o que sugere que há outras características importantes para considerar.
#
# Em resumo, as análises estatísticas e inferências sugerem que as instituições podem ser agrupadas de acordo com suas características estatísticas, mas é importante considerar a variedade de características entre as instituições e não se limitar apenas às variáveis mais óbvias.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOT OK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOT OK
# - Uma incidência das IES não estarem numa capital (68.85%)NOT OK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) NOT OK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOT OK
# - Predominância em participar em redes sociais (71.20%) NOT OK
# - Possuem predominância em ter catalogo online (79.45%) NOT OK
# - Possuem predominância em ter outras bases (73.43%) NOT OK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) (98,04) NOT OK
# - Maioria dos anos da IES são Faculdade (99.15%) NOT OK
#
# - Quantidade de técnicos na média baixo (33.68	) NOT OK
# - Quantidade de alunos média de alunos  moderado (932.89)NOT OK
# - Corpo docente muito na média (45.12) NOT OK
# - Pouca quantidade média de cursos (6.21) NOT OK
# - Despesas e receitas média acima do moderado NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOT OK
#
# Insights:
# -  instituições na capital tendem a ter uma receita maior e um custo menor, o que sugere que elas podem ter mais recursos disponíveis
# - A análise é baseada ter relevancia significativa ou não.

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quarto', 1.0, 17, 4, 13, 3, 1]

# %% [markdown]
# ### Firth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'quinto'))
# Out:
# **Coluna**: QT_ALUNOS
# "Analise estatística: A média da variável é de 150, a mediana é de 120 e a moda é de 100. Essa variável está relacionada com a quantidade de alunos que compõem o agrupamento. É provável que a instituição tenha uma população acadêmica em crescimento."
#
# **Inferências**: "A alta média da variável pode indicar uma instituição com uma população academia mais desenvolvida, o que pode estar relacionado à qualidade dos cursos oferecidos."
#
# **Análise geral do agrupamento**: "Essa variável está estreitamente relacionada com a quantidade de alunos e pode ser um indicador da importância da educação no agrupamento. A instituição pode estar enfatizando a educação como uma prioridade."
#
# **Coluna**: QT_DOCENTES
# "Analise estatística: A média da variável é de 50, a mediana é de 40 e a moda é de 30. Essa variável está relacionada com a quantidade de docentes que compõem o agrupamento. É provável que a instituição tenha uma equipe docente relativamente pequena."
#
# **Inferências**: "A média da variável pode indicar uma instituição com uma equipe docente mais restrita, o que pode estar relacionado à capacidade de oferecer cursos de qualidade."
#
# **Análise geral do agrupamento**: "Essa variável está estreitamente relacionada com a quantidade de docentes e pode ser um indicador da importância da formação acadêmica no agrupamento. A instituição pode estar investindo em qualificação dos seus professores para melhorar os cursos."
#
# **Coluna**: QT_CURSO
# "Analise estatística: A média da variável é de 20, a mediana é de 15 e a moda é de 10. Essa variável está relacionada com a quantidade de cursos que compõem o agrupamento. É provável que a instituição tenha uma oferta curricular limitada."
#
# **Inferências**: "A média da variável pode indicar uma instituição com uma oferta curricular mais restrita, o que pode estar relacionado à falta de diversidade em cursos oferecidos."
#
# **Análise geral do agrupamento**: "Essa variável está estreitamente relacionada com a quantidade de cursos e pode ser um indicador da importância da formação em diferentes áreas no agrupamento. A instituição pode estar enfatizando a formação em uma área específica."
#
# **Coluna**: QT_TEC_TOTAL
# "Analise estatística: A média da variável é de 10, a mediana é de 8 e a moda é de 5. Essa variável está relacionada com a quantidade de técnicos que compõem o agrupamento. É provável que a instituição tenha uma equipe técnica relativamente pequena."
#
# **Inferências**: "A média da variável pode indicar uma instituição com uma equipe técnica mais restrita, o que pode estar relacionado à capacidade de oferecer cursos técnicos de qualidade."
#
# **Análise geral do agrupamento**: "Essa variável está estreitamente relacionada com a quantidade de técnicos e pode ser um indicador da importância da formação técnica no agrupamento. A instituição pode estar investindo em qualificação dos seus técnicos para melhorar os cursos."
#
# **Coluna**: QT_PERIODICO_ELETRONICO
# "Analise estatística: A média da variável é de 50, a mediana é de 40 e a moda é de 30. Essa variável está relacionada com a quantidade de periodicos eletronicos que compõem o agrupamento. É provável que a instituição tenha uma oferta bibliográfica rica."
#
# **Inferências**: "A média da variável pode indicar uma instituição com uma oferta bibliográfica mais abundante, o que pode estar relacionado à qualidade dos cursos oferecidos."
#
# **Análise geral do agrupamento**: "Essa variável está estreitamente relacionada com a quantidade de periodicos eletronicos e pode ser um indicador da importância da formação em áreas científicas no agrupamento. A instituição pode estar enfatizando a pesquisa como uma prioridade."
#
# **Coluna**: QT_LIVRO_ELETRONICO
# "Analise estatística: A média da variável é de 20, a mediana é de 15 e a moda é de 10. Essa variável está relacionada com a quantidade de livros eletronicos que compõem o agrupamento. É provável que a instituição tenha uma oferta bibliográfica limitada."
#
# **Inferências**: "A média da variável pode indicar uma instituição com uma oferta bibliográfica mais restrita, o que pode estar relacionado à falta de diversidade em livros eletronicos oferecidos."
#
# **Análise geral do agrupamento**: "Essa variável está estreitamente relacionada com a quantidade de livros eletronicos e pode ser um indicador da importância da formação em áreas específicas no agrupamento. A instituição pode estar enfatizando a formação em áreas específicas."
#
# **Coluna**: T1_VL_RECEITAS
# "Analise estatística: A média da variável é de 1000, a mediana é de 800 e a moda é de 600. Essa variável está relacionada com a receita da instituição. É provável que a instituição tenha uma fonte de renda significativa."
#
# **Inferências**: "A média da variável pode indicar uma instituição com uma fonte de renda mais estabelecida, o que pode estar relacionado à capacidade de oferecer cursos de qualidade e gerar receita."
#
# **Análise geral do agrupamento**: "Essa variável está estreitamente relacionada com a receita da instituição e pode ser um indicador da importância da gerência financeira no agrupamento. A instituição pode estar investindo em gestão de recursos para melhorar a qualidade dos cursos."
#
# **Coluna**: T1_VL_RECEITAS
# "Analise estatística: A média da variável é de 1000, a mediana é de 800 e a moda é de 600. Essa variável está relacionada com a receita da instituição. É provável que a instituição tenha uma fonte de renda significativa."
#
# **Inferências**: "A média da variável pode indicar uma instituição com uma fonte de renda mais estabelecida, o que pode estar relacionado à capacidade de oferecer cursos de qualidade e gerar receita."
#
# **Análise geral do agrupamento**: "Essa variável está estreitamente relacionada com a receita da instituição e pode ser um indicador da importância da gerência financeira no agrupamento. A instituição pode estar investindo em gestão de recursos para melhorar a qualidade dos cursos."
#
# **Coluna**: T1_VL_RECEITAS
# "Analise estatística: A média da variável é de 1000, a mediana é de 800 e a moda é de 600. Essa variável está relacionada com a receita da instituição. É provável que a instituição tenha uma fonte de renda significativa."
#
# **Inferências**: "A média da variável pode indicar uma instituição com uma fonte de renda mais estabelecida, o que pode estar relacionado à capacidade de oferecer cursos de qualidade e gerar receita."
#
# **Análise geral do agrupamento**: "Essa variável está estreitamente relacionada com a receita da instituição e pode ser um indicador da importância da gerência financeira no agrupamento. A instituição pode estar investindo em gestão de recursos para melhorar a qualidade dos cursos."

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOT OK
# - Uma incidência das IES não estarem numa capital (59.17%)NOT OK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) NOT OK
# - Possuem predominância em busca integrada (77.90%) NOT OK
# - Possuem serviço de internet (97.47%) NOT OK
# - Predominância em participar em redes sociais (60.40%) NOT OK
# - Possuem catalogo online (85.57%) NOT OK
# - Possuem predominância em ter outras bases (78.28%) NOT OK
# - Maioria das instituições são privada (com e sem fins lucrativos) (96,85) NOT OK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) NOT OK
#
# - Quantidade de técnicos médio moderado (143.65) NOT OK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) NOT OK
# - Corpo docente muito acima da  média (151.18) NOT OK
# - Moderada quantidade média de cursos (18.49)NOT OK
# - Despesas e receitas média altas OK
# - Quantidade de periodicos e livros eletronicos com relevância alto  OK
#
# Insights:
# - equipe docente relativamente pequena
# - A análise é pautada entre análise estatítica e inferências

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quinto', 0, 16, 4, 12, 3, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'quinto'))
# Out:
# **Coluna**: QT_ALUNOS
# "Analise estatística: Mediana = 250,0, Variância = 120,00. Verificar relação com T1_VL_RECEITAS e IN_CAPITAL"
#
# **Inferências**: A instituição com maior quantidade de alunos tem uma média de 250 alunos, o que pode indicar um grande número de estudantes. Além disso, a variância é alta, sugerindo uma distribuição desigual dos alunos.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de alunos, o que pode ser relacionado à sua categorização administrativa (NOME_CATEGORIA_ADMINISTRATIVA) e à sua localização geográfica (CO_REGIAO).
#
# **Coluna**: QT_DOCENTES
# "Analise estatística: Média = 150,0, Variância = 90,00. Verificar relação com IN_CAPITAL e IN_REPOSITORIO_INSTITUCIONAL"
#
# **Inferências**: A instituição com maior quantidade de docentes tem uma média de 150 docentes, o que pode indicar um professorado comprometido com a educação. A variância é alta, sugerindo uma distribuição desigual dos docentes.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de docentes, especialmente aquelas localizadas na capital (IN_CAPITAL) ou que possuem um repositorio institucional (IN_REPOSITORIO_INSTITUCIONAL).
#
# **Coluna**: QT_CURSO
# "Analise estatística: Moda = 20,0, Mediana = 15,0. Verificar relação com IN_BUSCA_INTEGRADA e IN_SERVICO_INTERNET"
#
# **Inferências**: A instituição com maior quantidade de cursos tem uma moda de 20 cursos, o que pode indicar um foco em desenvolvimento de currículos. A mediana é menor, sugerindo uma distribuição desigual dos cursos.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de cursos, especialmente aquelas que possuem uma busca integrada (IN_BUSCA_INTEGRADA) ou um serviço de internet (IN_SERVICO_INTERNET).
#
# **Coluna**: QT_TEC_TOTAL
# "Analise estatística: Média = 100,0, Variância = 50,00. Verificar relação com IN_REPOSITORIO_INSTITUCIONAL e IN_CATALOGO_ONLINE"
#
# **Inferências**: A instituição com maior quantidade de técnicos tem uma média de 100 técnicos, o que pode indicar um foco em desenvolvimento de tecnologias. A variância é alta, sugerindo uma distribuição desigual dos técnicos.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de técnicos, especialmente aquelas que possuem um repositorio institucional (IN_REPOSITORIO_INSTITUCIONAL) ou um catalogo online (IN_CATALOGO_ONLINE).
#
# **Coluna**: QT_PERIODICO_ELETRONICO
# "Analise estatística: Medida = 50. Verificar relação com IN_SERVICO_INTERNET"
#
# **Inferências**: A instituição com maior quantidade de periodicos eletronicos tem uma medida significativa, o que pode indicar um foco em desenvolvimento de recursos digitais.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de periodicos eletronicos, especialmente aquelas que possuem um serviço de internet (IN_SERVICO_INTERNET).
#
# **Coluna**: QT_LIVRO_ELETRONICO
# "Analise estatística: Medida = 20. Verificar relação com IN_CATALOGO_ONLINE"
#
# **Inferências**: A instituição com maior quantidade de livros eletronicos tem uma medida significativa, o que pode indicar um foco em desenvolvimento de recursos digitais.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de livros eletronicos, especialmente aquelas que possuem um catalogo online (IN_CATALOGO_ONLINE).
#
# **Coluna**: T1_VL_RECEITAS
# "Analise estatística: Média = 500.000,00, Variância = 200.000,00"
#
# **Inferências**: A instituição com maior receita tem uma média de R$ 500.000,00, o que pode indicar um grande sucesso econômico.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de receita, especialmente aquelas categorizadas como administrativas (NOME_CATEGORIA_ADMINISTRATIVA) e localizadas na capital (IN_CAPITAL).
#
# **Coluna**: T1_VL_DESPESAS
# "Analise estatística: Média = 300.000,00, Variância = 100.000,00"
#
# **Inferências**: A instituição com maior despesa tem uma média de R$ 300.000,00, o que pode indicar um alto custo de operação.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de despesas, especialmente aquelas categorizadas como administrativas (NOME_CATEGORIA_ADMINISTRATIVA) e localizadas na capital (IN_CAPITAL).
#
# **Coluna**: IN_CAPITAL
# "Analise estatística: Frequência = 60%. Verificar relação com T1_VL_RECEITAS e NOME_CATEGORIA_ADMINISTRATIVA"
#
# **Inferências**: A instituição com maior probabilidade de ser localizada na capital tem uma frequência significativa, o que pode indicar um grande número de recursos econômicos.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de recursos econômicos, especialmente aquelas localizadas na capital (IN_CAPITAL) e categorizadas como administrativas (NOME_CATEGORIA_ADMINISTRATIVA).
#
# **Coluna**: IN_REPOSITORIO_INSTITUCIONAL
# "Analise estatística: Frequência = 80%. Verificar relação com QT_TEC_TOTAL e IN_CATALOGO_ONLINE"
#
# **Inferências**: A instituição com maior probabilidade de possuir um repositorio institucional tem uma frequência significativa, o que pode indicar um grande desenvolvimento tecnológico.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de recursos tecnológicos, especialmente aquelas que possuem um repositorio institucional (IN_REPOSITORIO_INSTITUCIONAL) ou um catalogo online (IN_CATALOGO_ONLINE).
#
# **Coluna**: IN_SERVICO_INTERNET
# "Analise estatística: Frequência = 70%. Verificar relação com QT_PERIODICO_ELETRONICO e IN_CATALOGO_ONLINE"
#
# **Inferências**: A instituição com maior probabilidade de possuir um serviço de internet tem uma frequência significativa, o que pode indicar um grande desenvolvimento digital.
#
# **Análise geral do agrupamento**: O cluster tende a ter instituições com números significativos de recursos digitais, especialmente aquelas que possuem um serviço de internet (IN_SERVICO_INTERNET) ou um catalogo online (IN_CATALOGO_ONLINE).
#
# Essas são as principais conclusões alcançadas após analisar os dados dos indicadores. Cada uma das categorias de índices apresenta padrões específicos que permitem identificar instituições com características econômicas e tecnológicas destacadas.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOT OK
# - Uma incidência das IES não estarem numa capital (59.17%) NOT OK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) NOT OK
# - Possuem predominância em busca integrada (77.90%)  OK
# - Possuem serviço de internet (97.47%) NOT OK
# - Predominância em participar em redes sociais (60.40%) NOT OK
# - Possuem catalogo online (85.57%) NOT OK
# - Possuem predominância em ter outras bases (78.28%) OK
# - Maioria das instituições são privada (com e sem fins lucrativos) (96,85)
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) NOT OK
#
# - Quantidade de técnicos médio moderado (143.65) NOT OK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) NOT OK
# - Corpo docente muito acima da  média (151.18) NOT OK
# - Moderada quantidade média de cursos (18.49)NOT OK
# - Despesas e receitas média altas NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOT OK
#
# Insights:
# - Não detalha todas as variaveis de influência

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quinto', 0.5, 16, 5, 11, 3, 1]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'quinto'))
# Out:
# **Coluna**: QT_ALUNOS
# "Analise estatística da variável: Mediana = 50,00, Variação padrão (σ) = 20,00. Verificar relação com IN_CAPITAL, pois instituições na capital tendem a ter mais alunos."
#
# **Inferências**: Conclusão: A mediana de QT_ALUNOS é significativamente maior do que a média geral de instituições, indicando uma relação inversa entre a localização da instituição e a quantidade de alunos.
#
# **Análise geral do agrupamento**: O agrupamento tem uma concentração grande de instituições com mais alunos, sugerindo que essas instituições podem ter um foco na educação ou em outros serviços que atraem mais estudantes. Além disso, as instituições na capital tendem a ter mais alunos, indicando uma relação positiva entre a localização e a quantidade de alunos.
#
# **Coluna**: QT_DOCENTES
# "Analise estatística da variável: Média = 30,00, Variação padrão (σ) = 10,00. Verificar relação com IN_CAPITAL, pois instituições na capital tendem a ter mais docentes."
#
# **Inferências**: Conclusão: A média de QT_DOCENTES é significativamente maior do que a média geral de instituições, indicando uma relação inversa entre a localização da instituição e a quantidade de docentes. Além disso, as instituições na capital tendem a ter mais docentes, sugerindo uma concentração de recursos humanos em áreas centrais do país.
#
# **Análise geral do agrupamento**: O agrupamento tem uma concentração grande de instituições com mais docentes, indicando que essas instituições podem ter um foco na educação ou em outros serviços que requerem mais profissionais. As instituições na capital tendem a ter mais recursos humanos, sugerindo uma relação positiva entre a localização e a quantidade de docentes.
#
# **Coluna**: QT_CURSO
# "Analise estatística da variável: Moda = 5, Variação padrão (σ) = 2,00. Verificar relação com IN_REPOSITORIO_INSTITUCIONAL, pois instituições com repositorio tendem a ter mais cursos."
#
# **Inferências**: Conclusão: A moda de QT_CURSO é significativamente menor do que a média geral de instituições, indicando uma relação inversa entre a presença de um repositorio e a quantidade de cursos. Além disso, as instituições com repositorio tendem a ter mais cursos, sugerindo uma concentração de recursos em áreas específicas.
#
# **Análise geral do agrupamento**: O agrupamento tem uma concentração grande de instituições com menos cursos, indicando que essas instituições podem ter um foco em serviços ou atividades específicas. As instituições com repositorio tendem a ter mais recursos e mais cursos, sugerindo uma relação positiva entre a presença de um repositorio e a quantidade de cursos.
#
# **Coluna**: QT_TEC_TOTAL
# "Analise estatística da variável: Variação padrão (σ) = 15,00. Verificar relação com IN_SERVICO_INTERNET, pois instituições com serviço de internet tendem a ter mais técnicos."
#
# **Inferências**: Conclusão: A variação padrão de QT_TEC_TOTAL é significativamente maior do que a média geral de instituições, indicando uma relação inversa entre a presença de um serviço de internet e a quantidade de técnicos. Além disso, as instituições com serviço de internet tendem a ter mais técnicos, sugerindo uma concentração de recursos humanos em áreas específicas.
#
# **Análise geral do agrupamento**: O agrupamento tem uma concentração grande de instituições com menos técnicos, indicando que essas instituições podem ter um foco em serviços ou atividades específicas. As instituições com serviço de internet tendem a ter mais recursos humanos, sugerindo uma relação positiva entre a presença de um serviço de internet e a quantidade de técnicos.
#
# **Coluna**: IN_CAPITAL
# "Analise estatística da variável: Frequência = 60%, Verificar relação com QT_ALUNOS, pois instituições na capital tendem a ter mais alunos."
#
# **Inferências**: Conclusão: A frequência de IN_CAPITAL é significativamente maior do que a média geral de instituições, indicando uma relação inversa entre a localização da instituição e a quantidade de alunos. Além disso, as instituições na capital tendem a ter mais recursos humanos e mais serviços, sugerindo uma concentração de recursos em áreas centrais do país.
#
# **Análise geral do agrupamento**: O agrupamento tem uma concentração grande de instituições com mais recursos humanos e mais serviços, indicando que essas instituições podem ter um foco na educação ou em outros serviços que atraem mais estudantes. As instituições na capital tendem a ter mais alunos, sugerindo uma relação positiva entre a localização e a quantidade de alunos.
#
# **Coluna**: NOME_CATEGORIA_ADMINISTRATIVA
# "Analise estatística da variável: Frequência = 30%, Verificar relação com IN_CAPITAL, pois instituições na capital tendem a ter mais recursos administrativos."
#
# **Inferências**: Conclusão: A frequência de NOME_CATEGORIA_ADMINISTRATIVA é significativamente maior do que a média geral de instituições, indicando uma relação inversa entre a localização da instituição e a quantidade de recursos administrativos. Além disso, as instituições na capital tendem a ter mais recursos administrativos, sugerindo uma concentração de recursos em áreas centrais do país.
#
# **Análise geral do agrupamento**: O agrupamento tem uma concentração grande de instituições com mais recursos administrativos, indicando que essas instituições podem ter um foco na administração ou em outros serviços que requerem mais recursos. As instituições na capital tendem a ter mais recursos humanos e mais serviços, sugerindo uma relação positiva entre a localização e a quantidade de recursos administrativos.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOT OK
# - Uma incidência das IES não estarem numa capital (59.17%) NOT OK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) NOT OK
# - Possuem predominância em busca integrada (77.90%) OK
# - Possuem serviço de internet (97.47%) OK
# - Predominância em participar em redes sociais (60.40%) NOT OK
# - Possuem catalogo online (85.57%) OK
# - Possuem predominância em ter outras bases (78.28%) NOT OK
# - Maioria das instituições são privada (com e sem fins lucrativos) (96,85) NOT OK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) NOT OK
#
# - Quantidade de técnicos médio moderado (143.65) NOT OK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) NOT OK
# - Corpo docente muito acima da  média (151.18) NOT OK
# - Moderada quantidade média de cursos (18.49)NOT OK
# - Despesas e receitas média altas NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOT OK
#
# Insights:
# - `IN_SERVICO_INTERNET`, pois instituições com serviço de internet tendem a ter mais técnicos.
# - As instituições na capital tendem a ter mais recursos humanos e mais serviços, sugerindo uma relação positiva entre a localização e a quantidade de recursos administrativos. (Isto é evidenciado por ter um corpo docente acima da média)

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quinto', 1.0, 16, 6, 10, 1, 0]

# %% [markdown]
# ### Sixth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'sexto'))
# Out:
# **Coluna**: Quantidade de alunos (QT_ALUNOS)
#
# * Analise estatística: Mediana da variável é 200, com uma moda de 300 e uma média de 250.
# * Relação com outra variável: Existe uma relação positiva entre a quantidade de alunos e a média das receitas da instituição (T1_VL_RECEITAS), com uma correlação de Pearson de 0,8.
#
# **Inferências**: Pode-se concluir que as instituições com mais alunos tendem a ter maior receita, sugerindo que o tamanho do grupo pode ser um fator importante para o sucesso da instituição.
#
# **Análise geral do agrupamento**: A quantidade de alunos é um dos principais fatores que contribuem para o sucesso das instituições. Além disso, existem instituições com quantidades médias e baixas de alunos que ainda possuem receita significativa, sugerindo que outros fatores, como a qualidade da educação ou a disponibilidade de recursos, também desempenham um papel importante.
#
# **Coluna**: Quantidade de docentes (QT_DOCENTES)
#
# * Analise estatística: A moda da variável é 50, com uma média de 60 e uma mediana de 40.
# * Relação com outra variável: Não há relação significativa entre a quantidade de docentes e a receita das instituições.
#
# **Inferências**: Pode-se concluir que não há uma relação direta entre a quantidade de docentes e as receitas das instituições, sugerindo que outros fatores, como a qualidade da educação ou a disponibilidade de recursos, são mais importantes para o sucesso do grupo.
#
# **Análise geral do agrupamento**: A quantidade de docentes parece ser um fator secundário no sucesso das instituições. No entanto, é importante notar que existem instituições com quantidades médias e baixas de docentes que ainda possuem receita significativa, sugerindo que outros fatores, como a qualidade da educação ou a disponibilidade de recursos, também desempenham um papel importante.
#
# **Coluna**: Quantidade de cursos (QT_CURSO)
#
# * Analise estatística: A moda da variável é 100, com uma média de 120 e uma mediana de 90.
# * Relação com outra variável: Existe uma relação positiva entre a quantidade de cursos e a receita das instituições (T1_VL_RECEITAS), com uma correlação de Pearson de 0,7.
#
# **Inferências**: Pode-se concluir que as instituições com mais cursos tendem a ter maior receita, sugerindo que o número de cursos pode ser um fator importante para o sucesso da instituição.
#
# **Análise geral do agrupamento**: A quantidade de cursos é outro fator que contribui para o sucesso das instituições. Além disso, existem instituições com quantidades médias e baixas de cursos que ainda possuem receita significativa, sugerindo que outros fatores, como a qualidade da educação ou a disponibilidade de recursos, também desempenham um papel importante.
#
# **Coluna**: Quantidade de técnicos (QT_TEC_TOTAL)
#
# * Analise estatística: A moda da variável é 20, com uma média de 30 e uma mediana de 10.
# * Relação com outra variável: Não há relação significativa entre a quantidade de técnicos e as receitas das instituições.
#
# **Inferências**: Pode-se concluir que não há uma relação direta entre a quantidade de técnicos e as receitas das instituições, sugerindo que outros fatores, como a qualidade da educação ou a disponibilidade de recursos, são mais importantes para o sucesso do grupo.
#
# **Análise geral do agrupamento**: A quantidade de técnicos parece ser um fator secundário no sucesso das instituições. No entanto, é importante notar que existem instituições com quantidades médias e baixas de técnicos que ainda possuem receita significativa, sugerindo que outros fatores, como a qualidade da educação ou a disponibilidade de recursos, também desempenham um papel importante.
#
# **Coluna**: Quantidade de periodicos eletronicos (QT_PERIODICO_ELETRONICO)
#
# * Analise estatística: A moda da variável é 10, com uma média de 15 e uma mediana de 5.
# * Relação com outra variável: Existe uma relação positiva entre a quantidade de periodicos eletronicos e a receita das instituições (T1_VL_RECEITAS), com uma correlação de Pearson de 0,6.
#
# **Inferências**: Pode-se concluir que as instituições com mais periodicos eletronicos tendem a ter maior receita, sugerindo que o número de publicações pode ser um fator importante para o sucesso da instituição.
#
# **Análise geral do agrupamento**: A quantidade de periodicos eletronicos é outro fator que contribui para o sucesso das instituições. Além disso, existem instituições com quantidades médias e baixas de publicações que ainda possuem receita significativa, sugerindo que outros fatores, como a qualidade da educação ou a disponibilidade de recursos, também desempenham um papel importante.
#
# **Coluna**: Quantidade de livros eletronicos (QT_LIVRO_ELETRONICO)
#
# * Analise estatística: A moda da variável é 5, com uma média de 10 e uma mediana de 0.
# * Relação com outra variável: Existe uma relação positiva entre a quantidade de livros eletronicos e a receita das instituições (T1_VL_RECEITAS), com uma correlação de Pearson de 0,5.
#
# **Inferências**: Pode-se concluir que as instituições com mais livros eletronicos tendem a ter maior receita, sugerindo que o número de publicações pode ser um fator importante para o sucesso da instituição.
#
# **Análise geral do agrupamento**: A quantidade de livros eletronicos é outro fator que contribui para o sucesso das instituições. Além disso, existem instituições com quantidades médias e baixas de publicações que ainda possuem receita significativa, sugerindo que outros fatores, como a qualidade da educação ou a disponibilidade de recursos, também desempenham um papel importante.
#
# **Coluna**: Receita das instituições (T1_VL_RECEITAS)
#
# * Analise estatística: A moda da variável é 1000, com uma média de 1200 e uma mediana de 800.
# * Relação com outras variáveis: Existe uma relação positiva com as quantidades de cursos, periodicos eletronicos e livros eletronicos.
#
# **Inferências**: Pode-se concluir que as instituições com mais cursos, periodicos eletronicos e livros eletronicos tendem a ter maior receita. Além disso, existem instituições com quantidades médias e baixas de esses fatores que ainda possuem receita significativa.
#
# **Análise geral do agrupamento**: A receita das instituições é o objetivo final para as quais são utilizadas as outras variáveis. As instituições que têm mais cursos, periodicos eletronicos e livros eletronicos tendem a ter maior receita. Além disso, existem instituições com quantidades médias e baixas de esses fatores que ainda possuem receita significativa, sugerindo que outros fatores, como a qualidade da educação ou a disponibilidade de recursos, também desempenham um papel importante.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%) NOT OK
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%) NOT OK
# - Predominância das IES não estarem numa capital (69.21%) NOT OK
# - Predominância das Instituições sem acesso ao portal Capes (73.15%) NOT OK
# - Predominância das Instituições sem repositorio institucional (68.00%) NOT OK
# - Possuem predominância em busca integrada (65.43%) NOTOK
# - Possuem serviço de internet (90.62%) OK
# - Predominância em participar em redes sociais (65.28%) NOT OK
# - Possuem catalogo online (72.39%) NOT OK
# - Possuem predominância em ter outras bases (62.25%) NOT OK
# - Maioria das instituições são privada (com e sem fins lucrativos) (90,01%)NOT OK
# - Maioria dos anos da IES são Faculdade (95.39%) NOT OK
#
# - Quantidade de técnicos médio baixo (46.05	)  OK
# - Quantidade de alunos média de alunos  moderado (1,202.21) NOT OK
# - Corpo docente moderado na  média (60.92) NOT OK
# - Moderada quantidade baixa de cursos (16.76) NOT OK
# - Despesas e receitas média altas  NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância baixo NOT OK
#
# Insights falso:
# - As instituições com mais cursos, periodicos eletronicos e livros eletronicos tendem a ter maior receitas.

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'sexto', 0, 18, 9, 9, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'sexto'))
# Out:
# **Análise Estatística e Inferências**
#
# A seguir, apresentaremos as análises estatísticas e inferências para cada variável:
#
# *   **QT_ALUNOS**: A média da quantidade de alunos é de 200. A mediana é de 150 e a moda é de 100. Verificar relação com T1_VL_RECEITAS.
#     *   Inferências: A relação entre a quantidade de alunos e a receita da instituição pode indicar que as instituições com mais alunos têm maior receita.
# *   **QT_DOCENTES**: A média da quantidade de docentes é de 50. A mediana é de 40 e a moda é de 30. Verificar relação com IN_CAPITAL.
#     *   Inferências: As instituições na capital tendem a ter mais docentes, sugerindo uma maior importância política e econômica das instituições no censo.
# *   **QT_CURSO**: A média da quantidade de cursos é de 5. A mediana é de 3 e a moda é de 2. Verificar relação com NOME_ORGANIZACAO_ACADEMICA.
#     *   Inferências: As instituições com categorias administrativas mais altas tendem a ter mais cursos, sugerindo uma maior variedade e abrangência das atividades acadêmicas.
# *   **QT_TEC_TOTAL**: A média da quantidade de técnicos é de 20. A mediana é de 15 e a moda é de 10. Verificar relação com IN_REPOSITORIO_INSTITUCIONAL.
#     *   Inferências: As instituições com repositorio institucional tendem a ter mais técnicos, sugerindo uma maior abertura para colaborações e compartilhamento de conhecimentos.
# *   **QT_PERIODICO_ELETRONICO**: A média da quantidade de periodicos eletronicos é de 2. A mediana é de 1 e a moda é de 0. Verificar relação com IN_BUSCA_INTEGRADA.
#     *   Inferências: As instituições que têm busca integrada tendem a ter mais periodicos eletronicos, sugerindo uma maior importância para a visibilidade e o alcance das suas publicações.
# *   **QT_LIVRO_ELETRONICO**: A média da quantidade de livros eletronicos é de 1. A mediana é de 0 e a moda é de 0. Verificar relação com IN_CATALOGO_ONLINE.
#     *   Inferências: As instituições que têm catalogo online tendem a ter mais livros eletronicos, sugerindo uma maior facilidade para a busca e acesso aos seus recursos digitais.
#
# **Análise Geral do Agrupamento**
#
# A partir das análises estatísticas e inferências, podemos concluir que:
#
# *   As instituições com mais alunos tendem a ter maior receita, sugerindo uma relação positiva entre a quantidade de alunos e o rendimento.
# *   As instituições na capital tendem a ter mais docentes, sugerindo uma maior importância política e econômica das instituições no censo.
# *   As instituições com categorias administrativas mais altas tendem a ter mais cursos, sugerindo uma maior variedade e abrangência das atividades acadêmicas.
# *   As instituições com repositorio institucional tendem a ter mais técnicos, sugerindo uma maior abertura para colaborações e compartilhamento de conhecimentos.
# *   As instituições que têm busca integrada tendem a ter mais periodicos eletronicos, sugerindo uma maior importância para a visibilidade e o alcance das suas publicações.
#
# É importante notar que essas conclusões são baseadas apenas nos dados disponíveis e podem não refletir a realidade completa da instituição.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%)
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%)
# - Predominância das IES não estarem numa capital (69.21%)
# - Predominância das Instituições sem acesso ao portal Capes (73.15%)
# - Predominância das Instituições sem repositorio institucional (68.00%)
# - Possuem predominância em busca integrada (65.43%) NOTOK
# - Possuem serviço de internet (90.62%)
# - Predominância em participar em redes sociais (65.28%)
# - Possuem catalogo online (72.39%)
# - Possuem predominância em ter outras bases (62.25%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (90,01%)
# - Maioria dos anos da IES são Faculdade (95.39%)
#
# - Quantidade de técnicos médio baixo (46.05	)
# - Quantidade de alunos média de alunos  moderado (1,202.21)
# - Corpo docente moderado na  média (60.92)
# - Moderada quantidade baixa de cursos (16.76)
# - Despesas e receitas média altas
# - Quantidade de periodicos e livros eletronicos com relevância baixo
#
# Insights :

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'sexto', 0.5, 18, 4, 14, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'sexto'))
# Out:
# **Agrupamento dos Dados**
#
# **Coluna:** QT_ALUNOS
# *   **Análise estatística**: Mediana: 500,00; Média: 525,00 e Moda: 550,00. A quantidade de alunos é a variável mais comum no agrupamento.
# *   **Relação com outra variável**: Relacionada com QT_CURSO e T1_VL_RECEITAS.
#
# **Inferências**: Conclusão pode ser feita que as instituições com maior quantidade de alunos tendem a ter mais cursos e receita, o que sugere uma relação positiva entre o tamanho do agrupamento e sua capacidade de geração de receita.
#
# **Análise geral do agrupamento**: Embora a quantidade de alunos seja a variável mais presente, observa-se que a instituição com maior quantidade de alunos não é necessariamente a única com maior receita, o que sugere que outras variáveis são importantes para explicar o tamanho e os resultados das instituições.
#
# **Coluna:** QT_DOCENTES
# *   **Análise estatística**: Mediana: 250,00; Média: 300,00 e Moda: 350,00. A quantidade de docentes é menor do que a de alunos.
# *   **Relação com outra variável**: Relacionada com QT_CURSO.
#
# **Inferências**: Conclusão pode ser feita que as instituições com maior quantidade de alunos tendem a ter mais docentes e cursos, o que sugere uma relação positiva entre o tamanho do agrupamento e sua estrutura orgânica e acadêmica.
#
# **Análise geral do agrupamento**: A quantidade de docentes não parece ser um fator determinante para o tamanho do agrupamento, sugerindo que outras variáveis são mais importantes.
#
# **Coluna:** QT_CURSO
# *   **Análise estatística**: Mediana: 20; Média: 25 e Moda: 30. A quantidade de cursos é relativamente baixa.
# *   **Relação com outra variável**: Relacionada com T1_VL_RECEITAS.
#
# **Inferências**: Conclusão pode ser feita que as instituições com maior quantidade de alunos tendem a ter mais cursos e receita, o que sugere uma relação positiva entre o tamanho do agrupamento e sua capacidade de geração de receita.
#
# **Análise geral do agrupamento**: A pequena quantidade de cursos pode indicar que a instituição não se encontra no mercado para desenvolver novos cursos, ou pode estar focada em outras áreas.
#
# **Coluna:** QT_TEC_TOTAL
# *   **Análise estatística**: Mediana: 50; Média: 65 e Moda: 80. A quantidade de técnicos é relativamente baixa.
# *   **Relação com outra variável**: Relacionada com T1_VL_RECEITAS.
#
# **Inferências**: Conclusão pode ser feita que as instituições com maior quantidade de alunos tendem a ter mais técnicos e receita, o que sugere uma relação positiva entre o tamanho do agrupamento e sua capacidade de geração de receita.
#
# **Análise geral do agrupamento**: A baixa quantidade de técnicos pode indicar que a instituição não se encontra no mercado para desenvolver novos cursos ou que está focada em outras áreas.
#
# **Coluna:** QT_PERIODICO_ELETRONICO
# *   **Análise estatística**: Mediana: 20; Média: 25 e Moda: 30. A quantidade de periodicos eletronicos é relativamente baixa.
# *   **Relação com outra variável**: Relacionada com IN_REPOSITORIO_INSTITUCIONAL.
#
# **Inferências**: Conclusão pode ser feita que as instituições que têm repositorio institucional tendem a ter mais periodicos eletronicos, o que sugere uma relação positiva entre a presença do repositorio e a produção de conteúdo digital.
#
# **Análise geral do agrupamento**: A baixa quantidade de periodicos eletronicos pode indicar que a instituição não está ativamente envolvida com produções digitais, o que pode ser relacionado à falta de uma estratégia de comunicação digital eficaz.
#
# **Coluna:** QT_LIVRO_ELETRONICO
# *   **Análise estatística**: Mediana: 15; Média: 20 e Moda: 25. A quantidade de livros eletronicos é relativamente baixa.
# *   **Relação com outra variável**: Relacionada com IN_CATALOGO_ONLINE.
#
# **Inferências**: Conclusão pode ser feita que as instituições que têm catalogo online tendem a ter mais livros eletronicos, o que sugere uma relação positiva entre a presença do catalogo e a produção de conteúdo digital.
#
# **Análise geral do agrupamento**: A baixa quantidade de livros eletrônicos pode indicar que a instituição não está ativamente envolvida com produções digitais, o que pode ser relacionado à falta de uma estratégia de comunicação digital eficaz.
#
# **Coluna:** T1_VL_RECEITAS
# *   **Análise estatística**: Mediana: 100.000; Média: 150.000 e Moda: 200.000. A receita da instituição é o fator que mais se destaca no agrupamento.
# *   **Relação com outra variável**: Relacionada com QT_ALUNOS.
#
# **Inferências**: Conclusão pode ser feita que as instituições com maior quantidade de alunos tendem a ter maior receita, o que sugere uma relação positiva entre o tamanho do agrupamento e sua capacidade de geração de receita.
#
# **Análise geral do agrupamento**: A grande variedade das variáveis pode indicar que cada instituição tem características únicas que podem ser exploradas.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%) NOT OK
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%) NOT OK
# - Predominância das IES não estarem numa capital (69.21%) NOT OK
# - Predominância das Instituições sem acesso ao portal Capes (73.15%)
# - Predominância das Instituições sem repositorio institucional (68.00%) NOT OK
# - Possuem predominância em busca integrada (65.43%) NOTOK
# - Possuem serviço de internet (90.62%) NOT OK
# - Predominância em participar em redes sociais (65.28%) NOT OK
# - Possuem catalogo online (72.39%) NOT OK
# - Possuem predominância em ter outras bases (62.25%) NOT OK
# - Maioria das instituições são privada (com e sem fins lucrativos) (90,01%)NOT OK
# - Maioria dos anos da IES são Faculdade (95.39%) NOT OK
#
# - Quantidade de técnicos médio baixo (46.05	) OK
# - Quantidade de alunos média de alunos  moderado (1,202.21) NOT OK
# - Corpo docente moderado na  média (60.92) NOT OK
# - Moderada quantidade baixa de cursos (16.76) NOT OK
# - Despesas e receitas média altas NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância baixoNOT OK
#
# Insights :
# - Verificar relação com `IN_REPOSITORIO_INSTITUCIONAL`.

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'sexto', 1.0, 18, 3, 15, 0, 0]

# %% [markdown]
# ### Seventh Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'setimo'))
# Out:
# **Coluna**: QT_ALUNOS
# "Análise estatística: A média da quantidade de alunos é de 250. A mediana é de 200 e a moda é de 100. Verificar relação com outras variáveis, como QT_CURSO e T1_VL_RECEITAS."
#
# **Inferências**: "É possível que instituições com mais cursos tenham mais alunos, já que a média da quantidade de cursos é de 80, o que está abaixo da média geral do cluster (50). Além disso, as instituições com maior receita tendem a ter mais alunos."
#
# **Análise geral do agrupamento**: "As instituições com mais alunos tendem a ser aquelas com mais cursos e maior receita. É possível que essas instituições tenham uma estrutura de ensino mais completa e eficaz."
#
# **Coluna**: QT_DOCENTES
# "Análise estatística: A média da quantidade de docentes é de 120. A mediana é de 100 e a moda é de 80. Verificar relação com outras variáveis, como IN_CAPITAL e NOME_CATEGORIA_ADMINISTRATIVA."
#
# **Inferências**: "As instituições na capital tendem a ter mais docentes, já que 60% dos docentes estão localizados nesses lugares. Além disso, as instituições com categoria administrativa 'Municipal' têm mais docentes do que as de outras categorias."
#
# **Análise geral do agrupamento**: "As instituições na capital tendem a ter uma estrutura de ensino mais desenvolvida, com mais docentes e uma maior presença de instituições públicas. É possível que essas instituições tenham um impacto maior na sociedade."
#
# **Coluna**: QT_CURSO
# "Análise estatística: A média da quantidade de cursos é de 50. A mediana é de 40 e a moda é de 20. Verificar relação com outras variáveis, como T1_VL_RECEITAS e IN_CAPITAL."
#
# **Inferências**: "As instituições com maior receita tendem a ter mais cursos, já que a média da quantidade de cursos é de 80 (mais do que a média geral). Além disso, as instituições na capital tendem a ter mais cursos do que as outras."
#
# **Análise geral do agrupamento**: "As instituições com maior receita e localizadas na capital tendem a ter uma estrutura de ensino mais diversificada, com mais cursos. É possível que essas instituições tenham um impacto maior no mercado de trabalho."
#
# **Coluna**: QT_TEC_TOTAL
# "Análise estatística: A média da quantidade de técnicos é de 80. A mediana é de 70 e a moda é de 50. Verificar relação com outras variáveis, como IN_REPOSITORIO_INSTITUCIONAL e NOME_CATEGORIA_ADMINISTRATIVA."
#
# **Inferências**: "As instituições com repositorio institucional tendem a ter mais técnicos, já que 60% dos técnicos estão localizados nesses lugares. Além disso, as instituições com categoria administrativa 'Federal' têm mais técnicos do que as de outras categorias."
#
# **Análise geral do agrupamento**: "As instituições com repositorio institucional tendem a ter uma estrutura de ensino mais desenvolvida, com mais técnicos. É possível que essas instituições tenham um impacto maior no mercado de trabalho."
#
# Esses são os resultados da análise dos dados fornecidos. Cada coluna foi analisada estatisticamente e as inferências foram feitas com base nas relações observadas entre as variáveis. A análise geral do agrupamento permitiu entender o padrão mais amplo das instituições e suas características.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%) NOT OK
# - Predominância das Instituições com acesso ao portal Capes (87.76%) NOT OK
# - Predominância das Instituições com repositorio institucional (70.41%) OK
# - Possuem predominância em busca integrada (67.18%) NOT OK
# - Possuem serviço de internet (98.81%) NOT OK
# - Predominância em participar em redes sociais (71.94%) NOT OK
# - Possuem catalogo online (92.69%) NOT OK
# - Possuem predominância em ter outras bases (91.16%) NOT OK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%)  OK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%) NOT OK
#
# - Quantidade de técnicos médio alto (1,170.62	) NOT OK
# - Quantidade de alunos média de alunos alto (27,666.31) NOT OK
# - Corpo docente alto na  média (970.69)  OK
# - altga quantidade baixa de cursos (73.91) NOT OK
# - Despesas e receitas média altas NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOT OK
#
# Insights:
# - As instituições com mais alunos tendem a ser aquelas com mais cursos e maior receita

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'setimo', 0, 16, 7, 9, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'setimo'))
# Out:
# **Agrupamento e Análise Estatística**
#
# **Coluna**: QT_ALUNOS
# "Analise estatistica de mediana da variavel. Além disso verificar relação com outra variavel como NOME_CATEGORIA_ADMINISTRATIVA, pois instituções que pertencem a categorias administrativas diferentes podem ter diferentes quantidades de alunos."
#
# **Inferências**: Conclusão: "Instituicoes com maior mediana de quantidade de alunos pertencem a categorias administrativas mais pequenas ou menores."
#
# **Análise geral do agrupamento**: "A maioria das instituicoes com maior quantidade de alunos pertence a categorias administrativas menores, sugerindo que essas instituicoes podem ter uma estrutura organizacional mais centralizada ou terem menos opcoes de carreira para os estudantes."
#
# **Coluna**: QT_DOCENTES
# "Analise estatistica de moda da variavel. Além disso verificar relação com outra variavel como IN_SERVICO_INTERNET, pois instituicoes que possuem um serviço de internet mais eficiente podem ter mais docentes."
#
# **Inferências**: Conclusão: "Instituicoes com maior quantidade de docentes tendem a ter um servicio de internet mais eficiente, sugerindo que essas instituicoes podem ter uma infraestrutura tecnica mais avançada."
#
# **Análise geral do agrupamento**: "A maioria das instituicoes com maior quantidade de docentes possui um serviço de internet mais eficiente, indicando que essas instituicoes podem priorizar a educação e o desenvolvimento dos estudantes."
#
# **Coluna**: QT_CURSO
# "Analise estatistica de mediana da variavel. Além disso verificar relação com outra variavel como IN_REPOSITORIO_INSTITUCIONAL, pois instituicoes que possuem um repositorio institucional mais eficiente podem ter mais cursos."
#
# **Inferências**: Conclusão: "Instituicoes com maior mediana de quantidade de cursos tendem a ter um repositorio institucional mais eficiente, sugerindo que essas instituicoes podem priorizar a produção e disseminacao de conhecimento."
#
# **Análise geral do agrupamento**: "A maioria das instituicoes com maior quantidade de cursos possui um repositorio institucional mais eficiente, indicando que essas instituicoes podem ter uma cultura mais inovadora e colaborativa."
#
# **Coluna**: QT_TEC_TOTAL
# "Analise estatistica de moda da variavel. Além disso verificar relação com outra variavel como IN_BUSCA_INTEGRADA, pois instituicoes que possuem uma busca integrada mais eficiente podem ter mais tecnicos."
#
# **Inferências**: Conclusão: "Instituicoes com maior quantidade de tecnicos tendem a ter uma busca integrada mais eficiente, sugerindo que essas instituicoes podem priorizar a tecnologia e o desenvolvimento dos estudantes."
#
# **Análise geral do agrupamento**: "A maioria das instituicoes com maior quantidade de tecnicos possui uma busca integrada mais eficiente, indicando que essas instituicoes podem ter uma estrutura organizacional mais aberta e colaborativa."
#
# **Coluna**: QT_PERIODICO_ELETRONICO
# "Analise estatistica de mediana da variavel. Além disso verificar relação com outra variavel como IN_CATALOGO_ONLINE, pois instituicoes que possuem um catalogo online mais eficiente podem ter mais periodicos eletronicos."
#
# **Inferências**: Conclusão: "Instituicoes com maior mediana de quantidade de periodicos eletronicos tendem a ter um catalogo online mais eficiente, sugerindo que essas instituicoes podem priorizar a digitalizacao e a disseminacao de conhecimento."
#
# **Análise geral do agrupamento**: "A maioria das instituicoes com maior quantidade de periodicos eletronicos possui um catalogo online mais eficiente, indicando que essas instituicoes podem ter uma cultura mais inovadora e colaborativa."
#
# **Coluna**: QT_LIVRO_ELETRONICO
# "Analise estatistica de moda da variavel. Além disso verificar relação com outra variavel como IN_ACESSO_PORTAL_CAPES, pois instituicoes que possuem acesso ao portal CAPES mais eficiente podem ter mais livros eletronicos."
#
# **Inferências**: Conclusão: "Instituicoes com maior quantidade de livros eletronicos tendem a ter um acesso ao portal CAPES mais eficiente, sugerindo que essas instituicoes podem priorizar a educação e o desenvolvimento dos estudantes."
#
# **Análise geral do agrupamento**: "A maioria das instituicoes com maior quantidade de livros eletronicos possui um acesso ao portal CAPES mais eficiente, indicando que essas instituicoes podem ter uma estrutura organizacional mais aberta e colaborativa."

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%) NOT OK
# - Predominância das Instituições com acesso ao portal Capes (87.76%) NOT OK
# - Predominância das Instituições com repositorio institucional (70.41%)NOT OK
# - Possuem predominância em busca integrada (67.18%) OK
# - Possuem serviço de internet (98.81%)OK
# - Predominância em participar em redes sociais (71.94%) NOT OK
# - Possuem catalogo online (92.69%) NOT OK
# - Possuem predominância em ter outras bases (91.16%) OK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%)  OK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%) NOT OK
#
# - Quantidade de técnicos médio alto (1,170.62	) NOT OK
# - Quantidade de alunos média de alunos alto (27,666.31) NOT OK
# - Corpo docente alto na  média (970.69)  OK
# - altga quantidade baixa de cursos (73.91) NOT OK
# - Despesas e receitas média altas  OK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOT OK
#
# Insights:
# - instituicoes que possuem um serviço de internet mais eficiente podem ter mais docentes
# - instituicoes que possuem uma busca integrada mais eficiente podem ter mais tecnicos

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'setimo', 0.5, 16, 7, 9, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'setimo'))
# Out:
# **Agrupamento 1: Instituições na Capital**
#
# * **QT_ALUNOS**: Mediana = 120,0
# * **IN_CAPITAL**: 100% das instituições estão na capital (não há valores nulas)
#
# Análise estatística da média e relação com outra variável:
# A mediana de QT_ALUNOS é alta, sugerindo que as instituições na capital possuem mais alunos. Além disso, a frequência máxima de IN_CAPITAL é de 100%, o que sugere uma forte relação entre ser instituição na capital e o tamanho dos alunos.
#
# Inferências:
# A presença de instituições na capital está relacionada à quantidade de alunos, sugerindo que essas instituições podem ter políticas educacionais mais abrangentes ou terem acesso a recursos mais abundantes.
#
# Análise geral do agrupamento:
# As instituições na capital tendem a ter mais alunos e recursos, o que pode indicar uma maior capacidade de atração de estudantes e investimento em infraestrutura.
#
# **Agrupamento 2: Instituições com Busca Integrada**
#
# * **IN_BUSCA_INTEGRADA**: 50% das instituições possuem busca integrada (não há valores nulas)
#
# Análise estatística da média e relação com outra variável:
# Não há dados suficientes para analisar a relação entre IN_BUSCA_INTEGRADA e outras variáveis.
#
# Inferências:
# A presença de busca integrada pode ser um fator importante na estratégia de marketing das instituições, sugerindo que elas podem estar investindo mais em tecnologia e digitalização.
#
# Análise geral do agrupamento:
# As instituições com busca integrada tendem a ter uma estratégia de marketing mais moderna e abrangente, o que pode indicar uma maior capacidade de atrair estudantes e investidores.
#
# **Agrupamento 3: Instituições com Catálogo Online**
#
# * **IN_CATALOGO_ONLINE**: 75% das instituições possuem catálogo online (não há valores nulas)
#
# Análise estatística da média e relação com outra variável:
# Não há dados suficientes para analisar a relação entre IN_CATALOGO_ONLINE e outras variáveis.
#
# Inferências:
# A presença de catálogo online pode ser um fator importante na experiência do estudante, sugerindo que as instituições podem estar investindo mais em serviços de apoio à aprendizagem.
#
# Análise geral do agrupamento:
# As instituições com catálogo online tendem a ter uma estratégia de serviço mais centrada no estudo, o que pode indicar uma maior capacidade de apoiar os estudantes.
#
# **Agrupamento 4: Instituições com Acesso ao Portal CAPES**
#
# * **IN_ACESSO_PORTAL_CAPES**: 25% das instituições possuem acesso ao portal CAPES (não há valores nulas)
#
# Análise estatística da média e relação com outra variável:
# Não há dados suficientes para analisar a relação entre IN_ACESSO_PORTAL_CAPES e outras variáveis.
#
# Inferências:
# A presença de acesso ao portal CAPES pode ser um fator importante para os estudantes que buscam oportunidades de pesquisa ou carreira, sugerindo que as instituições podem estar investindo mais em estratégias de promoção à carreira.
#
# Análise geral do agrupamento:
# As instituições com acesso ao portal CAPES tendem a ter uma estratégia de desenvolvimento profissional mais centrada na carreira dos estudantes, o que pode indicar uma maior capacidade de apoiar os estudantes em sua jornada profissional.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%) NOT OK
# - Predominância das Instituições com acesso ao portal Capes (87.76%) OK
# - Predominância das Instituições com repositorio institucional (70.41%) not OK
# - Possuem predominância em busca integrada (67.18%) OK
# - Possuem serviço de internet (98.81%) OK
# - Predominância em participar em redes sociais (71.94%)  NOT OK
# - Possuem catalogo online (92.69%)  NOT OK
# - Possuem predominância em ter outras bases (91.16%)  NOT OK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%)  NOT OK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%) OK
#
# - Quantidade de técnicos médio alto (1,170.62	) NOT OK
# - Quantidade de alunos média de alunos alto (27,666.31)  NOT OK
# - Corpo docente alto na  média (970.69)  NOT OK
# - altga quantidade baixa de cursos (73.91)  NOT OK
# - Despesas e receitas média altas  NOT OK
# - Quantidade de periodicos e livros eletronicos com relevância alto  NOT OK
#
# Insights:
# - As instituições na capital tendem a ter mais alunos e recursos
# - O foco desta analise se deu em `IN_BUSCA_INTEGRADA`e `IN_CAPITAL`

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'setimo', 1.0, 16, 9, 7, 3, 0]
