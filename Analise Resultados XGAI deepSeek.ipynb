# %%
import pandas as pd
import numpy as np

# %%
analise_kmeans = pd.DataFrame([], columns=['prompt', 'cluster', 'temperature', 'Total_suposições', 'Mapeadas_pelo_modelo', 'Ignoradas_pelo_modelo', 'alucinação_do_modelo', 'insights'])

# %%
def show_result_kmeans_prompt(df, temperature, cluster):
    return df.loc[(df['temperature'] == temperature) & (df['cluster'] == cluster), ['result']]['result'].tolist()[0]

# %%
kmeans_fase2.loc[(kmeans_fase2['temperature'] == 1) & (kmeans_fase2['cluster'] == 'primeiro'), ['result']]['result'].tolist()[0]
# Out:
# ' Como um analista de dados, ao analisar os dados fornecidos para identificar fatores relacionados à criação de um determinado cluster, uma abordagem geralmente envolveria algumas etapas importantes. Vamos assumir que o conjunto de dados é um arquivo CSV contendo instâncias de um cluster específico, e iremos descrevê-lo e analisá-lo estatisticamente para entender as tendências subjacentes.\n\n1. **Análise Exploratória dos Dados (Exploratory Data Analysis - EDA)**:\n   Primeiro passo seria realizar uma análise inicial do conjunto de dados, analisando tipos de variáveis e sua distribuição. Isso pode incluir contagens únicas, estatísticas descritivas básicas como média, mediana, desvio padrão, extremos e outliers.\n\n2. **Identificação de Características Relevantes**:\n   A partir dos dados brutos fornecidos no arquivo CSV, identificaremos quais variáveis ou características podem ser relevantes para o cluster em questãcom base na literatura existente e nos conhecimentos prévios do setor. Por exemplo, se esse cluster é sobre clientes de uma determinada região, então as variáveis geográficas como latitude, longitude, cidade e estado seriam importantes.\n\n3. **Análise Estatística**:\n   Com base nas características identificadas, realizaremos testes estatísticos para entender a relação entre essas variáveis. Por exemplo:\n   - Correlação: Usamos correlação de Pearson ou Spearman para analisar como as variáveis se relacionam linearmente ou não.\n   - Testes T para comparações múltiplas: Para verificar se algumas variáveis são estatisticamente significativamente diferentes entre si.\n   - Análise de Componentes Principais (PCA) ou outras técnicas de redução de dimensionalidade, caso a complexidade das variáveis se mostre necessitar de simplificação para análises mais aprofundadas.\n\n4. **Identificação do Cluster**:\n   A partir desses dados estatísticos e características identificadas no conjunto de dados, poderemos inferir sobre as tendências que levam a um cluster específico. Por exemplo, se encontramos uma alta concentração de clientes em uma região com baixo índice de desemprego, pode-se concluir que talvez haja alguma relação entre essas variáveis e o fato do cluster ser formado por empresas de serviços ou atividades relacionadas a economia local.\n\n5. **Análise Geral**:\n   Ao final, realizaremos uma análise geral levantando pontos fortes e fracos do clustering identificado com base nas variáveis estatísticas analisadas. Isso incluiria considerações sobre a robustez da associação encontrada, o quanto ela pode ser influenciada por outliers ou dados inconsistentes, e se as características identificadas estão alinhadas com os objetivos e expectativas do setor.\n\nÉ importante lembrar que a interpretação de fatores que levam à criação de um cluster sempre deve ser feita com cuidado, levando em conta todos os dados disponíveis, bem como outras informações contextuais e conhecimentos do setor. Além disso, a confiabilidade dos resultados depende fortemente da qualidade e representatividade das variáveis incluídas no modelo de clustering.'

# %%
analise_kmeans
# Out:
#     prompt   cluster  temperature  Total_suposições  Mapeadas_pelo_modelo  \
# 0   Fase 2  primeiro          0.0                15                     2
# 1   Fase 2  primeiro          0.5                15                     2
# 2   Fase 2  primeiro          1.0                15                     9
# 3   Fase 2   segundo          0.0                17                     0
# 4   Fase 2   segundo          0.5                17                     0
# 5   Fase 2   segundo          1.0                17                     0
# 6   Fase 2  terceiro          0.0                15                     0
# 7   Fase 2  terceiro          0.5                15                     0
# 8   Fase 2  terceiro          1.0                15                     0
# 9   Fase 2    quarto          0.0                17                     2
# 10  Fase 2    quarto          0.5                17                     1
# 11  Fase 2    quarto          1.0                17                     1
# 12  Fase 2    quinto          0.0                17                     2
# 13  Fase 2    quinto          0.5                17                     2
# 14  Fase 2    quinto          1.0                17                     1
# 15  Fase 2     sexto          0.0                18                     3
# 16  Fase 2     sexto          0.5                18                     4
# 17  Fase 2     sexto          1.0                18                     1
# 18  Fase 2    setimo          0.0                16                     3
# 19  Fase 2    setimo          0.5                16                     2
# 20  Fase 2    setimo          1.0                16                     1
#
#     Ignoradas_pelo_modelo  alucinação_do_modelo  insights
# 0                      11                     2         0
# 1                      11                     2         0
# 2                       6                     2         0
# 3                      15                     2         0
# 4                      17                     1         0
# 5                      17                     0         0
# 6                       8                     2         1
# 7                      15                     2         3
# 8                      15                     1         1
# 9                      14                     1         4
# 10                     16                     2         0
# 11                     16                     2         1
# 12                     13                     1         0
# 13                     15                     2         1
# 14                     16                     1         2
# 15                     15                     1         0
# 16                     14                     1         0
# 17                     17                     1         0
# 18                     13                     1         0
# 19                     14                     1         0
# 20                     15                     2         0

# %%
analise_kmeans.to_csv('analise_kmeans_fase2.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Fase 2

# %%
kmeans_fase2 = pd.read_csv('./Models/resultado_deepSeek/K-means_Fase 2_results.csv')

# %% [markdown]
# ### First Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'primeiro'))
# Out:
#  Para analisar e explicar um cluster fornecido em um arquivo CSV, primeiro é importante compreender qualquer dados relevantes presentes no arquivo, como variáveis, unidades amostrais (por exemplo, usuários ou empresas) e intervalos de valores.
#
# 1. Análise descritiva: Comece analisando a distribuição das principais variáveis no conjunto de dados. Essencialmente separamos os dados em categorias gerais como por exemplo, idade, salário e estado civil, entre outras informações possíveis presente na base de dados. Isso pode ser feito através da contagem de ocorrências de cada categoria, cálculo de médias, desvios padrão, ou estatísticas mais avançadas como medidas de assimetria e curtose para avaliar a forma da distribuição.
#
# 2. Análise precoce de outliers: Após uma breve análise descritiva, o próximo passo é identificar possíveis outliers no conjunto de dados. Esses podem ser médias extremas ou valores discrepantes que podem alterar a precisão das inferências feitas sobre os dados.
#
# 3. Análise cruzada: Um próximo passo pode ser analisar como as variáveis estão relacionadas entre si, uma vez que o cluster em questão seja formado por indivíduos com características similares umas das outras. Essa análise de correlação ou dependência pode ser feita através de técnicas estatísticas como correlação de Pearson, testes t pareados ou análises de componentes principais.
#
# 4. Análise de cluster: Com base na distribuição das variáveis e nas relações entre elas, pode ser possível inferir algumas hipóteses sobre a origem do cluster. O objetivo é identificar os fatores que podem ter levado à formação desse grupo de indivíduos ou entidades.
#
# 5. Considerações gerais: Após analisar cada variável individualmente e compreendendo como estão relacionadas, a análise do cluster pode ser complementada com uma análise geral das relações entre as variáveis dentro e fora desse grupo.
#
# 6. Conclusões: Com base na análise feita até agora, é possível formular algumas conclusões sobre a ocorrência de um determinado cluster e suas implicações para os indivíduos ou entidades envolvidos.
#
# No final, recomendo descrever as descobertas obtidas ao longo do processo analítico, incluindo quaisquer evidências que possam apontar a ocorrência de um determinado cluster e sua origem. Além disso, também é importante discutir como esses resultados podem impactar na tomada de decisão em áreas relevantes do negócio ou da pesquisa.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%)NOTOK
# - Uma incidência das IES não estarem numa capital (59,78%)NOTOK
# - Instituições com acesso ao portal Capes (87.34%)NOTOK
# - Possuem serviço de internet (94.97%)NOTOK
# - Participam em redes sociais (71.51%)NOTOK
# - Possuem catalogo online (86.22%)NOTOK
# - Busca integrada (58.29%)NOTOK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%)NOTOK
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%)NOTOK
#
# - Quantidade alta de técnicos na média (765.03)NOTOK
# - Quantidade de alunos média de alunos alto (12,553.95)NOTOK
# - Corpo docente forte na média (761.73)NOTOK
# - Quantidade considerável de cursos na média (média de 52.45)NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# Insights falsos:
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2', 'primeiro', 0, 15, 2, 11, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'primeiro'))
# Out:
#  Para realizar essa análise, primeiro precisamos garantir-se de algumas informações fundamentais sobre o conjunto de dados fornecido. No entanto, como nenhum dado foi especificamente mencionado neste caso, vou assumir que você está procurando algo genérico e teria um arquivo CSV contendo uma variável dependente (por exemplo, a classe ao qual os exemplos pertencem) e várias variáveis independentes.
#
# 1. **Análise exploratória dos dados**: A primeira etapa é examinar as colunas do arquivo CSV para ter uma compreensão inicial sobre o que cada coluna representa. Esse processo pode envolver verificar se há valores faltantes ou outliers, e tentar compreender a consistência das categorias nos dados.
#
# 2. **Análise descritiva**: Uma vez com um conjunto de dados limpo, você geralmente começa a analisar estatisticamente os dados para ter uma compreensão do cenário como um todo. Isso pode envolver calcular médias, medidas de dispersão, proporções e correlações entre variáveis.
#
# 3. **Análise com base em grupo**: Em uma segunda etapa, você pode analisar o agrupamento ou cluster usando técnicas estatísticas como Agrupamento K-Means, Hierarchical Clustering, DBSCAN e assim por diante. Isso geralmente envolve escolher a quantidade de grupos (K) ou classes para alocar as instâncias, conforme apropriado.
#
# 4. **Interpretação dos resultados**: Depois de identificar os clusters com base nos dados estatísticos, o próximo passo é interpretar esses resultados. Isso geralmente envolve procurar padrões ou tendências e explicar por que aquele cluster se formou daquela maneira.
#
# 5. **Análise geral do agrupamento**: Por fim, você deveria realizar uma análise geral para analisar a consistência e plausibilidade dos clusters identificados com base nas variáveis fornecidas no conjunto de dados. Isso pode envolver avaliar se os grupos são homogêneos (todos os membros do grupo têm características similares) ou heterogêneos e considerando a plausibilidade dos clusters identificados com base nas variáveis fornecidas.
#
# Em resumo, para analisar um cluster específico, você começa examinando dados exploratórios, seguido de uma análise descritiva, seguida de técnicas estatísticas para identificar grupos e finalizando com a interpretação desses resultados.
#
# Espero que isso ajude!

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%)
# - Uma incidência das IES não estarem numa capital (59,78%)
# - Instituições com acesso ao portal Capes (87.34%)
# - Possuem serviço de internet (94.97%)
# - Participam em redes sociais (71.51%)
# - Possuem catalogo online (86.22%)
# - Busca integrada (58.29%)
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%)
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%)
#
# - Quantidade alta de técnicos na média (765.03)
# - Quantidade de alunos média de alunos alto (12,553.95)
# - Corpo docente forte na média (761.73)
# - Despesas e receitas média moderadas
# - Quantidade de periodicos e livros eletronicos com relevância baixa
#
# Insights falsos:

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'primeiro', 0.5,15, 2, 11, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'primeiro'))
# Out:
#  Como um analista de dados, ao analisar os dados fornecidos para identificar fatores relacionados à criação de um determinado cluster, uma abordagem geralmente envolveria algumas etapas importantes. Vamos assumir que o conjunto de dados é um arquivo CSV contendo instâncias de um cluster específico, e iremos descrevê-lo e analisá-lo estatisticamente para entender as tendências subjacentes.
#
# 1. **Análise Exploratória dos Dados (Exploratory Data Analysis - EDA)**:
#    Primeiro passo seria realizar uma análise inicial do conjunto de dados, analisando tipos de variáveis e sua distribuição. Isso pode incluir contagens únicas, estatísticas descritivas básicas como média, mediana, desvio padrão, extremos e outliers.
#
# 2. **Identificação de Características Relevantes**:
#    A partir dos dados brutos fornecidos no arquivo CSV, identificaremos quais variáveis ou características podem ser relevantes para o cluster em questãcom base na literatura existente e nos conhecimentos prévios do setor. Por exemplo, se esse cluster é sobre clientes de uma determinada região, então as variáveis geográficas como latitude, longitude, cidade e estado seriam importantes.
#
# 3. **Análise Estatística**:
#    Com base nas características identificadas, realizaremos testes estatísticos para entender a relação entre essas variáveis. Por exemplo:
#    - Correlação: Usamos correlação de Pearson ou Spearman para analisar como as variáveis se relacionam linearmente ou não.
#    - Testes T para comparações múltiplas: Para verificar se algumas variáveis são estatisticamente significativamente diferentes entre si.
#    - Análise de Componentes Principais (PCA) ou outras técnicas de redução de dimensionalidade, caso a complexidade das variáveis se mostre necessitar de simplificação para análises mais aprofundadas.
#
# 4. **Identificação do Cluster**:
#    A partir desses dados estatísticos e características identificadas no conjunto de dados, poderemos inferir sobre as tendências que levam a um cluster específico. Por exemplo, se encontramos uma alta concentração de clientes em uma região com baixo índice de desemprego, pode-se concluir que talvez haja alguma relação entre essas variáveis e o fato do cluster ser formado por empresas de serviços ou atividades relacionadas a economia local.
#
# 5. **Análise Geral**:
#    Ao final, realizaremos uma análise geral levantando pontos fortes e fracos do clustering identificado com base nas variáveis estatísticas analisadas. Isso incluiria considerações sobre a robustez da associação encontrada, o quanto ela pode ser influenciada por outliers ou dados inconsistentes, e se as características identificadas estão alinhadas com os objetivos e expectativas do setor.
#
# É importante lembrar que a interpretação de fatores que levam à criação de um cluster sempre deve ser feita com cuidado, levando em conta todos os dados disponíveis, bem como outras informações contextuais e conhecimentos do setor. Além disso, a confiabilidade dos resultados depende fortemente da qualidade e representatividade das variáveis incluídas no modelo de clustering.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%) NOTOK
# - Uma incidência das IES não estarem numa capital (59,78%) NOTOK
# - Instituições com acesso ao portal Capes (87.34%) NOTOK
# - Possuem serviço de internet (94.97%) NOTOK
# - Participam em redes sociais (71.51%) NOTOK
# - Possuem catalogo online (86.22%) NOTOK
# - Busca integrada (58.29%) NOTOK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%) NOTOK
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%) NOTOK
#
# - Quantidade alta de técnicos na média (765.03) NOTOK
# - Quantidade de alunos média de alunos alto (12,553.95) NOTOK
# - Corpo docente forte na média (761.73) NOTOK
# - Despesas e receitas média moderadas
# - Quantidade de periodicos e livros eletronicos com relevância baixa

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'primeiro', 1, 15, 9, 6, 2, 0]

# %% [markdown]
# ### Second Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'segundo'))
# Out:
#  Para começar, vou analisar o arquivo CSV fornecido para identificar algumas possíveis características e tendências que podem estar relacionadas à criação do cluster em questão. Consigo observar alguns insights a partir dos dados estatísticos:
#
# 1. Variáveis numéricas (como idade, renda, etc.) parecem ter uma distribuição bastante uniforme e não apresentam tendências distintas que possam estar relacionadas à criação do cluster.
# 2. Algumas variáveis categóricas (como gênero, estado civil, etc.), embora tenham um tamanho amostral menor, também não apresentam uma distribuição extremamente assimétrica ou desequilibrada que possa indicar a presença de um cluster.
# 3. Algumas variáveis parecem ter valores atípicos significativos, como alturas muito elevadas e taxas de criminalidade extremamente baixas em uma determinada região do cluster. Isso pode ser relevante para entender a dinâmica social ou geográfica dessa área.
# 4. A análise unidimensional (analisando um único conjunto de variáveis) não é suficiente para desvendar completamente as características do cluster, pois alguns relacionamentos e padrões complexos podem ser perdidos ao considerar apenas uma série de dados isolada.
# 5. A presença de variáveis correlacionadas (como renda e gasto com educação) ou contraditórias (por exemplo, taxa de criminalidade alta e baixa segurança pública) pode ser um indicativo de uma interação entre diferentes fatores que contribui para a criação do cluster.
#
# Após analisar as variáveis estatísticas fornecidas no arquivo CSV, recomendo mergulhar em mais detalhes e coletar informações adicionais sobre o contexto social, geográfico e econômico dessa área para compreender melhor a dinâmica do cluster. Isso pode incluir entrevistas com moradores locais, levantamentos de opinião pública ou análise secundária de notícias relacionadas à região em estudo.
#
# Dessa forma, a análise estatística e descritiva fornece um quadro geral inicial sobre as variáveis relevantes para o cluster em questão. No entanto, é importante considerar outros fatores sociais, culturais, geográficos e econômicos nessa região ao longo do processamento de dados e modelagem estatísticas. Isso permitirá desvendar um cenário mais abrangente sobre a dinâmica do cluster e fornecer insights fundamentais para iniciativas futuras, como planejamento urbano ou políticas públicas.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%)
# - Possuem busca integrada (74.35%) NOTOK
# - Possuem serviço de internet (93.00%) NOTOK
# - Participam em redes sociais (74.03%) NOTOK
# - Possuem predominância em catalogo online (64.87%) NOTOK
# - Possuem predominâncai em ter outras bases (69.29%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) NOTOK(98,6) NOTOK
# - Maioria dos anos da IES são Faculdade (99.89%) NOTOK
#
# - Pouca quantidade de técnicos na média (12.87) NOTOK
# - Quantidade de alunos média de alunos abaixo (153.83) NOTOK
# - Corpo docente muito pouco na média (14.20) NOTOK
# - Pouca quantidade de cursos (2.30) NOTOK
# - Despesas e receitas média moderadas
# - Quantidade de periodicos e livros eletronicos com relevância baixa
#
# Insights falsos:
# -  análise apenas descreveu etapas de como deveria ser feita as análises dos clusters

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'segundo', 0, 17,0, 15, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'segundo'))
# Out:
#  Para analisar e explicar um determinado cluster fornecido em um arquivo CSV, primeiro é importante compreender as informações contidas no arquivo e como elas se relacionam entre si. Assumindo que você já tem acesso ao arquivo CSV, aqui estão alguns passos que você pode seguir para realizar o processo:
#
# 1. **Análise Exploratória dos Dados (EDA)**: Primeiro, é recomendado analisar e entender os dados fornecidos no arquivo CSV. Isso inclui identificar a estrutura geral do arquivo, verificar se todos os campos são relevantes para o cluster em questão e determinar como eles podem estar inter-relacionados.
#
# 2. **Análise Estatística**: A seguir, você pode aplicar técnicas estatísticas para analisar as relações entre os campos no arquivo CSV. Isso inclui calcular médias, desvios padrão e outras medidas de tendência central e variabilidade para cada campo ou conjunto de dados relevante. Além disso, também é recomendável analisar se há correlação entre diferentes campos no arquivo CSV.
#
# 3. **Identificação de Padrões**: Com base nas análises estatísticas e exploratórias realizadas até agora, você pode começar a identificar possíveis padrões ou fatores que podem estar contribuindo para o cluster em questão. Isso pode incluir relações entre características isoladas ou conjuntamente com outras características no conjunto de dados, assim como tendências e variações nos dados ao longo do tempo ou geográfico.
#
# 4. **Análise dos Resultados**: Avançando na análise, você pode examinar as descobertas identificadas em etapas anteriores para determinar se há evidências de que determinado padrão ou conjunto de características estão relacionados à criação do cluster. Isso pode envolver a realização de testes estatísticos, como análise de regressão e técnicas de machine learning para avaliar se o padrão identificado é significativamente diferente das outras observações no conjunto de dados.
#
# 5. **Análise Geral do Aglomeramento**: Ao final, você pode realizar uma análise geral sobre os resultados obtidos após analisar e interpretar o cluster fornecido. Isso inclui discutir como as características identificadas no arquivo CSV podem ter levado a essa criação de cluster, assim como quaisquer limitações ou desvios do modelo em relação à realidade dos dados.
#
# Em suma, analisar e explicar um determinado cluster envolve uma série de etapas que incluem análise exploratória de dados, estatística analítica, identificação de padrões e discussão sobre a natureza do agrupamento em questão. Ao longo deste processo, é importante considerar as descobertas identificadas para determinar como elas podem se conectar com o cluster fornecido e gerar uma compreensão mais profunda desses dados.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOTOK
# - Possuem busca integrada (74.35%) NOTOK
# - Possuem serviço de internet (93.00%) NOTOK
# - Participam em redes sociais (74.03%) NOTOK
# - Possuem predominância em catalogo online (64.87%) NOTOK
# - Possuem predominâncai em ter outras bases (69.29%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) NOTOK (98,6) NOTOK
# - Maioria dos anos da IES são Faculdade (99.89%) NOTOK
#
# - Pouca quantidade de técnicos na média (12.87) NOTOK
# - Quantidade de alunos média de alunos abaixo (153.83) NOTOK
# - Corpo docente muito pouco na média (14.20) NOTOK
# - Pouca quantidade de cursos (2.30) NOTOK
# - Despesas e receitas média moderadas
# - Quantidade de periodicos e livros eletronicos com relevância baixa
#
# Insights:
# -  análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'segundo', 0.5, 17, 0, 17, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'segundo'))
# Out:
#  Para analisar o arquivo CSV fornecido e identificar os fatores que levaram à criação do cluster em questão, farei uma abordagem passo a passo com base na minha experiência como analista de dados. Vou considerar alguns passos comuns em tarefas de análise exploratória de dados (EDA):
#
# 1. **Importação e Visualização**: Comecei analisando o arquivo CSV para entender a estrutura geral, incluindo as colunas disponíveis. A primeira etapa é importar o arquivo usando um framework como pandas ou dplyr na linguagem de programação desejada (Python ou R).
#
# 2. **Análise Descritiva**: Revise a descrição geral das variáveis, incluindo tipos de dados, valores únicos e estatísticas básicas como média, mediana, desvio padrão e quartis. Isso ajuda a ter uma noção inicial do conjunto de dados e identificar se há qualquer anomalia imediatamente aparente.
#
# 3. **EDA Primordial**: Realize análise exploratória através de visualizações estatísticas, como gráficos de barra, boxplots e scatter plots. Essas visualizações podem ajudar a identificar padrões ou tendências interessantes relacionadas ao cluster em questão.
#
# 4. **Análise Exploratória Detalhada**: Procure relações entre variáveis, como correlação através de heatmaps e gráficos de covariância. Isso pode revelar quais características são mais relevantes para o agrupamento.
#
# 5. **Detalhamento das Variáveis**: Analise as variáveis individuais mais detidamente, considerando sua distribuiçãcom a média e os outliers. Isso pode ajudar a entender como elas se comportam em relação ao cluster criado.
#
# 6. **Análise de Texto ou Outras Características Especiais**: Se houver dados textuais ou características não numéricas, essenciais para o entendimento do cluster, analize-os separadamente usando técnicas apropriadas.
#
# 7. **Relações com Outras Variáveis**: Para identificar possíveis fatores de agrupamento, verifique se as variáveis selecionadas estão correlacionadas com a saída esperada ou outras variáveis relevantes para o cluster.
#
# 8. **Análise Estatística e Modelagem Preditiva**: Use técnicas estatísticas mais avançadas, como regressão logística, análises de grupos (como K-means ou hierarquias) e modelos preditivos para explorar a estrutura subjacente do cluster.
#
# 9. **Comunicação dos Resultados**: Após analisar os dados, o próximo passo é comunicar suas descobertas de forma clara e objetiva. Isso pode envolver criar relatórios ou apresentações que destacam as principais conclusões do análise e seus insights para a tomada de decisão.
#
# 10. **Análise Geral**: A partir das descobertas individuais, faça uma análise geral dos resultados para identificar tendências globais e padrões que unem todas as variáveis relevantes ao cluster em questão. Isso incluiria um levantamento de quão influentes foram os fatores identificados, como a magnitude do impacto das variáveis principais e o quanto eles se correlacionaram com o agrupamento observado.
#
# Após essas etapas, minha interpretação geral sobre o cluster seria consolidada levantando as seguintes questões:
# - Qual é a natureza do cluster? (Por exemplo, está ele definido por uma característica única ou por várias?)
# - Quais variáveis são mais influentes no agrupamento?
# - Existe alguma relação significativa entre as variáveis e o cluster que pode oferecer insights sobre a origem do agrupamento?
#
# A partir dessas respostas, seria possível fornecer uma visão mais ampla e sólida da criação de um determinado cluster, baseada nas análises detalhadas das informações contidas no arquivo CSV.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOTOK
# - Possuem busca integrada (74.35%) NOTOK
# - Possuem serviço de internet (93.00%) NOTOK
# - Participam em redes sociais (74.03%) NOTOK
# - Possuem predominância em catalogo online (64.87%) NOTOK
# - Possuem predominâncai em ter outras bases (69.29%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) NOTOK (98,6) NOTOK
# - Maioria dos anos da IES são Faculdade (99.89%) NOTOK
#
# - Pouca quantidade de técnicos na média (12.87) NOTOK
# - Quantidade de alunos média de alunos abaixo (153.83) NOTOK
# - Corpo docente muito pouco na média (14.20) NOTOK
# - Pouca quantidade de cursos (2.30) NOTOK
# - Despesas e receitas média moderadas
# - Quantidade de periodicos e livros eletronicos com relevância baixa
#
# Insights falsos:
# -  A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'segundo', 1.0, 17, 0, 17, 0, 0]

# %% [markdown]
# ### Third Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'terceiro'))
# Out:
#  Para analisar o cluster fornecido e explicar os fatores que levaram à sua criação, primeiro precisamos entender as informações contidas no arquivo CSV fornecido. Portanto, vamos considerar algumas hipóteses baseadas nas colunas disponíveis:
#
# 1. A coluna "cluster" é a variável alvo que descreve os grupos de instâncias em nossa análise.
# 2. As colunas 'feature1', 'feature2' e assim por diante representam as características observadas para cada instância no cluster. Estas podem incluir variáveis categóricas, numéricas ou até mesmo texto.
# 3. A data de coleta das informações também é importante para compreender a consistência temporal do cluster.
# 4. As colunas 'age', 'quantity' e outras relacionadas podem ser utilizadas para analisar se as instâncias são mais velhas ou novas, além de quantidade ou frequência com que ocorrem.
# 5. Outras variáveis como "size" ou "location", também podem ser relevantes para entender a natureza do cluster.
#
# Agora, o procedimento geral para analisar e explicar os fatores levantados seria:
#
# 1. Analisando as médias e desvios padrão das características entre os grupos de instâncias (cluster) com base nas variáveis mais relevantes. Isso pode ser feito usando técnicas estatísticas como ANOVA, regressão logística ou agrupamento hierarquico e densidade.
# 2. Investigar a interação entre as características através de análise de correlação, matriz de confusão ou redes sociais para determinar como diferentes variáveis estão relacionadas com o cluster em questão.
# 3. Avaliar se existem outliers significativos na distribuição das características que podem influenciar a interpretação dos resultados e, caso haja, investigar sua causa e significância.
# 4. Considerar as implicações legais ou éticas de acordo com o conteúdo do cluster (exemplo: dados pessoais sensíveis).
# 5. Apresentar uma análise geral baseada nas informações coletadas, incluindo qualquer evidência empírica que aponte os fatores chave relacionados à criação do cluster e suas implicações para estudantes de dados ou profissionais da área.
#
# Além disso, recomendo analisar o desempenho de um algoritmo de aprendizado supervisionado (como clustering k-means, DBSCAN etc.) para validar se os resultados são consistentes com as hipóteses formuladas pela análise estatística baseia.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%)NOTOK
# - Predominãncia das IES não estarem numa capital (62.70%)NOTOK
# - Instituições sem acesso ao portal Capes (83.09%)NOTOK
# - Possuem predominância em não possuir repositorio institucional (74.68%)NOTOK
# - Possuem predominância em serviço de internet (79.13%)NOTOK
# - Predominância em participar em redes sociais (62.62%)NOTOK
# - Possuem predominância em ter outras bases (75.57%)NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos)NOTOK(97,73)NOTOK
# - Maioria dos anos da IES são Faculdade (99.92%)NOTOK
#
# - Quantidade baixa de média de técnicos (10.78)NOTOK
# - Quantidade de alunos média de alunos baixo (185.81)NOTOK
# - Corpo docente muito baixo na média (16.72)NOTOK
# - Pouca quantidade de cursos (2.03)NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# Insights falsos:
# -  A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'terceiro', 0, 15, 0, 8, 2, 1]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'terceiro'))
# Out:
#  Para analisar e interpretar um conjunto de dados fornecido para encontrar fatores relacionados à criação de um determinado cluster, seguiríamos os passos listados abaixo:
#
# 1. **Análise Inicial do Conjunto de Dados:**
#    Analisaremos primeiro o tipo e a estrutura dos dados fornecidos para ter uma compreensãcomum das variáveis contidas, bem como verificar qual é a granularidade desses dados. Também podemos buscar informações sobre o período de coleta dessas informações para entender mais sobre as tendências observadas nos dados.
#
# 2. **Exploração Exploratória dos Dados:**
#    A análise exploratória pode ser realizada utilizando ferramentas como visualização de dados, estatística descritiva e testes paramétricos para ter uma visão geral sobre a consistência e representatividade das variáveis. Essa etapa busca identificar tendências e padrões nos dados que podem ser relevantes para o cluster em análise.
#
# 3. **Análise Estatística dos Dados:**
#    Agora, iremos analisar os resultados obtidos da etapa anterior com mais detalhe, buscando identificar relações e padrões entre as variáveis de interesse e também verificar a existência ou não de algumas associações que podem estar relacionadas ao cluster em estudo.
#
# 4. **Identificação das Variáveis Mais Significativas:**
#    A partir da análise estatística, identificaremos as variáveis mais significativas e as relações entre elas como uma fonte possível de agrupamento ou comunicação do cluster. Podemos verificar também se algumas variáveis estão correlacionadas positivamente ou negativamente com o cluster, sugerindo que tais variáveis podem ser responsáveis pela forma como os dados são agrupados.
#
# 5. **Análise Detalhada de Conjunto de Dados:**
#    Nesta etapa, analisaremos cada instância do conjunto de dados individualmente para identificar possíveis características que levariam a criar o cluster em questão. Podemos procurar encontrar padrões ou tendências específicos nas variáveis que podem ser úteis na identificação do cluster.
#
# 6. **Análise Geral e Conclusão:**
#    Com base nos resultados das etapas anteriores, faremos uma análise geral dos dados para encontrar evidências que sugiram a existência de um cluster no conjunto de dados fornecido. Tentaremos correlacionar as descobertas realizadas na etapa anterior com as principais hipóteses sobre o fenômeno em estudo, chegando a conclusões baseadas nas evidências disponíveis nos dados analisados.
#
# De maneira geral, para realizar essa análise, necessitaremos de uma compreensão ampla e sólida do contexto histórico e das implicações dos resultados da pesquisa. Além disso, o trabalho também incluiria a revisão de literatura sobre as principais teorias ou hipóteses que podem explicar os fenômenos observados no cluster em análise, permitindo assim uma discussão mais aprofundada e sustentada com base nas descobertas feitas durante o processo de análise.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOTOK
# - Predominãncia das IES não estarem numa capital (62.70%) NOTOK
# - Instituições sem acesso ao portal Capes (83.09%) NOTOK
# - Possuem predominância em não possuir repositorio institucional (74.68%) NOTOK
# - Possuem predominância em serviço de internet (79.13%) NOTOK
# - Predominância em participar em redes sociais (62.62%) NOTOK
# - Possuem predominância em ter outras bases (75.57%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (97,73) OK
# - Maioria dos anos da IES são Faculdade (99.92%) NOTOK
#
# - Quantidade baixa de média de técnicos (10.78) NOTOK
# - Quantidade de alunos média de alunos baixo (185.81	) NOTOK
# - Corpo docente muito baixo na média (16.72) NOTOK
# - Pouca quantidade de cursos (2.03) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# Insights:
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'terceiro', 0.5, 15, 0, 15, 2, 3]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'terceiro'))
# Out:
#  Para analisar um arquivo CSV e determinar os fatores que levaram à criação de um determinado cluster, seguiremos alguns passos fundamentais:
#
# 1. Análise Descritiva: Comece analisando as principais estatísticas do conjunto de dados como média, mediana, desvio padrão e outras medidas de tendência central e dispersãcom o objetivo de ter uma visão geral das características dos dados.
#
# 2. Análise Exploratória: Procurar relações entre as variáveis com visualização de gráficos como a correlação, scatter plots, box plots e outros tipos que mostrem relações complexas ou relacionamentos não triviais.
#
# 3. Detecção de Padrões: A partir da análise exploratória das variáveis pode ser identificado um determinado padrão ou tendência que leva a formação do cluster, como uma relação entre duas variáveis ou anomalias.
#
# 4. Categorização: Classificar as instâncias no cluster conforme suas características e atribuir pesos para cada uma delas baseada em análise de correlações com outras features, considerando que mais peso é dado aos fatores relevantes.
#
# 5. Avaliação: A avaliação dos clusters pode ser feita por meio do método do cotovelo ou o núcleo, onde um cluster deve ter uma alta densidade em seu centro e gradativamente diminuir sua concentração conforme se afasta do centro.
#
# 6. Análise Geral: Considerando todas as informações coletadas durante a análise, concluir sobre os fatores que levaram à formação desse cluster e sugerir estratégias futuras para analisar clusters similares.
#
# Para ilustrar esses passos, vamos supor que tenhamos um arquivo CSV com dados demográficos de alunos em uma escola pública onde pretendemos criar grupos (clusters) baseado nas características individuais dos estudantes. Ao analisar os dados estatisticamente, poderiamos notar algumas tendências:
#
# 1. Idade média e mediana de alunos em cada cluster
# 2. Taxa de matrícula por escola primária ou secundária dentro do cluster
# 3. Desempenho escolar (média das notas) e frequência presencial como outras variáveis que podem ter influenciado a formação dos clusters.
# 4. Gráficos de dispersão para identificar relacionamentos entre as variáveis relevantes, como o impacto da idade sobre o desempenho escolar e frequência presencial na taxa de matrícula.
# 5. Categorização das instâncias nos clusters baseada em análise estatística das relações e tendências identificadas, como por exemplo um cluster com maior idade tende a ter menor desempenho escolar e frequencia presencial baixa na escola primaria.
# 6. Análise Geral: Após realizar todos os passos acima, chegaria-se a conclusão de que o fato de os alunos no cluster serem mais velozes está associado a uma menor frequência presencial e desempenho escolar abaixo da média.
#
# A partir dessas análises, podemos criar estratégias para enfrentar esses desafios levando em consideração que os fatores relevantes são sua idade e frequencia presencial, como aumentar horas de aula ou oferecer programas extra-curriculares voltados para estudantes dessa faixa etária.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOTOK
# - Predominãncia das IES não estarem numa capital (62.70%) NOTOK
# - Instituições sem acesso ao portal Capes (83.09%) NOTOK
# - Possuem predominância em não possuir repositorio institucional (74.68%) NOTOK
# - Possuem predominância em serviço de internet (79.13%) NOTOK
# - Predominância em participar em redes sociais (62.62%) NOTOK
# - Possuem predominância em ter outras bases (75.57%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) NOTOK (97,73) NOTOK
# - Maioria dos anos da IES são Faculdade (99.92%) NOTOK
#
# - Quantidade baixa de média de técnicos (10.78) NOTOK
# - Quantidade de alunos média de alunos baixo (185.81) NOTOK
# - Corpo docente muito baixo na média (16.72) NOTOK
# - Pouca quantidade de cursos (2.03) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
#
#
# Insights:
# -A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'terceiro', 1.0, 15, 0, 15, 1, 1]

# %% [markdown]
# ### Forth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'quarto'))
# Out:
#  Após uma análise inicial do arquivo CSV fornecido, identificamos algumas tendências e padrões interessantes que podem estar relacionados ao cluster em questão. Aqui estão alguns insights gerais sobre os dados:
#
# 1. **Caracteres Estatísticos**: O arquivo CSV parece ser composto por várias colunas, sendo a maioria delas numéricas (como idade, renda e escolaridade). Há também algumas colunas categóricas como gênero e localização.
#
# 2. **Correlações**: Analisando as correlações entre as variáveis contínuas, identificamos que a idade e a renda tiveram uma forte relação estatisticamente significativa (r=0,8). A escolaridade também parece ter uma boa correlação com essas duas características (r=0,65).
#
# 3. **Distribuição de Variáveis**: Observamos que a distribuição das variáveis é bastante uniforme, o que pode ser um indicativo de que o cluster não está baseado em padrões locais ou demográficos. Em vez disso, talvez seja causado por fatores econômicos comuns, como renda e acessibilidade a educação superior.
#
# 4. **Gênero vs Renda**: Ao analisar as diferenças de gênero em relação à renda, percebemos uma disparidade entre os homens e as mulheres naquele cluster. As mulheres tinham uma renda mais alta do que os homens nesse cluster.
#
# 5. **Localização vs Renda**: Ao analisar a localização em relação à renda, também notamos um padrão interessante: quanto mais próximo da cidade central, maior a renda média. Isso pode indicar que o cluster está focado em áreas com melhor acessibilidade e oportunidades econômicas.
#
# 6. **Educação vs Renda**: A escolaridade também parece ter uma relação inversamente proporcional com a renda, ou seja, quanto mais educado um indivíduo, menor sua renda média. Isso pode indicar que os membros desse cluster são mais orientados em direção à educação e preferirem investir no aprendizado ao invés de buscar oportunidades lucrativas.
#
# Dada essas informações, podemos inferir que o cluster está fortemente relacionado a fatores econômicos como renda e acessibilidade à educação superior. Além disso, há um padrão interessante de preferências por investimento em aprendizado ao invés de oportunidades lucrativas.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOTOK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOTOK
# - Uma incidência das IES não estarem numa capital (68.85%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) NOTOK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOTOK
# - Predominância em participar em redes sociais (71.20%) NOTOK
# - Possuem predominância em ter catalogo online (79.45%) NOTOK
# - Possuem predominância em ter outras bases (73.43%) NOTOK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) NOTOK (98,04) NOTOK
# - Maioria dos anos da IES são Faculdade (99.15%) NOTOK
#
# - Quantidade de técnicos na média baixo (33.68	) NOTOK
# - Quantidade de alunos média de alunos  moderado (932.89) NOTOK
# - Corpo docente muito na média (45.12) NOTOK
# - Pouca quantidade média de cursos (6.21) NOTOK
# - Despesas e receitas média acima do moderado NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quarto', 0, 17, 2, 14, 1, 4]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'quarto'))
# Out:
#  Como solicitado, farei uma análise detalhada e exploratória dos dados fornecidos para entender os fatores responsivos pela criação do cluster em questão. Estou assumindo que o arquivo CSV contém colunas relevantes para a identificação do cluster, como variáveis demográficas, financeiras ou de comportamento.
#
# 1. **Introdução**:
#    Primeiramente, é importante entender qual tipo de cluster estamos lidando com e o contexto em que os dados foram coletados. Isso pode incluir informações sobre a região geográfica, a idade dos participantes do cluster, ou outras características demográficas.
#
# 2. **Análise Exploratória**:
#    Comecei analisando os dados para identificar variáveis quantitativas e qualitativas. Visitei cada coluna para verificar se existem valores faltantes (nulos) ou outliers, que podem ser indicativos de erros no processo de coleta de dados.
#
# 3. **Análise Estatística**:
#    Para compreender melhor as tendências e relações entre variáveis, calcule estatísticas descritivas como média, mediana, desvio padrão, máximo e mínimo. Isso ajudará a identificar se há uma tendência central ou se existe assimetria nos dados.
#
# 4. **Análise de Correlaçãpas**:
#    Realizei um gráfico de correlação para visualizar as relações entre variáveis significativas. Notamos quais pares de variáveis apresentam forte associação, sugerindo que podem estar intimamente relacionadas e contribuem para a definição do cluster.
#
# 5. **Análise Cluster-Centroidaria**:
#    Aplicou-se técnicas como análise de agrupamento (clustering) para identificar padrões ou clusters nos dados. Analisamos quais variáveis são mais discriminantes no processo de divisão dos participantes em grupos.
#
# 6. **Detalhamento dos Clusters**:
#    Ao identificar os clusters, fiz uma análise detalhada para entender a composição demográfica e comportamental de cada grupo. Isso incluiu analisar a distribuição das variáveis dentro do cluster e compará-las com o restante da população.
#
# 7. **Análise Multivariada**:
#    Para refinar nossa compreensão, realizei uma análise multivariada usando técnicas estatísticas mais avançadas, como modelos lineares ou regressão logística. Isso permitiu avaliar se as variáveis associadas a um cluster são independentes ou se estão correlacionadas entre si.
#
# 8. **Análise de Conclusão**:
#    Com base na análise exploratória e estatística, pude descrever os fatores que levaram à criação do cluster em questão. Esses fatores podem incluir combinações especiais de variáveis demográficas ou comportamentais, assim como relações entre variáveis observadas no conjunto de dados.
#
# 9. **Análise Geral**:
#    A partir das análises realizadas, concluí que o cluster é formado por indivíduos com padrões especiais de comportamento e características demográficas incomuns em comparação com a população geral. Essa abordagem diversificada pode ser resultado da interação entre variáveis socioeconômicas, culturais ou comportamentais.
#
# 10. **Recomendações**:
#     Para alcançar um entendimento mais aprofundado sobre os fatores que levaram a essa distribuição em clusters, recomendo uma pesquisa longitudinal para monitorar como as variáveis demográficas e comportamentais se desenvolvem ao longo do tempo. Além disso, recomendo análises exploratórias adicionais com dados de outras fontes (como entrevistas profundas ou pesquisas qualitativas) para complementar a visão geral das preferências e necessidades desses grupos.
#
# No final, o processo envolveu uma combinação de técnicas estatísticas avançadas e insights humanos para entender com precisão os motivos por trás da formação desse cluster específico.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOTOK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOTOK
# - Uma incidência das IES não estarem numa capital (68.85%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) NOTOK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOTOK
# - Predominância em participar em redes sociais (71.20%) NOTOK
# - Possuem predominância em ter catalogo online (79.45%) NOTOK
# - Possuem predominância em ter outras bases (73.43%) NOTOK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) NOTOK(98,04) NOTOK
# - Maioria dos anos da IES são Faculdade (99.15%) NOTOK
#
# - Quantidade de técnicos na média baixo (33.68	) NOTOK
# - Quantidade de alunos média de alunos  moderado (932.89) NOTOK
# - Corpo docente muito na média (45.12) NOTOK
# - Pouca quantidade média de cursos (6.21) NOTOK
# - Despesas e receitas média acima do moderado NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights:
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quarto', 0.5, 17, 1, 16, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'quarto'))
# Out:
#  Analisando um conjunto de dados CSV, posso identificar algumas tendências e padrões no agrupamento fornecido. Antes de começar o processo analítico, é importante entender a estrutura do arquivo CSV e quais são as principais variáveis que estou trabalhando com.
#
# 1. **Importação dos dados**: Inicialmente, importei os dados usando uma biblioteca de manipulação de dados como a pandas no Python. Isso me permitiu ter um DataFrame organizado e facilita a análise exploratória posterior. Importei o CSV para este DataFrame.
#
# 2. **Exploração inicial**: Uma vez que os dados estão em uma estrutura de DataFrame, foi realizada uma análise descritiva básica, como verificar a distribuição das variáveis numéricas e quais as possíveis anomalias ou outliers no conjunto de dados.
#
# 3. **Análise estatística**: Desta vez, o foco foi na análise estatística do cluster fornecido. Aqui eu tive uma busca pelos fatores que levaram à criação deste cluster e analisar a presença de qualquer padrão ou relações entre as variáveis relevantes para o agrupamento selecionado. Essencialmente, olhei para quaisquer tendências estatísticas que possam ter levado à formação desse cluster específico, como por exemplo, a distribuição de uma ou mais variáveis com relação ao agrupamento selecionado.
#
# 4. **Análise dos fatores**: Ao analisar os dados, percebi algumas tendências e padrões que podem ter contribuído para a formação deste cluster específico. Algumas variáveis parecem estar fortemente relacionadas ao agrupamento selecionado, como por exemplo:
#    - Variável 1: Uma medida de atividade econômica (por exemplo, vendas) que parecia ter um efeito significativo no cluster.
#    - Variável 2: Outro indicador demográfico (como populaçãpas ou idade média), também pareceu ter uma relação significativa com o agrupamento em questão.
#
# 5. **Análise geral do agrupamento**: Ao analisar esses fatores estatisticamente, pude notar algumas possíveis relações entre as variáveis e a forma como elas influenciam o agrupamento selecionado. Essas análises podem ser utilizadas para ajudar na exploração de outros dados relacionados ao cluster e também para identificar quaisquer lacunas ou problemas no conjunto de dados que necessitam ser corrigidos.
#
# Em resumo, a minha abordagem envolveu: 1) análise inicial do DataFrame fornecido; 2) exploração estatística das variáveis relevantes para o cluster selecionado; e 3) identificação de fatores que podem ter contribuído para a formação desse agrupamento específico. Essas informações poderiam ser úteis ao tentar compreender melhor como esse cluster foi formado e quais estratégias ou políticas podem ser implementadas com base nesses resultados analíticos.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOTOK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOTOK
# - Uma incidência das IES não estarem numa capital (68.85%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) NOTOK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOTOK
# - Predominância em participar em redes sociais (71.20%) NOTOK
# - Possuem predominância em ter catalogo online (79.45%) NOTOK
# - Possuem predominância em ter outras bases (73.43%) NOTOK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) NOTOK (98,04) NOTOKOK
# - Maioria dos anos da IES são Faculdade (99.15%) NOTOKOK
#
# - Quantidade de técnicos na média baixo (33.68	) NOTOK
# - Quantidade de alunos média de alunos  moderado (932.89) NOTOK
# - Corpo docente muito na média (45.12) NOTOK
# - Pouca quantidade média de cursos (6.21) NOTOK
# - Despesas e receitas média acima do moderado NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quarto', 1.0, 17, 1, 16, 2, 1]

# %% [markdown]
# ### Firth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'quinto'))
# Out:
#  Para analisar e interpretar um arquivo CSV com base em clusters identificados, é crucial seguir alguns passos sistêmicos para compreender as características que influenciaram a forma como os dados foram agrupados. Aqui está uma abordagem geral para isso:
#
# 1. **Visão Geral do Arquivo CSV:**
#    Inicialmente, analisar o arquivo CSV para ter uma noção geral sobre quais colunas existem e qual a estrutura básica dos dados. Isso pode incluir informações sobre as variáveis numéricas ou categóricas que foram usadas para definir os clusters, bem como o número de linhas e colunas no arquivo.
#
# 2. **Visão Estatística dos Dados:**
#    Compreender a distribuição das variáveis nos dados é fundamental. Isso pode incluir analisar médias, desvios padrão, outliers e correlações entre as variáveis. Gráficos como boxplots, histogramas e scatter plots podem ser úteis para visualizar essas distribuições.
#
# 3. **Análise Exploratória dos Dados:**
#    Realizar testes estatísticos simples ou múltiplas para identificar relações significativas entre variáveis e entender como elas podem influenciar a criação de um cluster. Por exemplo, pode ser interessante verificar se há uma correlação linear significativa entre duas variáveis que poderiam estar relacionadas à formaçãcom que os dados foram agrupados.
#
# 4. **Detalhamento do Cluster:**
#    Para cada cluster identificado, analisar detalhadamente suas características. Isso pode envolver:
#    - Análise de quais variáveis estão fortemente relacionadas com o cluster (por exemplo, se os clusters são claramente divididos por uma ou mais variáveis).
#    - Identificar padrões específicos nos dados que podem estar refletindo as características do grupo (como tendências sazonais, ciclos de tempo, etc.).
#
# 5. **Análise dos Fatores Influentes:**
#    Tentativa de identificar fatores ou variáveis específicos que levaram à formação de um cluster. Isso pode incluir:
#    - Variáveis categóricas como marca, modelo, localização geográfica, etc., que podem ter sido usadas para definir os grupos.
#    - Análise de tendências temporais ou sazonais se relevante.
#    - Interações entre variáveis que sugiram um fator de influência maior nos clusters.
#
# 6. **Análise Geral do Agrupamento:**
#    Uma vez que detalhes individuais foram analisados, resumir as conclusões em uma visão geral dos grupos identificados. Isso pode envolver:
#    - Reafirmar a relevância e significado de cada cluster baseado nas características observadas.
#    - Discutir como esses clusters podem ser aplicáveis ou relevantes para uma variedade de aplicações, sejam elas estratégicas, operacionais ou financeiras.
#
# 7. **Dicas e Sugestões para Aplicação Prática:**
#    Após a análise, fornecer insights úteis que podem ajudar na tomada de decisão no contexto da identificação dos clusters. Isso pode incluir sugestões sobre como os grupos se comportam em diferentes cenários ou como eles podem ser usados para melhorar a tomada de decisão e estratégia empresarial.
#
# 8. **Limitações e Desafios:**
#    Finalmente, reconhecer as limitações do método estatístico usado na análise e considerar fatores não observados que podem ter influenciado os clusters, como viés de amostragem ou erros humanos embutidos no processo de coleta de dados.
#
# Ao longo deste processo, a importância da consistência na documentação das conclusões e metas é enfatizada, além do rigor estatístico para garantir que as descobertas sejam baseadas em evidências sólidas. Isso ajuda a construir uma abordagem robusta e sustentável para o entendimento de clusters complexos.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.17%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) NOTOK
# - Possuem predominância em busca integrada (77.90%) NOTOK
# - Possuem serviço de internet (97.47%) NOTOK
# - Predominância em participar em redes sociais (60.40%) NOTOK
# - Possuem catalogo online (85.57%) NOTOK
# - Possuem predominância em ter outras bases (78.28%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) NOTOK (96,85) NOTOK OK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) NOTOK OK
#
# - Quantidade de técnicos médio moderado (143.65) NOTOK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) NOTOK
# - Corpo docente muito acima da  média (151.18) NOTOK
# - Moderada quantidade média de cursos (18.49) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights:
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quinto', 0, 17, 2, 13, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'quinto'))
# Out:
#  Para começar, é importante compreender o propósito e contexto do cluster em questão. A partir disso, pode-se ter uma idéia inicial de quais variáveis ou características são mais relevantes para análise. Em casos extremos, poderiam ser identificadas variáveis específicas que levam a um cluster e nãcomum em outras.
#
# Uma vez que você tenha o conjunto de dados CSV disponível, é importante primeiro analisar estatisticamente os dados para entender algumas informações básicas, como tipo dos dados, valores ausentes e outliers. Essencialmente, esse passo ajudará a ter uma compreensão inicial do conjunto de dados e o que esperar durante a análise exploratória.
#
# A seguir, começar a analisar os dados com base nas variáveis relevantes ao cluster em questão. Pode ser útil usar técnicas estatísticas como correlação, regressão, ANOVA ou outras, para determinar relações entre as características e o cluster. Por exemplo, se esse cluster é de empresas, uma vez que variáveis como 'receita anual' e 'custos operacionais' pode ter um impacto significativo sobre a formação do cluster.
#
# Além disso, também seria útil analisar visualmente as instâncias de cluster para identificar padrões ou tendências que podem ser difíceis de perceber através apenas dos dados numéricos. Isso pode incluir análise de componentes principais, agrupamento hierarquico e redes sociais.
#
# Por fim, é importante analisar a consistência da formação do cluster para garantir que não haja flúidos temporais ou outros fatores externos que possam estar influenciando os dados. Se houver qualquer evidência de tal inconsistências, seria necessário investigar mais profundamente esse problema e determinar se ele tem alguma implicação no cluster em questão.
#
# Essa análise geralmente ajudará a desvendar motivos por trás da formação do cluster e permitirá tomar decisões informadas com base nas variáveis e características identificadas como mais relevantes.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.17%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) NOTOK
# - Possuem predominância em busca integrada (77.90%) NOTOK
# - Possuem serviço de internet (97.47%) NOTOK
# - Predominância em participar em redes sociais (60.40%) NOTOK
# - Possuem catalogo online (85.57%) NOTOK
# - Possuem predominância em ter outras bases (78.28%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) NOTOK(96,85) NOTOK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) NOTOK
#
# - Quantidade de técnicos médio moderado (143.65) NOTOK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) NOTOK
# - Corpo docente muito acima da  média (151.18) NOTOK
# - Moderada quantidade média de cursos (18.49) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights :
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quinto', 0.5, 17, 2, 15, 2, 1]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'quinto'))
# Out:
#  Para analisar e interpretar um cluster fornecido em um arquivo CSV, é crucial seguir etapas organizadas e aplicar técnicas estatísticas para extrair insights relevantes sobre os dados. Aqui está uma abordagem geral para realizar essa análise:
#
# ### 1. Visão Geral do Arquivo CSV
# Primeiro, compreenda o conteúdo e a estrutura básica do arquivo CSV. Identifique as colunas principais (variáveis) que são relevantes para a análise de clusterização. Essas variáveis podem incluir demográficos, comportamentais, financeiros ou outras características distintas que sejam importantes para o cluster em questão.
#
# ### 2. Análise Exploratória dos Dados (EDA)
# #### a. Estatística descritivas:
# Calcule estatísticas básicas como médias, medianas, desvios padrão, valores extremos e percentis para entender melhor a distribuição das variáveis no conjunto de dados.
#
# #### b. Análise unidimensional:
# Analise individualmente cada característica para identificar tendências, anomalias ou padrões significativos. Isso pode incluir o uso de histogramas, gráficos de dispersão e outros tipos de visualizaçãcomuns para entender melhor a variável em estudo.
#
# ### 3. Análise Multidimensional
# Utilizando técnicas de análise multivariada, como correlação ou componentes principais, examine as relações entre diferentes características. Isso pode ajudar a identificar quais variáveis estão fortemente correlacionadas e podem ter um impacto significativo no cluster.
#
# ### 4. Análise de Clusters
# #### a. Técnicas de Cluster:
# Inspecione as classes identificadas pela técnica de cluster (como K-means, DBSCAN, hierarquica) para garantir que o agrupamento reflita algum sentido ou padrão preditorio.
#
# #### b. Avaliação da Qualidade do Clustering:
# Use métricas como within-cluster sum of squares (WCSS), silhuetas score ou outras para avaliar a qualidade e consistência do cluster. Discorra sobre as escolhas de parâmetros, se necessário, que podem afetar significativamente o agrupamento.
#
# ### 5. Insights e Justificativas
# Após analisar os dados estatisticamente, descreva insights relevantes sobre o grupo. Isso pode incluir discussão sobre por que essa população é uma unidade única ou interessante em termos de marketing, política, ciência etc.
#
# ### 6. Análise Geral e Conclusões
# Reúna as informações coletadas para formular conclusões sobre o cluster. Esteja direto e baseie suas conclusões nas evidências fornecidas pelos dados, considerando a confiabilidade e validade das análises estatísticas realizadas.
#
# ### 7. Sugestões para Aplicações Futuras
# Se possível, ofereça sugestões sobre como os insights podem ser utilizados em contextos de negócios ou pesquisa futuros. Isso pode incluir recomendações para estudos adicionais, estratégias de marketing, projetos futuros etc.
#
# ### 8. Limites e Avisos
# Discuta os limites das análises, incluindo qualquer viés ou limitações no acesso aos dados, escolha de parâmetros na técnica de clusterização, ou outras questões que possam influenciar as conclusões.
#
# Essa abordagem fornece uma estrutura para analisar e interpretar um conjunto de dados relacionado a um cluster específico. Anote que o processo é iterativo e pode requerer revisão contínua das análises à medida que novos insights são descobertos ou evidências novas se tornam disponíveis.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%)NOTOK
# - Uma incidência das IES não estarem numa capital (59.17%)NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%)NOTOK
# - Possuem predominância em busca integrada (77.90%)NOTOK
# - Possuem serviço de internet (97.47%)NOTOK
# - Predominância em participar em redes sociais (60.40%)NOTOK
# - Possuem catalogo online (85.57%)NOTOK
# - Possuem predominância em ter outras bases (78.28%)NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos)NOTOK (96,85)NOTOK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%)NOTOK
#
# - Quantidade de técnicos médio moderado (143.65)NOTOK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86)NOTOK
# - Corpo docente muito acima da  média (151.18)NOTOK
# - Moderada quantidade média de cursos (18.49)NOTOK
# - Despesas e receitas média altas  NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'quinto', 1.0, 17, 1, 16, 1, 2]

# %% [markdown]
# ### Sixth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'sexto'))
# Out:
#  Olá! Estou à disposição para ajudar você com sua tarefa. No entanto, não recebemos informações sobre o "csv" ou qualquer outro detalhe relevante que eu poderia usar como base para análise e explicação do cluster.
#
# Mas, em um contexto genérico, se você deseja analisar um arquivo csv de dados relacionado a um cluster específico, aqui estão algumas etapas que eu recomendaria seguir:
#
# 1. **Análise Inicial**: Comece analisando a estrutura geral do arquivo csv e identifique as colunas relevantes para o cluster em questão. Certifique-se de entender quais variáveis estão sendo utilizadas e se há alguma ausência ou redundância nesses dados.
#
# 2. **Caracterização dos Dados**: Com base nas colunas identificadas, caracterize os dados adotando a análise descritiva estatística. Calcule médias, mediana, desvio padrão, variabilidade e outras medidas para entender melhor o conjunto de dados.
#
# 3. **Análise Exploratória**: Analisar correlações entre as diferentes características do dataset pode fornecer insights sobre quais variáveis estão correlacionadas com maior intensidade, sugerindo que poderiam ser fatores relevantes no cluster.
#
# 4. **Detecção de Padrões**: Procure por padrões ou tendências nos dados que possam indicar o motivo pelo qual os itens se agruparam juntos. Isso pode incluir a observação de clusters dentro de subconjuntos, diferenças significativas entre grupos ou até mesmo variações sazonais.
#
# 5. **Análise Estatística**: Aplique testes estatísticos apropriados para determinar se as diferenças observadas entre os clusters são significantes o suficiente para rejeitar a hipótese nula, garantindo um rigor científico em suas conclusões.
#
# 6. **Explicação do Cluster**: No final da análise exploratória, você poderá propor uma explicação plausível para o cluster baseada nas evidências empíricas coletadas. Isso pode incluir a identificaçãcom características comuns e variáveis explicativas que levaram ao agrupamento observado.
#
# 7. **Análise Geral**: Após analisar os detalhes individuais do cluster, unifique suas descobertas para criar uma análise geral sobre o motivo pelo qual aquele conjunto de dados se organizou daquela maneira.
#
# Se você puder me fornecer algumas informações específicas sobre o arquivo csv e suas variáveis, poderei oferecer uma análise mais precisa. Mas, baseado na discussão acima, espero que essas etapas sirvam como um guia para analisar qualquer conjunto de dados relacionado a um cluster específico.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%)NOTOK
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%)NOTOK
# - Predominância das IES não estarem numa capital (69.21%)NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (73.15%)NOTOK
# - Predominância das Instituições sem repositorio institucional (68.00%)NOTOK
# - Possuem predominância em busca integrada (65.43%)NOTOK
# - Possuem serviço de internet (90.62%)NOTOK
# - Predominância em participar em redes sociais (65.28%)NOTOK
# - Possuem catalogo online (72.39%)NOTOK
# - Possuem predominância em ter outras bases (62.25%)NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos)NOTOK (90,01%)NOTOK
# - Maioria dos anos da IES são Faculdade (95.39%)NOTOK
#
# - Quantidade de técnicos médio baixo (46.05	)NOTOK
# - Quantidade de alunos média de alunos  moderado (1,202.21)NOTOK
# - Corpo docente moderado na  média (60.92)NOTOK
# - Moderada quantidade baixa de cursos (16.76)NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixo NOTOK
#
# Insights falsos:
# -A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'sexto', 0, 18, 3, 15, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'sexto'))
# Out:
#  A tarefa é identificar fatores ou variáveis que influenciaram na criação do cluster fornecido em um arquivo CSV. Primeiro, analisei a estrutura básica e os tipos de dados das colunas no arquivo CSV para garantir uma análise adequada. Após essa primeira avaliação, comecei a explorar as correlações e relações entre diferentes features (colunas) do conjunto de dados.
#
# ### Análise Preliminar:
#
# 1. **Revisão dos Dados**: Primeiro passei em revista o arquivo CSV, identificando suas colunas e tipos de dado. Isso incluiu verificar se todas as variáveis estavam presentes e se todos os dados eram relevantes para a análise do cluster.
#
# 2. **Validação Inicial**: Verifiquei a consistência dos dados, como preenchimento de campos nulos e valores inconsistentes ou inexistentes. Isso pode ajudar a identificar se algumas colunas estão faltando por erro humano antes da geração do cluster.
#
# ### Análise Estatística:
#
# 1. **Correlações**: Utilizei técnicas estatísticas como correlação de Pearson para analisar a relação entre as variáveis e identificar quais pares de features estão fortemente correlacionadas, sugerindo uma possível causa-efeito ou interdependência.
#
# 2. **Distribuições**: Analisei as distribuições das variáveis para entender como os dados se distribuem e identificar possíveis outliers que podem ser relevantes na análise do cluster.
#
# 3. **Teste T pareado (se aplicável)**: Se houvesse uma amostra dentro de um cluster, seria útil usar o teste t pareado para comparar médias entre diferentes períodos ou condições dentro do cluster.
#
# ### Análise Exploratória:
#
# 1. **Visualização**: Utilize gráficos e visualizações como boxplots, histogramas e heatmaps para analisar melhor a estrutura dos dados e identificar padrões ou tendências que podem estar relacionadas ao cluster em questão.
#
# 2. **Análise de Componentes Principais (PCA)**: Se houvesse uma grande quantidade de features, poderia usar técnicas estatísticas mais avançadas como PCA para reduzir a dimensionalidade e facilitar a interpretação dos dados.
#
# ### Análise do Cluster:
#
# 1. **Descrição Geral**: Realizei uma descrição geral do cluster, identificando quais features estão mais presentes ou mais variáveis dentro desse grupo de instâncias.
#
# 2. **Fatores Críticos**: Identifiquei fatores que podem ter influenciado a criaçãcom um determinado ocorrência ou conjugada com outra característica isolado ou particularmente significativos no contexto do cluster.
#
# 3. **Relato Final**: Após análises estatísticas e exploratórias, apresentei minha interpretação baseada nas evidências empíricas encontradas nos dados. Isso incluiria uma discussão sobre quais variáveis são mais influentes no cluster, considerando tanto as correlações quanto a análise de distribuição e visualização dos dados.
#
# ### Análise Geral:
#
# Em suma, para analisar um cluster usando dados estatísticos, primeiro compreenda o conjunto de dados com base na estrutura do arquivo CSV. Em seguida, explore as correlações e relações entre variáveis. Conclua com uma análise detalhada dos fatores que levaram à criação do cluster, levando em consideração tanto a estatística quanto visualização de dados para fornecer um relatório robusto e empírico.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%)
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%)
# - Predominância das IES não estarem numa capital (69.21%)
# - Predominância das Instituições sem acesso ao portal Capes (73.15%)
# - Predominância das Instituições sem repositorio institucional (68.00%)
# - Possuem predominância em busca integrada (65.43%)
# - Possuem serviço de internet (90.62%)
# - Predominância em participar em redes sociais (65.28%)
# - Possuem catalogo online (72.39%)
# - Possuem predominância em ter outras bases (62.25%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (90,01%)
# - Maioria dos anos da IES são Faculdade (95.39%)
#
# - Quantidade de técnicos médio baixo (46.05	)
# - Quantidade de alunos média de alunos  moderado (1,202.21)
# - Corpo docente moderado na  média (60.92)
# - Moderada quantidade baixa de cursos (16.76)
# - Despesas e receitas média altas
# - Quantidade de periodicos e livros eletronicos com relev ncia baixo
#
# Insights falsos:
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'sexto', 0.5, 18, 4, 14, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'sexto'))
# Out:
#  Para começar a análise dos agrupamentos fornecidos, é importante primeiro entender os dados coletados e como eles foram organizados em um arquivo CSV. Como não há informações específicas sobre o cluster ou o conjunto de dados em questão, assumiremos que estamos lidando com uma variável dependente (por exemplo, preço de ações) e várias variáveis independentes (como taxa de crescimento, lucro líquido, endividamento etc.).
#
# 1. Análise descritiva dos dados:
# Antes de analisar os dados estatisticamente, é fundamental realizar uma análise descritiva básica para entender a estrutura geral do conjunto de dados fornecido. Isso inclui calcular médias, medianas, modos, desvios padrão, máximos e mínimos das variáveis relevantes.
# 2. Correlação entre variáveis:
# Avaliar a correlação entre as variáveis independentes pode ajudar a identificar quais pares de características estão relacionadas positivamente ou negativamentemente umas com as outras. Uma matriz de correlação poderá ser útil para visualizar essa relação e indicar quais variáveis podem estar envolvidas no agrupamento dos dados.
# 3. Análise multivariada:
# Com base nas análises descritivas e na matriz de correlação, selecionar as variáveis mais relevantes para o estudo do cluster. Em seguida, aplicar técnicas estatísticas como ANOVA, regressão linear ou clustering (K-means, DBSCAN etc.) para analisar a consistência e os fatores que levaram à criaçãcomunidade particular no conjunto de dados fornecido.
# 4. Detecção de padrões complexos:
# Às vezes, as relações entre variáveis podem ser não-lineares ou complexas, e isso pode levar a agrupamentos inesperados ou não óbvios. Por exemplo, é possível que haja uma combinação específica de características que resulta em clusters únicos. É importante analisar esses padrões complexos para garantir que nenhum efeito anômalo tenha sido ignorado ou malinterpretado.
# 5. Análise geral do agrupamento:
# Após a análise estatística, é recomendável realizar uma revisão visual dos dados para verificar se as conclusões extraídas estatisticamente estão de acordo com o conjunto de dados coletado. Isso pode incluir plotar gráficos de dispersão e análise exploratória de imagem (principalmente se os clusters forem visualizados em um espaço dimensional mais alto).
# 6. Considerações finais:
# Em última análise, é importante levar em consideração a viabilidade e a plausibilidade das conclusões extraídas dos dados. É fundamental ter uma compreensão clara da complexidade do problema de agrupamento e não subestimar as ocorrências isoladas ou anomalias, mas reconhecer que os resultados estatisticamente significativos podem oferecer insights valiosos sobre a dinâmica do cluster em questão.
#
# Com base nas análises mencionadas acima, podemos fazer uma conclusão geral sobre o agrupamento e as variáveis envolvidas, identificando os fatores mais significativos que levaram à criação desse determinado cluster no conjunto de dados fornecido.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%)
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%)
# - Predominância das IES não estarem numa capital (69.21%)
# - Predominância das Instituições sem acesso ao portal Capes (73.15%)
# - Predominância das Instituições sem repositorio institucional (68.00%)
# - Possuem predominância em busca integrada (65.43%)
# - Possuem serviço de internet (90.62%)
# - Predominância em participar em redes sociais (65.28%)
# - Possuem catalogo online (72.39%)
# - Possuem predominância em ter outras bases (62.25%)
# - Maioria das instituições são privada (com e sem fins lucrativos) (90,01%)  OK
# - Maioria dos anos da IES são Faculdade (95.39%) OK
#
# - Quantidade de técnicos médio baixo (46.05	)
# - Quantidade de alunos média de alunos  moderado (1,202.21)
# - Corpo docente moderado na  média (60.92)
# - Moderada quantidade baixa de cursos (16.76)
# - Despesas e receitas média altas
# - Quantidade de periodicos e livros eletronicos com relevância baixo
#
# Insights falsos:
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'sexto', 1.0, 18, 1, 17, 1, 0]

# %% [markdown]
# ### Seventh Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0, 'setimo'))
# Out:
#  Para realizar análise e interpretação dos dados do cluster fornecido, seguir-se-ão etapas detalhadas baseadas na exploração inicial dos dados disponibilizados (csv). Essa abordagem envolve a análise descritiva das variáveis relevantes e o desenvolvimento de insights sobre as tendências e padrões identificados nos dados.
#
# 1. **Introdução ao Conjunto de Dados**: Analisando rapidamente o arquivo CSV, percebemos que contém informações relevantes relacionadas a uma determinada área geográfica ou segmento do mercado. O conjunto de dados pode abordar aspectos demográficos, financeiros, comportamentais ou outros.
#
# 2. **Exploração Inicial**: Ao analisar os primeiros registros, observamos a presença de colunas como ID (identificação única), Data e Variaveis relevantes (como População, Renda per capita, Taxas de criminalidade etc.). Essencialmente, estamos olhando por algum padrão ou tendência inicial.
#
# 3. **Análise Estatística**: A partir desses dados iniciais, a próxima etapa seria executar análises estatísticas para entender melhor como as variáveis estão relacionadas entre si e com o cluster em questão. Estas incluem:
#     - **Análise de Correlação**: Apliquei testes estatísticos para analisar se há uma relação linear significativa entre as variáveis (como renda x população, crime rate x income etc.). Isso pode ajudar a identificar quais pares de características estão fortemente correlacionadas.
#     - **Teste T para Pares Simples**: Realizei testes t para verificar se há uma diferença estatisticamente significante entre as médias da variável dependente e a categoria independente (por exemplo, comparar renda per capita de diferentes regiões).
#
# 4. **Detalhamento dos Fatores**: Aplicando análise exploratória com um olhar para encontrar padrões ou tendências mais específicas, identificamos:
#     - **Variáveis Clusters Especificas**: Analisei o comportamento dessas variáveis em diferentes categorias do cluster. Isso pode nos dar uma ideia de como os indivíduos no cluster se comportam ou diferem uns dos outros, e podem estar intimamente relacionados às causas subjacentes para a formação desse cluster.
#     - **Ciclo Vital/Comportamento Econômico**: Se o cluster estiver associado a um período demográfico específico, talvez possamos notar tendências temporais como ascensão ou declínio de uma população em determinado momento.
#
# 5. **Análise Geral do Aglomeramento**: Em conjunto, todas essas análises podem ser utilizadas para desenvolver um entendimento geral sobre o cluster e sua formação:
#     - **Causas Subjacentes ao Cluster**: Ao analisar correlações e tendências em várias variáveis, podemos começar a entender quais fatores geográficos, sociais ou econômicos podem ter contribuído para o surgimento do cluster.
#     - **Implicações Socioeconômicas**: Ao examinar como as pessoas no cluster se comportam em relação a variáveis importantes (como renda, escolaridade e crime rate), podemos adivinhar sobre as implicações socioeconômicas do cluster.
#     - **Estratégias Potenciais para Intervir**: Com base nas tendências identificadas no conjunto de dados, poderíamos propor estratégias que visem a melhorar o desenvolvimento ou qualidade de vida dos membros do cluster, levando em consideração as relações complexas entre variáveis e fatores envolvidos.
#
# No geral, essa abordagem envolveu uma análise descritiva detalhada das características demográficas, econômicas e de comportamento que compõem o cluster fornecido, buscando desvendar a complexidade de sua formação e as implicações para intervenções futuras.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%) NOTOK
# - Predominância das Instituições com acesso ao portal Capes (87.76%) NOTOK
# - Predominância das Instituições com repositorio institucional (70.41%) NOTOK
# - Possuem predominância em busca integrada (67.18%) NOTOK
# - Possuem serviço de internet (98.81%) NOTOK
# - Predominância em participar em redes sociais (71.94%) NOTOK
# - Possuem catalogo online (92.69%) NOTOK
# - Possuem predominância em ter outras bases (91.16%) NOTOK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%) NOTOK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%) NOTOK
#
# - Quantidade de técnicos médio alto (1,170.62	) NOTOK
# - Quantidade de alunos média de alunos alto (27,666.31) NOTOK
# - Corpo docente alto na  média (970.69) NOTOK
# - altga quantidade baixa de cursos (73.91) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'setimo', 0, 16, 3,13, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 0.5, 'setimo'))
# Out:
#  Para começar o processo analítico e exploratório sobre um cluster, primeiro é importante entender qual o contexto ou motivação para criá-lo. Esteja ele relacionado a marketing, saúde pública, finanças etc., uma vez que isto irá influenciar diretamente como você interpretará os dados e quais insights podem ser obtidos do cluster em questão.
#
# O primeiro passo na análise estatística seria a verificação das principais métricas descritivas para o conjunto de dados, tais como: média, mediana, desvio padrão, variância, percentis e etc., que irão ajudar a entender a dinâmica do cluster.
#
# Depois disso, será útil olhar para distribuições de frequências (ou histogramas) das principais variáveis para ter uma melhor ideia se o cluster está bem definido ou nãcom um padrão irregular. O mesmo vale para a correlação entre as características, que pode ser analisada através de um mapa de calor (scatter plots) ou matrizes de correlação.
#
# A partir desta primeira análise estatística, você poderia começar a formular hipóteses sobre quais variáveis estão influenciando mais na formação do cluster e se há algumas que podem estar associadas com uma causa raiz.
#
# Assim como analisar os dados de maneira quantitativa, seria interessante também analisar a qualitative data presente no CSV caso haja disponível. Por exemplo, análise textual pode ser útil para entender opiniões ou sentimentos dos usuários em relação ao cluster.
#
# Após uma primeira análise quantitativa e qualitativa das variáveis relacionadas ao cluster, é importante então realizar um agrupamento mais formal (cluster analysis) com o propósito de identificar padrões ou tendências não óbvias a partir dos dados.
#
# A análise final do cluster poderia ser resumida da seguinte maneira: O cluster é composto por um grupo de observações (instancias) que compartilham características similares em termos das variáveis analisadas. Essas características podem estar relacionadas a alguma combinação de variáveis, como uma ocorrência isolada ou múltiplas ocorrências.
#
# Dentre os possíveis insights que se poderiam obter do cluster incluem: O segmento alvo mais promissor para um marketing campaign, condições preditorias de saúde pública, grupos de clientes com necessidades especiais etc.
#
# Porém é importante notar que o processo iterativo e exploratório de análise estatística sempre vai contribuir para a descoberta mais precisa deste cluster.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%) NOTOK
# - Predominância das Instituições com acesso ao portal Capes (87.76%) NOTOK
# - Predominância das Instituições com repositorio institucional (70.41%) NOTOK
# - Possuem predominância em busca integrada (67.18%) NOTOK
# - Possuem serviço de internet (98.81%) NOTOK
# - Predominância em participar em redes sociais (71.94%) NOTOK
# - Possuem catalogo online (92.69%) NOTOK
# - Possuem predominância em ter outras bases (91.16%)
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%) NOTOK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%) NOTOK
#
# - Quantidade de técnicos médio alto (1,170.62	) NOTOK
# - Quantidade de alunos média de alunos alto (27,666.31) NOTOK
# - Corpo docente alto na  média (970.69) NOTOK
# - altga quantidade baixa de cursos (73.91) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights falsos:
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters
# -

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'setimo', 0.5, 16, 2,14, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase2, 1.0, 'setimo'))
# Out:
#  A análise de um determinado cluster requer um rastreio minucioso dos dados disponibilizados para identificar padrões e tendências que possam estar relacionadas à formação desse cluster. Como analista de dados, a estratégia geral é inicialmente identificar características estatisticamente significativas através de análise descritiva, seguida por testes estatísticos para validar hipóteses e inferir causas potenciais para a formação desse cluster.
#
# ### 1. Análise Descritiva:
# Primeiro passo é compreender os dados brutos, incluindo tipos de colunas (categorias ou numéricas) e o número de registros. A análise descritiva pode incluir a média, mediana, moda, desvio padrão, variância e outras medidas estatísticas para características relevantes à formação do cluster.
#
# ### 2. Teste de Hipóteses:
# Em seguida, aplicamos testes estatísticos para identificar se as diferenças observadas nas características entre o grupo e o controle são significativas. Tests t podem ser usados para comparar médias individuais ou ANOVA para analisar a significância de múltiplas medidas.
#
# ### 3. Análise Exploratória por Conjunto:
# Analisando os dados em conjunto, pode-se identificar características que variam significativamente entre o cluster e o restante dos dados (clusters ou contémpo). Pode ser útil usar técnicas como clustering hierárquico, k-means, análise de componentes principais etc., para agrupar os dados e identificar padrões.
#
# ### 4. Análise das Características Locais:
# Desta vez focamos em analisar cada característica individualmente com o intuito de perceber como ela influencia a criação do cluster, levando em conta que fatores isolados ou conjugados podem ter participado. Estatística univariada pode ser usada para identificar relações fortes entre essas variáveis e a presença do cluster.
#
# ### 5. Análise de Congruência:
# Esta etapa envolve examinar como as características individuais se relacionam com o grupo alvo, identificando padrões especiais ou anomalias que podem ser importantes na identificação do cluster.
#
# ### 6. Criação de Modelos Probabilísticos:
# Com base nas descobertas feitas até agora, uma vez que as características estatisticamente significativas são identificadas e testadas, pode-se começar a criar modelos probabilísticos para tentar explicar por que um cluster foi formado. Esse processo pode incluir análise de regressão ou machine learning se necessário.
#
# ### 7. Conclusão Geral:
# Ao final, uma vez que todas as etapas da análise foram completadas e o cluster foi bastante analisado estatisticamente, pode-se começar a fazer conclusões gerais sobre o porquê de esse grupo se formar. Pode incluir análise das principais características que levaram à formação desse cluster e como elas interagem para resultar na existência do mesmo.
#
# Esse processo de análise iterativo permitirá a identificação dos fatores mais prováveis que levaram à criação desse determinado cluster, levando em consideração dados estatísticos e análises descritivas, testes estatísticos, técnicas de agrupamento, interpretações das características locais e a construção de modelos probabilísticos.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%)NOTOK
# - Predominância das Instituições com acesso ao portal Capes (87.76%)NOTOK
# - Predominância das Instituições com repositorio institucional (70.41%)NOTOK
# - Possuem predominância em busca integrada (67.18%)NOTOK
# - Possuem serviço de internet (98.81%)NOTOK
# - Predominância em participar em redes sociais (71.94%)NOTOK
# - Possuem catalogo online (92.69%)NOTOK
# - Possuem predominância em ter outras bases (91.16%)NOTOK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%)NOTOK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%)NOTOK
#
# - Quantidade de técnicos médio alto (1,170.62	)NOTOK
# - Quantidade de alunos média de alunos alto (27,666.31)NOTOK
# - Corpo docente alto na  média (970.69)NOTOK
# - altga quantidade baixa de cursos (73.91)NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK
#
# Insights:
# - A análise apenas descreveu etapas de como deveria ser feita as análises dos clusters

# %%
analise_kmeans.loc[len(analise_kmeans)] = ['Fase 2',  'setimo', 1.0, 16, 1,15, 2, 0]

# %% [markdown]
# # K-means

# %% [markdown]
# ### Fase 4

# %%
analise_kmeans_fase4 = pd.DataFrame([], columns=['prompt', 'cluster', 'temperature', 'Total_suposições', 'Mapeadas_pelo_modelo', 'Ignoradas_pelo_modelo', 'alucinação_do_modelo', 'insights'])

# %%
kmeans_fase4 = pd.read_csv('Models/results/K-means_Fase 4_results.csv')

# %%
kmeans_fase4.loc[(kmeans_fase4['temperature'] == 1) & (kmeans_fase2['cluster'] == 'primeiro'), ['result']]['result'].tolist()[0]
# Out:
# '**Análise dos Agrupamentos**\n\n**QT_ALUNOS**: "A média da quantidade de alunos é de 250, com uma variância de 50. Existe uma relação positiva entre a quantidade de alunos e a quantidade de recursos (docentes, cursos, técnicos). Além disso, as instituições com mais alunos tendem a ter mais recursos disponíveis."\n\n**QT_DOCENTES**: "A média da quantidade de docentes é de 80, com uma variância de 20. Existe uma relação positiva entre a quantidade de docentes e a quantidade de alunos. As instituições com mais alunos também tendem a ter mais docentes."\n\n**QT_CURSO**: "A média da quantidade de cursos é de 30, com uma variância de 10. Existe uma relação positiva entre a quantidade de cursos e a quantidade de recursos (docentes, técnicos). As instituições com mais cursos tendem a ter mais recursos disponíveis."\n\n**QT_TEC_TOTAL**: "A média da quantidade de técnicos é de 20, com uma variância de 5. Existe uma relação positiva entre a quantidade de técnicos e a quantidade de recursos (docentes, cursos). As instituições com mais técnicos tendem a ter mais recursos disponíveis."\n\n**QT_PERIODICO_ELETRONICO**: "A média da quantidade de periodicos eletronicos é de 10, com uma variância de 3. Existe uma relação negativa entre a quantidade de periodicos eletronicos e a quantidade de receita. As instituições com mais periodicos tendem a ter menos receita."\n\n**QT_LIVRO_ELETRONICO**: "A média da quantidade de livros eletronicos é de 5, com uma variância de 2. Existe uma relação positiva entre a quantidade de livros e a quantidade de receita. As instituições com mais livros tendem a ter mais receita."\n\n**T1_VL_RECEITAS**: "A média da receita é de 100.000, com uma variância de 50.000. Existe uma relação positiva entre a receita e a quantidade de recursos (docentes, cursos, técnicos). As instituições com mais recursos tendem a ter mais receita."\n\n**T1_VL_DESPESAS**: "A média das despesas é de 80.000, com uma variância de 30.000. Existe uma relação positiva entre as despesas e a quantidade de recursos (docentes, cursos, técnicos). As instituições com mais recursos tendem a ter mais despesas."\n\n**IN_CAPITAL**: "Há uma predominância de instituições na capital, com 60% das instituições sendo capitalinas. Existe uma relação positiva entre a instituição ser na capital e ter mais recursos disponíveis."\n\n**IN_OUTRAS_BASES**: "40% das instituições têm outras bases além da instituição matriz. Existe uma relação negativa entre a instituição ter outras bases e ter menos receita."\n\n**IN_REPOSITORIO_INSTITUCIONAL**: "20% das instituições têm repositorio institucional. Existe uma relação positiva entre a instituição ter repositorio e ter mais recursos disponíveis."\n\n**IN_BUSCA_INTEGRADA**: "15% das instituições têm busca integrada. Existe uma relação positiva entre a instituição ter busca integrada e ter mais recursos disponíveis."\n\n**IN_SERVICO_INTERNET**: "80% das instituições têm serviço de internet. Existe uma relação positiva entre a instituição ter serviço de internet e ter mais recursos disponíveis."\n\n**IN_PARTICIPA_REDE_SOCIAL**: "50% das instituições participam nas redes sociais. Existe uma relação positiva entre a instituição participar das redes sociais e ter mais recursos disponíveis."\n\n**IN_CATALOGO_ONLINE**: "30% das instituições têm catalogo online. Existe uma relação positiva entre a instituição ter catalogo online e ter mais recursos disponíveis."\n\n**IN_ACESSO_PORTAL_CAPES**: "20% das instituições têm acesso ao portal capes. Existe uma relação positiva entre a instituição ter acesso ao portal capes e ter mais recursos disponíveis."\n\n**NU_ANO_CENSO**: "A média do ano censo é de 2010, com uma variância de 5 anos. Existe uma relação negativa entre o ano censo e a receita. As instituições com anos mais antigos tendem a ter menos receita."\n\n**CO_REGIAO**: "Há uma predominância de instituições da região Sudeste, com 50% das instituições sendo do estado do Rio de Janeiro. Existe uma relação positiva entre a instituição e ...

# %%
analise_kmeans_fase4
# Out:
#     prompt   cluster  temperature  Total_suposições  Mapeadas_pelo_modelo  \
# 0   Fase 4  primeiro          0.0                15                     8
# 1   Fase 4  primeiro          0.5                15                     9
# 2   Fase 4  primeiro          1.0                15                     8
# 3   Fase 4   segundo          0.0                17                     2
# 4   Fase 4   segundo          0.5                17                     3
# 5   Fase 4   segundo          1.0                17                     4
# 6   Fase 4  terceiro          0.0                15                     2
# 7   Fase 4  terceiro          0.5                15                     6
# 8   Fase 4  terceiro          1.0                15                     6
# 9   Fase 4    quarto          0.0                17                     1
# 10  Fase 4    quarto          0.5                17                     6
# 11  Fase 4    quarto          1.0                17                     4
# 12  Fase 4    quinto          0.0                16                     3
# 13  Fase 4    quinto          0.5                16                     5
# 14  Fase 4    quinto          1.0                16                     5
# 15  Fase 4     sexto          0.0                18                     9
# 16  Fase 4     sexto          0.5                18                     6
# 17  Fase 4     sexto          1.0                18                     7
# 18  Fase 4    setimo          0.0                16                     6
# 19  Fase 4    setimo          0.5                16                     7
# 20  Fase 4    setimo          1.0                16                     9
#
#     Ignoradas_pelo_modelo  alucinação_do_modelo  insights
# 0                       7                     3         0
# 1                       6                     2         0
# 2                       6                     1         0
# 3                      15                     4         0
# 4                      14                     1         0
# 5                      13                     2         0
# 6                      13                     2         1
# 7                       9                     2         2
# 8                       9                     2         4
# 9                      16                     2         1
# 10                     11                     3         0
# 11                     13                     3         1
# 12                     11                     3         0
# 13                     11                     3         1
# 14                     11                     2         0
# 15                     10                     2         0
# 16                     12                     2         0
# 17                      9                     0         0
# 18                     10                     1         0
# 19                      9                     1         0
# 20                      7                     1         0

# %%
analise_kmeans_fase4.to_csv('analise_kmeans_fase4.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### First Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'primeiro'))
# Out:
# **Análise dos Agrupamentos**
#
# Aqui está a análise dos agrupamentos com base nos dados fornecidos:
#
# **QT_ALUNOS;IN_CAPITAL**: A média de QT_ALUNOS é de 500,00 e a mediana é de 400,00. Há uma relação positiva entre a quantidade de alunos e a posição da instituição como capital (p = 0,01). Isso sugere que as instituições situadas na capital tendem a ter mais alunos.
#
# **QT_DOCENTES;NOME_CATEGORIA_ADMINISTRATIVA**: A média de QT_DOCENTES é de 150,00 e a mediana é de 120,00. Há uma relação negativa entre a quantidade de docentes e a categoria administrativa (p = 0,05). Isso sugere que as instituições com maior importância política tendem a ter menos docentes.
#
# **QT_CURSO;IN_REPOSITORIO_INSTITUCIONAL**: A média de QT_CURSO é de 50,00 e a mediana é de 30,00. Há uma relação positiva entre a quantidade de cursos e a presença de um repositorio institucional (p = 0,01). Isso sugere que as instituições com um repositorio institucional tendem a ter mais cursos.
#
# **QT_TEC_TOTAL;IN_SERVICO_INTERNET**: A média de QT_TEC_TOTAL é de 20,00 e a mediana é de 10,00. Há uma relação positiva entre a quantidade de técnicos e o serviço de internet (p = 0,05). Isso sugere que as instituições com um serviço de internet tendem a ter mais técnicos.
#
# **QT_PERIODICO_ELETRONICO;IN_busca_INTEGRADA**: A média de QT_PERIODICO_ELETRONICO é de 50,00 e a mediana é de 30,00. Há uma relação positiva entre a quantidade de periodicos eletronicos e a presença de busca integrada (p = 0,05). Isso sugere que as instituições com busca integrada tendem a ter mais periodicos eletronicos.
#
# **QT_LIVRO_ELETRONICO;NU_ANO_CENSO**: A média de QT_LIVRO_ELETRONICO é de 10,00 e a mediana é de 5,00. Há uma relação negativa entre a quantidade de livros eletronicos e o ano do censo (p = 0,05). Isso sugere que as instituições mais antigas tendem a ter menos livros eletronicos.
#
# **T1_VL_RECEITAS;NOME_ORGANIZACAO_ACADEMICA**: A média de T1_VL_RECEITAS é de 1000000,00 e a mediana é de 500000,00. Há uma relação positiva entre a receita da instituição e a organização academica (p = 0,01). Isso sugere que as instituições com maior importância acadêmica tendem a ter mais receita.
#
# **T1_VL_DESPESAS;CO_REGIAO**: A média de T1_VL_DESPESAS é de 500000,00 e a mediana é de 200000,00. Há uma relação negativa entre as despesas da instituição e a região (p = 0,05). Isso sugere que as instituições localizadas em regiões mais ricas tendem a ter menos despesas.
#
# **IN_CAPITAL;NOME_CATEGORIA_ADMINISTRATIVA**: A média de IN_CAPITAL é de 1,00 e a mediana é de 0,50. Há uma relação positiva entre a instituição como capital e a categoria administrativa (p = 0,01). Isso sugere que as instituições situadas na capital tendem a ter maior importância política.
#
# **IN_OUTRAS_BASES;NOME_ORGANIZACAO_ACADEMICA**: A média de IN_OUTRAS_BASES é de 1,00 e a mediana é de 0,50. Há uma relação positiva entre a presença de outras bases e a organização academica (p = 0,05). Isso sugere que as instituições com maior importância acadêmica tendem a ter mais outras bases.
#
# **NU_ANO_CENSO;NOME_ORGANIZACAO_ACADEMICA**: A média de NU_ANO_CENSO é de 2015,00 e a mediana é de 2000,00. Há uma relação positiva entre o ano do censo e a organização academica (p = 0,01). Isso sugere que as instituições mais antigas tendem a ter maior importância acadêmica.
#
# **Análise Geral do Agrupamento**
#
# Os agrupamentos apresentam características de instituições universitárias com uma grande importância acadêmica. As instituições situadas na capital e com maior importância política tendem a ter mais alunos, cursos e técnicos. Além disso, as instituições com serviços de internet e busca integrada tendem a ter mais livros eletrônicos e periodicos eletrónicos.
#
# As instituições mais antigas tendem a ter menos livros eletrônicos e periodicos eletrónicos, enquanto as instituições com maior importância acadêmica tendem a ter mais receita. As regiões mais ricas tendem a ter menos despesas das instituições.
#
# Em resumo, os agrupamentos apresentam características de instituições universitárias que dependem de fatores como importância acadêmica, recursos financeiros e localização geográfica.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%) NOTOK
# - Uma incidência das IES não estarem numa capital (59,78%)  OK
# - Instituições com acesso ao portal Capes (87.34%) NOTOK
# - Possuem serviço de internet (94.97%) OK
# - Participam em redes sociais (71.51%) OK
# - Possuem catalogo online (86.22%) OK
# - Busca integrada (58.29%) OK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%)  NOTOK
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%) NOTOK
#
# - Quantidade alta de técnicos na média (765.03) OK
# - Quantidade de alunos média de alunos alto (12,553.95) OK
# - Corpo docente forte na média (761.73) OK
# - Quantidade considerável de cursos na média (média de 52.45) NOTOK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK
#
# InsightS:
# - Apesar de mapear características do cluster, não explicitou as colunas  a que se referia

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4', 'primeiro', 0, 15, 8, 7, 3, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'primeiro'))
# Out:
# **Análise dos Agrupamentos**
#
# **QT_ALUNOS:** "A média de QT_ALUNOS é de 200,00, com uma mediana de 180,00 e uma moda de 150,00. Verificando a relação com outras variáveis, é possível observar que as instituições com mais alunos tendem a ter mais cursos e técnicos."
#
# **QT_DOCENTES:** "A média de QT_DOCENTES é de 50,00, com uma mediana de 40,00 e uma moda de 30,00. É interessante notar que as instituições com mais docentes tendem a ter mais despesas e menos receita."
#
# **QT_CURSO:** "A média de QT_CURSO é de 10,00, com uma mediana de 8,00 e uma moda de 6,00. As instituições com mais cursos tendem a ter mais alunos e menos técnicos."
#
# **QT_TEC_TOTAL:** "A média de QT_TEC_TOTAL é de 5,00, com uma mediana de 4,00 e uma moda de 3,00. É possível observar que as instituições com mais técnicos tendem a ter mais cursos e menos alunos."
#
# **QT_PERIODICO_ELETRONICO:** "A média de QT_PERIODICO_ELETRONICO é de 2,00, com uma mediana de 1,50 e uma moda de 1,00. As instituições com mais periodicos eletronicos tendem a ter mais livros eletronicos e menos receita."
#
# **QT_LIVRO_ELETRONICO:** "A média de QT_LIVRO_ELETRONICO é de 1,50, com uma mediana de 1,00 e uma moda de 0,50. É interessante notar que as instituições com mais livros eletronicos tendem a ter menos alunos e mais despesas."
#
# **T1_VL_RECEITAS:** "A média de T1_VL_RECEITAS é de 10.000,00, com uma mediana de 8.000,00 e uma moda de 6.000,00. As instituições com mais receita tendem a ter mais cursos e técnicos."
#
# **T1_VL_DESPESAS:** "A média de T1_VL_DESPESAS é de 5.000,00, com uma mediana de 4.000,00 e uma moda de 3.000,00. É possível observar que as instituições com mais despesas tendem a ter menos alunos e mais docentes."
#
# **IN_CAPITAL:** "A média de IN_CAPITAL é de 0,50, com uma mediana de 0,25 e uma moda de 0,00. As instituições em capital tendem a ter mais cursos e técnicos."
#
# **IN_OUTRAS_BASES:** "A média de IN_OUTRAS_BASES é de 1,00, com uma mediana de 0,50 e uma moda de 0,00. É possível observar que as instituições com outras bases tendem a ter mais alunos e menos despesas."
#
# **IN_REPOSITORIO_INSTITUCIONAL:** "A média de IN_REPOSITORIO_INSTITUCIONAL é de 0,50, com uma mediana de 0,25 e uma moda de 0,00. As instituições com repositorio institucional tendem a ter mais cursos e técnicos."
#
# **IN_BUSCA_INTEGRADA:** "A média de IN_BUSCA_INTEGRADA é de 1,00, com uma mediana de 0,50 e uma moda de 0,00. É possível observar que as instituições com busca integrada tendem a ter mais alunos e menos despesas."
#
# **IN_SERVICO_INTERNET:** "A média de IN_SERVICO_INTERNET é de 1,00, com uma mediana de 0,50 e uma moda de 0,00. É possível observar que as instituições com serviço de internet tendem a ter mais cursos e técnicos."
#
# **IN_PARTICIPA_REDE_SOCIAL:** "A média de IN_PARTICIPA_REDE_SOCIAL é de 1,00, com uma mediana de 0,50 e uma moda de 0,00. É possível observar que as instituições com participação nas redes sociais tendem a ter mais alunos e menos despesas."
#
# **IN_CATALOGO_ONLINE:** "A média de IN_CATALOGO_ONLINE é de 1,00, com uma mediana de 0,50 e uma moda de 0,00. É possível observar que as instituições com catalogo online tendem a ter mais cursos e técnicos."
#
# **IN_ACESSO_PORTAL_CAPES:** "A média de IN_ACESSO_PORTAL_CAPES é de 1,00, com uma mediana de 0,50 e uma moda de 0,00. É possível observar que as instituições com acesso ao portal CAPES tendem a ter mais cursos e técnicos."
#
# **NU_ANO_CENSO:** "A média de NU_ANO_CENSO é de 2010, com uma mediana de 2005 e uma moda de 1990. É possível observar que as instituições mais antigas tendem a ter mais alunos e menos despesas."
#
# **CO_REGIAO:** "A média de CO_REGIAO é de 1,00, com uma mediana de 0,50 e uma moda de 0,00. É possível observar que as instituições da região Norte tendem a ter mais cursos e técnicos."
#
# **NOME_CATEGORIA_ADMINISTRATIVA:** "A média de NOME_CATEGORIA_ADMINISTRATIVA é de Administrativa, com uma mediana de Governo e uma moda de Educação. É possível observar que as instituições de categoria administrativa tendem a ter mais alunos e menos despesas."
#
# **NOME_CATEGORIA_INSTITUCIONAL:** "A média de NOME_CATEGORIA_INSTITUCIONAL é de Instituto, com uma mediana de Escola e uma moda de Universidade. É possível observar que as instituições de categoria institucional tendem a ter mais cursos e técnicos."
#
# **TABELA COMPARATIVA**
#
# | Critério | Valor Médio | Valor Médida | Valor Moda |
# | --- | --- | --- | --- |
# | Número de alunos | 200 | 150 | 100 |
# | Número de docentes | 50 | 30 | 20 |
# | Receita | 15.000,00 | 10.000,00 | 6.000,00 |
# | Despesas | 8.000,00 | 5.000,00 | 3.000,00 |
# | Número de cursos | 50 | 30 | 20 |
# | Número de técnicos | 20 | 10 | 0 |
#
# Observações:
#
# * A média e a moda são valores estatísticos que representam o valor central do conjunto de dados.
# * O valor médio é a soma dos valores dividida pelo número de elementos do conjunto.
# * A moda é o valor que aparece mais frequentemente no conjunto.
# * A tabela comparativa apresenta uma visão geral das medições realizadas nos critérios estudados.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%)  NOTOK
# - Uma incidência das IES não estarem numa capital (59,78%)   OK
# - Instituições com acesso ao portal Capes (87.34%) OK
# - Possuem serviço de internet (94.97%) OK
# - Participam em redes sociais (71.51%) OK
# - Possuem catalogo online (86.22%) OK
# - Busca integrada (58.29%) OK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%) OK
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%)
#
# - Quantidade alta de técnicos na média (765.03) OK
# - Quantidade de alunos média de alunos alto (12,553.95) OK
# - Corpo docente forte na média (761.73) OK
# - Quantidade considerável de cursos na média (média de 52.45)
# - Despesas e receitas média moderadas OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa
#
# Insights:
# - A quantidade de alunos parece ter uma relação inversa com as receitas da instituição, ou seja, instituições com maior número de alunos têm menos receitas do que aquelas com menor número de alunos.

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'primeiro', 0.5, 15, 9, 6, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'primeiro'))
# Out:
# **Análise dos Agrupamentos**
#
# **QT_ALUNOS**: "A média da quantidade de alunos é de 250, com uma variância de 50. Existe uma relação positiva entre a quantidade de alunos e a quantidade de recursos (docentes, cursos, técnicos). Além disso, as instituições com mais alunos tendem a ter mais recursos disponíveis."
#
# **QT_DOCENTES**: "A média da quantidade de docentes é de 80, com uma variância de 20. Existe uma relação positiva entre a quantidade de docentes e a quantidade de alunos. As instituições com mais alunos também tendem a ter mais docentes."
#
# **QT_CURSO**: "A média da quantidade de cursos é de 30, com uma variância de 10. Existe uma relação positiva entre a quantidade de cursos e a quantidade de recursos (docentes, técnicos). As instituições com mais cursos tendem a ter mais recursos disponíveis."
#
# **QT_TEC_TOTAL**: "A média da quantidade de técnicos é de 20, com uma variância de 5. Existe uma relação positiva entre a quantidade de técnicos e a quantidade de recursos (docentes, cursos). As instituições com mais técnicos tendem a ter mais recursos disponíveis."
#
# **QT_PERIODICO_ELETRONICO**: "A média da quantidade de periodicos eletronicos é de 10, com uma variância de 3. Existe uma relação negativa entre a quantidade de periodicos eletronicos e a quantidade de receita. As instituições com mais periodicos tendem a ter menos receita."
#
# **QT_LIVRO_ELETRONICO**: "A média da quantidade de livros eletronicos é de 5, com uma variância de 2. Existe uma relação positiva entre a quantidade de livros e a quantidade de receita. As instituições com mais livros tendem a ter mais receita."
#
# **T1_VL_RECEITAS**: "A média da receita é de 100.000, com uma variância de 50.000. Existe uma relação positiva entre a receita e a quantidade de recursos (docentes, cursos, técnicos). As instituições com mais recursos tendem a ter mais receita."
#
# **T1_VL_DESPESAS**: "A média das despesas é de 80.000, com uma variância de 30.000. Existe uma relação positiva entre as despesas e a quantidade de recursos (docentes, cursos, técnicos). As instituições com mais recursos tendem a ter mais despesas."
#
# **IN_CAPITAL**: "Há uma predominância de instituições na capital, com 60% das instituições sendo capitalinas. Existe uma relação positiva entre a instituição ser na capital e ter mais recursos disponíveis."
#
# **IN_OUTRAS_BASES**: "40% das instituições têm outras bases além da instituição matriz. Existe uma relação negativa entre a instituição ter outras bases e ter menos receita."
#
# **IN_REPOSITORIO_INSTITUCIONAL**: "20% das instituições têm repositorio institucional. Existe uma relação positiva entre a instituição ter repositorio e ter mais recursos disponíveis."
#
# **IN_BUSCA_INTEGRADA**: "15% das instituições têm busca integrada. Existe uma relação positiva entre a instituição ter busca integrada e ter mais recursos disponíveis."
#
# **IN_SERVICO_INTERNET**: "80% das instituições têm serviço de internet. Existe uma relação positiva entre a instituição ter serviço de internet e ter mais recursos disponíveis."
#
# **IN_PARTICIPA_REDE_SOCIAL**: "50% das instituições participam nas redes sociais. Existe uma relação positiva entre a instituição participar das redes sociais e ter mais recursos disponíveis."
#
# **IN_CATALOGO_ONLINE**: "30% das instituições têm catalogo online. Existe uma relação positiva entre a instituição ter catalogo online e ter mais recursos disponíveis."
#
# **IN_ACESSO_PORTAL_CAPES**: "20% das instituições têm acesso ao portal capes. Existe uma relação positiva entre a instituição ter acesso ao portal capes e ter mais recursos disponíveis."
#
# **NU_ANO_CENSO**: "A média do ano censo é de 2010, com uma variância de 5 anos. Existe uma relação negativa entre o ano censo e a receita. As instituições com anos mais antigos tendem a ter menos receita."
#
# **CO_REGIAO**: "Há uma predominância de instituições da região Sudeste, com 50% das instituições sendo do estado do Rio de Janeiro. Existe uma relação positiva entre a instituição estar na região Sudeste e ter mais recursos disponíveis."
#
# **NOME_CATEGORIA_ADMINISTRATIVA**: "A média da categoria administrativa é de 'Pública', com uma variância de 1 categoria. Existe uma relação positiva entre a categoria administrativa ser 'Pública' e ter mais recursos disponíveis."
#
# **NOME_ORGANIZACAO_ACADEMICA**: "A média da organização acadêmica é de 'Universidade Estadual', com uma variância de 2 organizações. Existe uma relação positiva entre a organização acadêmica ser 'Universidade Estadual' e ter mais recursos disponíveis."
#
# **Análise geral do agrupamento**
#
# Os dados sugerem que as instituições com mais recursos disponíveis tendem a ter mais receita, mas também têm mais despesas. Isso pode indicar que as instituições estão gastando mais em recursos para manter uma reputação de qualidade e atrair mais alunos e docentes.
#
# A região Sudeste tem mais instituições do estado do Rio de Janeiro, o que pode ser relacionado à proximidade com a capital federal e ao acesso a mais recursos e oportunidades.
#
# As instituições públicas tendem a ter mais recursos disponíveis e receita.
#
# A busca integrada e o repositorio institucional são fatores positivos para as instituições, indicando que elas estão investindo em tecnologia e conhecimento.
#
# No entanto, é importante notar que esses resultados podem ser influenciados por variáveis externas, como a política governamental, a economia local e o mercado de educação.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste, Nordeste e Sul (37.43%, 22.35%, 18.81%)  NOTOK
# - Uma incidência das IES não estarem numa capital (59,78%) NOTOK
# - Instituições com acesso ao portal Capes (87.34%) NOTOK
# - Possuem serviço de internet (94.97%) OK
# - Participam em redes sociais (71.51%) OK
# - Possuem catalogo online (86.22%) OK
# - Busca integrada (58.29%) OK
# - Quase a métade das IES são públicas federais, Privada sem fins lucrativos, Pública Estadual (49.16%, 22.91%, 21.04%) NOTOK
# - Mais da metade das IES são do tipo universidade e Instituto Federal de Educação, Ciência e Tecnologia (59.96%, 20.48%) NOTOK
#
# - Quantidade alta de técnicos na média (765.03) OK
# - Quantidade de alunos média de alunos alto (12,553.95) OK
# - Corpo docente forte na média (761.73) OK
# - Quantidade considerável de cursos na média (média de 52.45)  NOTOK
# - Despesas e receitas média moderadas  OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa  NOTOK
#
# Insights :
# -Os clusters com maiores quantidades de alunos tendem a ter um número relativamente menor de docentes

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'primeiro', 1.0, 15, 8, 6, 1, 0]

# %% [markdown]
# ### Second Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'segundo'))
# Out:
# **Análise Estatística das Colunas**
#
# A seguir, apresentaremos a análise estatística das colunas do CSV fornecido:
#
# *   **QT_ALUNOS**:
#     *   Média: 500
#     *   Mediana: 475
#     *   Moda: 450
#     *   Relação com outra variável: Não há uma relação clara com outras variáveis, exceto talvez com a quantidade de cursos (QT_CURSO), onde há uma tendência ligeiramente positiva.
# *   **QT_DOCENTES**:
#     *   Média: 200
#     *   Mediana: 185
#     *   Moda: 175
#     *   Relação com outra variável: Não há uma relação clara com outras variáveis, exceto talvez com a quantidade de técnicos (QT_TEC_TOTAL), onde há uma tendência ligeiramente negativa.
# *   **QT_CURSO**:
#     *   Média: 20
#     *   Mediana: 18
#     *   Moda: 15
#     *   Relação com outra variável: Há uma relação positiva com a quantidade de alunos (QT_ALUNOS), onde mais cursos podem significar mais alunos.
# *   **QT_TEC_TOTAL**:
#     *   Média: 50
#     *   Mediana: 45
#     *   Moda: 40
#     *   Relação com outra variável: Há uma relação negativa com a quantidade de docentes (QT_DOCENTES), onde mais técnicos podem significar menos docentes.
# *   **QT_PERIODICO_ELETRONICO**:
#     *   Média: 100
#     *   Mediana: 90
#     *   Moda: 80
#     *   Relação com outra variável: Não há uma relação clara com outras variáveis, exceto talvez com a quantidade de livros eletrônicos (QT_LIVRO_ELETRONICO), onde há uma tendência ligeiramente positiva.
# *   **QT_LIVRO_ELETRONICO**:
#     *   Média: 50
#     *   Mediana: 40
#     *   Moda: 30
#     *   Relação com outra variável: Há uma relação positiva com a quantidade de periodicos eletronicos (QT_PERIODICO_ELETRONICO), onde mais livros podem significar mais eletrônicos.
# *   **T1_VL_RECEITAS**:
#     *   Média: 100000
#     *   Mediana: 90000
#     *   Moda: 80000
#     *   Relação com outra variável: Não há uma relação clara com outras variáveis, exceto talvez com a quantidade de despesas (T1_VL_DESPESAS), onde há uma tendência ligeiramente negativa.
# *   **T1_VL_DESPESAS**:
#     *   Média: 50000
#     *   Mediana: 45000
#     *   Moda: 40000
#     *   Relação com outra variável: Há uma relação positiva com a quantidade de receita (T1_VL_RECEITAS), onde mais despesas podem significar menos receita.
# *   **IN_CAPITAL**:
#     *   Média: 0,2
#     *   Mediana: 0,15
#     *   Moda: 0,05
#     *   Relação com outra variável: Não há uma relação clara com outras variáveis, exceto talvez com a quantidade de outras bases (IN_OUTRAS_BASES), onde há uma tendência ligeiramente positiva.
# *   **IN_OUTRAS_BASES**:
#     *   Média: 0,5
#     *   Mediana: 0,4
#     *   Moda: 0,3
#     *   Relação com outra variável: Há uma relação positiva com a instituição estar na capital (IN_CAPITAL), onde mais outras bases podem significar mais chances de estar na capital.
# *   **IN_REPOSITORIO_INSTITUCIONAL**:
#     *   Média: 0,8
#     *   Mediana: 0,7
#     *   Moda: 0,6
#     *   Relação com outra variável: Não há uma relação clara com outras variáveis, exceto talvez com a quantidade de busca integrada (IN_BUSCA_INTEGRADA), onde há uma tendência ligeiramente positiva.
# *   **IN_BUSCA_INTEGRADA**:
#     *   Média: 0,9
#     *   Mediana: 0,8
#     *   Moda: 0,7
#     *   Relação com outra variável: Há uma relação positiva com a instituição ter repositorio institucional (IN_REPOSITORIO_INSTITUCIONAL), onde mais busca integrada pode significar mais repositorios.
# *   **IN_SERVICO_INTERNET**:
#     *   Média: 1
#     *   Mediana: 0,9
#     *   Moda: 0,8
#     *   Relação com outra variável: Não há uma relação clara com outras variáveis, exceto talvez com a quantidade de instituição participar redes sociais (IN_PARTICIPA_REDE_SOCIAL), onde há uma tendência ligeiramente positiva.
# *   **IN_PARTICIPA_REDE_SOCIAL**:
#     *   Média: 0,5
#     *   Mediana: 0,4
#     *   Moda: 0,3
#     *   Relação com outra variável: Há uma relação positiva com a instituição ter serviço de internet (IN_SERVICO_INTERNET), onde mais participar redes sociais pode significar mais chances de ter o serviço de internet.
# *   **IN_CATALOGO_ONLINE**:
#     *   Média: 0,7
#     *   Mediana: 0,6
#     *   Moda: 0,5
#     *   Relação com outra variável: Não há uma relação clara com outras variáveis, exceto talvez com a quantidade de instituição ter outros recursos (IN_OUTRAS_BASES), onde há uma tendência ligeiramente positiva.
# *   **IN_CATALOGO_ONLINE**:
#     *   Média: 0,7
#     *   Mediana: 0,6
#     *   Moda: 0,5
#     *   Relação com outra variável: Há uma relação positiva com a instituição ter outros recursos (IN_OUTRAS_BASES), onde mais chances de ter o catalogo online podem significar mais chances de ter outros recursos.
# *   **T1_VL_DESPESAS**:
#     *   Média: 50000
#     *   Mediana: 45000
#     *   Moda: 40000
#     *   Relação com outra variável: Há uma relação positiva com a instituição ter mais receita (T1_VL_RECEITAS), onde mais despesas podem significar menos chances de ter mais receita.
#
# **Conclusão**
#
# Os resultados indicam que a relação entre os variáveis é complexa e multifacetada. No entanto, alguns padrões se destacam:
#
# *   Há uma tendência geral de que as instituições com mais recursos (receita, despesas) também têm mais chances de ter outras bases.
# *   As instituições com mais recursos também têm mais chances de ter um serviço de internet e participar redes sociais.
# *   A presença de repositorios institucionais é uma variável importante para as instituições que buscam buscar informações integradas.
# *   Há uma relação positiva entre a quantidade de livros eletrônicos e os periodicos eletrónicos.
#
# **Dicas**
#
# *   As instituições devem considerar o padrão de desenvolvimento das redes sociais e suas implicações para o uso dos serviços.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) OK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) OK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) OK
# - Possuem busca integrada (74.35%) OKOK
# - Possuem serviço de internet (93.00%) OK
# - Participam em redes sociais (74.03%) OK
# - Possuem predominância em catalogo online (64.87%) OK
# - Possuem predominâncai em ter outras bases (69.29%) OK
# - Maioria das instituições são privada (com e sem fins lucrativos) OK(98,6) OK
# - Maioria dos anos da IES são Faculdade (99.89%) OK
#
# - Pouca quantidade de técnicos na média (12.87) OK
# - Quantidade de alunos média de alunos abaixo (153.83) OK
# - Corpo docente muito pouco na média (14.20) OK
# - Pouca quantidade de cursos (2.30) OK
# - Despesas e receitas média moderadas OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa  NOTOK
#
# Insights:
# - Instituições com maior receita podem estar atraindo mais recursos para suas

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'segundo', 0, 17, 2, 15, 4, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'segundo'))
# Out:
# **Análise dos Agrupamentos**
#
# O CSV fornecido contém as instâncias de um determinado cluster, com várias colunas que descrevem características da instituição. Vamos realizar uma análise estatística e exploratória dos agrupamentos para entender melhor o que os define.
#
# **Análise Estatística das Colunas**
#
# 1. **QT_ALUNOS**: A média é de 500, a mediana é de 450 e a moda é de 400. Verificar relação com outras variáveis como **QT_DOCENTES**, **QT_CURSO**, etc.
# 2. **QT_DOCENTES**: A média é de 100, a mediana é de 90 e a moda é de 80. Verificar relação com outras variáveis como **QT_ALUNOS**, **QT_CURSO**, etc.
# 3. **QT_CURSO**: A média é de 20, a mediana é de 18 e a moda é de 15. Verificar relação com outras variáveis como **QT_ALUNOS**, **QT_DOCENTES**, etc.
# 4. **QT_TEC_TOTAL**: A média é de 50, a mediana é de 40 e a moda é de 30. Verificar relação com outras variáveis como **QT_CURSO**, **QT_DOCENTES**, etc.
# 5. **QT_PERIODICO_ELETRONICO**: A média é de 10, a mediana é de 8 e a moda é de 6. Verificar relacionamento com outras variáveis como **QT_LIVRO_ELETRONICO**, **T1_VL_RECEITAS**, etc.
# 6. **QT_LIVRO_ELETRONICO**: A média é de 5, a mediana é de 4 e a moda é de 3. Verificar relação com outras variáveis como **QT_PERIODICO_ELETRONICO**, **T1_VL_RECEITAS**, etc.
# 7. **T1_VL_RECEITAS**: A média é de 1000, a mediana é de 900 e a moda é de 800. Verificar relacionamento com outras variáveis como **QT_PERIODICO_ELETRONICO**, **QT_LIVRO_ELETRONICO**, etc.
# 8. **T1_VL_DESPESAS**: A média é de 500, a mediana é de 450 e a moda é de 400. Verificar relação com outras variáveis como **T1_VL_RECEITAS**, **IN_CAPITAL**, etc.
# 9. **IN_CAPITAL**: Sim/Não. Verificar relacionamento com outras variáveis como **T1_VL_DESPESAS**, **IN_OUTRAS_BASES**, etc.
# 10. **IN_OUTRAS_BASES**: Sim/Não. Verificar relacionamento com outras variáveis como **T1_VL_DESPESAS**, **IN_CAPITAL**, etc.
# 11. **IN_REPOSITORIO_INSTITUCIONAL**: Sim/Não. Verificar relacionamento com outras variáveis como **T1_VL_RECEITAS**, **T1_VL_DESPESAS**, etc.
# 12. **IN_BUSCA_INTEGRADA**: Sim/Não. Verificar relação com outras variáveis como **IN_REPOSITORIO_INSTITUCIONAL**, **IN_SERVICO_INTERNET**, etc.
# 13. **IN_SERVICO_INTERNET**: Sim/Não. Verificar relacionamento com outras variáveis como **IN_BUSCA_INTEGRADA**, **IN_PARTICIPA_REDE_SOCIAL**, etc.
# 14. **IN_PARTICIPA_REDE SOCIAIS**: Sim/Não. Verificar relação com outras variáveis como **IN_SERVICO_INTERNET**, **IN_CATALOGO_ONLINE**, etc.
# 15. **IN_CATALOGO_ONLINE**: Sim/Não. Verificar relacionamento com outras variáveis como **IN_PARTICIPA_REDE_SOCIAIS**, **IN_ACESSO_PORTAL_CAPES**, etc.
# 16. **IN_ACESSO_PORTAL_CAPES**: Sim/Não. Verificar relação com outras variáveis como **IN_CATALOGO_ONLINE**, **NOME_CATEGORIA_ADMINISTRATIVA**, etc.
# 17. **NU_ANO_CENSO**: Ano. Verificar relacionamento com outras variáveis como **CO_REGIAO**, **NOME_ORGANIZACAO_ACADEMICA**, etc.
# 18. **CO_REGIAO**: Região. Verificar relação com outras variáveis como **NU_ANO_CENSO**, **NOME_CATEGORIA_ADMINISTRATIVA**, etc.
# 19. **NOME_CATEGORIA_ADMINISTRATIVA**: Categoria administrativa. Verificar relacionamento com outras variáveis como **NU_ANO_CENSO**, **CO_REGIAO**, etc.
# 20. **NOME_ORGANIZACAO_ACADEMICA**: Organização acadêmica. Verificar relação com outras variáveis como **NU_ANO_CENSO**, **CO_REGIAO**, etc.
#
# **Inferências**
#
# * A instituição tem uma média de 500 alunos, o que pode indicar um tamanho moderado.
# * A instituição tem uma média de 100 docentes, o que pode indicar um número relativamente baixo de personalidade docente.
# * A instituição oferece uma média de 20 cursos, o que pode indicar uma oferta de programas limitada.
# * A instituição tem uma média de 50 técnicos, o que pode indicar uma presença moderada de pessoal técnico.
#
# **Análise Geral do Agrupamento**
#
# A análise dos dados revela que a instituição tem características variadas, mas algumas tendências são evidentes. A instituição parece ter um tamanho moderado e oferece programas limitados, o que pode indicar uma presença moderada de personalidade docente.
#
# A instituição também tem uma presença moderada em serviços online, como serviço de internet e busca integrada, o que pode indicar uma presença moderada na rede social. No entanto, a instituição não parece ter uma forte presença em serviços especializados, como repositorio institucional.
#
# Além disso, a instituição tem uma média de 1000 receitas anuais, o que pode indicar uma estabilidade financeira. No entanto, a instituição também tem uma média de 500 despesas anuais, o que pode indicar uma presença moderada em despesas.
#
# Em resumo, a análise dos dados revela que a instituição é um organismo educacional com características variadas, mas algumas tendências são evidentes. A instituição parece ter um tamanho moderado e oferece programas limitados, o que pode indicar uma presença moderada de personalidade docente.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) OK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) OK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOTOK
# - Possuem busca integrada (74.35%) OK
# - Possuem serviço de internet (93.00%) OK
# - Participam em redes sociais (74.03%) OK
# - Possuem predominância em catalogo online (64.87%) OK
# - Possuem predominâncai em ter outras bases (69.29%) OK
# - Maioria das instituições são privada (com e sem fins lucrativos) OK (98,6) NOTOK
# - Maioria dos anos da IES são Faculdade (99.89%) OK
#
# - Pouca quantidade de técnicos na média (12.87) OK
# - Quantidade de alunos média de alunos abaixo (153.83) OK
# - Corpo docente muito pouco na média (14.20) OK
# - Pouca quantidade de cursos (2.30) OK
# - Despesas e receitas média moderadas OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'segundo', 0.5, 17, 3, 14, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'segundo'))
# Out:
# **Análise dos Agrupamentos**
#
# **Coluna**: "QT_ALUNOS"
# * Analise estatística: Média = 200, Mediana = 190, Moda = 180
# * Relação com outra variável: Verificar relação com QT_DOCENTES, pois instituições com mais alunos podem ter mais docentes.
#
# **Coluna**: "QT_DOCENTES"
# * Analise estatística: Média = 50, Mediana = 40, Moda = 30
# * Relação com outra variável: Verificar relação com QT_ALUNOS, pois instituições com mais alunos podem ter mais docentes.
#
# **Coluna**: "QT_CURSO"
# * Analise estatística: Média = 100, Mediana = 80, Moda = 60
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com mais alunos e docentes podem ter mais cursos.
#
# **Coluna**: "QT_TEC_TOTAL"
# * Analise estatística: Média = 20, Mediana = 10, Moda = 5
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com mais alunos e docentes podem ter mais técnicos.
#
# **Coluna**: "QT_PERIODICO_ELETRONICO"
# * Analise estatística: Média = 10, Mediana = 5, Moda = 2
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com mais alunos e docentes podem ter mais periodicos eletronicos.
#
# **Coluna**: "QT_LIVRO_ELETRONICO"
# * Analise estatística: Média = 5, Mediana = 3, Moda = 2
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com mais alunos e docentes podem ter mais livros eletronicos.
#
# **Coluna**: "T1_VL_RECEITAS"
# * Analise estatística: Média = 1000000, Mediana = 500000, Moda = 200000
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com mais alunos e docentes podem ter receita maior.
#
# **Coluna**: "T1_VL_DESPESAS"
# * Analise estatística: Média = 500000, Mediana = 200000, Moda = 100000
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com mais alunos e docentes podem ter despesas maior.
#
# **Coluna**: "IN_CAPITAL"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições na capital podem ter mais alunos e docentes.
#
# **Coluna**: "IN_OUTRAS_BASES"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com outras bases podem ter mais alunos e docentes.
#
# **Coluna**: "IN_REPOSITORIO_INSTITUCIONAL"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com repositorio institucional podem ter mais alunos e docentes.
#
# **Coluna**: "IN_BUSCA_INTEGRADA"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com busca integrada podem ter mais alunos e docentes.
#
# **Coluna**: "IN_SERVICO_INTERNET"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições com serviço de internet podem ter mais alunos e docentes.
#
# **Coluna**: "IN_PARTICIPA_REDE_SOCIAL"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições que participam das redes sociais podem ter mais alunos e docentes.
#
# **Coluna**: "IN_CATALOGO_ONLINE"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições que têm catalogo online podem ter mais alunos e docentes.
#
# **Coluna**: "IN_ACESSO_PORTAL_CAPES"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições que têm acesso ao portal CAPES podem ter mais alunos e docentes.
#
# **Coluna**: "NU_ANO_CENSO"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições que são mais antigas podem ter mais alunos e docentes.
#
# **Coluna**: "IN_OUTRAS_VARIAVEIS"
# * Analise estatística:
#  + Média: Não disponível
#  + Mediana: Não disponível
#  + Moda: Não disponível
# * Relação com outra variável: Verificar relação com QT_ALUNOS e QT_DOCENTES, pois instituições que têm outras variáveis podem ter mais alunos e docentes.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,12%) ONOTOK
# - Predominância das regiões Sudeste e Nordeste (60,67%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.38%) OK
# - Predominância das Instituições sem acesso ao portal Capes (63.25%) NOTOK
# - Possuem busca integrada (74.35%) OK
# - Possuem serviço de internet (93.00%) OK
# - Participam em redes sociais (74.03%) NOTOK
# - Possuem predominância em catalogo online (64.87%) NOTOK
# - Possuem predominâncai em ter outras bases (69.29%) OK
# - Maioria das instituições são privada (com e sem fins lucrativos) OK(98,6) OK
# - Maioria dos anos da IES são Faculdade (99.89%) OK
#
# - Pouca quantidade de técnicos na média (12.87) OK
# - Quantidade de alunos média de alunos abaixo (153.83) OK
# - Corpo docente muito pouco na média (14.20) OK
# - Pouca quantidade de cursos (2.30) OK
# - Despesas e receitas média moderadas OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'segundo', 1.0, 17, 4, 13, 2, 0]

# %% [markdown]
# ### Third Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'terceiro'))
# Out:
# **Análise dos Agrupamentos**
#
# O CSV fornecido contém as instâncias de um determinado cluster, com várias colunas que podem ser analisadas para entender melhor os fatores que levaram à criação desse agrupamento.
#
# **QT_ALUNOS**:
# - "Média estatística: 100"
# - "Relação com outra variável: Não há relação significativa com outras colunas, exceto por QT_DOCENTES e QT_CURSO."
# - Análise geral do agrupamento: As instituições com mais alunos tendem a ter mais docentes e cursos, sugerindo uma relação entre a quantidade de alunos e as estruturas educacionais.
#
# **QT_DOCENTES**:
# - "Média estatística: 50"
# - "Relação com outra variável: Há relação positiva com QT_ALUNOS e QT_CURSO."
# - Análise geral do agrupamento: As instituições com mais docentes tendem a ter mais alunos e cursos, indicando uma estrutura educacional mais abundante.
#
# **QT_CURSO**:
# - "Média estatística: 20"
# - "Relação com outra variável: Há relação positiva com QT_DOCENTES e QT_ALUNOS."
# - Análise geral do agrupamento: As instituições com mais cursos tendem a ter mais docentes e alunos, sugerindo uma estrutura educacional mais diversificada.
#
# **QT_TEC_TOTAL**:
# - "Média estatística: 10"
# - "Relação com outra variável: Não há relação significativa com outras colunas."
# - Análise geral do agrupamento: As instituições com mais técnicos podem indicar uma ênfase na formação de pessoal técnico, mas isso não se relaciona diretamente com as demais variáveis.
#
# **QT_PERIODICO_ELETRONICO**:
# - "Média estatística: 5"
# - "Relação com outra variável: Há relação positiva com IN_REPOSITORIO_INSTITUCIONAL."
# - Análise geral do agrupamento: As instituições com mais periodicos eletronicos tendem a ter um repositorio institucional, sugerindo uma cooperação entre as áreas de publicação e desenvolvimento tecnológico.
#
# **QT_LIVRO_ELETRONICO**:
# - "Média estatística: 3"
# - "Relação com outra variável: Não há relação significativa com outras colunas."
# - Análise geral do agrupamento: As instituições com mais livros eletronicos podem indicar uma ênfase na formação de pessoal especializado em tecnologia, mas isso não se relaciona diretamente com as demais variáveis.
#
# **T1_VL_RECEITAS**:
# - "Média estatística: 100000"
# - "Relação com outra variável: Há relação positiva com IN_PARTICIPA_REDE_SOCIAL e IN_CATALOGO_ONLINE."
# - Análise geral do agrupamento: As instituições com maior receita tendem a ter mais presença nas redes sociais e no catálogo online, sugerindo uma estratégia de marketing eficaz.
#
# **T1_VL_DESPESAS**:
# - "Média estatística: 50000"
# - "Relação com outra variável: Há relação negativa com IN_REPOSITORIO_INSTITUCIONAL."
# - Análise geral do agrupamento: As instituições com maior despesa tendem a ter um repositorio institucional de forma menos frequente, sugerindo uma possível falta de cooperação entre as áreas de desenvolvimento tecnológico e publicação.
#
# **IN_CAPITAL**:
# - "Média estatística: 0"
# - "Relação com outra variável: Não há relação significativa com outras colunas."
# - Análise geral do agrupamento: As instituições não localizadas na capital tendem a ter uma estrutura educacional mais aberta, com mais cursos e alunos.
#
# **IN_OUTRAS_BASES**:
# - "Média estatística: 1"
# - "Relação com outra variável: Há relação positiva com IN_PARTICIPA_REDE_SOCIAL."
# - Análise geral do agrupamento: As instituições com outras bases tendem a ter mais presença nas redes sociais, sugerindo uma estratégia de marketing eficaz.
#
# **IN_REPOSITORIO_INSTITUCIONAL**:
# - "Média estatística: 0"
# - "Relação com outra variável: Há relação negativa com T1_VL_DESPESAS."
# - Análise geral do agrupamento: As instituições que têm um repositorio institucional tendem a ter menos despesa, sugerindo uma possível cooperação entre as áreas de desenvolvimento tecnológico e publicação.
#
# **IN_BUSCA_INTEGRADA**:
# - "Média estatística: 1"
# - "Relação com outra variável: Não há relação significativa com outras colunas."
# - Análise geral do agrupamento: As instituições que têm busca integrada tendem a ter uma estrutura educacional mais aberta, com mais cursos e alunos.
#
# **IN_SERVICO_INTERNET**:
# - "Média estatística: 1"
# - "Relação com outra variável: Há relação positiva com IN_PARTICIPA_REDE_SOCIAL."
# - Análise geral do agrupamento: As instituições que têm serviço de internet tendem a ter mais presença nas redes sociais, sugerindo uma estratégia de marketing eficaz.
#
# **IN_PARTICIPA_REDE SOCIAIS**:
# - "Média estatística: 1"
# - "Relação com outra variável: Há relação positiva com IN_CAPITAL e T1_VL_RECEITAS."
# - Análise geral do agrupamento: As instituições que participam das redes sociais tendem a ter mais alunos, cursos e receita, sugerindo uma estratégia de marketing eficaz.
#
# **IN_CATALOGO_ONLINE**:
# - "Média estatística: 1"
# - "Relação com outra variável: Há relação positiva com IN_REPOSITORIO_INSTITUCIONAL."
# - Análise geral do agrupamento: As instituições que têm catálogo online tendem a ter um repositorio institucional, sugerindo uma cooperação entre as áreas de publicação e desenvolvimento tecnológico.
#
# Em resumo, as instituições que atuam com maior sucesso nas redes sociais tendem a ter mais alunos, cursos e receita. As instituições que têm um catálogo online também tendem a ter um repositorio institucional, sugerindo uma cooperação entre as áreas de publicação e desenvolvimento tecnológico.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOTOK
# - Predominãncia das IES não estarem numa capital (62.70%) OK
# - Instituições sem acesso ao portal Capes (83.09%) OK
# - Possuem predominância em não possuir repositorio institucional (74.68%) NOTOK
# - Possuem predominância em serviço de internet (79.13%) OK
# - Predominância em participar em redes sociais (62.62%) ok
# - Possuem predominância em ter outras bases (75.57%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) (97,73)   NOTOK
# - Maioria dos anos da IES são Faculdade (99.92%) OK
#
# - Quantidade baixa de média de técnicos (10.78) OK
# - Quantidade de alunos média de alunos baixo (185.81) OK
# - Corpo docente muito baixo na média (16.72) OK
# - Pouca quantidade de cursos (2.03) OK
# - Despesas e receitas média moderadas OK
# - Quantidade de periodicos e livros eletronicos com relevância baixa OK

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'terceiro', 0, 15, 2, 13, 2, 1]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'terceiro'))
# Out:
# **Análise Estatística da Coluna: QT_ALUNOS**
#
# * Analise estatística: Média = 300, Mediana = 250, Moda = 200
# * Relação com outra variável: Não há uma relação clara com outra variável, mas pode ser observado que a média é maior quando a instituição tem outras bases (IN_OUTRAS_BASES=1) e menor quando não é capital (IN_CAPITAL=0).
#
# **Inferências**
#
# * Conclusão: A quantidade de alunos pode estar relacionada à presença de outras bases e ao status da instituição em relação à capitalidade.
#
# **Análise Geral do Agrupamento**
#
# * Com base nos resultados da análise estatística, podemos concluir que a quantidade de alunos é um fator importante para o agrupamento. Além disso, a presença de outras bases e o status da instituição em relação à capitalidade também podem influenciar a quantidade de alunos.
#
# **Análise Estatística da Coluna: QT_DOCENTES**
#
# * Analise estatística: Média = 50, Mediana = 40, Moda = 30
# * Relação com outra variável: Há uma relação positiva entre a quantidade de docentes e a quantidade de alunos (Correlação positiva: r=0,8).
#
# **Inferências**
#
# * Conclusão: A quantidade de docentes está diretamente relacionada com a quantidade de alunos, sugerindo que há uma gestão eficaz da instituição.
#
# **Análise Geral do Agrupamento**
#
# * Com base nos resultados da análise estatística, podemos concluir que a quantidade de docentes é um fator importante para o agrupamento. Além disso, a relação positiva entre a quantidade de docentes e a quantidade de alunos sugere uma gestão eficaz da instituição.
#
# **Análise Estatística da Coluna: QT_CURSO**
#
# * Analise estatística: Média = 20, Mediana = 15, Moda = 10
# * Relação com outra variável: Não há uma relação clara com outras variáveis, mas pode ser observado que a média é maior quando a instituição tem busca integrada (IN_BUSCA_INTEGRADA=1).
#
# **Inferências**
#
# * Conclusão: A quantidade de cursos pode estar relacionada à presença de busca integrada, embora seja necessário mais estudos para confirmar essa relação.
#
# **Análise Geral do Agrupamento**
#
# * Com base nos resultados da análise estatística, podemos concluir que a quantidade de cursos é um fator importante para o agrupamento. Além disso, a presença de busca integrada pode estar relacionada à quantidade de cursos.
#
# **Análise Estatística da Coluna: QT_TEC_TOTAL**
#
# * Analise estatística: Média = 100, Mediana = 80, Moda = 60
# * Relação com outra variável: Há uma relação positiva entre a quantidade de técnicos e a quantidade de alunos (Correlação positiva: r=0,6).
#
# **Inferências**
#
# * Conclusão: A quantidade de técnicos está diretamente relacionada com a quantidade de alunos, sugerindo que há uma gestão eficaz da instituição.
#
# **Análise Geral do Agrupamento**
#
# * Com base nos resultados da análise estatística, podemos concluir que a quantidade de técnicos é um fator importante para o agrupamento. Além disso, a relação positiva entre a quantidade de técnicos e a quantidade de alunos sugere uma gestão eficaz da instituição.
#
# Esses são apenas alguns exemplos de análise estatística e inferências que podem ser feitas com os dados fornecidos. É importante notar que cada coluna pode ter sua própria análise estatística e inferências, e é necessário considerar todos os fatores para obter uma compreensão completa do agrupamento.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOTOK
# - Predominãncia das IES não estarem numa capital (62.70%) NOTOK
# - Instituições sem acesso ao portal Capes (83.09%) OK
# - Possuem predominância em não possuir repositorio institucional (74.68%) OK
# - Possuem predominância em serviço de internet (79.13%) OK
# - Predominância em participar em redes sociais (62.62%) NOTOK
# - Possuem predominância em ter outras bases (75.57%) OK
# - Maioria das instituições são privada (com e sem fins lucrativos) OK(97,73) NOTOK
# - Maioria dos anos da IES são Faculdade (99.92%) OK
#
# - Quantidade baixa de média de técnicos (10.78) NOTOK
# - Quantidade de alunos média de alunos baixo (185.81) OK
# - Corpo docente muito baixo na média (16.72) NOTOK
# - Pouca quantidade de cursos (2.03) OK
# - Despesas e receitas média moderadas
# - Quantidade de periodicos e livros eletronicos com relevância baixa

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'terceiro', 0.5, 15, 6,9, 2, 2]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'terceiro'))
# Out:
# **Análise dos Agrupamentos**
#
# **QT_ALUNOS**: "A mediana de QT_ALUNOS é de 2000 com uma moda de 1500 e uma média de 1900. A relação entre QT_ALUNOS e QT_DOCENTES é significativa, pois as instituições com mais alunos também têm mais docentes."
#
# **QT_DOCENTES**: "A média de QT_DOCENTES é de 100 com uma moda de 50 e uma mediana de 80. Há uma relação positiva entre a quantidade de alunos e a quantidade de docentes, mas não há correlação estatística."
#
# **QT_CURSO**: "A mediana de QT_CURSO é de 5 com uma moda de 3 e uma média de 4. Não há relação significativa entre a quantidade de cursos e as outras variáveis."
#
# **QT_TEC_TOTAL**: "A moda de QT_TEC_TOTAL é de 10 com uma mediana de 15 e uma média de 20. Há uma relação positiva entre a quantidade de técnicos e a quantidade de alunos e docentes."
#
# **QT_PERIODICO_ELETRONICO**: "A moda de QT_PERIODICO_ELETRONICO é de 2 com uma mediana de 1 e uma média de 2. Não há correlação estatística com as outras variáveis."
#
# **QT_LIVRO_ELETRONICO**: "A mediana de QT_LIVRO_ELETRONICO é de 5 com uma moda de 3 e uma média de 4. Há uma relação positiva entre a quantidade de livros eletrônicos e a quantidade de alunos."
#
# **T1_VL_RECEITAS**: "A média de T1_VL_RECEITAS é de 1000000 com uma moda de 500000 e uma mediana de 750000. Há uma relação positiva entre a receita da instituição e a quantidade de alunos, docentes e cursos."
#
# **T1_VL_DESPESAS**: "A média de T1_VL_DESPESAS é de 500000 com uma moda de 200000 e uma mediana de 300000. Há uma relação positiva entre as despesas da instituição e a quantidade de alunos, docentes e cursos."
#
# **IN_CAPITAL**: "A proporção de IN_CAPITAL é de 50% com uma moda de 0% e uma mediana de 25%. Há uma relação significativa entre a condição de capitalização das instituições e a receita e as despesas da instituição."
#
# **IN_OUTRAS_BASES**: "A proporção de IN_OUTRAS_BASES é de 75% com uma moda de 0% e uma mediana de 50%. Há uma relação significativa entre a existência de outras bases e a receita da instituição."
#
# **IN_REPOSITORIO_INSTITUCIONAL**: "A proporção de IN_REPOSITORIO_INSTITUCIONAL é de 80% com uma moda de 0% e uma mediana de 60%. Há uma relação positiva entre o repositorio institucional e a quantidade de livros eletrônicos."
#
# **IN_BUSCA_INTEGRADA**: "A proporção de IN_BUSCA_INTEGRADA é de 90% com uma moda de 0% e uma mediana de 80%. Há uma relação significativa entre a existência da busca integrada e a receita da instituição."
#
# **IN_SERVICO_INTERNET**: "A proporção de IN_SERVICO_INTERNET é de 95% com uma moda de 0% e uma mediana de 90%. Há uma relação positiva entre o serviço de internet e a quantidade de alunos, docentes e cursos."
#
# **IN_PARTICIPA_REDE_SOCIAL**: "A proporção de IN_PARTICIPA_REDE_SOCIAL é de 85% com uma moda de 0% e uma mediana de 60%. Há uma relação significativa entre a participação nas redes sociais e a receita da instituição."
#
# **IN_CATALOGO_ONLINE**: "A proporção de IN_CATALOGO_ONLINE é de 75% com uma moda de 0% e uma mediana de 50%. Há uma relação positiva entre o catalogo online e a quantidade de livros eletrônicos."
#
# **IN_ACESSO_PORTAL_CAPES**: "A proporção de IN_ACESSO_PORTAL_CAPES é de 95% com uma moda de 0% e uma mediana de 90%. Há uma relação significativa entre o acesso ao portal Capes e a receita da instituição."
#
# **NU_ANO_CENSO**: "A média de NU_ANO_CENSO é de 2015 com uma moda de 2000 e uma mediana de 2025. Não há correlação estatística com as outras variáveis."
#
# **CO_REGIAO**: "A media de CO_REGIAO é de 3 com uma moda de 2 e uma média de 4. Há uma relação positiva entre a região da instituição e a quantidade de alunos, docentes e cursos."
#
# **NOME_CATEGORIA_ADMINISTRATIVA**: "A mediana de NOME_CATEGORIA_ADMINISTRATIVA é de Administração com uma moda de outros valores e uma média de 2. Não há correlação estatística com as outras variáveis."
#
# **NOME_ORGANIZACAO_ACADEMICA**: "A mediana de NOME_ORGANIZACAO_ACADEMICA é de Federação das Instituições de Ensino Superior do Brasil (FIESP) com uma moda de outros valores e uma média de 1. Não há correlação estatística com as outras variáveis."
#
# **Análise geral do agrupamento**: "As instituições que são na capital têm receita e despesas maiores, além de ter mais alunos, docentes e cursos. As instituições com mais técnicos têm receita e despesas maiores, além de ter mais alunos e docentes. As instituições com busca integrada têm receita maiores. As instituições com serviço de internet têm receita maiores. As instituições que participam das redes sociais têm receita maiores."

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste e Sul (47.17%, 19.17%, 17.48%) NOTOK
# - Predominãncia das IES não estarem numa capital (62.70%) NOTOK
# - Instituições sem acesso ao portal Capes (83.09%) NOTOK
# - Possuem predominância em não possuir repositorio institucional (74.68%) OK
# - Possuem predominância em serviço de internet (79.13%) OK
# - Predominância em participar em redes sociais (62.62%) NOTOK
# - Possuem predominância em ter outras bases (75.57%) OK
# - Maioria das instituições são privada (com e sem fins lucrativos) OK(97,73) NOTOK
# - Maioria dos anos da IES são Faculdade (99.92%) OK
#
# - Quantidade baixa de média de técnicos (10.78) NOTOK
# - Quantidade de alunos média de alunos baixo (185.81) OK
# - Corpo docente muito baixo na média (16.72) OK
# - Pouca quantidade de cursos (2.03) OK
# - Despesas e receitas média moderadas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixa NOTOK

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'terceiro', 1.0, 15, 6, 9, 2, 4]

# %% [markdown]
# ### Forth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'quarto'))
# Out:
# **Análise dos Agrupamentos**
#
# Considerando o CSV fornecido, vamos realizar uma análise estatística e exploratória para entender melhor as características dos agrupamentos.
#
# **Variáveis relevantes**
#
# * QT_ALUNOS
# * QT_DOCENTES
# * QT_CURSO
# * T1_VL_RECEITAS
# * IN_CAPITAL
#
# **Análise Estatística**
#
# * **QT_ALUNOS**: A média é de 1200 alunos, a mediana é de 1000 e a moda é de 500. Verificar relação com T1_VL_RECEITAS: pode ser que instituições mais ricas tenham mais alunos.
# * **QT_DOCENTES**: A média é de 50 docentes, a mediana é de 40 e a moda é de 20. Verificar relação com QT_ALUNOS: pode ser que instituições com mais alunos tenham mais docentes.
# * **QT_CURSO**: A média é de 10 cursos, a mediana é de 5 e a moda é de 2. Não há relação clara com outras variáveis.
# * **T1_VL_RECEITAS**: A média é de R$ 500.000,00, a mediana é de R$ 300.000,00 e a moda não é relevante. Verificar relação com QT_ALUNOS: pode ser que instituições mais ricas tenham mais alunos.
# * **IN_CAPITAL**: 50% das instituições são capitalinas, o que sugere uma conexão entre o tamanho da instituição (QT_ALUNOS) e a localização.
#
# **Inferências**
#
# * A maioria das instituições tem um número médio de alunos, docentes e cursos.
# * As instituições mais ricas têm um número maior de alunos e, em média, mais docentes.
# * Não há uma relação clara entre o número de cursos e outras variáveis.
# * As instituições são divididas entre capitalinas e não capitalinas.
#
# **Análise Geral do Agrupamento**
#
# Diante das análises realizadas, podemos observar que as instituições estão divididas em diferentes grupos com características distintas. As instituições mais ricas têm um número maior de alunos e docentes, enquanto as instituições menos ricas têm um número menor desses indicadores.
#
# A localização é outro fator importante, já que a maioria das instituições é capitalina. Além disso, as instituições com mais cursos não apresentam uma relação clara com outras variáveis.
#
# Em resumo, os agrupamentos apresentam características distintas, sugerindo diferentes tipos de instituições com diferentes características e objetivos.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) OK OK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) OK NOTOK
# - Uma incidência das IES não estarem numa capital (68.85%) OK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) OK OK
# - Possuem predominância em busca integrada (77.29%) OK NOTOK
# - Possuem serviço de internet (97.45%) OK OK
# - Predominância em participar em redes sociais (71.20%) OK OK
# - Possuem predominância em ter catalogo online (79.45%) OK NOTOK
# - Possuem predominância em ter outras bases (73.43%) OK OK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) OK NOTOK(98,04) OK OK
# - Maioria dos anos da IES são Faculdade (99.15%) OK NOTOK
#
# - Quantidade de técnicos na média baixo (33.68	) OK OK
# - Quantidade de alunos média de alunos  moderado (932.89) OK
# - Corpo docente muito na média (45.12) OK OK
# - Pouca quantidade média de cursos (6.21) OK OK
# - Despesas e receitas média acima do moderado OK
# - Quantidade de periodicos e livros eletronicos com relevância alto OK

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quarto', 0, 17, 1, 16, 2, 1]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'quarto'))
# Out:
# **Análise dos Agrupamentos**
#
# Ao analisar o CSV fornecido, podemos começar identificando as variáveis que parecem estar relacionadas à criação de agrupamentos. Aqui estão algumas observações iniciais:
#
# * A variável "QT_ALUNOS" parece estar diretamente relacionada ao tamanho do grupo, com maior valor nas instâncias com mais alunos.
# * A variável "T1_VL_RECEITAS" e "T1_VL_DESPESAS" podem estar relacionadas à receita e despesa da instituição, respectivamente. Uma maior receita pode estar associada a um aumento no tamanho do grupo.
#
# **Relações entre Variáveis**
#
# Uma análise estatística de correlação pode ser realizada para entender como as variáveis estão relacionadas uma com a outra. Por exemplo:
#
# * Correlação entre "QT_ALUNOS" e "T1_VL_RECEITAS": A instância com o maior valor de "QT_ALUNOS" tem um valor elevado de "T1_VL_RECEITAS", sugerindo que as instituições com mais alunos tendem a ter uma receita maior.
# * Correlação entre "IN_CAPITAL" e "NOME_CATEGORIA_ADMINISTRATIVA": As instituições capitalinas tendem a ter categorias administrativas mais elevadas, sugerindo uma relação de dependência entre as duas variáveis.
#
# **Análise Geral do Agrupamento**
#
# Diante das análises estatísticas e das relações entre variáveis, podemos concluir que os agrupamentos parecem estar relacionados às instituições com maior receita e tamanho. Além disso, as instituições capitalinas tendem a ter categorias administrativas mais elevadas.
#
# As principais características desses agrupamentos podem ser resumidas como:
#
# * Instituto de grande porte
# * Receita significativa
# * Tamanho elevado
# * Categorias administrativas mais elevadas (para instituições capitalinas)
#
# É importante notar que essas conclusões são baseadas em análises estatísticas e não necessariamente refletem a realidade prática. Além disso, é fundamental realizar mais análises e pesquisas para entender melhor as características desses agrupamentos e suas implicações.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOTOK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOTOK
# - Uma incidência das IES não estarem numa capital (68.85%)NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) OK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) OK
# - Predominância em participar em redes sociais (71.20%) OK
# - Possuem predominância em ter catalogo online (79.45%) OK
# - Possuem predominância em ter outras bases (73.43%) OK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) OK(98,04) OK
# - Maioria dos anos da IES são Faculdade (99.15%) OK
#
# - Quantidade de técnicos na média baixo (33.68	) NOTOK
# - Quantidade de alunos média de alunos  moderado (932.89)
# - Corpo docente muito na média (45.12) NOTOK
# - Pouca quantidade média de cursos (6.21) OK
# - Despesas e receitas média acima do moderado
# - Quantidade de periodicos e livros eletronicos com relevância alto

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quarto', 0.5, 17, 6, 11, 3, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'quarto'))
# Out:
# **Análise dos Agrupamentos**
#
# **QT_ALUNOS**: "A média de alunos é de 500 com uma variância de 1000, indicando uma grande variedade de número de alunos nas instituições. Verificar relação com IN_CAPITAL: A medição de desigualdade entre as instituições na capital e fora pode ajudar a entender como o tamanho da instituição está relacionado à sua localização."
#
# **QT_DOCENTES**: "A média de docentes é de 200 com uma variância de 500, indicando que há um padrão grande de número de docentes nas instituições. Relacionar com IN_REPOSITORIO_INSTITUCIONAL: A relação entre o número de docentes e a presença de repositorio institucional pode ajudar a entender como a infraestrutura da instituição está relacionada ao seu tamanho."
#
# **QT_CURSO**: "A média de cursos é de 100 com uma variância de 200, indicando que as instituições têm uma variedade moderada de cursos. Verificar relação com NOME_ORGANIZACAO_ACADEMICA: A relação entre o número de cursos e a categoria administrativa da instituição pode ajudar a entender como o tamanho da instituição está relacionado à sua organização acadêmica."
#
# **QT_TEC_TOTAL**: "A média de técnicos é de 50 com uma variância de 100, indicando que as instituições têm um número pequeno de técnicos. Relacionar com IN_SERVICO_INTERNET: A relação entre o número de técnicos e a presença do serviço de internet pode ajudar a entender como a infraestrutura da instituição está relacionada ao seu tamanho."
#
# **QT_PERIODICO_ELETRONICO**: "A média de periodicos eletronicos é de 20 com uma variância de 50, indicando que as instituições têm um número pequeno de recursos digitais. Verificar relação com IN_PARTICIPA_REDE_SOCIAL: A relação entre o número de recursos digitais e a participação nas redes sociais pode ajudar a entender como a instituição está conectada à sociedade."
#
# **QT_LIVRO_ELETRONICO**: "A média de livros eletronicos é de 10 com uma variância de 20, indicando que as instituições têm um número muito pequeno de recursos digitais. Relacionar com IN_CATALOGO_ONLINE: A relação entre o número de livros eletrônicos e a presença do catalogo online pode ajudar a entender como a infraestrutura da instituição está relacionada ao seu tamanho."
#
# **T1_VL_RECEITAS**: "A média de receita é de 1000 com uma variância de 500, indicando que as instituições têm um padrão grande de receita. Verificar relação com IN_CAPITAL: A medição de desigualdade entre as instituições na capital e fora pode ajudar a entender como o tamanho da instituição está relacionado à sua receita."
#
# **T1_VL_DESPESAS**: "A média de despesas é de 500 com uma variância de 200, indicando que as instituições têm um padrão moderado de despesas. Relacionar com IN_REPOSITORIO_INSTITUCIONAL: A relação entre o número de despesas e a presença de repositorio institucional pode ajudar a entender como a infraestrutura da instituição está relacionada ao seu tamanho."
#
# **IN_CAPITAL**: "A média de instituições na capital é de 30 com uma variância de 10, indicando que as instituições na capital têm um padrão muito grande de número. Relacionar com QT_ALUNOS: A relação entre o número de alunos e a localização da instituição pode ajudar a entender como o tamanho da instituição está relacionado à sua localização."
#
# **IN_OUTRAS_BASES**: "A média de instituições com outras bases é de 20 com uma variância de 5, indicando que as instituições com outras bases têm um padrão muito grande de número. Relacionar com IN_CAPITAL: A relação entre o número de instituições na capital e fora pode ajudar a entender como o tamanho da instituição está relacionado à sua localização."
#
# **IN_REPOSITORIO_INSTITUCIONAL**: "A média de instituições com repositorio institucional é de 50 com uma variância de 20, indicando que as instituições com repositorio institucional têm um padrão grande de número. Relacionar com QT_DOCENTES: A relação entre o número de docentes e a presença de repositorio institucional pode ajudar a entender como a infraestrutura da instituição está relacionada ao seu tamanho."
#
# **IN_BUSCA_INTEGRADA**: "A média de instituições com busca integrada é de 10 com uma variância de 2, indicando que as instituições com busca integrada têm um padrão muito grande de número. Relacionar com IN_PARTICIPA_REDE_SOCIAL: A relação entre o número de recursos digitais e a participação nas redes sociais pode ajudar a entender como a instituição está conectada à sociedade."
#
# **IN_SERVICO_INTERNET**: "A média de instituições com serviço de internet é de 30 com uma variância de 10, indicando que as instituições com serviço de internet têm um padrão muito grande de número. Relacionar com QT_TEC_TOTAL: A relação entre o número de técnicos e a presença do serviço de internet pode ajudar a entender como a infraestrutura da instituição está relacionada ao seu tamanho."
#
# **IN_PARTICIPA_REDE_SOCIAL**: "A média de instituições que participam nas redes sociais é de 20 com uma variância de 5, indicando que as instituições que participam das redes sociais têm um padrão muito grande de número. Relacionar com IN_BUSCA_INTEGRADA: A relação entre o número de recursos digitais e a participação nas redes sociais pode ajudar a entender como a instituição está conectada à sociedade."
#
# **IN_CATALOGO_ONLINE**: "A média de instituições com catalogo online é de 10 com uma variância de 2, indicando que as instituições com catalogo online têm um padrão muito grande de número. Relacionar com QT_LIVRO_ELETRONICO: A relação entre o número de livros eletrônicos e a presença do catalogo online pode ajudar a entender como a infraestrutura da instituição está relacionada ao seu tamanho."

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2018 e 2019 (60,08%) NOTOK
# - Predominância das regiões Sudeste, Sul e Nordeste (82,92%) NOTOK
# - Uma incidência das IES não estarem numa capital (68.85%)
# - Predominância das Instituições sem acesso ao portal Capes ( 64.73%) OK
# - Possuem predominância em busca integrada (77.29%) NOTOK
# - Possuem serviço de internet (97.45%) NOTOK
# - Predominância em participar em redes sociais (71.20%) OK
# - Possuem predominância em ter catalogo online (79.45%) OK
# - Possuem predominância em ter outras bases (73.43%) OK
# - Maioria das iinstituições são privada (com e sem fins lucrativos) OK(98,04) OK
# - Maioria dos anos da IES são Faculdade (99.15%) OK
#
# - Quantidade de técnicos na média baixo (33.68	) NOTOK
# - Quantidade de alunos média de alunos  moderado (932.89)
# - Corpo docente muito na média (45.12) OK
# - Pouca quantidade média de cursos (6.21) NOTOK
# - Despesas e receitas média acima do moderado NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quarto', 1.0, 17, 4, 13, 3, 1]

# %% [markdown]
# ### Firth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'quinto'))
# Out:
# **Análise Estatística**
#
# Vamos começar analisando cada variável estatística:
#
# * QT_ALUNOS: A média da quantidade de alunos é de 500, a mediana é de 450 e a moda é de 400. Não há relação estatística significativa com outra variável.
# * QT_DOCENTES: A média da quantidade de docentes é de 30, a mediana é de 25 e a moda é de 20. Há uma relação estatística positiva entre QT_ALUNOS e QT_DOCENTES, pois mais alunos tendem a ter mais docentes.
# * QT_CURSO: A média da quantidade de cursos é de 10, a mediana é de 8 e a moda é de 6. Não há relação estatística significativa com outra variável.
# * QT_TEC_TOTAL: A média da quantidade de técnicos é de 20, a mediana é de 15 e a moda é de 10. Há uma relação estatística positiva entre QT_ALUNOS e QT_TEC_TOTAL, pois mais alunos tendem a ter mais técnicos.
# * QT_PERIODICO_ELETRONICO: A média da quantidade de periodicos eletronicos é de 5, a mediana é de 3 e a moda é de 2. Não há relação estatística significativa com outra variável.
# * QT_LIVRO_ELETRONICO: A média da quantidade de livros eletronicos é de 10, a mediana é de 8 e a moda é de 6. Há uma relação estatística positiva entre QT_CURSO e QT_LIVRO_ELETRONICO, pois mais cursos tendem a ter mais livros eletronicos.
# * T1_VL_RECEITAS: A média da receita da instituição é de 100000, a mediana é de 80000 e a moda é de 60000. Há uma relação estatística positiva entre QT_ALUNOS e T1_VL_RECEITAS, pois mais alunos tendem a ter mais receita.
# * T1_VL_DESPESAS: A média da despesa da instituição é de 50000, a mediana é de 40000 e a moda é de 30000. Há uma relação estatística positiva entre QT_DOCENTES e T1_VL_DESPESAS, pois mais docentes tendem a ter mais despesas.
# * IN_CAPITAL: A proporção de instituições na capital é de 30%. Não há relação estatística significativa com outra variável.
# * IN_OUTRAS_BASES: A proporção de instituições com outras bases é de 20%. Não há relação estatística significativa com outra variável.
# * IN_REPOSITORIO_INSTITUCIONAL: A proporção de instituições com repositorio institucional é de 15%. Há uma relação estatística positiva entre QT_ALUNOS e IN_REPOSITORIO_INSTITUCIONAL, pois mais alunos tendem a ter instituições com repositorio.
# * IN_BUSCA_INTEGRADA: A proporção de instituições com busca integrada é de 25%. Não há relação estatística significativa com outra variável.
# * IN_SERVICO_INTERNET: A proporção de instituições com serviço de internet é de 80%. Há uma relação estatística positiva entre QT_CURSO e IN_SERVICO_INTERNET, pois mais cursos tendem a ter serviços de internet.
# * IN_PARTICIPA_REDE_SOCIAL: A proporção de instituições que participam nas redes sociais é de 40%. Não há relação estatística significativa com outra variável.
# * IN_CATALOGO_ONLINE: A proporção de instituições com catalogo online é de 30%. Há uma relação estatística positiva entre QT_LIVRO_ELETRONICO e IN_CATALOGO_ONLINE, pois mais livros eletronicos tendem a ter instituições com catalogo online.
# * IN_ACESSO_PORTAL_CAPES: A proporção de instituições com acesso ao portal CAPES é de 50%. Não há relação estatística significativa com outra variável.
# * NU_ANO_CENSO: A média do ano censo é de 2015, a mediana é de 2000 e a moda é de 1999. Não há relação estatística significativa com outra variável.
# * CO_REGIAO: A média da região da instituição é de Sul, a mediana é de Centro-Oeste e a moda é de Norte. Não há relação estatística significativa com outra variável.
# * NOME_CATEGORIA_ADMINISTRATIVA: A proporção de instituições em categoria administrativa 1 é de 40%. Há uma relação estatística positiva entre QT_ALUNOS e NOME_CATEGORIA_ADMINISTRATIVA, pois mais alunos tendem a ter instituições em categoria administrativa 1.
# * NOME_ORGANIZACAO_ACADEMICA: A proporção de instituições na Organização Acadêmica A é de 30%. Não há relação estatística significativa com outra variável.
#
# **Inferências**
#
# Com base nos resultados, podemos inferir que:
#
# * Existem relações estatísticas positivas entre a quantidade de alunos e outras variáveis, como docentes, técnicos, cursos, receita, despesas, instituições com repositorio institucional e busca integrada.
# * A quantidade de livros eletronicos está relacionada à presença do catalogo online.
# * A proporção de instituições na capital e outras bases é baixa.
# * A maior parte das instituições participa das redes sociais, mas a relação com a quantidade de alunos não é estatisticamente significativa.
#
# **Análise Geral do Agrupamento**
#
# Diante dos resultados, podemos concluir que o agrupamento em questão tem características que podem ser relacionadas à quantidade de alunos e instituições. A maior parte das instituições tende a ter uma quantidade de alunos elevada e participar das redes sociais, mas há uma proporção relativamente baixa de instituições na capital e outras bases.
#
# Além disso, é importante notar que a relação entre a quantidade de livros eletronicos e a presença do catalogo online é estatisticamente significativa, o que pode ser um indicador de desenvolvimento institucional.
#
# É fundamental realizar mais investigações para entender melhor as características desse agrupamento e suas relações com outras variáveis.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) OK
# - Uma incidência das IES não estarem numa capital (59.17%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) OK
# - Possuem predominância em busca integrada (77.90%) OK
# - Possuem serviço de internet (97.47%) NOTOK
# - Predominância em participar em redes sociais (60.40%) OK
# - Possuem catalogo online (85.57%) OK
# - Possuem predominância em ter outras bases (78.28%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) OK(96,85) OK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) OK
#
# - Quantidade de técnicos médio moderado (143.65) OK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) OK
# - Corpo docente muito acima da  média (151.18) OK
# - Moderada quantidade média de cursos (18.49)NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância alto  OK

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quinto', 0, 16, 3, 11, 3, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'quinto'))
# Out:
# **Análise dos Agrupamentos**
#
# Considerando o CSV fornecido, vamos analisar os fatores que levaram à criação de um determinado cluster.
#
# **QT_ALUNOS**: "A média da quantidade de alunos é de 500, com uma mediana de 350 e uma moda de 200. Verificar relação com a variável **IN_CAPITAL**, pois instituições na capital tendem a ter mais alunos."
#
# **QT_DOCENTES**: "A média da quantidade de docentes é de 50, com uma mediana de 30 e uma moda de 10. Verificar relação com a variável **CO_REGIAO**, pois instituições em diferentes regiões podem ter taxas de docentagem diferentes."
#
# **QT_CURSO**: "A média da quantidade de cursos é de 20, com uma mediana de 15 e uma moda de 5. Verificar relação com a variável **IN_REPOSITORIO_INSTITUCIONAL**, pois instituições com repositorio institucional tendem a ter mais cursos."
#
# **QT_TEC_TOTAL**: "A média da quantidade de técnicos é de 30, com uma mediana de 20 e uma moda de 10. Verificar relação com a variável **IN_BUSCA_INTEGRADA**, pois instituições que têm busca integrada tendem a ter mais técnicos."
#
# **QT_PERIODICO_ELETRONICO**: "A média da quantidade de periodicos eletronicos é de 100, com uma mediana de 50 e uma moda de 20. Verificar relação com a variável **IN_CATALOGO_ONLINE**, pois instituições que têm catalogo online tendem a ter mais periodicos eletronicos."
#
# **QT_LIVRO_ELETRONICO**: "A média da quantidade de livros eletronicos é de 50, com uma mediana de 30 e uma moda de 10. Verificar relação com a variável **IN_ACESSO_PORTAL_CAPES**, pois instituições que têm acesso ao portal capes tendem a ter mais livros eletronicos."
#
# **T1_VL_RECEITAS**: "A média da receita é de 1000, com uma mediana de 500 e uma moda de 200. Verificar relação com a variável **IN_OUTRAS_BASES**, pois instituições que têm outras bases tendem a ter mais receita."
#
# **T1_VL_DESPESAS**: "A média da despesa é de 500, com uma mediana de 250 e uma moda de 100. Verificar relação com a variável **IN_REPOSITORIO_INSTITUCIONAL**, pois instituições com repositorio institucional tendem a ter mais despesas."
#
# **IN_CAPITAL**: "A média da variável é de 0,5, com uma mediana de 0 e uma moda de 0. Conclusão: A maioria das instituições não está localizada na capital."
#
# **IN_OUTRAS_BASES**: "A média da variável é de 0,2, com uma mediana de 0 e uma moda de 0. Conclusão: A maioria das instituições tem outras bases."
#
# **IN_REPOSITORIO_INSTITUCIONAL**: "A média da variável é de 0,8, com uma mediana de 1 e uma moda de 1. Conclusão: A maioria das instituições tem repositorio institucional."
#
# **IN_BUSCA_INTEGRADA**: "A média da variável é de 0,4, com uma mediana de 0 e uma moda de 0. Conclusão: A maioria das instituições não tem busca integrada."
#
# **IN_CATALOGO_ONLINE**: "A média da variável é de 0,6, com uma mediana de 1 e uma moda de 1. Conclusão: A maioria das instituições tem catalogo online."
#
# **IN_ACESSO_PORTAL_CAPES**: "A média da variável é de 0,2, com uma mediana de 0 e uma moda de 0. Conclusão: A maioria das instituições não tem acesso ao portal capes."
#
# **IN_PARTICIPA_REDE_SOCIAL**: "A média da variável é de 0,8, com uma mediana de 1 e uma moda de 1. Conclusão: A maioria das instituições participa nas redes sociais."
#
# **IN_SERVICO_INTERNET**: "A média da variável é de 0,9, com uma mediana de 1 e uma moda de 1. Conclusão: A maioria das instituições tem serviço de internet."
#
# **NU_ANO_CENSO**: "A média do ano censo é de 2015, com uma mediana de 2000 e uma moda de 1999. Verificar relação com a variável **CO_REGIAO**, pois instituições em diferentes regiões podem ter anos censo diferentes."
#
# **CO_REGIAO**: "A média da variável é de 2,5, com uma mediana de 1 e uma moda de 0. Conclusão: A maioria das instituições está localizada na região Sul do Brasil."
#
# **NOME_CATEGORIA_ADMINISTRATIVA**: "A média da variável é de 'Administração Pública', com uma mediana de 'Administração Pública' e uma moda de 'Administração Pública'. Conclusão: A maioria das instituições tem categoria administrativa pública."
#
# **NOME_ORGANIZACAO_ACADEMICA**: "A média da variável é de 'Universidade Estadual', com uma mediana de 'Universidade Estadual' e uma moda de 'Universidade Estadual'. Conclusão: A maioria das instituições é uma universidade estadual."
#
# **Análise geral do agrupamento**: "Considerando as análises feitas acima, podemos concluir que a maioria das instituições está localizada na região Sul do Brasil, tem categoria administrativa pública e é uma universidade estadual. Além disso, a maioria das instituições tem repositorio institucional, catalogo online, acesso ao portal capes e participa nas redes sociais."

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.17%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) OK
# - Possuem predominância em busca integrada (77.90%) NOT
# - Possuem serviço de internet (97.47%) OK
# - Predominância em participar em redes sociais (60.40%) NOTOK
# - Possuem catalogo online (85.57%) OK
# - Possuem predominância em ter outras bases (78.28%) OKOK
# - Maioria das instituições são privada (com e sem fins lucrativos) OK(96,85) OK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) OK
#
# - Quantidade de técnicos médio moderado (143.65) NOTOK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) OK
# - Corpo docente muito acima da  média (151.18) OK
# - Moderada quantidade média de cursos (18.49)
# - Despesas e receitas média altas
# - Quantidade de periodicos e livros eletronicos com relevância alto
#
# Insights:
# -

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quinto', 0.5, 16, 5, 11, 3, 1]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'quinto'))
# Out:
# **Análise dos Agrupamentos**
#
# Com base nos dados fornecidos, vamos realizar uma análise estatística e exploratória para entender melhor o agrupamento de instituições educacionais.
#
# **Colunas relevantes**
#
# * QT_ALUNOS
# * QT_DOCENTES
# * QT_CURSO
# * QT_TEC_TOTAL
# * T1_VL_RECEITAS
# * T1_VL_DESPESAS
# * IN_CAPITAL
# * IN_OUTRAS_BASES
# * IN_REPOSITORIO_INSTITUCIONAL
# * IN_BUSCA_INTEGRADA
# * IN_SERVICO_INTERNET
# * IN_PARTICIPA_REDE_SOCIAL
# * IN_CATALOGO_ONLINE
# * IN_ACESSO_PORTAL_CAPES
#
# **Análise estatística**
#
# * **QT_ALUNOS**: A média é de 250 alunos, a mediana é de 200 e a moda é de 150. A variância é de 100.
# * **QT_DOCENTES**: A média é de 50 docentes, a mediana é de 40 e a moda não foi observada. A variância é de 20.
# * **QT_CURSO**: A média é de 10 cursos, a mediana é de 8 e a moda é de 5. A variância é de 2.
# * **T1_VL_RECEITAS**: A média é de R$ 100.000,00, a mediana é de R$ 80.000,00 e a moda não foi observada. A variância é de R$ 20.000,00.
# * **IN_CAPITAL**: A proporção de instituições na capital é de 30%.
# * **IN_OUTRAS_BASES**: A proporção de instituições com outras bases é de 40%.
# * **T1_VL_DESPESAS**: A média é de R$ 50.000,00, a mediana é de R$ 30.000,00 e a moda não foi observada. A variância é de R$ 10.000,00.
#
# **Inferências**
#
# * As instituições educacionais têm uma variedade de características, incluindo o número de alunos, docentes, cursos, receita e despesas.
# * A proporção de instituições na capital e com outras bases varia significativamente.
# * A média da receita das instituições é alta, mas há uma variância significativa.
#
# **Análise geral do agrupamento**
#
# * O agrupamento de instituições educacionais apresenta uma grande variedade de características, incluindo o número de alunos, docentes, cursos e receita.
# * As instituições na capital tendem a ter mais recursos e experiência, enquanto as instituições com outras bases têm uma maior variabilidade.
# * A receita das instituições é um fator importante, mas há uma grande variância.
# * É possível identificar tendências e padrões em algumas características, como o número de cursos e a proporção de instituições na capital.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Nordeste (69,45%) NOTOK
# - Uma incidência das IES não estarem numa capital (59.17%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes ( 63.55%) NOTOK
# - Possuem predominância em busca integrada (77.90%) OK
# - Possuem serviço de internet (97.47%) OK
# - Predominância em participar em redes sociais (60.40%) NOTOK
# - Possuem catalogo online (85.57%) NOTOKOK
# - Possuem predominância em ter outras bases (78.28%) OK
# - Maioria das instituições são privada (com e sem fins lucrativos) NOTOK(96,85) NOTOK
# - Maioria dos anos da IES são Faculdade e centro universitário (66.16%, 32.23%) NOTOK
#
# - Quantidade de técnicos médio moderado (143.65) NOTOK
# - Quantidade de alunos média de alunos acima do moderado (4,691.86) OK
# - Corpo docente muito acima da  média (151.18) NOTOK
# - Moderada quantidade média de cursos (18.49) OK
# - Despesas e receitas média altas OK
# - Quantidade de periodicos e livros eletronicos com relevância alto OK
#
# Insights:
# -

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'quinto', 1.0, 16, 5, 11, 2, 0]

# %% [markdown]
# ### Sixth Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'sexto'))
# Out:
# **Análise Estatística**
#
# A seguir apresentamos as análises estatísticas realizadas sobre cada variável:
#
# * **QT_ALUNOS**: A média é de 350 alunos, com uma variação amostral (SEM) de 50. Não há relações significativas entre a quantidade de alunos e outras variáveis.
# * **QT_DOCENTES**: A média é de 25 docentes, com uma SEM de 5. Há uma relação positiva com a variável **IN_CAPITAL** (85% dos institutos capitais têm mais de 20 docentes).
# * **QT_CURSO**: A média é de 8 cursos, com uma SEM de 2. Não há relações significativas entre a quantidade de cursos e outras variáveis.
# * **QT_TEC_TOTAL**: A média é de 15 técnicos, com uma SEM de 3. Há uma relação positiva com a variável **IN_CAPITAL** (70% dos institutos capitais têm mais de 10 técnicos).
# * **QT_PERIODICO_ELETRONICO**: A média é de 2 periódicos eletrônicos, com uma SEM de 1. Não há relações significativas entre a quantidade de periódicos e outras variáveis.
# * **QT_LIVRO_ELETRONICO**: A média é de 1 livro eletrônico, com uma SEM de 0.5. Há uma relação positiva com a variável **IN_REPOSITORIO_INSTITUCIONAL** (80% dos institutos com repositorio institucional têm mais de um livro eletrônico).
# * **T1_VL_RECEITAS**: A média é de R$ 100.000,00, com uma SEM de R$ 20.000,00. Há uma relação positiva com a variável **QT_CURSO** (institutos com mais cursos tendem a ter maiores receitas).
# * **T1_VL_DESPESAS**: A média é de R$ 80.000,00, com uma SEM de R$ 15.000,00. Há uma relação positiva com a variável **IN_OUTRAS_BASES** (institutos com outras bases tendem a ter maiores despesas).
# * **IN_CAPITAL**: 85% dos institutos capitais têm mais de 20 docentes.
# * **IN_OUTRAS_BASES**: 60% dos institutos com outras bases têm mais de 10 técnicos.
# * **IN_REPOSITORIO_INSTITUCIONAL**: 80% dos institutos com repositorio institucional têm mais de um livro eletrônico.
# * **IN_BUSCA_INTEGRADA**: 90% dos institutos com busca integrada têm mais de um periódico eletrônico.
# * **IN_SERVICO_INTERNET**: 95% dos institutos com serviço de internet têm mais de 5 cursos.
# * **IN_PARTICIPA_REDE_SOCIAL**: 80% dos institutos que participam das redes sociais têm mais de 10 técnicos.
# * **IN_CATALOGO_ONLINE**: 75% dos institutos com catalogo online têm mais de um livro eletrônico.
# * **IN_ACESSO_PORTAL_CAPES**: 90% dos institutos com acesso ao portal CAPES têm mais de 20 docentes.
# * **NU_ANO_CENSO**: A média é de 2020, com uma SEM de 5. Não há relações significativas entre o ano censo e outras variáveis.
# * **CO_REGIAO**: A média é de 6, com uma SEM de 1. Há uma relação positiva com a variável **NOME_CATEGORIA_ADMINISTRATIVA** (institutos com categorias administrativas mais altas tendem a ter regiões mais ricas).
# * **NOME_CATEGORIA_ADMINISTRATIVA**: A média é de 4, com uma SEM de 1. Há uma relação positiva com a variável **CO_REGIAO** (institutos em regiões mais ricas tendem a ter categorias administrativas mais altas).
#
# **Inferências**
#
# Com base nas análises estatísticas, podemos concluir que:
#
# * Institutos capitais tendem a ter mais docentes e técnicos.
# * Institutos com outras bases tendem a ter mais despesas.
# * Institutos com repositorio institucional tendem a ter mais livros eletrônicos.
# * Institutos com busca integrada tendem a ter mais periódicos eletrônicos.
# * Institutos com serviço de internet tendem a ter mais cursos.
#
# **Análise Geral do Agrupamento**
#
# Diante das análises estatísticas e inferências, podemos observar que os institutos se agrupam de acordo com suas características administrativas e operacionais. Os institutos capitais são os que têm mais recursos e docentes, enquanto os institutos com outras bases tendem a ter mais despesas. Além disso, os institutos com repositorio institucional tendem a ter mais livros eletrônicos e buscar integradas tendem a ter mais periódicos eletrônicos.
#
# Esses agrupamentos se refletem também na categoria administrativa da instituição, que é uma variável que tem relação positiva com a região onde o instituto está localizado. Em geral, podemos dizer que os institutos se agrupam de acordo com suas características administrativas e operacionais, e que essas características tendem a influenciar suas políticas e estratégias.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%) NOTOK
# - Predominância das IES não estarem numa capital (69.21%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (73.15%) OK
# - Predominância das Instituições sem repositorio institucional (68.00%) NOTOK
# - Possuem predominância em busca integrada (65.43%) OK
# - Possuem serviço de internet (90.62%) OK
# - Predominância em participar em redes sociais (65.28%) OK
# - Possuem catalogo online (72.39%) OK
# - Possuem predominância em ter outras bases (62.25%) OK
# - Maioria das instituições são privada (com e sem fins lucrativos) NOTOK (90,01%) OK
# - Maioria dos anos da IES são Faculdade (95.39%) NOTOK
#
# - Quantidade de técnicos médio baixo (46.05	) NOTOK  OK
# - Quantidade de alunos média de alunos  moderado (1,202.21) NOTOK
# - Corpo docente moderado na  média (60.92) NOTOK
# - Moderada quantidade baixa de cursos (16.76) NOTOK
# - Despesas e receitas média altas  OK
# - Quantidade de periodicos e livros eletronicos com relevância baixo OK
#
# Insights falso:

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'sexto', 0, 18, 9, 10, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'sexto'))
# Out:
# **Análise Estatística**
#
# *   **QT_ALUNOS**: "Mediada: 15; Variação padrão: 10,32"
#     *   Relação com outras variáveis: não há uma relação clara com outras características da instituição.
# *   **QT_DOCENTES**: "Moda: 40; Variação padrão: 20,56"
#     *   Relação com outras variáveis: existe uma relação positiva com QT_ALUNOS e QT_CURSO.
# *   **QT_CURSO**: "Moda: 30; Variação padrão: 15,21"
#     *   Relação com outras variáveis: existe uma relação positiva com QT_DOCENTES e QT_ALUNOS.
# *   **QT_TEC_TOTAL**: "Mediada: 25; Variação padrão: 12,34"
#     *   Relação com outras variáveis: não há uma relação clara com outras características da instituição.
# *   **QT_PERIODICO_ELETRONICO**: "Moda: 20; Variação padrão: 8,98"
#     *   Relação com outras variáveis: existe uma relação positiva com QT_LIVRO_ELETRONICO.
# *   **QT_LIVRO_ELETRONICO**: "Mediada: 15; Variação padrão: 6,81"
#     *   Relação com outras variáveis: existe uma relação positiva com QT_PERIODICO_ELETRONICO.
# *   **T1_VL_RECEITAS**: "Moda: 100.000; Variação padrão: 50.000"
#     *   Relação com outras variáveis: existe uma relação positiva com IN_CAPITAL e IN_OUTRAS_BASES.
# *   **T1_VL_DESPESAS**: "Mediada: 20.000; Variação padrão: 10.000"
#     *   Relação com outras variáveis: não há uma relação clara com outras características da instituição.
# *   **IN_CAPITAL**: "Sim (60%); Não (40%)"
#     *   Relação com outras variáveis: existe uma relação positiva com T1_VL_RECEITAS e IN_OUTRAS_BASES.
# *   **IN_OUTRAS_BASES**: "Sim (50%); Não (50%)"
#     *   Relação com outras variáveis: existe uma relação positiva com T1_VL_RECEITAS e IN_CAPITAL.
# *   **IN_REPOSITORIO_INSTITUCIONAL**: "Sim (80%); Não (20%)"
#     *   Relação com outras variáveis: não há uma relação clara com outras características da instituição.
# *   **IN_BUSCA_INTEGRADA**: "Sim (70%); Não (30%)"
#     *   Relação com outras variáveis: existe uma relação positiva com IN_REPOSITORIO_INSTITUCIONAL e IN_SERVICO_INTERNET.
# *   **IN_SERVICO_INTERNET**: "Sim (90%); Não (10%)"
#     *   Relação com outras variáveis: existe uma relação positiva com IN_BUSCA_INTEGRADA e IN_CATALOGO_ONLINE.
# *   **IN_PARTICIPA_REDE_SOCIAL**: "Sim (80%); Não (20%)"
#     *   Relação com outras variáveis: não há uma relação clara com outras características da instituição.
# *   **IN_CATALOGO_ONLINE**: "Sim (60%); Não (40%)"
#     *   Relação com outras variáveis: existe uma relação positiva com IN_SERVICO_INTERNET e IN_ACESSO_PORTAL_CAPES.
# *   **IN_ACESSO_PORTAL_CAPES**: "Sim (90%); Não (10%)"
#     *   Relação com outras variáveis: existe uma relação positiva com IN_CATALOGO_ONLINE e IN_BUSCA_INTEGRADA.
#
# **Inferências**
#
# A partir dos dados, podemos concluir que:
#
# *   A instituição tem uma boa reputação em termos de receita e despesa.
# *   Existem relações positivas entre a instituição e suas características, como QT_ALUNOS, QT_DOCENTES, QT_CURSO, IN_CAPITAL, IN_OUTRAS_BASES, T1_VL_RECEITAS, IN_BUSCA_INTEGRADA e IN_SERVICO_INTERNET.
# *   A instituição tem uma boa infraestrutura e recursos para suportar sua atividade acadêmica.
# *   Existem relações positivas entre a instituição e suas características relacionadas à tecnologia, como QT_TEC_TOTAL, QT_PERIODICO_ELETRONICO, QT_LIVRO_ELETRONICO e IN_REPOSITORIO_INSTITUCIONAL.
#
# **Análise Geral do Agrupamento**
#
# Diante de todas as colunas, podemos observar que a instituição é uma entidade acadêmica bem-sucedida com uma boa infraestrutura e recursos. A relação positiva entre a instituição e suas características sugere que há uma estreita conexão entre as atividades acadêmicas e os recursos disponíveis. Além disso, a presença de tecnologia e serviços como IN_SERVICO_INTERNET e IN_ACESSO_PORTAL_CAPES indica que a instituição está investindo em sua infraestrutura para suportar a atividade acadêmica.
#
# No entanto, ainda há espaço para melhoria, especialmente em relação às características relacionadas à receita e despesa. Além disso, a instituição pode continuar a desenvolver suas atividades acadêmicas e tecnológicas para manter sua competitividade.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%) NOTOK
# - Predominância das IES não estarem numa capital (69.21%) OK
# - Predominância das Instituições sem acesso ao portal Capes (73.15%) NOTOK
# - Predominância das Instituições sem repositorio institucional (68.00%) OK
# - Possuem predominância em busca integrada (65.43%) OK NOTOK
# - Possuem serviço de internet (90.62%) OK
# - Predominância em participar em redes sociais (65.28%) OK
# - Possuem catalogo online (72.39%) NOTOK
# - Possuem predominância em ter outras bases (62.25%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) OK (90,01%) OK
# - Maioria dos anos da IES são Faculdade (95.39%) OK
#
# - Quantidade de técnicos médio baixo (46.05	) OK
# - Quantidade de alunos média de alunos  moderado (1,202.21) NOTOK
# - Corpo docente moderado na  média (60.92) OK
# - Moderada quantidade baixa de cursos (16.76) OK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixo NOTOK
#
# Insights :

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'sexto', 0.5, 18, 6, 12, 2, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'sexto'))
# Out:
# **Análise do Cluster**
#
# O CSV fornecido contém as instâncias de um determinado cluster, com 13 variáveis estatísticas e descriptivas sobre a instituição. Vamos proceder à análise estatística e explorar as relações entre as variáveis.
#
# **Coluna:** QT_ALUNOS
# "Analise estatística da média: M=150, Mediana=100, Moda=50 (experiência com frequência)"
# "Verificar relação com outra variável: Relação positiva com QT_DOCENTES e QT_CURSO, sugestivo de uma instituição de ensino com um alto número de alunos."
#
# **Coluna:** QT_DOCENTES
# "Analise estatística da média: M=20, Mediana=15, Moda=10 (experiência com frequência)"
# "Verificar relação com outra variável: Relação positiva com QT_ALUNOS e QT_CURSO, sugestivo de uma instituição de ensino com um alto número de docentes."
#
# **Coluna:** QT_CURSO
# "Analise estatística da média: M=50, Mediana=40, Moda=20 (experiência com frequência)"
# "Verificar relação com outra variável: Relação positiva com QT_ALUNOS e QT_DOCENTES, sugestivo de uma instituição de ensino com um alto número de cursos."
#
# **Coluna:** QT_TEC_TOTAL
# "Analise estatística da média: M=15, Mediana=10, Moda=5 (experiência com frequência)"
# "Verificar relação com outra variável: Relação negativa com T1_VL_RECEITAS e T1_VL_DESPESAS, sugestivo de uma instituição que inverte recursos em técnicos."
#
# **Coluna:** QT_PERIODICO_ELETRONICO
# "Analise estatística da média: M=10, Mediana=5, Moda=0 (experiência com frequência)"
# "Verificar relação com outra variável: Relação negativa com T1_VL_RECEITAS e T1_VL_DESPESAS, sugestivo de uma instituição que não investe em publicações."
#
# **Coluna:** QT_LIVRO_ELETRONICO
# "Analise estatística da média: M=5, Mediana=3, Moda=1 (experiência com frequência)"
# "Verificar relação com outra variável: Relação negativa com T1_VL_RECEITAS e T1_VL_DESPESAS, sugestivo de uma instituição que não investe em livros eletrônicos."
#
# **Coluna:** T1_VL_RECEITAS
# "Analise estatística da média: R$ 10.000.000,00"
# "Verificar relação com outra variável: Relação negativa com QT_TEC_TOTAL e QT_PERIODICO_ELETRONICO, sugestivo de uma instituição que inverte recursos em técnicos e publicações."
#
# **Coluna:** T1_VL_DESPESAS
# "Analise estatística da média: R$ 5.000.000,00"
# "Verificar relação com outra variável: Relação negativa com QT_TEC_TOTAL e QT_PERIODICO_ELETRONICO, sugestivo de uma instituição que inverte recursos em técnicos e publicações."
#
# **Coluna:** IN_CAPITAL
# "Analise estatística da média: 0"
# "Verificar relação com outra variável: Relação negativa com NOME_CATEGORIA_ADMINISTRATIVA, sugestivo de uma instituição que não é classificada como capital."
#
# **Coluna:** IN_OUTRAS_BASES
# "Analise estatística da média: 1"
# "Verificar relação com outra variável: Relação positiva com IN_REPOSITORIO_INSTITUCIONAL e IN_BUSCA_INTEGRADA, sugestivo de uma instituição que tem outras bases e investe em tecnologia."
#
# **Coluna:** IN_REPOSITORIO_INSTITUCIONAL
# "Analise estatística da média: 0"
# "Verificar relação com outra variável: Relação positiva com IN_OUTRAS_BASES e IN_BUSCA_INTEGRADA, sugestivo de uma instituição que tem outras bases e investe em tecnologia."
#
# **Coluna:** INBUSCA_INTEGRADA
# "Analise estatística da média: 1"
# "Verificar relação com outra variável: Relação positiva com IN_REPOSITORIO_INSTITUCIONAL, sugestivo de uma instituição que tem outras bases e investe em tecnologia."
#
# **Coluna:** IN_SERVICO_INTERNET
# "Analise estatística da média: 1"
# "Verificar relação com outra variável: Relação positiva com IN_PARTICIPA_REDE_SOCIAL, sugestivo de uma instituição que tem serviço de internet e participa nas redes sociais."
#
# **Coluna:** IN_PARTICIPA_REDE_SOCIAL
# "Analise estatística da média: 1"
# "Verificar relação com outra variável: Relação positiva com IN_SERVICO_INTERNET, sugestivo de uma instituição que tem serviço de internet e participa nas redes sociais."
#
# **Coluna:** IN_CATALOGO_ONLINE
# "Analise estatística da média: 1"
# "Verificar relação com outra variável: Relação positiva com IN_SERVICO_INTERNET, sugestivo de uma instituição que tem serviço de internet e investe em tecnologia."
#
# **Coluna:** IN_ACESSO_PORTAL_CAPES
# "Analise estatística da média: 1"
# "Verificar relação com outra variável: Relação positiva com NOME_ORGANIZACAO_ACADEMICA, sugestivo de uma instituição que tem acesso ao portal Capes e é parte de uma organização acadêmica."
#
# **Coluna:** NU_ANO_CENSO
# "Analise estatística da média: 2020"
# "Verificar relação com outra variável: Relação positiva com NOME_CATEGORIA_ADMINISTRATIVA, sugestivo de uma instituição que é classificada como capital e tem um ano mais recente de censo."
#
# **Coluna:** NOME_CATEGORIA_ADMINISTRATIVA
# "Analise estatística da média: Administração Pública"
# "Verificar relação com outra variável: Relação positiva com NU_ANO_CENSO, sugestivo de uma instituição que é classificada como capital e tem um ano mais recente de censo."
#
# **Coluna:** NOME_ORGANIZACAO_ACADEMICA
# "Analise estatística da média: Universidade"
# "Verificar relação com outra variável: Relação positiva com IN_ACESSO_PORTAL_CAPES, sugestivo de uma instituição que tem acesso ao portal Capes e é parte de uma organização acadêmica."
#
# **Coluna:** NOME_CATEGORIA_ADMINISTRATIVA
# "Analise estatística da média: Administração Pública"
# "Verificar relação com outra variável: Relação positiva com NU_ANO_CENSO, sugestivo de uma instituição que é classificada como capital e tem um ano mais recente de censo."
#
# **Coluna:** NOME_ORGANIZACAO_ACADEMICA
# "Analise estatística da média: Universidade"
# "Verificar relação com outra variável: Relação positiva com IN_ACESSO_PORTAL_CAPES, sugestivo de uma instituição que tem acesso ao portal Capes e é parte de uma organização acadêmica."
#
# Aqui estão os principais resultados:
#
# * A instituição é classificada como capital (0% dos casos).
# * A instituição tem outras bases (1% dos casos) e investe em tecnologia.
# * A instituição tem serviço de internet e participa nas redes sociais (97% dos casos).
# * A instituição tem acesso ao portal Capes e é parte de uma organização acadêmica (85% dos casos).
# * A instituição é classificada como capital e tem um ano mais recente de censo (0% dos casos).
#
# Em resumo, a instituição em questão é caracterizada por ter um alto nível de interatividade com tecnologia, investir em tecnologia e serviços, e ser parte de uma organização acadêmica.

# %% [markdown]
# Conclusões:
#
# - Predominância dos anos 2016 e 2017 (35.63%, 28.14%) NOTOK
# - Predominância das regiões Sudeste e Nordeste (43.65%, 20.80%) NOTOK
# - Predominância das IES não estarem numa capital (69.21%) NOTOK
# - Predominância das Instituições sem acesso ao portal Capes (73.15%) OK
# - Predominância das Instituições sem repositorio institucional (68.00%) OK
# - Possuem predominância em busca integrada (65.43%) NOTOK
# - Possuem serviço de internet (90.62%) OK
# - Predominância em participar em redes sociais (65.28%) OK
# - Possuem catalogo online (72.39%) OK
# - Possuem predominância em ter outras bases (62.25%) NOTOK
# - Maioria das instituições são privada (com e sem fins lucrativos) OK (90,01%) OK
# - Maioria dos anos da IES são Faculdade (95.39%) OK
#
# - Quantidade de técnicos médio baixo (46.05	) OK OK
# - Quantidade de alunos média de alunos  moderado (1,202.21) OK
# - Corpo docente moderado na  média (60.92) NOTOK
# - Moderada quantidade baixa de cursos (16.76) NOTOK
# - Despesas e receitas média altas NOTOK
# - Quantidade de periodicos e livros eletronicos com relevância baixo NOTOK

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'sexto', 1.0, 18, 7, 9, 0, 0]

# %% [markdown]
# ### Seventh Cluster

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0, 'setimo'))
# Out:
# **Análise de Agrupamento e Exploratória**
#
# **Coluna:** QT_ALUNOS
# "Analise estatística: Média = 300, Mediana = 290, Moda = 280. Verificar relação com IN_CAPITAL (instituições na capital têm mais alunos) e IN_OUTRAS_BASES (instituições com outras bases têm menos alunos)."
#
# **Inferências:** As instituições com mais alunos são aquelas que estão localizadas em outras bases e não na capital. Isso sugere que essas instituições podem ter uma estrutura mais ampla e diversificada.
#
# **Análise geral do agrupamento:** O cluster tem uma distribuição simétrica, mas a média é um pouco inferior à mediana, sugerindo que existem valores isolados abaixo da média. Isso pode indicar que há instituições com números reduzidos de alunos.
#
# **Coluna:** QT_DOCENTES
# "Analise estatística: Média = 50, Mediana = 40, Moda = 30. Verificar relação com IN_CAPITAL (instituições na capital têm mais docentes) e NOME_CATEGORIA_ADMINISTRATIVA (instituições de categorias administrativas diferentes têm mais docentes)."
#
# **Inferências:** As instituições com mais docentes são aquelas que estão localizadas na capital e pertencem a categorias administrativas específicas. Isso sugere que essas instituições podem ter uma estrutura mais burocrática e centralizada.
#
# **Análise geral do agrupamento:** O cluster tem uma distribuição desigual, com valores extremos em ambos os lados da média. Isso pode indicar que existem instituições com números reduzidos de docentes ou outras características não relacionadas.
#
# **Coluna:** QT_CURSO
# "Analise estatística: Média = 20, Mediana = 15, Moda = 10. Verificar relação com IN_OUTRAS_BASES (instituições com outras bases têm mais cursos) e NOME_ORGANIZACAO_ACADEMICA (instituições de organizações acadêmicas diferentes têm mais cursos)."
#
# **Inferências:** As instituições com mais cursos são aquelas que estão localizadas em outras bases e pertencem a organizações acadêmicas específicas. Isso sugere que essas instituições podem ter uma estrutura mais diversificada e ampla.
#
# **Análise geral do agrupamento:** O cluster tem uma distribuição desigual, com valores extremos em ambos os lados da média. Isso pode indicar que existem instituições com números reduzidos de cursos ou outras características não relacionadas.
#
# **Coluna:** QT_TEC_TOTAL
# "Analise estatística: Média = 10, Mediana = 5, Moda = 0. Verificar relação com IN_REPOSITORIO_INSTITUCIONAL (instituições com repositorios institucionais têm mais técnicos) e IN_BUSCA_INTEGRADA (instituições com busca integrada têm mais técnicos)."
#
# **Inferências:** As instituições com mais técnicos são aquelas que têm um repositorio institucional ou uma busca integrada. Isso sugere que essas instituições podem ter uma estrutura mais atualizada e conectada à comunidade acadêmica.
#
# **Análise geral do agrupamento:** O cluster tem uma distribuição desigual, com valores extremos em ambos os lados da média. Isso pode indicar que existem instituições com números reduzidos de técnicos ou outras características não relacionadas.
#
# Essa análise estatística e exploratória sugere que as instituições no cluster têm características específicas relacionadas à sua localização, estrutura administrativa e conectividade à comunidade acadêmica. As conclusões podem ser interpretadas como:
#
# * As instituições com mais alunos estão localizadas em outras bases e não na capital.
# * As instituições com mais docentes são aquelas que estão localizadas na capital e pertencem a categorias administrativas específicas.
# * As instituições com mais cursos estão localizadas em outras bases e pertencem a organizações acadêmicas específicas.
# * As instituições com mais técnicos têm um repositorio institucional ou uma busca integrada.
#
# Essas conclusões podem ser utilizadas para entender melhor as características das instituições dentro do cluster e identificar tendências e padrões que possam informar decisões futuras.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%)NOTOK
# - Predominância das Instituições com acesso ao portal Capes (87.76%)NOTOK
# - Predominância das Instituições com repositorio institucional (70.41%)NOTOKOK
# - Possuem predominância em busca integrada (67.18%)OK
# - Possuem serviço de internet (98.81%)OK
# - Predominância em participar em redes sociais (71.94%)NOTOK
# - Possuem catalogo online (92.69%)OK
# - Possuem predominância em ter outras bases (91.16%)NOTOK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%)NOTOK OK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%)NOTOK
#
# - Quantidade de técnicos médio alto (1,170.62	)NOTOK
# - Quantidade de alunos média de alunos alto (27,666.31)NOTOK
# - Corpo docente alto na  média (970.69)NOTOK OK
# - altga quantidade baixa de cursos (73.91)NOTOK
# - Despesas e receitas média altas OK
# - Quantidade de periodicos e livros eletronicos com relevância alto NOTOK

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'setimo', 0, 16, 6, 10, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 0.5, 'setimo'))
# Out:
# **Análise dos Agrupamentos**
#
# **QT_ALUNOS:** "A média de QT_ALUNOS é de 123,45 alunos, com uma mediana de 100 e uma moda de 50. Observamos que a variável é positivamente correlida com QT_DOCENTES (R = 0,8), indicando que instituições com mais docentes tendem a ter mais alunos."
#
# **QT_DOCENTES:** "A média de QT_DOCENTES é de 200,12 docentes, com uma mediana de 150 e uma moda de 100. A variável está positivamente correlida com IN_REPOSITORIO_INSTITUCIONAL (R = 0,7), sugerindo que instituições com repositorio institucional tendem a ter mais docentes."
#
# **QT_CURSO:** "A média de QT_CURSO é de 50,21 cursos, com uma mediana de 30 e uma moda de 20. Observamos que a variável está negativamente correlida com IN_OUTRAS_BASES (R = -0,5), indicando que instituições sem outras bases tendem a ter mais cursos."
#
# **QT_TEC_TOTAL:** "A média de QT_TEC_TOTAL é de 50,12 técnicos, com uma mediana de 30 e uma moda de 20. A variável está positivamente correlida com IN_CAPITAL (R = 0,6), sugerindo que instituições na capital tendem a ter mais técnicos."
#
# **QT_PERIODICO_ELETRONICO:** "A média de QT_PERIODICO_ELETRONICO é de 10,21 periodicos eletronicos, com uma mediana de 5 e uma moda de 0. Observamos que a variável está positivamente correlida com IN_BUSCA_INTEGRADA (R = 0,8), indicando que instituições com busca integrada tendem a ter mais periodicos eletronicos."
#
# **QT_LIVRO_ELETRONICO:** "A média de QT_LIVRO_ELETRONICO é de 5,12 livros eletronicos, com uma mediana de 2 e uma moda de 0. A variável está positivamente correlida com IN_CATALOGO_ONLINE (R = 0,7), sugerindo que instituições com catalogo online tendem a ter mais livros eletronicos."
#
# **T1_VL_RECEITAS:** "A média de T1_VL_RECEITAS é de 100.000,12 reais, com uma mediana de 50.000 e uma moda de 0. Observamos que a variável está positivamente correlida com IN_SERVICO_INTERNET (R = 0,9), indicando que instituições com serviço de internet tendem a ter mais receita."
#
# **T1_VL_DESPESAS:** "A média de T1_VL_DESPESAS é de 50.000,12 reais, com uma mediana de 20.000 e uma moda de 0. A variável está positivamente correlida com IN_PARTICIPA_REDE_SOCIAL (R = 0,6), sugerindo que instituições que participam das redes sociais tendem a ter mais despesas."
#
# **IN_CAPITAL:** "A média de IN_CAPITAL é de 70%, com uma mediana de 60% e uma moda de 50%. Observamos que a variável está positivamente correlida com QT_TEC_TOTAL (R = 0,6), indicando que instituições na capital tendem a ter mais técnicos."
#
# **IN_OUTRAS_BASES:** "A média de IN_OUTRAS_BASES é de 40%, com uma mediana de 30% e uma moda de 20%. A variável está negativamente correlida com QT_CURSO (R = -0,5), sugerindo que instituições sem outras bases tendem a ter mais cursos."
#
# **IN_REPOSITORIO_INSTITUCIONAL:** "A média de IN_REPOSITORIO_INSTITUCIONAL é de 50%, com uma mediana de 40% e uma moda de 30%. A variável está positivamente correlida com QT_DOCENTES (R = 0,7), indicando que instituições com repositorio institucional tendem a ter mais docentes."
#
# **IN_BUSCA_INTEGRADA:** "A média de IN_BUSCA_INTEGRADA é de 80%, com uma mediana de 70% e uma moda de 60%. Observamos que a variável está positivamente correlida com QT_PERIODICO_ELETRONICO (R = 0,8), indicando que instituições com busca integrada tendem a ter mais periodicos eletronicos."
#
# **IN_SERVICO_INTERNET:** "A média de IN_SERVICO_INTERNET é de 90%, com uma mediana de 80% e uma moda de 70%. A variável está positivamente correlida com T1_VL_RECEITAS (R = 0,9), indicando que instituições com serviço de internet tendem a ter mais receita."
#
# **IN_PARTICIPA_REDE_SOCIAL:** "A média de IN_PARTICIPA_REDE_SOCIAL é de 60%, com uma mediana de 50% e uma moda de 40%. A variável está positivamente correlida com T1_VL_DESPESAS (R = 0,6), sugerindo que instituições que participam das redes sociais tendem a ter mais despesas."
#
# **IN_CATALOGO_ONLINE:** "A média de IN_CATALOGO_ONLINE é de 70%, com uma mediana de 60% e uma moda de 50%. A variável está positivamente correlida com QT_LIVRO_ELETRONICO (R = 0,7), indicando que instituições com catalogo online tendem a ter mais livros eletronicos."
#
# **IN_ACESSO_PORTAL_CAPES:** "A média de IN_ACESSO_PORTAL_CAPES é de 80%, com uma mediana de 70% e uma moda de 60%. A variável está positivamente correlida com T1_VL_RECEITAS (R = 0,9), indicando que instituições com acesso ao portal CAPES tendem a ter mais receita."
#
# **IN_busca_INTEGRADA:** "A média de IN_busca_INTEGRADA é de 80%, com uma mediana de 70% e uma moda de 60%. Observamos que a variável está positivamente correlida com QT_PERIODICO_ELETRONICO (R = 0,8), indicando que instituições com busca integrada tendem a ter mais periodicos eletronicos."
#
# **IN_PARTICIPA_REDE_SOCIAL:** "A média de IN_PARTICIPA_REDE_SOCIAL é de 60%, com uma mediana de 50% e uma moda de 40%. A variável está positivamente correlida com T1_VL_DESPESAS (R = 0,6), sugerindo que instituições que participam das redes sociais tendem a ter mais despesas."
#
# **IN_CATALOGO_ONLINE:** "A média de IN_CATALOGO_ONLINE é de 70%, com uma mediana de 60% e uma moda de 50%. A variável está positivamente correlida com QT_LIVRO_ELETRONICO (R = 0,7), indicando que instituições com catalogo online tendem a ter mais livros eletronicos."
#
# **IN_ACESSO_PORTAL_CAPES:** "A média de IN_ACESSO_PORTAL_CAPES é de 80%, com uma mediana de 70% e uma moda de 60%. A variável está positivamente correlida com T1_VL_RECEITAS (R = 0,9), indicando que instituições com acesso ao portal CAPES tendem a ter mais receita."
#
# As análises sugerem que as instituições que têm maior acesso à internet, buscam integradas e participam das redes sociais tendem a ter mais receita. Além disso, instituições na capital tendem a ter mais técnicos e instituições com repositorio institucional tendem a ter mais docentes.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%) NOTOK
# - Predominância das Instituições com acesso ao portal Capes (87.76%) NOTOK
# - Predominância das Instituições com repositorio institucional (70.41%)
# - Possuem predominância em busca integrada (67.18%) NOTOK
# - Possuem serviço de internet (98.81%)NOTOK
# - Predominância em participar em redes sociais (71.94%) OK
# - Possuem catalogo online (92.69%) NOTOK
# - Possuem predominância em ter outras bases (91.16%) NOTOK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%) OK OK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%) OK
#
# - Quantidade de técnicos médio alto (1,170.62	) OK
# - Quantidade de alunos média de alunos alto (27,666.31) OK
# - Corpo docente alto na  média (970.69) OK OK
# - altga quantidade baixa de cursos (73.91) OK
# - Despesas e receitas média altas  OK
# - Quantidade de periodicos e livros eletronicos com relevância alto
#
# Insights:
# -

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'setimo', 0.5, 16, 7, 9, 1, 0]

# %%
print(show_result_kmeans_prompt(kmeans_fase4, 1.0, 'setimo'))
# Out:
# **Análise Estatística**
#
# Aqui estão as análises estatísticas para cada variável:
#
# * **QT_ALUNOS**: "A quantidade de alunos é alta (Média: 450, Mediana: 300, Moda: 200)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **QT_DOCENTES**: "A quantidade de docentes é relativamente baixa (Média: 25, Mediana: 20, Moda: 15)".
#  + Verificação de relação com outra variável: tem uma relação positiva com a quantidade de alunos.
#
# * **QT_CURSO**: "A quantidade de cursos é média (Média: 100, Mediana: 80, Moda: 60)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **QT_TEC_TOTAL**: "A quantidade de técnicos é alta (Média: 150, Mediana: 120, Moda: 100)".
#  + Verificação de relação com outra variável: tem uma relação positiva com a quantidade de alunos e docentes.
#
# * **QT_PERIODICO_ELETRONICO**: "A quantidade de periodicos eletronicos é baixa (Média: 10, Mediana: 5, Moda: 3)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **QT_LIVRO_ELETRONICO**: "A quantidade de livros eletronicos é média (Média: 50, Mediana: 30, Moda: 20)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **T1_VL_RECEITAS**: "A receita da instituição é alta (Média: 100.000,00, Mediana: 50.000,00, Moda: 20.000,00)".
#  + Verificação de relação com outra variável: tem uma relação positiva com a quantidade de alunos e docentes.
#
# * **T1_VL_DESPESAS**: "A despesa da instituição é média (Média: 50.000,00, Mediana: 20.000,00, Moda: 10.000,00)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **IN_CAPITAL**: "A maioria das instituições está localizada na capital (Média: 0,7, Mediana: 0,8, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **IN_OUTRAS_BASES**: "A maioria das instituições tem outras bases (Média: 0,9, Mediana: 1,0, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **IN_REPOSITORIO_INSTITUCIONAL**: "A maioria das instituições tem repositorio institucional (Média: 0,6, Mediana: 0,7, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **IN_BUSCA_INTEGRADA**: "A maioria das instituições tem busca integrada (Média: 0,8, Mediana: 0,9, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **IN_SERVICO_INTERNET**: "A maioria das instituições tem serviço de internet (Média: 0,9, Mediana: 1,0, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **IN_PARTICIPA_REDE_SOCIAL**: "A maioria das instituições participa nas redes sociais (Média: 0,7, Mediana: 0,8, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **IN_CATALOGO_ONLINE**: "A maioria das instituições tem catalogo online (Média: 0,6, Mediana: 0,7, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **IN_ACESSO_PORTAL_CAPES**: "A maioria das instituições tem acesso ao portal capes (Média: 0,8, Mediana: 0,9, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **NU_ANO_CENSO**: "A idade média das instituições é de 20 anos (Média: 20, Mediana: 15, Moda: 10)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **CO_REGIAO**: "As instituições estão distribuídas em diferentes regiões do país (Média: 0,5, Mediana: 0,4, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **NOME_CATEGORIA_ADMINISTRATIVA**: "A maioria das instituições tem categoria administrativa em 'Educação' (Média: 0,9, Mediana: 1,0, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# * **NOME_ORGANIZACAO_ACADEMICA**: "A maioria das instituições tem nome de organização acadêmica em 'Universidade' (Média: 0,8, Mediana: 0,9, Moda: 1)".
#  + Verificação de relação com outra variável: não há uma relação clara com outras variáveis.
#
# **Conclusão**
#
# A análise das variáveis revelou que as instituições estão distribuídas em diferentes regiões do país e têm diferentes categorias administrativas e nomes de organização acadêmica. Além disso, as instituições têm acesso a serviços como internet, busca integrada e catalogo online. A receita das instituições é alta, mas a despesa média é relativamente baixa. As instituições também têm uma idade média de 20 anos.
#
# **Recomendações**
#
# * É importante que as instituições continuem a investir em serviços como internet e busca integrada para melhorar a experiência dos alunos e professores.
# * A categoria administrativa das instituições deve ser revisada para garantir que elas estejam alinhadas com os objetivos de educação.
# * É recomendável que as instituições continuem a desenvolver seus catálogos online para melhorar a acessibilidade e a qualidade dos serviços.
#
# **Limitações**
#
# A análise apresentada tem algumas limitações. Primeiramente, não foi possível obter dados sobre todas as variáveis disponíveis. Além disso, os dados foram coletados de uma amostra representativa das instituições brasileiras e, portanto, podem não ser generalizáveis para a população total de instituições.
#
# Em seguida, é importante notar que a análise foi realizada apenas com base nos dados disponíveis e pode ter sido afetada por erros ou lacunas nos dados. Além disso, a análise não considerou outras variáveis importantes, como a qualidade da educação oferecida pelas instituições.
#
# Por fim, é importante lembrar que a análise apresentada foi realizada para fornecer uma visão geral das características das instituições brasileiras e não deve ser interpretada como um estudo exhaustivo sobre o tema.

# %% [markdown]
# Conclusões:
#
# - Predominância das regiões Sudeste e Sul (44.90%, 24.32%)  NOTOK
# - Predominância das Instituições com acesso ao portal Capes (87.76%) OK
# - Predominância das Instituições com repositorio institucional (70.41%)
# - Possuem predominância em busca integrada (67.18%) OK
# - Possuem serviço de internet (98.81%) OK
# - Predominância em participar em redes sociais (71.94%)  OK
# - Possuem catalogo online (92.69%)  ok
# - Possuem predominância em ter outras bases (91.16%)  OK
# - Maioria das instituições são privada sem fins, federal e com fins lurativos (46.26%, 25.68%, 19.90%) OK
# - Maioria dos anos da IES são Universidade e centro universitario (69.73%, 22.28%) OK
#
# - Quantidade de técnicos médio alto (1,170.62	) OK
# - Quantidade de alunos média de alunos alto (27,666.31)
# - Corpo docente alto na  média (970.69)  OK
# - altga quantidade baixa de cursos (73.91)  OK
# - Despesas e receitas média altas  OK
# - Quantidade de periodicos e livros eletronicos com relevância alto  OK
#
# Insights:

# %%
analise_kmeans_fase4.loc[len(analise_kmeans_fase4)] = ['Fase 4',  'setimo', 1.0, 16, 9, 7, 1, 0]
