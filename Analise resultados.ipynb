# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('./Models\\results\\K-means_Fase 1_results.csv')
# Out:
#    algorithm   cluster  temperature               prompt  \
# 0    K-means  primeiro          0.0  Fase 1 - Direto.txt
# 1    K-means  primeiro          0.5  Fase 1 - Direto.txt
# 2    K-means  primeiro          1.0  Fase 1 - Direto.txt
# 3    K-means  primeiro          1.5  Fase 1 - Direto.txt
# 4    K-means  primeiro          2.0  Fase 1 - Direto.txt
# 5    K-means   segundo          0.0  Fase 1 - Direto.txt
# 6    K-means   segundo          0.5  Fase 1 - Direto.txt
# 7    K-means   segundo          1.0  Fase 1 - Direto.txt
# 8    K-means   segundo          1.5  Fase 1 - Direto.txt
# 9    K-means   segundo          2.0  Fase 1 - Direto.txt
# 10   K-means  terceiro          0.0  Fase 1 - Direto.txt
# 11   K-means  terceiro          0.5  Fase 1 - Direto.txt
# 12   K-means  terceiro          1.0  Fase 1 - Direto.txt
# 13   K-means  terceiro          1.5  Fase 1 - Direto.txt
# 14   K-means  terceiro          2.0  Fase 1 - Direto.txt
# ...
